# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
# https://www.kaggle.com/dattapiy/sec-edgar-companies-list
names_df = pd.read_csv('data/sec__edgar_company_info.csv')[:100000]
names_df.head(3)
# Out:
#    Line Number                        Company Name  Company CIK Key
# 0            1                              !J INC          1438823
# 1            2       #1 A LIFESAFER HOLDINGS, INC.          1509607
# 2            3  #1 ARIZONA DISCOUNT PROPERTIES LLC          1457512

# %%
import re

irrelevant_regex = re.compile(r'[^a-z0-9\s\!\@\#\$\%\&]')
multispace_regex = re.compile(r'\s\s+')

def assign_no_symbols_name(df):
    return df.assign(
        name=df['Company Name']
             .str.lower()
             .str.replace(irrelevant_regex, ' ')
             .str.replace(multispace_regex, ' ')
             .str.strip())

names_df = assign_no_symbols_name(names_df)
names_df.head(9)
# Out:
#    Line Number                        Company Name  Company CIK Key  \
# 0            1                              !J INC          1438823
# 1            2       #1 A LIFESAFER HOLDINGS, INC.          1509607
# 2            3  #1 ARIZONA DISCOUNT PROPERTIES LLC          1457512
# 3            4                   #1 PAINTBALL CORP          1433777
# 4            5                               $ LLC          1427189
# 5            6                 & S MEDIA GROUP LLC          1447162
# 6            7             &TV COMMUNICATIONS INC.          1479357
# 7            8                        'MKTG, INC.'           886475
# 8            9                    'OHANA LABS INC.          1703629
#
#                                  name
# 0                              !j inc
# 1         #1 a lifesafer holdings inc
# 2  #1 arizona discount properties llc
# 3                   #1 paintball corp
# 4                               $ llc
# 5                 & s media group llc
# 6              &tv communications inc
# 7                            mktg inc
# 8                      ohana labs inc

# %%
index_to_name = names_df['name'].to_dict()
name_to_index = {v: k for k, v in index_to_name.items()}

# %%
import more_itertools

cik_clusters = (
    names_df[['name', 'Company CIK Key']]
    .groupby('Company CIK Key')
    .indices
)
more_itertools.take(10, cik_clusters.values())
# Out:
# [array([5878]),
#  array([6287]),
#  array([6375]),
#  array([6459, 6468]),
#  array([6521]),
#  array([6578]),
#  array([7053, 7055]),
#  array([7209]),
#  array([7175]),
#  array([7525])]

# %%
import itertools

cik_name_pairs = [
    (index_to_name[id_x], index_to_name[id_y])
    for cik_cluster in cik_clusters.values()
    for id_x, id_y in itertools.combinations(cik_cluster, 2)
    if index_to_name[id_x] != index_to_name[id_y]
]
cik_name_pairs[:10]
# Out:
# [('abel noser corp bd', 'abel noser corp'),
#  ('abraham & co inc bd', 'abraham & co inc'),
#  ('acme metals inc de', 'acme metals inc'),
#  ('adams diversified equity fund inc', 'adams diversified equity fund'),
#  ('adams diversified equity fund inc', 'adams express co'),
#  ('adams diversified equity fund', 'adams express co'),
#  ('alliance gaming corp', 'bally technologies inc'),
#  ('aei securities inc bd', 'aei securities inc'),
#  ('aeroflex inc', 'arx inc'),
#  ('aetna life & casualty co', 'aetna services inc ct')]

# %%
import more_itertools
from fuzzywuzzy import fuzz

true_pairs = {
    tuple(sorted(pair))
    for pair in cik_name_pairs
    if fuzz.token_sort_ratio(*pair) >= 60
    # if fuzz.partial_ratio(*pair) >= 60  
}
display(more_itertools.take(10, true_pairs))
display(len(true_pairs))
# Out:
# [('blackstone madison ave offshore fund ltd',
#   'blackstone madison avenue offshore fund ltd class a b c & g shares'),
#  ('biolex inc', 'biolex therapeutics inc'),
#  ('alanar inc bd', 'alanar incorporated'),
#  ('advanced glassfiber yarns llc', 'advanced glassfiber yarus llc'),
#  ('agic equity & convertible income fund',
#   'allianzgi equity & convertible income fund'),
#  ('aqr global asset allocation offshore fund usd ii ltd',
#   'aqr global asset allocationoffshore fund usd ii ltd'),
#  ('american energy partners inc de', 'american energy production inc'),
#  ('across america real estate corp',
#   'across america real estate development corp'),
#  ('bonny paul a', 'bonny pual v'),
#  ('ad systems communications', 'ad systems communications inc')]
# 3986

# %%
names_with_duplicates = list(set(itertools.chain.from_iterable(true_pairs)))
names_with_duplicates.sort()
len(names_with_duplicates)
# Out:
# 6735

# %%
string_list = names_with_duplicates
k = 50
threshold = 0.8

# %%
from pymagnitude import Magnitude
vectors = Magnitude("~/Downloads/wiki-news-300d-1M-subword.magnitude")

# %%
# https://stackoverflow.com/a/50237379/145349
import numpy as np

def fasttext_vectorize_string_list(string_list):
    all_string_vectors = []
    for string in string_list:
        string_vectors = []
        for word in string.split():
            string_vectors.append(vectors.query(word))
        all_string_vectors.append(np.mean(string_vectors, axis=0))
    fasttext_matrix = np.array(all_string_vectors)
    return fasttext_matrix
    
fasttext_matrix = fasttext_vectorize_string_list(string_list)
fasttext_matrix
# Out:
# array([[ 0.00940245,  0.00476717, -0.02096105, ...,  0.01635175,
#          0.00679325, -0.00542458],
#        [-0.00581288,  0.01224012,  0.04869105, ...,  0.00975113,
#          0.0136479 , -0.00815085],
#        [ 0.00097756, -0.015883  ,  0.02517906, ..., -0.0164187 ,
#         -0.00445986, -0.0137378 ],
#        ...,
#        [ 0.00769634, -0.04264872,  0.01508736, ...,  0.0393482 ,
#          0.00134668, -0.02387204],
#        [ 0.02172828, -0.03250718,  0.00367697, ...,  0.00083562,
#          0.01238225,  0.01873857],
#        [ 0.01227023, -0.01549435, -0.00300307, ..., -0.00753788,
#          0.01825282,  0.01084107]])

# %%
from sklearn.cluster import AgglomerativeClustering

linkage = 'average'
fasttext_labels = AgglomerativeClustering(
    affinity='l2',
    linkage=linkage,
    distance_threshold=1 - threshold,
    n_clusters=None
).fit_predict(fasttext_matrix)
fasttext_labels
# Out:
# array([1474, 1861,  832, ...,  718,  752,  752])

# %%
len(set(fasttext_labels))
# Out:
# 2234

# %%
from collections import defaultdict

def blocks_from_labels(dataset, labels):
    blocks = defaultdict(list)
    for i, label in enumerate(labels):
        record = dataset[i]
        blocks[label].append(record)
    return blocks

def pairs_from_blocks(blocks):
    return set(
        tuple(sorted(pair))
        for block in blocks.values()
        for pair in itertools.combinations(block, 2))

# %%
def precision(found_pairs, true_pairs):
    return len(true_pairs & found_pairs) / len(found_pairs)

def recall(found_pairs, true_pairs):
    return len(true_pairs & found_pairs) / (len(true_pairs & found_pairs) + len(true_pairs - found_pairs))

# %%
fasttext_blocks = blocks_from_labels(string_list, fasttext_labels)
# fasttext_blocks

# %%
fastext_pairs = pairs_from_blocks(fasttext_blocks)
display(precision(fastext_pairs, true_pairs))
display(recall(fastext_pairs, true_pairs))
# Out:
# 0.030782301049740474
# 0.6635725037631711

# %%
true_pairs - fastext_pairs
# Out:
# {('blackstone madison ave offshore fund ltd',
#   'blackstone madison avenue offshore fund ltd class a b c & g shares'),
#  ('alanar inc bd', 'alanar incorporated'),
#  ('american energy partners inc de', 'american energy production inc'),
#  ('bonny paul a', 'bonny pual v'),
#  ('abengoa bioenergy new technologies inc', 'abengoa bioenergy r&d inc'),
#  ('berens credit opportunities fund l p',
#   'berens distressed opportunities lp'),
#  ('becker christipher', 'becker christopher'),
#  ('at&t capital corp de', 'capita corp'),
#  ('anaphore inc', 'anaphore nc'),
#  ('california limited maturity municipals portfolio',
#   'california ltd maturity municipals portfolio'),
#  ('alupka absolute return fund l p', 'alupka absolute return fund lp'),
#  ('brummett burcar alison', 'burcar alison d'),
#  ('birchtree financial services inc bd', 'birchtree financial services llc'),
#  ('aq holdings inc', 'aq holidings inc'),
#  ('advisors disciplined trsut 590', 'advisors disciplined trust 590'),
#  ('arnheim walter r', 'arnheim walter richard'),
#  ('bamco inc ny', 'banco inc'),
#  ('brown spencer', 'browne spencer'),
#  ('ag energy partners extension fund l p', 'ag energy partners ii l p'),
#  ('brog timothy', 'brog timothy e'),
#  ('blackstone fifth avenue fund l p', 'blackstone fifth avenue fund lp'),
#  ('adastra minerals inc', 'america mineral fields inc'),
#  ('american core realty fund l p', 'american core realty fund llc'),
#  ('american express trust co', 'ameriprise trust co'),
#  ('atlas america public # 14 2004 program',
#   'atlas america public #14 2004 l p'),
#  ('broadhead shaun', 'broadhead shaw'),
#  ('bankmont financial co', 'bmo financial corp'),
#  ('atlantic trading partners inc bd',
#   'atlantic trading partners incorporated'),
#  ('boise cascade co', 'boise cascade holdings l l c'),
#  ('belfinance securities inc', 'belfinance securities inc bd'),
#  ('babson capital corporate investors', 'barings corporate investors'),
#  ('brimberg & co l p', 'brimberg & co lp bd'),
#  ('aim international funds inc md', 'aim international mutual funds'),
#  ('caldera corp', 'caplan corp'),
#  ('babe inc', 'bebe stores inc'),
#  ('allen test co & release 8 2 inc', 'allen test co inc'),
#  ('arris pharmaceutical corp de', 'axys pharmecueticals inc'),
#  ('adage capital partners gp l l c', 'adage capital partners gp llc'),
#  ('axiom pharmaceuticals inc', 'axm pharma inc'),
#  ('aim fund services inc ta', 'aim investment services inc'),
#  ('bell derck', 'bell derek'),
#  ('brandywine asset management inc', 'brandywine asset management llc'),
#  ('allen test inc new name 2', 'allen testing co ism'),
#  ('basix capital fund l p', 'basix capital fund lp'),
#  ('ascend offshore fund ltd', 'ascend partners fund i ltd'),
#  ('bogle investment fund lp', 'bogle opportunity fund ii l p'),
#  ('brahman securities inc', 'brahman securities inc bd'),
#  ('altana aktiengesellschaft', 'atlanta aktiengesellschaft'),
#  ('american century international bond funds', 'benham international funds'),
#  ('brandon investments inc', 'brandon investments inc bd'),
#  ('ambit biosciences corp', 'aventa biosciences corp'),
#  ('american capital asset management llc', 'american capital llc'),
#  ('bluematrix l p', 'bluematrix lp'),
#  ('ariel way inc', 'arielway'),
#  ('arcelor', 'arcelormittal'),
#  ('aspenbio inc', 'bioptix inc'),
#  ('aplicor inc', 'aplicor llc'),
#  ('aureal semiconductor', 'aureal semiconductor inc'),
#  ('brandes investment partners l p', 'brandes investment partners llc'),
#  ('blue river capital llc', 'blue river llc bd'),
#  ('ab global thematic growth fund inc',
#   'alliancebernstein global thematic growth fund inc'),
#  ('alcoa inc', 'arconic inc'),
#  ('bhp billiton ltd', 'bhp ltd'),
#  ('bailard biehl & kaiser tehachapi onshore fund lp',
#   'bailard long short onshore fund lp'),
#  ('b riley & co llc', 'b riley and co inc'),
#  ('alliance institutional fund', 'alliancebernstein institutional fund'),
#  ('bridgehampton multi strategy fund llc',
#   'bridgehampton value strategies fund llc'),
#  ('canwest media inc', 'canwest mediaworks inc'),
#  ('babson capital securities inc', 'barings securities llc'),
#  ('c 2 utility contractors llc', 'c2 utility contractors llc'),
#  ('brahman partners ii l p', 'brahman partners ii lp'),
#  ('brazil iowa farms l l c', 'brazil iowa farms llc'),
#  ('auto by tel corp', 'autobytel com inc'),
#  ('alliance premier growth institutional fund',
#   'alliancebernstein large cap growth fund inc'),
#  ('bytemobile inc', 'bytemobileinc'),
#  ('assetmark capital corp bd', 'assetmark capital corporation'),
#  ('berens credit opportunities fund l p',
#   'berens distressed opporntunities lp'),
#  ('bradley michael j', 'bradley michael jack'),
#  ('baring asset management inc ma', 'baring asset management llc'),
#  ('brauvin securities inc', 'brauvin securities inc bd'),
#  ('camelot capital l p', 'camelot capital lp'),
#  ('bhp steel ltd', 'bluescope steel ltd'),
#  ('bli holding inc', 'bli holdings corp'),
#  ('astrotech corp', 'astrotech corp wa'),
#  ('ab municipal income fund inc', 'alliance municipal income fund inc'),
#  ('bailard fund services inc', 'bb&k fund services inc'),
#  ('ascend market neutral fund ltd', 'ascend u s market neutral fund ltd'),
#  ('berman capital llc', 'berman cohn llc bd'),
#  ('bbh long short equity offshore fund ltd',
#   'bbh longshort equity offshore fund ltd'),
#  ('alliance government reserves', 'alliancebernstein government reserves'),
#  ('big sky productions inc', 'bigsky productions inc'),
#  ('bianco research l l c', 'bianco research llc bd'),
#  ('ab government exchange reserves', 'afd exchange reserves'),
#  ('black diamond oc offshore fund ltd',
#   'black diamond structured opportunities ltd'),
#  ('adverum biotechnologies inc', 'avalanche biotechnologies inc'),
#  ('absolute potnetial inc', 'absolute waste services inc'),
#  ('bromley henry', 'bromley henry w'),
#  ('alternet securities inc', 'alternet securities inc bd'),
#  ('atlantis group inc de', 'atlantis plastics inc'),
#  ('banque paribas', 'bnp paribas'),
#  ('better place llc', 'better plc llc'),
#  ('brice carson h', 'brice carson holding'),
#  ('candela corp de', 'candela laser corp'),
#  ('berens capital partners l p', 'berens capital partners lp'),
#  ('auto carbon com inc', 'autocarbon inc'),
#  ('ambrose david', 'ambrose david d'),
#  ('bird estate limited partnership', 'bird estate lp'),
#  ('bianco research l l c', 'bianco research securities llc'),
#  ('accel brands inc', 'accelpath inc'),
#  ('byerwalter mariann h', 'byewalter marianh'),
#  ('ascend sequoia offshore fund ltd', 'ascend u s market neutral fund ltd'),
#  ('brighton securities corp', 'brighton securities corp bd'),
#  ('caldwell securities inc', 'caldwell securities incorporated'),
#  ('breitburn energy partners l p', 'breitburn energy partners lp'),
#  ('american express financial corp ta', 'ameriprise financial inc'),
#  ('campbell financial services inc bd', 'campbell financial services llc'),
#  ('absolute potential inc', 'absolute waste services inc'),
#  ('altegris winton futures fund l p', 'altegris winton futures fund lp'),
#  ('alphadyne investment strategies partners lp',
#   'alphadyne investment strategies partners lp series a lp interests segregated porfolio a'),
#  ('capital investments inc', 'capital investments inc bd'),
#  ('bnp paribas london branch', 'bnp paribas s a london branch'),
#  ('american career centers inc', 'american water star inc'),
#  ('ab government exchange reserves', 'alliancebernstein exchange reserves'),
#  ('bailard biehl & kaiser international fund group inc',
#   'bailard opportunity fund group inc'),
#  ('allied signal inc', 'alliedsignal inc'),
#  ('bank of new york delaware the', 'bny mellon trust of delaware'),
#  ('blackstone fifth avenue avenue fund lp',
#   'blackstone fifth avenue fund l p'),
#  ('box donald', 'box donald d'),
#  ('21 april fund l p', '21 april fund lp'),
#  ('babson capital global umbrella fund plc', 'barings umbrella fund plc'),
#  ('black rock dividend achievers trust', 'blackrock equity dividend trust'),
#  ('ab exchange reserves', 'alliancebernstein exchange reserves'),
#  ('advantage capital corp bd', 'advantage capital corporation'),
#  ('arden realty limited partnership', 'arden realty ltd'),
#  ('a c r securities inc', 'acr securities inc bd'),
#  ('b riley & co inc bd', 'b riley and co inc'),
#  ('boszhardt andrew', 'boszhardt andrew k jr'),
#  ('birinyi fund l p', 'birinyi fund lp'),
#  ('axel partners l p', 'axel partners lp'),
#  ('bthc x', 'bthc x inc'),
#  ('ab equity income fund inc', 'alliancebernstein utility income fund inc'),
#  ('bodleian partners a l p', 'bodleian partners a lp'),
#  ('alliancebernstein investment research and management inc',
#   'alliancebernstein investments inc'),
#  ('algevolve inc', 'algevolve llc'),
#  ('ab institutional funds inc', 'alliance institutional funds inc'),
#  ('benbow robert', 'benbow robert f'),
#  ('brightfield partners ii l p', 'brightfield partners ii lp'),
#  ('american classic financial co bd', 'american classic financial company'),
#  ('allen corinne e', 'allen corrine'),
#  ('brown capital management inc', 'brown capital management llc'),
#  ('aufhauser securities inc', 'aufhauser securities inc bd'),
#  ('aramark corp de', 'aramark worldwide corp'),
#  ('brandywine operating partnership l p',
#   'brandywine operating partnership lp pa'),
#  ('american ostrich co', 'american ostrich company llc'),
#  ('alamo capital', 'alamo capital bd'),
#  ('aerojet general corp', 'aerojet rocketdyne inc'),
#  ('avanti securities corp bd', 'avanti securities corporation'),
#  ('andor capital management l l c', 'andor capital management llc'),
#  ('calamos financial services inc', 'calamos financial services llc'),
#  ('banner apartments fund iii a llc',
#   'banner apartments fund iii a operating limited partnership'),
#  ('boomtown inc', 'boomtown llc'),
#  ('andrew alexander wise & co inc bd',
#   'andrew alexander wise & company incorporated'),
#  ('1 lane technologies corp', 'adama technologies corp'),
#  ('bradesco securities inc', 'bradesco securities inc bd'),
#  ('bancshares of florida inc', 'bank of florida corp'),
#  ('allen test co & release 8 3 inc', 'allen test co inc'),
#  ('brandywine asset management inc',
#   'brandywine global investment management llc'),
#  ('canamex resources corp', 'canamex silver corp'),
#  ('cadiz inc', 'cadiz land co inc'),
#  ('britesmile inc', 'bsml inc'),
#  ('abengoa yield ltd', 'atlantica yield plc'),
#  ('artist capital inc', 'artist capital llc'),
#  ('bny brokerage inc', 'bny esi & co inc'),
#  ('brittingham inc', 'brittingham inc bd'),
#  ('bawarsky david', 'bawarsky david b'),
#  ('allison williams co bd', 'allison williams company'),
#  ('aaron rents inc', 'aaron s inc'),
#  ('berghoff & co inc il bd', 'berghoff & company inc'),
#  ('banco santander s a', 'banco santander sa'),
#  ('ab municipal income fund inc', 'alliance municipal income fund inc ny'),
#  ('bolton llc', 'bolton lp'),
#  ('buckland partners l p', 'buckland partners lp'),
#  ('action minerals inc', 'aroway minerals inc'),
#  ('a k capital llc bd', 'ak capital llc'),
#  ('blackstone madison avenue fund l p', 'blackstone madison avenue fund lp'),
#  ('brooklyn craft works llc', 'brooklyn distilling co llc'),
#  ('capgroup securities l l c', 'capgroup securities llc va bd'),
#  ('alliance municipal income fund inc',
#   'alliancebernstein municipal income fund inc'),
#  ('blue arch coal co', 'blue arch resources inc'),
#  ('aes corp', 'aes corporation'),
#  ('arkansas municipals portfolio', 'arkansas tax free portfolio'),
#  ('afc building technologies inc', 'auto tool technologies inc'),
#  ('access financial group inc', 'access financial group inc bd'),
#  ('camelot trebuchet l p', 'camelot trebuchet lp'),
#  ('apoimmune inc', 'apovax inc'),
#  ('bear stearns alt a trust mtg pass through certs ser 2004 4',
#   'bear stearns trust mortgage pass through certs ser 2004'),
#  ('beasley george estate reduction trust',
#   'beasley george estate reduction trust 6 7 99'),
#  ('blackrock floating rate income trust',
#   'blackrock global inflation protected securities trust'),
#  ('bank of america mortgage securities inc',
#   'bankamerica mortgage securities inc'),
#  ('cannarsa david investments bd', 'cannarsa investments inc'),
#  ('aristeia partners l p', 'aristeia partners lp ny'),
#  ('ault glazer & co llc', 'ault glazer bodnar securities llc'),
#  ('burrill llc', 'burrill securities llc'),
#  ('ab funds trust de', 'annuity board funds trust'),
#  ('barrett securities inc', 'barrett securities inc bd'),
#  ('brechin chandra', 'brechin chandra c b'),
#  ('brown group inc', 'brown shoe co inc'),
#  ('bernstein global opportunities hedge fund ltd',
#   'bernstein global opportunities offshore ltd'),
#  ('arixa fund i llc', 'arixa secured income fund llc'),
#  ('ab large cap growth fund inc', 'alliancebernstein premier growth fund inc'),
#  ('argyrople christopher', 'argyrople christopher n'),
#  ('bnp paribas ny', 'bnp paribas sa'),
#  ('app47 inc', 'appmetrics inc'),
#  ('aquantive inc', 'avenue a inc'),
#  ('blakeslee & blakeslee inc bd', 'blakeslee and blakeslee inc'),
#  ('bank of america mort sec inc mort pas thr certs ser 2001 h',
#   'bank of america mortgage securities inc 2001 h'),
#  ('benchmark plus institutional parnters llc',
#   'benchmark plus institutional partners l l c'),
#  ('allen test', 'allen test co'),
#  ('bnp paribas arbitrage sa', 'bnp paribas arbitrage snc'),
#  ('capital square investment trust', 'capitol square funds'),
#  ('bartholomew daniel', 'bartholomew daniel r'),
#  ('canalaska uranium ltd', 'canalaska ventures ltd'),
#  ('american realty trust inc et al', 'american realty trust inc ga'),
#  ('brasada long short equity fund lp', 'brasada strategic growth fund lp'),
#  ('capistrano cogeneration co', 'capistrano congeneration co'),
#  ('ashton capital management inc', 'ashton capital management inc bd'),
#  ('attara ltd', 'atticus european ltd'),
#  ('basil investment corp bd', 'basil investment corporation'),
#  ('benton f fox', 'benton fred fox'),
#  ('amreit', 'amreit inc'),
#  ('basf aktiengesellschaft', 'basf aktiengesellschaft fa'),
#  ('allen test co inc', 'allen test co inc test time prod'),
#  ('avhana health inc', 'avhana llc'),
#  ('asiainfo holdings inc', 'asiainfo linkage inc'),
#  ('behringer harvard real estate investment trust i inc',
#   'behringer harvard reit i i inc'),
#  ('afem medical corp', 'athena medical corp'),
#  ('btm financial services inc', 'btmu securities inc'),
#  ('buckley benjamin', 'bulkley benjamin'),
#  ('beranek cheri podzimek', 'beranek cheryl p'),
#  ('blackrock global dynamic equity fund',
#   'blackrock long horizon equity fund'),
#  ('brokertec americas llc', 'brokertec usa llc bd'),
#  ('anchortherapeutics inc', 'ascent therapeutics inc'),
#  ('block kelly co bd', 'block kelly company'),
#  ('bright mountain holdings inc fl', 'bright mountain media inc'),
#  ('beautyavenues inc', 'beautyavenues llc'),
#  ('ares management holdings l p', 'ares management holdings llc'),
#  ('alden global emerging markets fund i l p', 'alden global india fund lp'),
#  ('abundant power securities llc', 'bourne partners securities llc'),
#  ('axa', 'axa uap'),
#  ('c&m convegor inc', 'c&m conveyor inc'),
#  ('burlington holdings inc', 'burlington stores inc'),
#  ('callaway golf co', 'callaway golf company'),
#  ('afting ernst guenter', 'afting ernst gunter'),
#  ('acm institutional reserves inc', 'alliance institutional reserves inc'),
#  ('31 group plc', '3i group plc'),
#  ('capital group companies inc', 'capital group companies inc et al'),
#  ('callaway golf co ca', 'callaway golf company'),
#  ('beta capital management l p', 'beta capital management lp'),
#  ('biosepra inc', 'biosphere medical inc'),
#  ('brill securities inc', 'brill securities inc bd'),
#  ('anglo american corp of south africa ltd fi', 'anglo american plc fi'),
#  ('blue ridge offshore limited partnership', 'blue ridge offshore lp'),
#  ('abt holdings inc', 'abt mining co inc'),
#  ('american republic equities corp bd',
#   'american republic equities corporation'),
#  ('buchholz karen d', 'buchholz karen dougherty'),
#  ('allovue inc', 'allovue llc'),
#  ('archstone communities trust', 'archstone smith operating trust'),
#  ('cali realty corp new', 'cali realty l p'),
#  ('allegheny technologies inc', 'allegheny teledyne inc'),
#  ('avondale partners llc', 'avondale partners llc bd'),
#  ('bauer anne', 'bauer anne m'),
#  ('aig life insurance co', 'american general life insurance co of delaware'),
#  ('access investments inc', 'access investments inc bd'),
#  ('bacon zack iii', 'bacon zack jr'),
#  ('brookwood securities partners l p', 'brookwood securities partners llc'),
#  ('abbey healthcare group inc de', 'apria healthcare group inc'),
#  ('aim international funds inc', 'aim international mutual funds'),
#  ('ae biofuels inc', 'aemetis inc'),
#  ('1717 capital management co bd', '1717 capital management company'),
#  ('cabrera capital markets inc', 'cabrera capital markets llc'),
#  ('aurion gold ltd', 'auriongold ltd'),
#  ('aberdeen investment funds', 'bjb investment funds'),
#  ('berthoux christophe', 'berthoux christopher'),
#  ('american enterprises mpt holdings l p',
#   'american enterprises mpt holdings llc'),
#  ('allen test inc new name 2', 'allen testing co ind'),
#  ('bernstein global opportunities hedge fund l p',
#   'bernstein global opportunities hedge fund lp'),
#  ('battelle venture partners lp', 'battelle ventures l p'),
#  ('beta capital management lp', 'beta capital securities llc'),
#  ('bank of boston corp', 'bankboston corp'),
#  ('american century manager funds', 'benham manager funds'),
#  ('arrow select', 'arrow select lp'),
#  ('advisors disciplined trus 437', 'advisors disciplined trust 437'),
#  ('attend com inc', 'attendware inc'),
#  ('bicker bruce p', 'bickner bruce p'),
#  ('bugniazet edward', 'bugniazet edward h'),
#  ('boston private wealth llc', 'bp wealth management llc'),
#  ('boswell j chris', 'boswell jon christopher'),
#  ('blackrock floating rate income trust',
#   'blackrock variable rate & inflation protected securities'),
#  ('berens distressed opportunities fund l p',
#   'berens distressed opportunities lp'),
#  ('american century government income trust',
#   'benham government income trust'),
#  ('autech corp', 'avtech corp'),
#  ('azure capital partners vc',
#   'azure capital partners vc administrators ii l p'),
#  ('black rock global horizons lp', 'blackrock global horizons i l p'),
#  ('blue rock capital fund l p', 'blue rock capital fund limited partnership'),
#  ('bauer jon', 'bauer jon r'),
#  ('campbell institutional multi strategy investment fund ltd',
#   'campbell long short equity investment fund ltd'),
#  ('aberdeen investment funds', 'artio global investment funds'),
#  ('afd exchange reserves', 'alliancebernstein exchange reserves'),
#  ('american century target maturities trust',
#   'benham target maturities trust'),
#  ('ambulatory surgery assoc llc', 'ambulatory surgery associates l l c'),
#  ('bennett mary b', 'bennett mary beth'),
#  ('allen test co', 'allen test co & rel 8 5 inc'),
#  ('aletheia securities inc', 'aletheia securities inc bd'),
#  ('campbell newman asset management inc',
#   'campbell newman pottinger & associates inc'),
#  ('bisignano michael', 'bisignano michael c'),
#  ('aristeia trading l l c', 'aristeia trading llc bd'),
#  ('blackey jeffrey', 'blakey jeff'),
#  ('aeroflex properties corp', 'aeroflex rad inc'),
#  ('alamos gold inc', 'alamos minerals ltd'),
#  ('canyon value realization fund l p', 'canyon value realization fund lp'),
#  ('arklow partners l p', 'arklow partners lp'),
#  ('allen test co & rel 8 5 inc', 'allen test co inc'),
#  ('ab portfolios', 'alliancebernstein portfolios'),
#  ('ab pooling portfolios', 'alliancebernstein pooling portfolios'),
#  ('alliancebernstein strategies dbt',
#   'alliancebernstein strategies dbt a delaware business trust'),
#  ('avalon advisors l p', 'avalon advisors llc'),
#  ('alderon iron ore corp', 'alderon resource corp'),
#  ('aviragen therapeutics inc', 'biota pharmaceuticals inc'),
#  ('breitburn operating l p', 'breitburn operating lp'),
#  ('bdc securities llc', 'bdirect securities inc ok bd'),
#  ('afba 5star fund inc', 'afba five star fund inc'),
#  ('afd exchange reserves inc', 'alliancebernstein exchange reserves'),
#  ('azel agustin', 'azel augustin'),
#  ('boston institutional services inc bd',
#   'boston institutional services incorporated'),
#  ('american atm corp', 'american wireless web corp'),
#  ('borden chemical inc', 'borden inc'),
#  ('american express certificate co', 'ameriprise certificate co'),
#  ('avtech corp', 'avtechtyee inc'),
#  ('american international ventures inc de',
#   'american precious metals inc new'),
#  ('agile group holdings limited adr', 'agile property holdings ltd'),
#  ('blackstone hedged equity fund l p', 'blackstone hedged equity fund lp'),
#  ('10x fund l p', '10x fund lp'),
#  ('allen kimberley', 'allen kimberly j'),
#  ('allen test inc new name 1', 'allen testing co ind'),
#  ('capital analysts inc bd', 'capital analysts incorporated'),
#  ('ameriprop inc', 'ameriprop inc bd'),
#  ('ab electrolux', 'aktiebolaget electrolux'),
#  ('baird management corp bd', 'baird management corporation'),
#  ('adams laboratories inc', 'adams respiratory therapeutics inc'),
#  ('apis capital lp', 'apis captial l p'),
#  ('aspeon inc', 'aspi inc'),
#  ('ab exchange reserves', 'afd exchange reserves'),
#  ('akana capital fund l p', 'akana capital fund lp'),
#  ('biomeridan corp', 'biomeridian corp'),
#  ('bedell frazier investment counseling llc', 'bedell investment counselling'),
#  ('bi02 medical inc', 'bio2 medical inc'),
#  ('bh dg systematic trading fund l p',
#   'brevan howard systematic trading fund l p'),
#  ('arden institutional advisers ii l p', 'arden institutional advisers ii lp'),
#  ('alliance international fund', 'alliance international fund inc'),
#  ('bain capital europe l p', 'bain capital europe llc'),
#  ('acacia ii partners l p', 'acacia ii partners lp'),
#  ('b e aerospace inc', 'be aerospace inc'),
#  ('artha emerging markets fund l p', 'artha emerging markets fund lp'),
#  ('a b watley group inc', 'ab watley group inc'),
#  ('@road inc', 'at road inc'),
#  ('arden institutional advisers lp', 'arden institutional holdings l p'),
#  ('blr capital partners l p', 'blr capital partners lp'),
#  ('allis chalmers corp', 'allis chalmers energy inc'),
#  ('aquila international fund limited', 'aquila international fund ltd'),
#  ('bedminster financial group limited', 'bedminster financial group ltd bd'),
#  ('aquila corp', 'aquila inc'),
#  ('big clix corp', 'bligclix corp'),
#  ('brar investment capital llc', 'brar investment fund lp'),
#  ('calamos advisors trust il', 'calamos insurance trust'),
#  ('averatek corp', 'averatek inc'),
#  ('a 1 group inc', 'a1 group inc'),
#  ('alliance institutional reserves inc',
#   'alliancebernstein institutional reserves inc'),
#  ('4 health inc', '4health inc'),
#  ('ab bond fund inc', 'alliancebernstein bond fund inc'),
#  ('ashraf capital corp', 'ashraf capital corp bd'),
#  ('appalachian basin royalty trust', 'appalachian natural gas trust'),
#  ('artigent capital partners lp', 'artigent china strategic lp'),
#  ('ab exchange reserves', 'afd exchange reserves inc'),
#  ('advisory research inc', 'advisory research inc heller david b'),
#  ('allen test new name inc md', 'allen test redfearn'),
#  ('ambac securities inc', 'cadre securities inc bd'),
#  ('aim equity funds', 'aim equity funds inc'),
#  ('bonanno ray', 'bonanno raymond j'),
#  ('austin george l', 'austin george leslie'),
#  ('barrington partners', 'barrington partners l p'),
#  ('bucketfeet inc', 'bucketfeet llc'),
#  ('apse inc', 'apse llc'),
#  ('caldwell phyllis', 'caldwell phyllis r'),
#  ('business objects s a', 'business objects sa'),
#  ('blackstone topaz fund l p', 'blackstone topaz fund lp'),
#  ('brooke securities inc', 'brooke securities inc bd'),
#  ('blackrock master llc', 'blackrock master trust'),
#  ('brahman institutional partners l p', 'brahman institutional partners lp'),
#  ('advanced aerodynamics', 'advanced aerodynamics & structures inc'),
#  ('babson capital funds trust', 'barings funds trust'),
#  ('bear stearns asset backed sec inc asset back cert se 03 sd1',
#   'bear stearns asset backed securities trust 2003 sd1'),
#  ('agrieuro corp', 'artex corp'),
#  ('alliancebernstein fixed income shares inc',
#   'alliancebernstein institutional reserves inc'),
#  ('allen test co rel test 550', 'allen test corp'),
#  ('ab mortgage securities corp', 'alliance securities corp'),
#  ('banque paribas', 'bnp paribas ny'),
#  ('american international ventures inc de', 'american precious metals inc'),
#  ('aew partners ii lp', 'aew partners l p'),
#  ('advanced thermal sciences corp', 'advanced thermal technologies inc'),
#  ('ab discovery growth fund inc', 'alliancebernstein mid cap growth fund inc'),
#  ('brandes investment partners l p', 'brandes investment partners lp'),
#  ('blackrock liquidity funds', 'blackrock provident institutional funds'),
#  ('allen test co', 'allen test co & rel 8 6 inc'),
#  ('aon corp', 'aon plc'),
#  ('bombay co inc', 'bombay company inc'),
#  ('capital international s a', 'capital international sarl'),
#  ('calvert asset management co inc md', 'calvert investment management inc'),
#  ('ashland inc', 'ashland llc'),
#  ('alphadyne investment strategies fund ltd',
#   'alphadyne investment strategies fund ltd class a & class b common stock segregated portfolio a'),
#  ('behringer harvard mid term value enhancement fund i lp',
#   'behringer harvard mid term value enhancement liquidating trust'),
#  ('adria partners', 'adria partners l p'),
#  ('arizona municipals portfolio', 'arizona tax free portfolio'),
#  ('buffalo high yield fund inc', 'buffalo premium income fund inc'),
#  ('blackstone event driven fund l p', 'blackstone event driven fund lp'),
#  ('antunovic eduardo', 'antunovic edwardo'),
#  ('bizness online com', 'biznessonline com inc de'),
#  ('afton capital management llc', 'blue ridge capital management llc'),
#  ('camcap resources l p', 'camcap resources lp'),
#  ('ai golf llc', 'aquimo llc'),
#  ('all energy corp', 'all fuels & energy co'),
#  ('afg investment partners iv l p', 'afg investment partners iv lp'),
#  ('allen & co inc bd', 'allen & company llc'),
#  ('beaith edmond c', 'beaith ted'),
#  ('alfiero salvalore h', 'alfiero salvatore'),
#  ('arthrocad inc', 'arthromeda inc'),
#  ('america northcoast securities inc', 'ancora securities inc bd'),
#  ('c & l securities corporation', 'c&l securities corp bd'),
#  ('bulletproof 360 inc', 'bulletproof digital inc'),
#  ('american century municipal trust', 'benham municipal trust'),
#  ('broadmark dynamic enhanced equity alpha fund ltd',
#   'broadmark long short equity fund ltd'),
#  ('athene securities llc', 'aviva securities llc'),
#  ('bracken george r', 'braden george r'),
#  ('abramson alan', 'abramson alan b'),
#  ('bgc financial inc', 'bgc financial l p'),
#  ('allen test co inc', 'allen test co inc & cut over test'),
#  ('alliancebernstein disciplined value fund inc',
#   'alliancebernstein focused growth & income fund inc'),
#  ('amaranth securities l l c', 'amaranth securities llc bd'),
#  ('avenue europe investments l p', 'avenue europe investments lp'),
#  ('aberdeen global credit strategies fund inc',
#   'aberdeen global high yield fund inc'),
#  ('bonanza resources corp', 'brs resources ltd'),
#  ('campbell financial services inc', 'campbell financial services llc'),
#  ('budlow robert', 'budlow robert m'),
#  ('ara services inc', 'aramark services inc'),
#  ('bergeron arthur', 'bergeron arthur p'),
#  ('allen test 440', 'allen test corp'),
#  ('buyers united inc', 'buyersonlinecom inc'),
#  ('b b funds', 'bjurman barry funds'),
#  ('bp4 s r l', 'bp4 spa'),
#  ('adelphi europe partners l p', 'adelphi europe partners lp'),
#  ('beacon capital strategic partners vi l p',
#   'beacon capital strategic partners vi lp'),
#  ('allen test co inc 1', 'allen test ltd'),
#  ('ballantyne of omaha inc', 'ballantyne strong inc'),
#  ('archipelago holdings inc', 'archipelago holdings l l c'),
#  ('blue harbour group l p', 'blue harbour group lp'),
#  ('brown & brown securities inc bd', 'brown and brown securities inc'),
#  ('arris pharmaceutical corp de', 'axys pharmaceuticals inc'),
#  ('acorn partners l p', 'acorn partners lp'),
#  ('babson capital global floating rate & income fund',
#   'babson capital global short duration high yield fund'),
#  ('california municipals portfolio', 'california tax free portfolio'),
#  ('anschutz co', 'anschutz corp'),
#  ('anooraq resources corp', 'atlatsa resources corp'),
#  ('blackrock dividend income trust', 'blackrock s&p quality rankings trust'),
#  ('barnard ray', 'barnard ray f'),
#  ('american stellar energy inc', 'american stewar energy corp'),
#  ('btmu financial services inc', 'btmu securities inc'),
#  ('boston partners asset management l p',
#   'boston partners asset management llc'),
#  ('ariel capital management inc', 'ariel capital management llc'),
#  ('burton andrew', 'burton andrew c'),
#  ('ab cap fund inc', 'alliancebernstein cap fund inc'),
#  ('brown bob', 'brown bob d'),
#  ('adidas ag', 'adidas salomon ag fi'),
#  ('bay colony securities co inc', 'bc securities inc'),
#  ('altrinsic international equity portfolio l p',
#   'altrinsic international equity portfolio lp'),
#  ('anaptys biosciences inc', 'anaptysbio inc'),
#  ('binks estates limited partnership', 'binks estates lp'),
#  ('ab high income fund inc', 'alliancebernstein high income fund inc'),
#  ('basswood opportunity partners liquidating fund l p',
#   'basswood opportunity partners lp'),
#  ('american securities bd co lp', 'american securities partners l p'),
#  ('behringer harvard short term liquidating trust',
#   'behringer harvard short term opportunity fund i lp'),
#  ('alliance emerging market debt fund inc',
#   'alliancebernstein high income fund inc'),
#  ('brazilian distribution co',
#   'brazilian distribution co companhia brasileira de distr cbd'),
#  ('ab sustainable global thematic fund inc',
#   'alliancebernstein global thematic growth fund inc'),
#  ('alliance municipal income fund inc ny',
#   'alliancebernstein municipal income fund inc'),
#  ('american renal associates holdings inc', 'c p atlas holdings inc'),
#  ('activa mutual fund trust', 'amway mutual fund inc'),
#  ('bennett restructuring fund l p', 'bennett restructuring fund lp'),
#  ('abada rami', 'abada yoram'),
#  ('aj greentech holdings', 'american jianye greentech holdings ltd'),
#  ('bauer roy', 'bauer roy a'),
#  ('brokerwest', 'brokerwest bd bd'),
#  ('blackstone park avenue fund l p', 'blackstone park avenue fund lp'),
#  ('bonde hank', 'bonde john h'),
#  ('addison clark management l l c', 'addison clark management llc'),
#  ('capital one securities inc', 'capital one southcoast inc'),
#  ('beta capital management l p', 'beta capital securities llc'),
#  ('alliance capital reserves', 'alliancebernstein capital reserves'),
#  ('advisors disciplined trsut 683', 'advisors disciplined trust 683'),
#  ('addicott virginia c', 'albanese virginia c'),
#  ('abound solar inc', 'ava solar inc'),
#  ('bellegard roland', 'bellegarde roland'),
#  ('allen test & snow removal co inc', 'allen test co inc'),
#  ('american bancorporation oh', 'american bancorporation wv'),
#  ('brown robert', 'brown robert s'),
#  ('apollo centre street partnership', 'apollo centre street partnership l p'),
#  ('amoco co', 'bp amoco co'),
#  ('bailard biehl & kaiser tehachapi accredited investor fund lp',
#   'bailard long short accredited investor fund lp'),
#  ('alberts jamie d', 'alberts jamie dennis'),
#  ('auto marketing network inc', 'automarketing network inc'),
#  ('brahman partners iv l p', 'brahman partners iv lp'),
#  ('alliancebernstein emerging market debt fund inc',
#   'alliancebernstein high income fund inc'),
#  ('buth jay', 'buth jay s'),
#  ('brahman capital corp bd', 'brahman securities inc bd'),
#  ('bnp paribas exchange traded trust', 'bnp paribas l s commodities trust'),
#  ('adam com inc de', 'adam inc'),
#  ('capital technology inc', 'capital technology inc bd'),
#  ('artal international s c a', 'artal international sca'),
#  ('altegris renaissance ie fund lp', 'altegris visium fund l p'),
#  ('adaptec inc', 'adpt corp'),
#  ('bnnt llc', 'bnnt materials llc'),
#  ('berwyn funds', 'berwyn income fund inc'),
#  ('cachematrix broker dealer llc', 'cachematrix llc'),
#  ('7x7 institutional partners l p', '7x7 institutional partners lp'),
#  ('addison clark fund l p', 'addison clark fund lp'),
#  ('bernstein steven e', 'brenstein steven e'),
#  ('alcohoot inc', 'alcohoot llc'),
#  ('american express financial corp', 'ameriprise financial inc'),
#  ('big hub com inc', 'bighub com inc'),
#  ('ameliatel', 'ameliatel lp'),
#  ('baker hughes a ge co llc', 'baker hughes inc'),
#  ('appnet inc de', 'appnet systems inc'),
#  ('american access technologies inc', 'american electric technologies inc'),
#  ('bueter & co inc bd', 'bueter and company inc'),
#  ('alcatel alsthom france', 'alcatel lucent'),
#  ('camden partners lp', 'camden partners ltd partnership'),
#  ('bearstead nicolas', 'bearsted nicholas'),
#  ('bolton financial services llc', 'bolton financial services llc bd'),
#  ('advantage advisers global growth l l c',
#   'advantage advisers technology partners llc'),
#  ('bromley henry w', 'bromley henry walford'),
#  ('aim stock funds', 'aim stock funds inc'),
#  ('c & c tours inc', 'c&c tours inc'),
#  ('barr laboratories inc', 'barr pharmaceuticals inc'),
#  ('alliance institutional fund',
#   'alliance institutional fund a delaware business trust'),
#  ('barclay investments inc', 'barclay investments inc bd'),
#  ('act ii partners l p', 'act ii partners lp'),
#  ('alliance atlantis communications inc', 'alliance communications corp'),
#  ('brinton eaton associates inc', 'brinton eaton llc'),
#  ('bear stearns as bckd sec inc hm eq ln bckd term nt sr 1999 1',
#   'bear stearns asset back sec inc gmacm rev ho eq lo tr 1999 1'),
#  ('aeterna laboratories inc', 'aeterna zentaris inc'),
#  ('bank of america mort sec inc mort pass thr cert ser 2002 2',
#   'bank of america mortgage securities inc 2002 2'),
#  ('bluefoot qualified investments l p', 'bluefoot qualified investments lp'),
#  ('ammonia hold inc', 'cali holdings inc'),
#  ('bullock james', 'bullock james w'),
#  ('canandaigua west inc', 'canandaigua wine co inc ny'),
#  ('berger growth & income fund inc', 'berger one hundred & one fund inc'),
#  ('astro med inc new', 'astronova inc'),
#  ('capital growth financial llc', 'capital growth securities llc'),
#  ('anpac securities group', 'asg securities inc'),
#  ('airgate pcs inc de', 'airgate wireless inc'),
#  ('ameritrade holding corp', 'arrow stock holding corp'),
#  ('aginity inc', 'aginity llc'),
#  ('brookdale international partners l p',
#   'brookdale international partners lp'),
#  ('algebris global financials fund l p', 'algebris global financials fund lp'),
#  ('biomedical value fund', 'biomedical value fund l p'),
#  ('3 d systems corp', '3d systems corp'),
#  ('a foods inc', 'aurora foods inc md'),
#  ('alliance capital management holding lp', 'alliancebernstein holding l p'),
#  ('blackstone capital partners vi l p', 'blackstone capital partners vi lp'),
#  ('agri general securities corp bd', 'agri general securities corporation'),
#  ('banc fund iv l p', 'banc funds co llc'),
#  ('c p baker securities inc bd', 'c p baker securities incorporated'),
#  ('activision blizzard inc', 'activision inc ny'),
#  ('american independence funds trust', 'arrivato funds trust'),
#  ('associated technologies', 'associated technologies inc'),
#  ('beradi hector', 'berardi hector'),
#  ('baxter financial corp bd', 'baxter financial corporation'),
#  ('birshstein boris', 'birshtein boris'),
#  ('adamas opportunities l p', 'adamas opportunities lp'),
#  ('bjurman funds', 'bjurman trust'),
#  ('advisors disciplined trust 551', 'advisors disciplined turst 551'),
#  ('amalgamated gadget l p', 'amalgamated gadget lp'),
#  ('ascend offshore leveraged fund ltd', 'ascend partners fund ii ltd'),
#  ('bolin james', 'bolin james e'),
#  ('cap gemini sa adr', 'capgemini se adr'),
#  ('bradley real estate inc', 'bradley real estate trust'),
#  ('brookville horizons fund l p', 'brookville horizons fund lp'),
#  ('bnp paribas asset management', 'bnp paribas asset management s a s'),
#  ('brc diamond corp', 'brc diamondcore ltd'),
#  ('barclays global investors fund distribution company',
#   'blackrock fund distribution company'),
#  ('barrington associates', 'barrington associates bd'),
#  ('bailey ralph e', 'biley ralph e'),
#  ('aucella thomas', 'aurella thomas'),
#  ('ab institutional funds inc', 'alliancebernstein institutional funds inc'),
#  ('aon securities corporation', 'aon securities inc'),
#  ('apex therapeutics inc', 'apexian pharmaceuticals inc'),
#  ('blackrock fixed income trust', 'blackrock funds ii'),
#  ('argenx n v', 'argenx se'),
#  ('acmc inc', 'acmc llc'),
#  ('american aadvantage select funds', 'american beacon select funds'),
#  ('american independence financial services llc',
#   'american independence funds trust'),
#  ('altair international gold inc', 'altair nanotechnologies inc'),
#  ('abbott medical optics inc', 'advanced medical optics inc'),
#  ('brean capital llc', 'brean murray carret & co llc'),
#  ('alliance government reserves inc', 'alliancebernstein government reserves'),
#  ('blount parrish & co inc bd', 'blount parrish & roton inc'),
#  ('builders fixed income fund inc', 'builders proloan fund inc'),
#  ('aquila corp', 'aquila energy corp'),
#  ('boshar kathleen i', 'boshar reynolds kathleen'),
#  ('brand scaffold services inc', 'brand services'),
#  ('berkshire capital corporation', 'berkshire capital securities llc'),
#  ('blackrock diamond property fund inc',
#   'blackrock income & growth property fund inc'),
#  ('anderson adam d', 'blue adam d'),
#  ('betzold research & trading inc bd', 'betzold research and trading inc'),
#  ('brady corp', 'brady w h co'),
#  ('aeroflex inc', 'arx inc'),
#  ('ani pharmaceuticals inc', 'biosante pharmaceuticals inc'),
#  ('ameritas investment corp', 'ameritas investment corp bd'),
#  ('american century investment trust', 'benham investment trust'),
#  ('advanced nutraceuticals inc tx', 'bactolac pharmaceutical inc'),
#  ('brockwell bruce t', 'brockwell bruce todd'),
#  ('abn amro funds', 'amg funds iv'),
#  ('bluecrest capital l p', 'bluecrest capital lp'),
#  ('aramark corp', 'aramark services inc'),
#  ('berkeley capital management funds', 'berkeley funds trust'),
#  ('abp investments us inc', 'apg asset management us inc'),
#  ('bbh asiaan opportunity fund lp', 'bbh asian opportunity fund l p'),
#  ('ae partners l l c', 'ae partners llc bd'),
#  ('bluetrend fund l p', 'bluetrend fund lp'),
#  ('bfi canada income fund', 'bfi canada ltd'),
#  ('canaccord adams inc', 'canaccord genuity inc'),
#  ('blackstone park avenue non taxable fund l p',
#   'blackstone park avenue non taxable fund lp'),
#  ('amici qualified associates l p', 'amici qualified associates lp'),
#  ('abbey capital ltd', 'abbey capital multi manager fund'),
#  ('balzer eric', 'balzer eric a'),
#  ('belle haven investments l p', 'belle haven investments lp'),
#  ('allos i limited partnership', 'blue chip v limited partnership'),
#  ('austin securities inc', 'austin securities inc bd'),
#  ('bush odonnell & co inc', 'bush odonnell investment advisors inc'),
#  ('afba 5star fund inc', 'afba five star funds inc'),
#  ('capital partnership lp', 'capital partnerships'),
#  ('capital growth advisors llc bd', 'capital growth securities llc'),
#  ('bank of america mort sec inc mort pass thr cert er 2002 2',
#   'bank of america mortgage securities inc 2002 b'),
#  ('advantage advisers catalyst partners l p',
#   'advantage advisers catalyst partners lp'),
#  ('allen test co inc', 'allen test inc new name 3'),
#  ('bankers corp', 'bankers corporation'),
#  ('brock financial services llc', 'brock securities llc'),
#  ('bengston jon', 'bengtson jon n'),
#  ('candente copper corp', 'candente resource corp'),
#  ('alternative investments l p', 'alternative investments lp'),
#  ('acm institutional reserves inc',
#   'alliancebernstein institutional reserves inc'),
#  ('aqr small cap value fund l p', 'aqr small cap value lp'),
#  ('alliance portfolios', 'alliancebernstein portfolios'),
#  ('activein inc', 'activein ltd'),
#  ('anderson john r', 'anderson john ross'),
#  ('aberdeen global high yield fund inc',
#   'aberdeen global short duration income fund inc'),
#  ('caldwell securities inc bd', 'caldwell securities incorporated'),
#  ('afsg securities corp bd', 'afsg securities corporation'),
#  ('broadwview holding llp', 'bv holdings llp'),
#  ('a m oppenheimer securities inc', 'am oppenheimer securities inc bd'),
#  ('barwell securities corp bd', 'barwell securities corporation'),
#  ('9lenses inc', '9lenses llc'),
#  ('archstone absolute return strategies fund ltd',
#   'archstone market neutral strategies fund ltd'),
#  ('aristotle fund l p', 'aristotle fund lp'),
#  ('access securities inc', 'access securities llc'),
#  ('banyan investment fund l p', 'banyan investment fund lp'),
#  ('bionovo', 'bionovo inc'),
#  ('apollo fund', 'apollo fund ct'),
#  ('burke jason', 'burke jason g'),
#  ('avanyx therapeutics inc', 'boston therapeutics inc'),
#  ('canandaigua brands inc', 'canandaigua wine co inc'),
#  ('black rock dividend achievers trust', 'blackrock dividend achievers trust'),
#  ('brentworth & co inc bd', 'brentworth & company incorporated'),
#  ('abn amro funds', 'aston funds'),
#  ('calypso ventures ii l p', 'calypso ventures ii llc'),
#  ('brookwood associates l l c', 'brookwood associates llc bd'),
#  ('blackpier atlas fund lp', 'blackpier market neutral fund l p'),
#  ('canaan vii l p', 'canaan vii lp'),
#  ('archview credit oportunities fund lp', 'archview fund l p'),
#  ('bcp affiliates fund llc', 'broadview capital partners affiliates fund ll'),
#  ('abengoa yield plc', 'atlantica yield plc'),
#  ('bear & bull investment corp b', 'bear and bull investment corporation'),
#  ('abry partners vi l p', 'abry partners vi lp'),
#  ('berean capital inc', 'berean capital incorporated'),
#  ('american realty trust inc', 'american realty trust inc et al'),
#  ('basswood financial partners lp', 'basswood opportunity partners l p'),
#  ('baumgartner rudolf a', 'baumgartner rudolph'),
#  ('advanced magnetics inc', 'amag pharmaceuticals inc'),
#  ('allegheny energy inc', 'allegheny power system inc'),
#  ('bionano genomics inc', 'bionanomatrix inc'),
#  ('b2 direct inc', 'b2direct inc'),
#  ('bondurant partners l p', 'bondurant partners lp'),
#  ('astoria capital markets inc', 'astoria capital markets inc bd'),
#  ('allen test co inc', 'allen test inc new name 2'),
#  ('breard linda m', 'breard linda marie'),
#  ('algonquin power & utilities corp', 'algonquin power income fund'),
#  ('arch coal inc', 'arch mineral corp'),
#  ('anderson group inc', 'anderson group incorporated'),
#  ('algos therapeuitics inc', 'algos therapeutics inc'),
#  ('america northcoast securities inc', 'ancora securities inc'),
#  ('alerus securities bd', 'alerus securities corporation'),
#  ('blackstone sers customized fund l p', 'blackstone sers customized fund lp'),
#  ('brokertec usa l l c', 'brokertec usa llc bd'),
#  ('baytide securities corp bd', 'baytide securities corporation'),
#  ('alexander barbara t', 'alexander stiles barbara'),
#  ('aetna life & casualty co', 'aetna services inc ct'),
#  ('access securities inc bd', 'access securities llc'),
#  ('allen test co', 'allen test co & release 8 2 inc'),
#  ('arris resources inc', 'bassett ventures inc'),
#  ('bergey james l', 'bergey james la verne'),
#  ('apollo partners l p', 'apollo partners lp bd'),
#  ('acadian global long short fund llc',
#   'acadian global market neutral fund llc'),
#  ('bullbag corp', 'bullbag llc'),
#  ('bernstein global opportunities hedge fund ltd',
#   'bernstein global opportunities offshore cayman ltd'),
#  ('aquilo partners inc', 'aquilo partners l p'),
#  ('bt advisor funds', 'bt global advisors'),
#  ('american securities corp', 'american securities partners l p'),
#  ('btc africa', 'btc africa s a'),
#  ('anthion master fund l p', 'anthion master fund lp'),
#  ('b b funds', 'bjurman funds'),
#  ('blue bell country club l p', 'blue bell country club lp'),
#  ('alcatel', 'alcatel lucent'),
#  ('bailard biehl & kaiser tehachapi offshore fund ltd',
#   'bailard long short offshore fund ltd'),
#  ('callinan mines limited', 'callinan royalties corp'),
#  ('ab international growth fund inc',
#   'alliancebernstein international growth fund inc'),
#  ('bernstein bruce g', 'bernstin bruce g'),
#  ('amreit securities co bd', 'amreit securities company'),
#  ('adventrx pharmaceuticals inc', 'biokeys pharmaceuticals inc'),
#  ('aurora global opportunities asw fund',
#   'aurora global opportunities asw fund a series of alternative strategies platform llc'),
#  ('biltmore international corp bd', 'biltmore international corporation'),
#  ('bernstein sanford c & co inc', 'bernstein sanford co inc'),
#  ('banc of america capital investors lp',
#   'bancamerica capital investors sbic i lp'),
#  ('barclays global fund advisors', 'blackrock fund advisors'),
#  ('acm income fund inc', 'alliancebernstein income fund inc'),
#  ('arena online inc', 'attaq online inc'),
#  ('asset management fund', 'asset management fund inc'),
#  ('behavioral healthcare corp', 'behavioral healthcare llc'),
#  ('annas linen co', 'annas linens inc'),
#  ('altmfx trust', 'altx trust'),
#  ('american realty capital ii llc', 'ar capital llc'),
#  ('axiom international micro cap fund lp',
#   'axiom small cap international fund l p'),
#  ('adondo corp', 'adondo fund lp'),
#  ('amoco corp', 'bp amoco corp'),
#  ('breeden partners california l p', 'breeden partners california lp'),
#  ('biomedical value fund i', 'biomedical value fund l p'),
#  ('ark multi manager fund l p', 'ark multi manager fund lp'),
#  ('bristow claire h', 'bristow claire holding'),
#  ('bhl partners l p', 'bhl partners lp'),
#  ('buscar co', 'buscar oil inc'),
#  ('american express west equity fund l p',
#   'american express west equity fund limited partnership'),
#  ('artorius partners ii l p', 'artorius partners ii lp'),
#  ('ab global bond fund inc', 'alliancebernstein global bond fund inc'),
#  ('banque paribas', 'bnp paribas sa'),
#  ('american funds money market fund',
#   'american funds u s government money market fund'),
#  ('american core realty fund l p', 'american stable value fund llc'),
#  ('american express financial advisors inc',
#   'ameriprise financial services inc'),
#  ('babson capital securities llc', 'babson securities corporation'),
#  ('camcap energy l p', 'camcap energy lp'),
#  ('20th century industries', '21st century insurance group'),
#  ('bcp caylux holdings luxembourg s c a', 'bcp luxembourg holdings sarl'),
#  ('acadian asset management inc ma', 'acadian asset management llc'),
#  ('bank of america mortgage sec inc mor pas thr ce se 2001 12',
#   'bank of america mortgage securities inc 2001 12'),
#  ('boren kim', 'boren kimberly'),
#  ('adb systems international inc', 'bid com international inc'),
#  ('beckham robert j', 'beckman robert j'),
#  ('bear stearns asset back sec inc mort pas thr ce se 03 abf1',
#   'bear stearns asset backed securities trust 2003 abf1'),
#  ('a c trading inc', 'ac trading inc'),
#  ('burch & co inc bd', 'burch & company inc'),
#  ('bulltick securities inc', 'bulltick securities llc'),
#  ('autocarbon com inc', 'autocarbon inc'),
#  ('2tor inc', '2u inc'),
#  ('avalon advanced materials inc', 'avalon rare metals inc'),
#  ('calgene ii inc', 'calgene inc de'),
#  ('aurora global opportunitites ii asw fund',
#   'aurora global opportunitites ii asw fund a series of alternative strategies platform llc'),
#  ('antares european fund l p', 'antares european fund lp'),
#  ('advanced medical inc', 'alaris medical inc'),
#  ('bullaro securities corp', 'bullaro securities corp bd'),
#  ('aurora financial services l l c', 'aurora financial services llc bd'),
#  ('blackrock credit allocation income trust',
#   'blackrock preferred & equity advantage trust'),
#  ('angelo gordon & co l p', 'angelo gordon & co lp ny'),
#  ('accor', 'accor sa fi'),
#  ('balfour investors inc', 'balfour investors inc bd'),
#  ('7x7 partners l p', '7x7 partners lp'),
#  ('american pharmaceutical partners inc ca', 'app pharmaceuticals inc'),
#  ('burkett paul', 'burkett paul j'),
#  ('cabrera luis', 'cabrera luis m'),
#  ('brolick emil', 'brolick emil j'),
#  ('alertid inc', 'alertid llc'),
#  ('allen test inc new name 3', 'allen testing co ind'),
#  ('ab large cap growth fund inc', 'alliance premier growth fund inc'),
#  ('beese fulmer & pincoe inc', 'beese fulmer investment management inc'),
#  ('allen test', 'allen test co inc 1'),
#  ('capital conservation corp', 'capital preservation fund l p'),
#  ('boise cascade co', 'boise cascade l l c'),
#  ('argent capital advisors llc', 'atlantic american capital advisors llc bd'),
#  ('blue water strategic currency fund i llc',
#   'blue water total return fund i l p'),
#  ('bracken frank', 'bracken frank d'),
#  ('bates securities inc', 'bates securities inc bd'),
#  ('660 partners fund l p', '660 partners fund lp'),
#  ('brand yourself com llc', 'brandyourself com inc'),
#  ('brookwood securities partners l p', 'brookwood securities partners lp bd'),
#  ('alps fund services inc', 'alps mutual funds services inc co ta'),
#  ('anthem cic ventures fund lp', 'anthem ventures fund l p'),
#  ('bernstein global diversified hedge fund l p',
#   'bernstein global diversified hedge fund lp'),
#  ('alliance institutional funds inc',
#   'alliancebernstein institutional funds inc'),
#  ('banco itau s a', 'banco itau sa'),
#  ('atmi holdings inc', 'atmi inc'),
#  ('american securities bd co lp', 'american securities corp'),
#  ('amerisource corp', 'amerisource health corp'),
#  ('brookfield investment funds', 'brookfield investment management inc'),
#  ('american beacon select funds', 'american select funds'),
#  ('arden institutional advisers ii ms feeder l p',
#   'arden institutional advisers ii ms feeder lp'),
#  ('bonnewell andrew', 'bonnewell g andrew'),
#  ('250 west 57th st associates', '250 west 57th st associates l l c'),
#  ('blackstone customized commodities fund l p',
#   'blackstone sers customized commodities fund lp'),
#  ('blackstone quarry fund l p', 'blackstone quarry fund lp'),
#  ('aeb corp bd', 'aeb corporation'),
#  ('broadmark futures fund ltd', 'broadmark long short equity fund ltd'),
#  ('aqr style premia fund l p', 'aqr vme fund l p'),
#  ('berenson richad', 'berenson richard a'),
#  ('bankmont financial inc', 'bmo financial corp'),
#  ('abeona therapeutics inc', 'access pharmaceuticals inc'),
#  ('alexander capital l p', 'alexander capital lp bd'),
#  ('bersticker albert c', 'bersticker albvert c'),
#  ('caldera equity fund l p', 'caldera equity fund lp'),
#  ('adance cps lp', 'advancepcs lp'),
#  ('bullock a richard', 'bullock anthony richard'),
#  ('alcresta inc', 'alcresta therapeutics inc'),
#  ('berlind securities inc', 'berlind securities inc bd'),
#  ('adamas partners l p', 'adamas partners lp'),
#  ('bailard biehl & kaiser inc', 'bailard inc'),
#  ('cambria investment management inc', 'cambria investment management l p'),
#  ('ballentine finn & company inc', 'ballentine partners llc'),
#  ('brf high value l p', 'brf high value lp'),
#  ('ab unconstrained bond fund inc',
#   'alliancebernstein unconstrained bond fund inc'),
#  ('blackstone partners investment fund l p',
#   'blackstone partners investment fund lp'),
#  ('capital consultants inc', 'capital consultants llc'),
#  ('ballad gold & silver ltd fi', 'ballad ventures ltd fi'),
#  ('aton securities inc', 'aton securities inc bd'),
#  ('british petroleum co plc', 'british petroleum company'),
#  ('bloombergsen inc', 'bloombergsen investment partners'),
#  ('abry partners v l p', 'abry partners v lp'),
#  ('aris multi strategy fund l p', 'aris multi strategy fund lp'),
#  ('ab bond fund inc', 'alliance bond fund inc'),
#  ('aegon funding co llc', 'aegon funding corp'),
#  ('bosco flooring inc', 'bosco holdings inc'),
#  ('bailey wiliam', 'bailey william c'),
#  ('ampex inc', 'ampex inc de'),
#  ('ameridrives international l p', 'ameridrives international llc'),
#  ('advanstar holdings inc', 'advanstar inc'),
#  ('bickell alan', 'brickell alan'),
#  ('blackstone capital partners vi executive fund l p',
#   'blackstone capital partners vi executive fund lp'),
#  ('bft financial group llc', 'butler freeman tally financial group llc'),
#  ('caliper life sciences inc', 'caliper technologies corp'),
#  ('afg investment partners iii l p', 'afg investment partners iii lp'),
#  ('caine investment fund i l p', 'caine investment fund i lp ca'),
#  ('aceler inc', 'acelere inc'),
#  ('blue fire equipment corp', 'bluefire equipment corp'),
#  ('ab portfolios', 'alliance portfolios'),
#  ('allrecipes com inc', 'allrecipescom inc'),
#  ('alex moore & co inc bd', 'alex moore & company inc'),
#  ('blackstone pacific opportunities master fund l p',
#   'blackstone pacific opportunities master fund lp'),
#  ('ab equity income fund inc', 'alliancebernstein equity income fund inc'),
#  ('boston chicken inc', 'boston chicken plan trust'),
#  ('ab corporate shares', 'alliancebernstein corporate shares'),
#  ('ayablu inc', 'ayablu incporated'),
#  ('bostwick compound l p', 'bostwick compound lp'),
#  ('advisory research global all cap fund l p',
#   'advisory research global value fund lp'),
#  ('bornhoft group securities corp bd',
#   'bornhoft group securities corporation'),
#  ('america first multifamily investors l p',
#   'america first tax exempt investors lp'),
#  ('alpine associates a limited partnership', 'alpine associates l p'),
#  ('akros securities inc', 'akros securities inc bd'),
#  ('a k capital llc', 'ak capital llc'),
#  ('brady brian', 'brady brian w'),
#  ('aquamer inc', 'aquamer medical corp'),
#  ('ba nutrition llc', 'body armor nutrition llc'),
#  ('adaptimmune ltd', 'adaptimmune therapeutics plc'),
#  ('advisors disciplined trust 1066', 'advisors disciplined turst 1066'),
#  ('alliance premier growth institutional fund',
#   'alliancebernstein premier growth fund inc'),
#  ('bnp paribas', 'bnp paribas sa'),
#  ('campbell financial futures fund l p',
#   'campbell managed futures onshore fund lp'),
#  ('bluedot inc', 'bluedot llc'),
#  ('asm lithography holding nv', 'asml holding nv'),
#  ('calonico john', 'calonico john e jr'),
#  ('advanced medical inc', 'alaris medical systems inc'),
#  ('avenue capital management ii l p', 'avenue capital management ii llc'),
#  ('budgethotels com inc', 'budgethotels network inc'),
#  ('burgess c coney', 'burgess c convey'),
#  ('ascend sequoia fund lp', 'ascend u s market neutral fund l p'),
#  ('adler lundgren tamara l', 'adler tamara'),
#  ('audobon securities inc', 'audobon securities inc bd'),
#  ('american beacon municipal enhanced cash trust',
#   'amr investments municipal enhanced cash trust'),
#  ('cannamed corp', 'cannamed corporation'),
#  ('apollo gold corp', 'brigus gold corp'),
#  ('ag diversified credit strategies fund lp',
#   'ag diversified income fund plus l p'),
#  ('analytics 4 life inc', 'analytics for life inc'),
#  ('arctco inc', 'arctco incorporated'),
#  ('ascend market neutral fund bpo ltd',
#   'ascend u s market neutral fund bpo ltd'),
#  ('aracruz cellulose', 'aracruz cellulose s a'),
#  ('allen test co', 'allen test co & rel 8 6 dr inc'),
#  ('abviva inc', 'biolabs inc'),
#  ('brokerageamerica llc', 'brokerageamerica llc bd'),
#  ('atlas america public #15 2005 a l p',
#   'atlas america public #15 2005 program'),
#  ('advisory research global value fund lp',
#   'advisory research international value fund l p'),
#  ('blue rock emerging manager fund l p', 'blue rock emerging manager fund lp'),
#  ('archview credit opportunities fund lp', 'archview fund l p'),
#  ('acacia pledge capital l p', 'acacia pledge capital lp'),
#  ('andro capital l p', 'andro capital lp'),
#  ('borow leonard', 'borow leonard j'),
#  ('bulter s lynn', 'butler s lynn'),
#  ('altair international inc fi', 'altair nanotechnologies inc fi'),
#  ('butler david r', 'butler david reid'),
#  ('bb&t funds', 'bb&t mutual funds group'),
#  ('beyer michael', 'beyer michael t'),
#  ('bedford securities inc', 'bedford securities inc bd'),
#  ('camden securities inc', 'camden securities inc bd'),
#  ('broad run associates l p', 'broad run associates lp'),
#  ('aspiriant global equity trust', 'aspiriant trust'),
#  ('blue rock capital fund ii l p', 'blue rock capital fund ii lp'),
#  ('allen test co & rel 8 5 inc', 'allen test ltd'),
#  ('better lesson llc', 'betterlesson llc'),
#  ('ampex corp de', 'ampex inc'),
#  ('60 east 42nd street associates', '60 east 42nd street associates l l c'),
#  ('aureal inc', 'aureal semiconductor'),
#  ('calgene inc de', 'calgene inc old'),
#  ('bank of new york delaware', 'bny mellon trust of delaware'),
#  ('boyle capital management l l c', 'boyle capital management llc'),
#  ('ba mortgage securities inc', 'bank of america mortgage securities inc'),
#  ('alpine partners l p', 'alpine partners lp bd'),
#  ('bell bank', 'bell state bank & trust'),
#  ('ascend partners fund ii lp', 'ascend partners leveraged fund l p'),
#  ('blue ridge analytics inc', 'blueridge analytics inc'),
#  ('agenus inc', 'antigenics inc de'),
#  ('alphasimplex quantitative global macro fund l p',
#   'alphasimplex quantitative global macro fund lp'),
#  ('aew partners ii lp', 'aew partners l p et al'),
#  ('amici associates l p', 'amici associates lp'),
#  ('berry iowa llc', 'berry plastics ik llc'),
#  ('caldwell securities inc', 'caldwell securities inc bd'),
#  ('bt shipping limited', 'bt shipping ltd'),
#  ('assured equities iv corp', 'assured equities llc'),
#  ('alliance utility income fund inc',
#   'alliancebernstein utility income fund inc'),
#  ('ab municipal income fund inc', 'alliance municipal income fund incc'),
#  ('aethlon capital l l c', 'aethlon capital llc bd'),
#  ('advantage advisers technology partners l l c',
#   'advantage advisers technology partners llc'),
#  ('aria diagnostics inc', 'ariosa diagnostics inc'),
#  ('alabama municipals portfolio', 'alabama tax free portfolio'),
#  ('bluecrest mercantile fund l p', 'bluecrest mercantile fund lp'),
#  ('ascend alpha strategies fund ltd', 'ascend multi strategy fund ltd'),
#  ('blackstone market opportunities fund l p',
#   'blackstone market opportunities fund lp'),
#  ('audubon ridge l p', 'audubon ridge lp'),
#  ('acuitas long short fund lp', 'acuitas microcap fund lp'),
#  ('auda capital v u s l p', 'auda capital v us lp'),
#  ('barnabus energy inc', 'barnabus enterprises ltd'),
#  ('baynet ltd', 'bayou international ltd'),
#  ('cadinha & co inc hawaii', 'cadinha & co llc'),
#  ('benjamin franklin bancorp inc', 'benjamin franklin bancorp m h c'),
#  ('biologicsmd inc', 'biologicsmd llc'),
#  ('angelo marc', 'angelo mark'),
#  ('benairie jacob', 'benarie jacob'),
#  ('aston asset management llc', 'aston asset management lp'),
#  ('access securities inc', 'access securities inc bd'),
#  ('beall pamela k m', 'beall pamela km'),
#  ('buehler david', 'buehler david g'),
#  ('actinver securities inc', 'actinver securities inc bd'),
#  ('alliance municipal income fund incc',
#   'alliancebernstein municipal income fund inc'),
#  ('access integrated technologies inc',
#   'access integrated technologies inc d b a cinedigm digital cinema corp'),
#  ('auerbach grayson & co llc', 'auerbach grayson & company incorporated'),
#  ('bioscience securities inc', 'bioscience securities inc bd'),
#  ('biovail corp', 'biovail corp international'),
#  ('berry plastics holding corp', 'bpc holding corp'),
#  ('canyon partners inc bd', 'canyon partners incorporated'),
#  ('behringer harvard real estate investment trust i inc',
#   'behringer harvard reit i inc'),
#  ('axa financial bermuda ltd',
#   'axa re arizona co f k a financial bermuda ltd'),
#  ('barlow david', 'barlow david s'),
#  ('blackstone corporate opportunities master fund l p',
#   'blackstone corporate opportunities master fund lp'),
#  ('argent capital advisors llc', 'atlantic american capital advisors llc'),
#  ('allianz global investors capital llc', 'allianz global investors u s llc'),
#  ('bluebridge digital inc', 'bluebridge llc'),
#  ('affiliated resources corp', 'basic natural resources inc'),
#  ('a t a p financial services inc', 'atap financial services inc bd'),
#  ('activeworlds com inc', 'activeworlds corp'),
#  ('ba residential securities inc', 'banc of america mortgage securities inc'),
#  ('43010', '43010 inc'),
#  ('avanir pharmaceuticals', 'avanir pharmaceuticals inc'),
#  ('aixtron ag', 'aixtron se'),
#  ('answerthink consulting group inc', 'answerthink inc'),
#  ('aurora electronics inc', 'aurora electronics inc et al'),
#  ('alleghany funds', 'aston funds'),
#  ('brookville onshore horizons fund i l p',
#   'brookville onshore horizons fund i lp'),
#  ('ba sports nutrition llc', 'body armor nutrition llc'),
#  ('aspen trading l l c', 'aspen trading llc bd'),
#  ('barr rosenberg funds distributor inc', 'bisys distribution services inc'),
#  ...}

# %%
fastext_pairs - true_pairs
# Out:
# {('alliancebernstein multi manager alternative fund',
#   'blackrock multi strategy fund ltd'),
#  ('aegis asset backed securities llc', 'bonds direct securities llc bd'),
#  ('banc of america capital management llc',
#   'california university of protection & intelligence management'),
#  ('adelphi europe partners l p', 'alloy global fund l p'),
#  ('ascend u s market neutral fund bpo ltd',
#   'blackstone partners investment fund l p'),
#  ('blue rock long duration plus fund l p', 'canyon balanced equity fund l p'),
#  ('birchtree financial services llc',
#   'capital research brokerage services llc bd'),
#  ('advanced magnetics inc', 'advanced medical inc'),
#  ('athena capital 2002 l p',
#   'blue point capital partners ii executive fund l p'),
#  ('blackstone credit opportunities fund l p',
#   'blackstone participation partnership cayman v nq l p'),
#  ('aqr style premia emerging bond master account l p',
#   'blue water total return fund i l p'),
#  ('ab high income fund inc', 'battery alternative income fund llc'),
#  ('arden institutional advisers l p', 'camden partners nexus fund l p'),
#  ('adviosrs disciplined trust 1225', 'advisors disciplined trust 54'),
#  ('aristotle fund l p', 'campbell institutional trend fund l p'),
#  ('adelphi europe partners l p',
#   'brazil real estate opportunities fund ii l p'),
#  ('argonaut global equitities partnership l p',
#   'arrowpoint income opportunity fund qp l p'),
#  ('axiom small cap international fund l p',
#   'btg pactual global emerging markets & macro fund llc'),
#  ('ama internatinal equity fund lp', 'capital structures opportunity fund lp'),
#  ('belmont land l p', 'capital preservation fund l p'),
#  ('aew partners l p et al', 'ameridrives international l p'),
#  ('advantage advisers global growth l l c',
#   'advisory research international value fund l p'),
#  ('advisors disciplined trust 284', 'advisors disciplined trust 590'),
#  ('adviosrs disciplined trust 284', 'advisors disciplined trust 641'),
#  ('american income fund i d ltd partnership', 'blue point oeg fund ii l p'),
#  ('attlalus alternative equity fund lp', 'birch creek credit value fund lp'),
#  ('blackrock muniholdings investment quality fund',
#   'blackrock muniyield insured investment fund'),
#  ('alden global distressed opportunities cayman fund l p',
#   'blue water total return fund i l p'),
#  ('apollo real estate advisors iii l p', 'augusta capital management l p'),
#  ('advisors disciplined trust 942', 'advisors disciplined trust series 56'),
#  ('advisors disciplined trust 134', 'advisors disciplined trust 444'),
#  ('blackrock municipal 2020 term trust',
#   'blackrock taxable municipal bond trust'),
#  ('archview offshore fund ltd', 'barnstar opportunities master fund ltd'),
#  ('7advisors disciplined trust 1197', 'advisors disciplined trust series 70'),
#  ('alliance mid cap growth fund inc',
#   'alliancebernstein global technology fund inc'),
#  ('berens distressed opportunities fund ltd',
#   'calypso global opportunities fund ltd'),
#  ('acm emerging markets master fund i l p',
#   'blue rock long duration plus fund l p'),
#  ('american income fund i a ltd partnership', 'blue point oeg fund ii l p'),
#  ('blackstone park avenue non taxable fund l p',
#   'cambria investment management l p'),
#  ('amaranth securities llc bd', 'bayou securities llc'),
#  ('alliancebernstein municipal income fund inc',
#   'andor global offshore fund inc'),
#  ('blackrock muniyield new jersey quality fund inc',
#   'blackrock muniyield quality fund iii inc'),
#  ('a j pace & co inc bd', 'c & c trading inc'),
#  ('ascend offshore fund ltd',
#   'blackrock absolute return partners offshore ltd'),
#  ('belle haven investments l p',
#   'blue vista student housing select strategies fund l p'),
#  ('advisors disciplined trust 645', 'advisors discplined trust 134'),
#  ('bates securities inc bd', 'belfinance securities inc bd'),
#  ('blackstone capital partners vi executive fund l p',
#   'bocage active commodity fund l p'),
#  ('bogle offshore opportunity fund ii ltd', 'canyon grf fund cayman ii ltd'),
#  ('american securities opportunities fund iii b l p',
#   'ares capital europe l p'),
#  ('apm equity long short fund l p',
#   'aqr risk managed buywrite master account l p'),
#  ('blackrock dividend achievers trust',
#   'blackrock global floating rate income trust'),
#  ('advisory research international value fund l p',
#   'bernstein global opportunities hedge fund l p'),
#  ('aqueous master fund l p', 'bailard emerging opportunities fund i l p'),
#  ('blackrock municipal income trust iii',
#   'blackrock new york insured municipal income trust'),
#  ('blackrock capital structure investments fund ltd',
#   'brigade leveraged capital structures fund ltd'),
#  ('apollo real estate capital advisors iii l p',
#   'campbell classic trend fund l p'),
#  ('aqr volatility enhanced s&p 500 fund l p',
#   'area european real estate fund iv l p'),
#  ('altegris global macro ii fund l p',
#   'aqr tax plus global relaxed constraint equity fund l p'),
#  ('barlow partners fundamental managers l p',
#   'btg pactual global emerging markets & macro fund l p'),
#  ('amidee 2006 iii tax deed real estate investment program ltd',
#   'bear stearns asset backed securities trust 2003 abf1'),
#  ('advisors disciplined trust 587', 'advisors discplined trust 136'),
#  ('area real estate opportunity fund vi lp',
#   'bailard biehl & kaiser real estate investment trust inc'),
#  ('audobon securities inc', 'brandywine securities inc bd'),
#  ('blackrock muniholdings insured fund ii inc',
#   'blackrock muniyield california quality fund inc'),
#  ('across america real estate development corp',
#   'bailard real estate investment trust i inc'),
#  ('abn amro asset management holdings inc',
#   'aim private asset management inc'),
#  ('blackrock muniyield insured fund inc',
#   'blackrock muniyield michigan quality fund ii inc'),
#  ('bacher & co inc bd', 'bernstein sanford c & co inc'),
#  ('ascend market neutral fund l p',
#   'blackstone family investment partnership cayman v nq l p'),
#  ('berger growth & income fund inc',
#   'blackrock capital & income strategies fund inc'),
#  ('acm emerging markets master fund i l p', 'adage capital partners gp l l c'),
#  ('avenue europe investments l p', 'avenue investments l p'),
#  ('arden institutional advisers l p',
#   'arrowmark fundamental opportunity fund l p'),
#  ('armetis investment management llc',
#   'bridgewater investment management llc'),
#  ('acacia pledge capital l p',
#   'alphasimplex quantitative global macro fund l p'),
#  ('american securities opportunities fund ii lp',
#   'barlow partners fundamental managers l p'),
#  ('american income fund i b', 'beta capital management l p'),
#  ('advisors disciplined trust 284', 'advisors disciplined trust 61'),
#  ('area european real estate fund iv l p',
#   'axiom investors trust axiom u s small cap equity portfolio'),
#  ('altegris global macro ii fund l p', 'banyan investment fund l p'),
#  ('banc fund iv l p', 'canyon value realization fund l p'),
#  ('affinity investment partners l p', 'blackstone park avenue fund l p'),
#  ('blackstone capital partners vi executive fund l p',
#   'blue rock core fixed income portable alpha fund ii l p'),
#  ('american income fund i e ltd partnership',
#   'blackstone capital partners vi executive fund l p'),
#  ('blackstone family investment partnership delaware v nq l p',
#   'brazil real estate opportunities fund ii l p'),
#  ('alexander capital l p', 'aristotle fund l p'),
#  ('advisors disciplined trust 1262', 'advisors disciplined trust 683'),
#  ('amb u s logistics fund holdings l p', 'blackstone topaz fund l p'),
#  ('blue rock capital fund ii l p', 'breeden partners california l p'),
#  ('ag diversified income fund plus l p', 'blue rock equity plus fund l p'),
#  ('aqueous master fund l p', 'blue vista student housing v l p'),
#  ('advisors disciplined trust series 76', 'advisors discplined trust 134'),
#  ('americal securities inc bd', 'bba icatu securities inc'),
#  ('administrative committee of longs drug stores ca espsp',
#   'baring advisor series llc multi employer global aggregate diversified portfolio'),
#  ('aew capital management l p',
#   'blackstone madison avenue offshore fund ltd class a b c & g shares'),
#  ('bailard emerging opportunities fund i l p',
#   'camden partners exelixis fund l p'),
#  ('alden global opportunities fund cayman l p',
#   'bernstein global opportunities hedge fund l p'),
#  ('alliance emerging market debt fund inc',
#   'blackrock developing capital markets fund inc'),
#  ('biotechnology value fund l p et al', 'breitburn energy partners l p'),
#  ('bradley woods & co ltd', 'bush odonnell & co inc'),
#  ('alden global distressed opportunities cayman fund l p',
#   'bogle opportunity fund ii sri l p'),
#  ('advisory research opportunities fund l p',
#   'bailard emerging life sciences fund i l p'),
#  ('advisors disciplined trust 1262', 'advisors discplined trust 134'),
#  ('arc real estate income fund', 'autonomy real estate fund iii'),
#  ('aqr tax plus u s hedged equity fund l p',
#   'bowman capital management l l c'),
#  ('adria partners l p', 'camcap energy l p'),
#  ('axiom investors trust ii axiom u s small cap equity portfolio',
#   'banc fund iv l p'),
#  ('bgi us dollar enhanced libor bond fund ltd',
#   'canyon balanced equity fund cayman ltd'),
#  ('blackstone capital partners vi executive fund l p',
#   'bogle opportunity fund ii sri l p'),
#  ('banc of america capital management sbic llc',
#   'banc of america finance services inc'),
#  ('blackstone advisory partners l p', 'capital preservation fund l p'),
#  ('advantage advisers catalyst partners l p',
#   'bp capital energy equity fund international i l p'),
#  ('aqr style premia emerging bond master account l p',
#   'blue rock equity plus fund l p'),
#  ('aqr global asset allocation instituitonal fund ii l p',
#   'blackstone fifth avenue offshore fund ltd class a d f k & l shares'),
#  ('advisors disciplined trust 68', 'advisors disciplined trust series 69'),
#  ('bridgescale partners l p', 'brightfield partners l p'),
#  ('americredit automobile receivables trust 2004 a f',
#   'capital auto finance trust 2002 c'),
#  ('advisory research global all cap fund l p',
#   'aqr trend following master account l p'),
#  ('aberon capital fund ii l p', 'breeden partners new york i l p'),
#  ('apollo credit short opportunities fund l p', 'bain capital europe l p'),
#  ('afa emerging manager platform llc arbitroption series',
#   'allianzgi structured alpha multi beta series llc i international equity series'),
#  ('blackrock muniyield florida insured fund',
#   'blackrock muniyield new jersey insured fund inc'),
#  ('advisors disciplined trust 437', 'advisors disciplined trust 59'),
#  ('adage capital partners gp l l c',
#   'blackstone participation partnership delaware v nq l p'),
#  ('advisors disciplined trust 137', 'advisors disciplined trust 57'),
#  ('acadian global market neutral fund llc',
#   'calamos global diversified income & opportunities fund'),
#  ('blue horizon foods inc', 'brown bridge industries inc tx'),
#  ('aqr tax advantaged global equity market neutral fund l p',
#   'avalon advisors l p'),
#  ('ares capital europe l p', 'blue rock all asset plus fund l p'),
#  ('blackrock credit allocation income trust ii',
#   'blackrock global equity income trust'),
#  ('acacia pledge capital l p', 'blackstone park avenue non taxable fund l p'),
#  ('advisors disciplined trust 1197', 'advisors disciplined trust series 64'),
#  ('arden strategic advisers l p', 'ascend u s market neutral fund l p'),
#  ('auldbrass partners secondary opportunity fund l p',
#   'berens distressed opportunities fund l p'),
#  ('aqr style premia emerging bond master account l p',
#   'btg pactual global emerging markets & macro fund l p'),
#  ('alger separate account a of voya insurance & annuity co',
#   'allmerica select sep acct of 1st allmerica fin life ins co'),
#  ('ag super fund international partners l p',
#   'alex brown investment management l p'),
#  ('advantage advisers technology partners l l c',
#   'axiom investors trust axiom u s small cap equity portfolio'),
#  ('aqr trend following master account l p',
#   'basswood financial enhanced fund l p'),
#  ('aqr volatility enhanced s&p 500 fund l p',
#   'blackstone madison avenue fund l p'),
#  ('bcm credit opportunities fund lp', 'broadfin helathcare fund lp'),
#  ('blackstone madison avenue offshore fund ltd class a b c & g shares',
#   'blackstone sers customized fund l p'),
#  ('allegiance capital llc bd', 'aurum capital llc'),
#  ('aew capital management l p', 'barlow partners fundamental managers l p'),
#  ('aqr tax plus u s relaxed constraint equity fund l p',
#   'blackstone sers customized fund l p'),
#  ('arrowstreet emerging market fund iii a sub fund of arrowstreet multi strategy umbrella fund plc',
#   'cais esg cross boarder equity fund llc'),
#  ('amb fund iii holdings l p',
#   'aqr global asset allocation instituitonal fund ii l p'),
#  ('birch creek rmbs value fund l p', 'brahman institutional partners l p'),
#  ('blackrock muniholdings quality fund inc',
#   'blackrock muniyield pennsylvania quality fund'),
#  ('acm emerging markets multi strategy fund i lp',
#   'blue water total return fund i l p'),
#  ('andor capital management l l c',
#   'brazil real estate opportunities fund ii l p'),
#  ('alternative investments institutional l p',
#   'brookwood securities partners l p'),
#  ('ascend u s market neutral fund ltd', 'blackstone capital partners vi l p'),
#  ('advisory research small cap value fund lp',
#   'ba sometros market neutral fund lp'),
#  ('alphasimplex quantitative global macro fund l p',
#   'caldera equity fund l p'),
#  ('advisors disciplined trust series 46',
#   'advisors disciplined trust series 61'),
#  ('alexander capital l p', 'ascribe opportunities fund iii l p'),
#  ('alliance international premier growth fund inc',
#   'andor global offshore fund inc'),
#  ('aei securities inc', 'austin securities inc bd'),
#  ('bailard emerging life scineces fund i l p', 'blr capital partners l p'),
#  ('atlas america public #14 2005 a l p',
#   'bear stearns as bckd sec inc hm eq ln bckd term nt sr 1999 1'),
#  ('bull & bear brokerage services inc',
#   'bull & bear municipal income fund inc'),
#  ('america first real estate investment partners l p',
#   'athena equity 2002 l p'),
#  ('area european real estate fund iv l p',
#   'argonaut global equities partnership l p'),
#  ('arden strategic advisers l p', 'cambria investment management l p'),
#  ('aqr style premia fund l p', 'bailard emerging opportunities fund i l p'),
#  ('angelo gordon & co lp', 'campbell & co lp de'),
#  ('allmerica select sep acct of 1st allmerica fin life ins co',
#   'axa rosenberg all county world intitutional fund llc'),
#  ('aberdeen global diversified fixed income fund inc',
#   'alliancebernstein unconstrained bond fund inc'),
#  ('andor capital management l l c', 'campbell global trend fund l p'),
#  ('alliancebernstein high yield fund inc',
#   'alliancebernstein worldwide privatization fund inc'),
#  ('asset backed securities i trust 2005 he10',
#   'capital one auto finance trust 2001 b'),
#  ('aberdeen global diversified fixed income fund inc',
#   'alliancebernstein health care fund inc'),
#  ('allianz global investors capital total return trust',
#   'capital guardian all country world equity fd tax exem tr'),
#  ('ariel capital management llc', 'bolton asset management llc'),
#  ('altegris equity long short fund l p',
#   'beacon capital strategic partners vi l p'),
#  ('aberon capital fund ii l p', 'aew capital management l p ma'),
#  ('algebris global financials fund l p', 'bogle opportunity fund ii sri l p'),
#  ('advisory research global opportunities fund l p',
#   'blackstone madison avenue offshore fund ltd class a b c & g shares'),
#  ('blackstone partners offshore fund ltd class e f i j & k shares',
#   'blackstone sers customized fund l p'),
#  ('biomedical value fund l p', 'blackstone credit opportunities fund l p'),
#  ('abacus impact fund 2013 l p', 'blackstone emerging markets fund i l p'),
#  ('american express west equity fund l p',
#   'bernstein global opportunities hedge fund l p'),
#  ('bodleian partners a l p', 'camcap energy l p'),
#  ('alliance international premier growth fund inc',
#   'alliancebernstein municipal income fund inc'),
#  ('affinity venture iii l p', 'aimco properties l p'),
#  ('advisory research opportunities fund l p',
#   'blackstone madison avenue fund l p'),
#  ('advisors disciplined trust 55', 'advisors disciplined trust series 20'),
#  ('bernstein global diversified hedge fund l p',
#   'blackstone sixth avenue offshore fund ltd class a b c k & l shares'),
#  ('aberdeen global credit strategies fund inc',
#   'alliancebernstein large cap growth fund inc'),
#  ('blackstone family investment partnership cayman v nq l p',
#   'blue rock capital fund ii l p'),
#  ('axiom investors trust axiom u s small cap equity portfolio',
#   'basswood opportunity partners liquidating fund l p'),
#  ('alliance north american government income tru inc',
#   'alliancebernstein global small cap fund inc'),
#  ('aqr volatility enhanced u s large cap equity fund l p',
#   'ascribe opportunities fund ii b lp'),
#  ('beacon rock multi strategy fund llc',
#   'campbell institutional multi strategy investment fund ltd'),
#  ('blackstone sers customized fund l p', 'bogle opportunity fund ii sri l p'),
#  ('allen test & snow removal co inc', 'allen test co name change test'),
#  ('7advisors disciplined trust 1197', 'advisors disciplined trust 55'),
#  ('blackstone capital partners cayman nq v ac l p',
#   'brookfield renewable energy partners l p'),
#  ('avenue europe investments l p',
#   'blue rock core fixed income portable apha fund ii l p'),
#  ('blackstone topaz fund l p', 'candela capital l p'),
#  ('auldbrass partners secondary opportunity fund l p',
#   'brevan howard systematic trading fund l p'),
#  ('atlas america series 25 2004 b l p', 'atlas america series 27 2006 l p'),
#  ('allen & company of florida inc', 'burch & company inc'),
#  ('birch creek rmbs value fund l p',
#   'blue rock core fixed income portable apha fund ii l p'),
#  ('braeside capital l p', 'camelot capital l p'),
#  ('aurora financial services llc bd', 'campbell financial services inc'),
#  ('ascend offshore leveraged fund ltd',
#   'blackrock absolute return partners ltd'),
#  ('barker partnership l p', 'bridgescale partners l p'),
#  ('acuitas emerging markets small cap fund lp',
#   'bluecrest mercantile fund lp'),
#  ('berens distressed opportunities fund l p', 'blr capital partners l p'),
#  ('aton securities inc', 'barrett securities inc'),
#  ('alliancebernstein small mid cap growth fund',
#   'andor global offshore fund inc'),
#  ('brazil real estate opportunities fund ii amazonas brl l p',
#   'candela capital l p'),
#  ('apollo value investment fund lp',
#   'boston co long short opportunistic equity fund lp'),
#  ('abs global long short asp fund a series of alternative strategies platform llc',
#   'atlas energy for the ninties public no 5 ltd'),
#  ('babson capital securities llc', 'berkshire capital securities llc'),
#  ('belle haven investments l p', 'breeden partners california l p'),
#  ('blue rock capital fund ii l p', 'caldera equity fund l p'),
#  ('acm emerging markets multi strategy fund i lp',
#   'axiom investors trust axiom u s small cap equity portfolio'),
#  ('ag growth capital partners i annex fund l p',
#   'benchmark plus institutional partners l l c'),
#  ('bluecrest capital l p', 'bogle opportunity fund ii l p'),
#  ('american fidelity financial services inc',
#   'callahan financial services inc'),
#  ('ascend market neutral fund l p',
#   'barlow partners fundamental managers l p'),
#  ('akana capital fund lp', 'blackstone market opportunities fund lp'),
#  ('alex moore & co inc bd', 'bigelow & co bd'),
#  ('advisory research global all cap fund l p',
#   'blackstone advisory partners l p'),
#  ('ag super fund international partners l p',
#   'american income fund i a ltd partnership'),
#  ('adelphi europe partners l p', 'brookwood securities partners l p'),
#  ('50 south capital buyout fund vi l p',
#   'argonaut global equitities partnership l p'),
#  ('blackstone firestone transaction participation cayman l p',
#   'campbell financial futures fund l p'),
#  ('beta capital management l p',
#   'blackstone park avenue non taxable fund l p'),
#  ('adviosrs disciplined trust 587', 'advisors disciplined trust series 57'),
#  ('align impact fund l p', 'andor capital management l l c'),
#  ('alternative investments l p', 'brookfield renewable partners l p'),
#  ('advisory research global all cap fund l p', 'berens capital partners l p'),
#  ('aqr real return fund ii l p', 'biotechnology value fund l p et al'),
#  ('aqueous master fund l p series i',
#   'arden institutional advisers ii ms feeder l p'),
#  ('ag energy partners extension fund l p',
#   'ag private equity iv annex fund l p'),
#  ('altura nelson & co inc', 'brockett tamny & co inc bd'),
#  ('american securities opportunities fund iii b l p',
#   'area european real estate fund iv l p'),
#  ('alliance all asia investment fund inc',
#   'alliancebernstein disciplined value fund inc'),
#  ('adelphi emerging europe partners l p',
#   'blackstone madison avenue offshore fund ltd class a b c & g shares'),
#  ('bain capital europe l p', 'banc fund iv l p'),
#  ('blackstone partners offshore fund ltd class e f i j k q & r shares',
#   'blue rock long duration plus fund l p'),
#  ('aqr global asset allocation instituitonal fund ii l p',
#   'basswood capital management l l c'),
#  ('arden strategic advisers l p', 'athena equity 2002 l p'),
#  ('7x7 institutional partners l p', 'abry partners vi l p'),
#  ('american income fund i d', 'argonaut macro partnership l p'),
#  ('arden institutional advisers ii ms feeder l p',
#   'blackstone pacific opportunities fund l p'),
#  ('afsg securities corp bd', 'bullaro securities corp bd'),
#  ('aberon capital fund ii l p',
#   'american securities opportunities fund iii l p'),
#  ('abacus impact fund 2013 l p',
#   'axiom investors trust ii axiom u s small cap equity portfolio'),
#  ('american securities opportunities fund ii b lp',
#   'blackstone corporate opportunities master fund l p'),
#  ('anthion master fund l p', 'apm paulson advantage plus fund l p'),
#  ('american income fund i e', 'ascend partners leveraged fund l p'),
#  ('abn amro mort corp multi class mort pas thr certs ser 2003 5',
#   'bank of america mort sec inc mort pas thr certs ser 2001 h'),
#  ('asia alternatives capital partners iii l p', 'auda capital v us lp'),
#  ('algebris global financials fund l p', 'arden strategic advisers l p'),
#  ('access financial group inc bd', 'asia pacific financial management group'),
#  ('blackburn & co inc bd', 'campbell & co lp ta'),
#  ('allen & co inc bd', 'bengur bryan & co inc bd'),
#  ('advantage advisers catalyst partners l p',
#   'ares european real estate fund iv l p'),
#  ('arklow partners l p', 'buckland partners l p'),
#  ('basswood financial long only fund l p', 'biotechnology value fund l p'),
#  ('acm emerging markets fund i lp', 'adelphi europe partners l p'),
#  ('abry partners v l p', 'caiman partmers l p'),
#  ('amresco residential sec corp mort loan tr 1996 5',
#   'bear stearns ast bck sec inc madison ave trust 2002 a'),
#  ('alliancebernstein global health care fund inc',
#   'alliancebernstein global technology fund inc'),
#  ('alden global distressed opportunities cayman fund l p',
#   'broadmark long short full exposure l p'),
#  ('alliance all asia investment fund inc',
#   'alliancebernstein international premier growth fund inc'),
#  ('axiom international micro cap fund lp', 'bcmcredit opportunities fund lp'),
#  ('arbitrage assoociates l p', 'brep international ii q gp l p'),
#  ('alliancebernstein pooling portfolios', 'alliancebernstein portfolios'),
#  ('archview master fund ltd', 'arrowpoint global opportunity fund ii lp'),
#  ('ascend u s market neutral fund bpo ltd',
#   'bocage active commodity fund l p'),
#  ('aqr style premia fund l p', 'baochuan black dragon fund l p'),
#  ('alliance americas government income trust inc',
#   'alliancebernstein cap fund inc'),
#  ('aqr global asset allocation offshore fund usd ii ltd',
#   'blackrock us dollar enhanced libor bond fund ltd'),
#  ('bailard emerging life sciences fund i l p',
#   'bp capital energy equity fund international i lp'),
#  ('bernstein global opportunities hedge fund l p',
#   'bogle opportunity fund ii l p'),
#  ('calvert investment management inc', 'capital management partners inc bd'),
#  ('arden institutional advisers ii l p', 'breeden partners new york i l p'),
#  ('blue point capital partners ii executive fund l p',
#   'caldera equity fund l p'),
#  ('aew partners l p', 'barker partnerhip l p'),
#  ('am oppenheimer securities inc bd', 'bradesco securities inc bd'),
#  ('advanta revolving home equity loan tr as bk notes ser 2000 a',
#   'bank of america mort sec inc mort pass thr cert er 2002 2'),
#  ('aqueous master fund l p series i', 'ascribe opportunities fund iii b l p'),
#  ('capital group emerging markets equity common trust us',
#   'capital group emerging markets total opportunities fund'),
#  ('ameriprise financial services inc', 'btmu financial services inc'),
#  ('arden institutional advisers l p',
#   'arrowpoint fundamental opportunity fund l p'),
#  ('acquisitor holdings ltd', 'berggruen freedom holdings ltd'),
#  ('adviosrs disciplined trust 1225', 'advisors disciplind trust 641'),
#  ('advisors disciplined trust 206', 'advisors disciplined trust series 57'),
#  ('augusta capital management l p', 'blackstone sers customized fund l p'),
#  ('abner herrman & brock inc', 'campbell newman pottinger & associates inc'),
#  ('blackgold opportunities offshore fund ltd',
#   'bogle offshore opportunity fund i ltd'),
#  ('ares capital europe l p',
#   'blue point capital partners ii executive fund l p'),
#  ('7x7 institutional partners l p', 'adria partners l p'),
#  ('align impact fund l p',
#   'blackstone sixth avenue offshore fund ltd class a b c & k shares'),
#  ('aim equity funds', 'aim investment securities funds'),
#  ('bluecrest emerging markets ltd',
#   'calamos arista strategic master fund ltd'),
#  ('asco healthcare of new england inc',
#   'bank of nova scotia trust co of new york ta'),
#  ('ascend u s market neutral fund bpo ltd', 'belmont land l p'),
#  ('bodington & co', 'bueter & co inc bd'),
#  ('blackrock insured municipal income investment trust',
#   'blackrock new york insured municipal income trust'),
#  ('beloyan investment securities inc', 'capital one securities inc'),
#  ('ab mortgage securities corp', 'bankamerica mortgage securities inc'),
#  ('aqueous fund l p series 1', 'ares european real estate fund iv l p'),
#  ('alden global distressed opportunities cayman fund l p',
#   'aristotle fund l p'),
#  ('americas senior financial services inc',
#   'campbell financial services inc bd'),
#  ('alliancebernstein emerging market debt fund inc',
#   'bluecrest emerging markets ltd'),
#  ('advisors disciplined trust 60', 'advisors discplined trust 134'),
#  ('advisors disciplind trust 641', 'advisors discliplined trust series 19'),
#  ('alpine associates l p', 'brep international ii q gp l p'),
#  ('augusta capital management l p',
#   'bernstein global opportunities hedge fund l p'),
#  ('administrative committee of longs drug stores ca 401k plan',
#   'aig multi strategy fund of funds llc'),
#  ('artha emerging markets fund l p', 'basswood capital management l l c'),
#  ('aqr volatility enhanced s&p 500 fund l p',
#   'birch creek rmbs value fund l p'),
#  ('ark multi manager fund l p', 'blue bell country club l p'),
#  ('benchmark capital management co llc', 'capital planning group llc bd'),
#  ('arklow partners l p', 'bodleian partners a l p'),
#  ('alger separate account a of voya insurance & annuity co',
#   'benefit street partners senior secured debt fund non us l p'),
#  ('acm emerging markets fund i lp',
#   'barlow partners fundamental managers l p'),
#  ('aletheia securities inc bd', 'bdirect securities inc ok bd'),
#  ('birch creek rmbs value fund l p', 'camden partners nexus fund l p'),
#  ('broad run associates l p', 'canyon balanced fund l p'),
#  ('blackrock ltd duration income trust',
#   'blackrock multi sector income trust'),
#  ('asset holder pcc 2 ltd re ashmore emerging economy port',
#   'blackrock multi strategy u s institutional fund ltd'),
#  ('axa rosenberg us enhanced index institutional fund llc',
#   'benefit street partners special situations fund cayman l p'),
#  ('affinity investment partners l p',
#   'alden global distressed opportunities fund cayman l p'),
#  ('agic international & premium strategy fund',
#   'aurora global opportunities ii asp fund a series of alternative strategies platform llc'),
#  ('american securities opportunities fund ii b lp',
#   'aqr tax advantaged global equity market neutral fund l p'),
#  ('bennett restructuring fund l p', 'candela capital l p'),
#  ('bernstein global opportunities hedge fund l p',
#   'brookfield renewable partners l p'),
#  ('7x7 institutional partners l p', 'barker partnership l p'),
#  ('blackstone firestone transaction participation cayman l p',
#   'bp capital energy equity fund international i lp'),
#  ('apm paulson advantage plus fund l p',
#   'brookfield renewable energy partners l p'),
#  ('augustus mjk offshore fund ltd',
#   'broadmark dynamic enhanced equity alpha fund ltd'),
#  ('blackstone event driven fund l p',
#   'blackstone pacific opportunities master fund l p'),
#  ('asia pacific associates iii ltd', 'blackrock asia pacific partners ltd'),
#  ('banco la hiptecaria s a',
#   'banco venezolano de credito s a banco universal fi'),
#  ('aqr style premia emerging bond master account l p', 'candela capital l p'),
#  ('affinity investment partners l p', 'ascribe opportunities fund iii b l p'),
#  ('aberdeen global credit strategies fund inc',
#   'alliancebernstein global risk allocation fund inc'),
#  ('birch run capital partners l p', 'blue rock equity plus fund l p'),
#  ('a g vonley center inc', 'a l pharma inc'),
#  ('adelphi emerging europe partners l p',
#   'brahman institutional partners l p'),
#  ('aberon capital fund ii l p',
#   'blackstone capital partners vi executive fund l p'),
#  ('apm equity long short fund l p', 'canyon value realization fund l p'),
#  ('alliance new europe fund inc',
#   'alliancebernstein international growth fund inc'),
#  ('acm emerging markets master fund i l p',
#   'advisory research global all cap fund l p'),
#  ('alexandra investment management llc', 'bencmark capital management co llc'),
#  ('advanta revolving home equity loan tr as bk notes ser 2000 a',
#   'asset securitization corp com mor pas thr cer ser 1997 mdv11'),
#  ('advantage advisers technology partners l l c',
#   'blue rock emerging manager fund l p'),
#  ('broad run associates l p', 'broadmark long short equity fund l p'),
#  ('andro capital l p', 'area european real estate fund iv l p'),
#  ('alloy global fund l p',
#   'bp capital energy equity fund international i l p'),
#  ('barrow hanley mewhinney & strauss llc', 'belden & blake energy co'),
#  ('astoria capital markets inc', 'boston capital services inc'),
#  ('blackstone madison avenue fund l p',
#   'blackstone sixth avenue offshore fund ltd class a b c & k shares'),
#  ('alliancebernstein cap fund inc',
#   'brookfield global listed infrastructure income fund inc'),
#  ('advisors disciplined trust series 67', 'advisors discplined trust 140'),
#  ('alden global emerging markets fund i l p',
#   'blackstone sers customized fund l p'),
#  ('basix capital fund lp', 'brigade opportunistic credit fund iconiq lp'),
#  ('advantage advisers technology partners l l c', 'banc fund iv l p'),
#  ('ag energy partners extension fund l p',
#   'blackstone market opportunities fund l p'),
#  ('aqr volatility enhanced s&p 500 fund l p',
#   'blackstone partners investment fund l p'),
#  ('atap financial services inc bd', 'benchmark financial services inc fl bd'),
#  ('blackstone hedged equity fund lp', 'broadfin healthcare fund lp'),
#  ('area european real estate fund iv l p',
#   'blackstone participation partnership delaware v nq l p'),
#  ('advisory research international value fund l p',
#   'blackstone advisory partners l p'),
#  ('blackstone fifth avenue offshore fund ltd class a d f k & l shares',
#   'bluecrest mercantile fund l p'),
#  ('blackstone park avenue non taxable fund l p', 'blue rock capital fund l p'),
#  ('banc fund iv l p', 'blackstone emerging markets fund l p'),
#  ('aew capital management l p ma', 'boyle capital management l l c'),
#  ('adage capital partners gp l l c',
#   'aqr global asset allocation instituitonal fund ii l p'),
#  ('aqr style premia emerging bond master account l p',
#   'blackstone partners offshore fund ltd class e f g i j k q & r shares'),
#  ('blackrock diamond property inc', 'blackrock focus twenty fund inc'),
#  ('ameridrives international l p', 'arbitrage associates l p'),
#  ('adams diversified equity fund inc', 'buffalo premium income fund inc'),
#  ('ag private equity iv annex fund l p', 'breeden partners new york i l p'),
#  ('alexander capital l p', 'blue water total return fund i l p'),
#  ('american securities opportunities fund iii b l p',
#   'blackstone event driven fund l p'),
#  ('alliance international fund inc',
#   'brookfield global listed infrastructure income fund inc'),
#  ('acuitas long short fund lp', 'bailard long short offshore fund ltd'),
#  ('advisors disciplined trust 508', 'advisors disciplined trust series 67'),
#  ('birch creek rmbs value fund l p',
#   'blackstone family investment partnership cayman v nq l p'),
#  ('america first multifamily investors l p',
#   'arden institutional advisers ii ms feeder l p'),
#  ('avalon advisors l p',
#   'blackstone partners offshore fund ltd class e f i j k q & r shares'),
#  ('basswood opportunity partners l p',
#   'bernstein global diversified hedge fund l p'),
#  ('american income fund i e ltd partnership', 'belle haven investments l p'),
#  ('advisory research opportunities fund l p',
#   'alphashares black dragon fund l p'),
#  ('american independence financial services llc',
#   'amstar financial services inc'),
#  ('advisors disciplined trust 1225', 'advisors disciplined trust adt 1279'),
#  ('bogle opportunity fund l p', 'canyon balanced equity fund l p'),
#  ('affinity investment parters l p',
#   'america first real estate investment partners l p'),
#  ('acn securities inc', 'ancora securities inc'),
#  ('apm global macro ii fund l p', 'bocage active commodity fund l p'),
#  ('apollo real estate capital advisors iii l p',
#   'arrowmark income opportunity fund qp l p'),
#  ('american income fund i b ltd partnership',
#   'bailard emerging life scineces fund i l p'),
#  ('american income fund i b', 'blackpier market neutral fund l p'),
#  ('american benefits & compensation securities corp',
#   'american financial group inc 401 k retirement & savings plan'),
#  ('american securities opportunities fund ii b lp',
#   'aqueous fund l p series i'),
#  ('advisors disciplined trust 587', 'advisors disciplined trust 60'),
#  ('aberon capital fund ii l p',
#   'bp capital energy equity fund international i lp'),
#  ('american financial group inc oh', 'bg financial group inc'),
#  ('amman robert j', 'blackwell roger j'),
#  ('barlow partners fundamental managers l p', 'berens capital partners l p'),
#  ('alphashares black dragon fund l p', 'beta capital management l p'),
#  ('blackstone pacific opportunities fund lp',
#   'blackstone partners investment fund lp'),
#  ('axa equitable financial services llc',
#   'capital research brokerage services llc bd'),
#  ('basso capital management l p', 'beacon capital strategic partners vi l p'),
#  ('adviosrs disciplined trust 802', 'advisors disciplined trust 134'),
#  ('allianz global investors capital total return trust',
#   'capital guardian emerging markets debt fund for tax exempt trusts'),
#  ('acm emerging markets fund i lp',
#   'american income fund i d ltd partnership'),
#  ('allen c ewing & co', 'c m bidwell & associates ltd'),
#  ('acm emerging markets fund i lp', 'andor capital management l l c'),
#  ('amb fund iii holdings l p', 'cambria investment management l p'),
#  ('aqr risk managed buywrite master account l p',
#   'artha emerging markets fund l p'),
#  ('blackstone market opportunities fund lp', 'bsp absolute fund of funds lp'),
#  ('andro capital l p', 'ascend partners leveraged fund l p'),
#  ('alpha equity multi strategy offshore fund ltd',
#   'aqr offshore multi strategy fund aud ltd'),
#  ('basswood opportunity partners l p', 'blackstone event driven fund l p'),
#  ('abundant power securities llc', 'bonds direct securities llc'),
#  ('ag energy partners extension fund l p',
#   'boston partners asset management l p'),
#  ('advisors disciplined trust 55', 'advisors disciplined trust 73'),
#  ('bocage active commodity long fund l p',
#   'boston partners asset management l p'),
#  ('alphashares black dragon fund l p',
#   'barlow partners fundamental managers l p'),
#  ('acm emerging markets fund i lp', 'cambria investment management l p'),
#  ('boston partners asset management llc', 'cadian capital management lp'),
#  ('ag energy partners ii l p', 'calypso ventures ii l p'),
#  ('alternative investments l p', 'blue rock fixed income plus fund l p'),
#  ('alternative investments l p', 'apm global macro fund l p'),
#  ('blackrock diamond property fund inc',
#   'blackrock muniholdings california insured fund inc'),
#  ('blue rock equity plus fund l p', 'caldera equity fund l p'),
#  ('breeden partners new york i l p', 'broad run associates l p'),
#  ('american express west equity fund l p', 'blue harbour group l p'),
#  ('blackstone pacific opportunities master fund l p',
#   'canyon balanced equity fund l p'),
#  ('blue rock all asset plus fund l p',
#   'blue vista student housing select strategies fund l p'),
#  ('advisors disciplined trust 942', 'advisors disciplined trust series 50'),
#  ('advisors disciplined trust 138', 'advisors discplined trust 845'),
#  ('advisors disciplined trust 65', 'advisors disciplined trust adt 1279'),
#  ('blackrock florida municipal 2020 term trust',
#   'blackrock municipal target term trust'),
#  ('alex brown investment management l p', 'blackstone fifth avenue fund l p'),
#  ('aqr small cap value fund l p', 'augusta capital management l p'),
#  ('apm paulson advantage plus fund l p',
#   'berens credit opportunities fund l p'),
#  ('blackrock california municipal 2020 term trust',
#   'blackrock municipal 2022 term trust'),
#  ('akana capital fund lp', 'basix capital fund lp'),
#  ('afg investment partners iv l p', 'brahman partners iv l p'),
#  ('actinver securities inc bd', 'ark securities co inc bd'),
#  ('advantage advisers technology partners l l c',
#   'arden institutional advisers ii l p'),
#  ('area european real estate fund iv l p',
#   'blue rock emerging manager fund l p'),
#  ('berens distressed opportunities fund l p', 'blue bell country club l p'),
#  ('american income fund i e ltd partnership',
#   'axa re arizona co f k a financial bermuda ltd'),
#  ('blackstone credit opportunities fund l p',
#   'blackstone sers customized fund l p'),
#  ('alliance premier growth fund inc',
#   'alliancebernstein global growth trends fund inc'),
#  ('bessemer investor services inc bd', 'callaway financial services inc bd'),
#  ('aew partners l p', 'camcap energy l p'),
#  ('attlalus alternative equity fund lp', 'broadfin helathcare fund lp'),
#  ('amaranth securities l l c', 'brahman c p f partners l p'),
#  ('ar asset managment inc', 'asset management fund inc'),
#  ('alupka absolute return fund lp', 'brar investment fund lp'),
#  ('bailard long short accredited investor fund lp',
#   'bailard long short onshore fund lp'),
#  ('american express west equity fund l p', 'avenue capital management ii l p'),
#  ('bernstein global opportunities hedge fund lp',
#   'bluecrest emerging markets fund lp'),
#  ('axiom investors trust ii axiom u s small cap equity portfolio',
#   'campbell institutional trend fund l p'),
#  ('aqueous fund l p series 1', 'blackstone customized commodities fund l p'),
#  ('altegris equity long short fund l p',
#   'blackstone capital partners vi executive fund l p'),
#  ('anthem ventures fund l p', 'bogle opportunity fund ii sri l p'),
#  ('aqueous fund l p', 'blackstone hedged equity fund l p'),
#  ('a b financial llc bd', 'a b watley inc'),
#  ('acacia partners l p', 'affinity venture iii l p'),
#  ('advisors disciplined trust 587', 'advisors disciplined trust 59'),
#  ('alliance fund inc',
#   'brookfield global listed infrastructure income fund inc'),
#  ('altegris paulson advantage plus fund l p',
#   'aqr tax plus global market neutral equity fund l p'),
#  ('7advisors disciplined trust 1197', 'advisors disciplined trust508'),
#  ('acm emerging markets master fund i l p',
#   'ascribe opportunities fund iii l p'),
#  ('affinity investment partners l p',
#   'argonaut global equitities partnership l p'),
#  ('auerbach grayson & co inc', 'bateman eichler & co llc bd'),
#  ('aberon capital fund ii l p', 'alden global opportunities fund cayman l p'),
#  ('axa re arizona co f k a financial bermuda ltd',
#   'birch run capital partners l p'),
#  ('basswood opportunity partners liquidating fund l p',
#   'blue rock capital fund l p'),
#  ('basix capital fund l p', 'blackstone madison avenue fund l p'),
#  ('alliancebernstein global growth trends fund inc',
#   'alliancebernstein new europe fund inc'),
#  ('bhirud associates inc', 'bouchey & associates inc'),
#  ('alliancebernstein large cap growth fund inc',
#   'brookfield investment management global infrastructure income fund inc'),
#  ('apollo real estate advisors iii l p', 'blackstone topaz fund l p'),
#  ('birch run capital partners l p', 'blackstone fifth avenue fund l p'),
#  ('alloy global fund l p', 'athene asset management l p'),
#  ('ascribe opportunities fund iii b l p',
#   'blackstone emerging markets fund l p'),
#  ('american general mrt ln asst bckd ps thr crts sr 2003 1',
#   'atlas america public #15 2005 a l p'),
#  ('advisors disciplined trust series 70',
#   'advisors disciplined trust series 73'),
#  ('advisoty research small cap value fund ii lp',
#   'canyon value realization fund lp'),
#  ('advisors disciplined trust 1081', 'advisors disciplined trust 55'),
#  ('aci capital america fund lp', 'bsp absolute return fund of funds lp'),
#  ('ari financial services inc', 'birchtree financial services inc'),
#  ('alupka absolute return fund l p',
#   'american securities opportunities fund iii b l p'),
#  ('aqr tax plus global market neutral equity fund l p',
#   'aqueous master fund l p series i'),
#  ('american income fund i c ltd partnership',
#   'bailard emerging opportunities fund i l p'),
#  ('callaway financial services inc', 'campbell financial services inc'),
#  ('allmerica fin life ins & ann co allmerica sel acct',
#   'campbell graham series a series of the frontier fund'),
#  ('allied holdings inc', 'allied ventures holdings corp'),
#  ('adapa new asia fund l p',
#   'aqr tax plus u s relaxed constraint equity fund l p'),
#  ('ab cap fund inc', 'ab institutional funds inc'),
#  ('advisoty research small cap value fund ii lp',
#   'blackstone credit opportunities fund lp'),
#  ('advisory research global value fund lp',
#   'bay city capital fund v co investment fund lp'),
#  ('aletheia securities inc bd', 'brauvin securities inc bd'),
#  ('advisors disciplined trust series 19',
#   'advisors disciplined trust series 72'),
#  ('algebris global financials fund l p', 'ascend u s market neutral fund ltd'),
#  ('alden global distressed opportunities fund lp',
#   'ama international equity fund lp'),
#  ('athena equity 2002 l p', 'avalon advisors l p'),
#  ('ascribe opportunities fund ii lp', 'campbell gold plus fund l p'),
#  ('andro capital l p',
#   'blackstone family investment partnership cayman v nq l p'),
#  ('ag private equity iv annex fund l p', 'blackstone fifth avenue fund l p'),
#  ('attkisson carter & co inc bd', 'campbell & co lp ta'),
#  ('alliancebernstein global growth trends fund inc',
#   'alliancebernstein multi market strategy trust inc'),
#  ('attkisson carter & co inc bd', 'bear stearns & co inc bd'),
#  ('american income fund i b', 'blackstone capital partners vi l p'),
#  ('bow ventures fund i lp', 'caine investment fund i lp ca'),
#  ('amsouth investment services inc bd', 'amstar financial services inc'),
#  ('axp discovery fund inc', 'axp equity series inc'),
#  ('apollo real estate advisors iii l p',
#   'blackstone emerging markets fund i l p'),
#  ('blackrock enhanced dividend achievers trust',
#   'blackrock fixed income trust'),
#  ('calypso financial services inc', 'campbell financial services inc'),
#  ('american income fund i a',
#   'aqr global asset allocation instituitonal fund ii l p'),
#  ('arden strategic advisers l p', 'camden partners exelixis fund l p'),
#  ('aberon capital fund ii l p',
#   'advantage advisers technology partners l l c'),
#  ('biotechnology value fund l p et al', 'canyon value realization fund l p'),
#  ('bateman eichler & co llc', 'berenson minella & co llc bd'),
#  ('ag energy partners ii l p', 'caiman partmers l p'),
#  ('angelo gordon & co lp', 'butler wick & co inc'),
#  ('aris multi strategy fund l p', 'broadmark long short full exposure l p'),
#  ('blackstone credit opportunities fund lp',
#   'capital structure opportunities fund lp'),
#  ('advisors disciplined trust 63', 'advisors disciplined trust series 69'),
#  ('alternative investments institutional l p',
#   'blue rock core equity portable alpha fund i l p'),
#  ('aqr us long short equity fund lp',
#   'campbell long short equity investment fund ltd'),
#  ('advisors disciplined trust 1279', 'advisors discplined trust 138'),
#  ('bencmark capital management co llc', 'brookside capital management llc'),
#  ('bessemer investor services inc bd', 'campbell financial services inc bd'),
#  ('administrative committee of longs drug stores ca espsp',
#   'campbell graham tiverton series a series of the frontier fund'),
#  ('berens credit opportunities fund l p', 'blackstone quarry fund l p'),
#  ('american home mort securities home mortgage invest tr 2004 1',
#   'bank of america mort sec inc mort pas thr certs ser 2001 h'),
#  ('alden global emerging markets fund i l p',
#   'altegris global macro ii fund l p'),
#  ('aberdeen emerging markets telecommunications fund inc',
#   'brevan howard systematic trading fund ltd'),
#  ('aberon capital fund ii l p',
#   'american securities opportunities fund ii b lp'),
#  ('american independence financial services llc',
#   'campbell financial services inc bd'),
#  ('acm emerging markets master fund i l p',
#   'american income fund i b ltd partnership'),
#  ('brookfield renewable partners l p', 'canyon value realization fund l p'),
#  ('blackstone customized commodities fund l p',
#   'blackstone participation partnership delaware v nq l p'),
#  ('arrowpoint fundamental opportunity fund l p', 'blackstone quarry fund l p'),
#  ('blackrock credit opportunities trust',
#   'blackrock managed duration income trust'),
#  ('american income fund i c', 'american securities opportunities fund ii lp'),
#  ('allmerica select sep acct ii of allmerica fin life ins co',
#   'cais esg cross border equity fund llc'),
#  ('advisors disciplined trust 74', 'advisors disciplined trust series 64'),
#  ('adage capital partners gp l l c',
#   'bp capital energy equity fund international i lp'),
#  ('blue rock core fixed income portable alpha fund ii l p',
#   'bogle opportunity fund l p'),
#  ('alaris medical systems inc', 'amoco medical service inc'),
#  ('apm global macro ii fund l p', 'ba sometros market neutral fund l p'),
#  ('alexander capital l p', 'bluecrest capital l p'),
#  ('avista capital opportunities fund ii offshore lp',
#   'avista capital partners ii lp'),
#  ('advisors disciplined trust 66', 'advisors discplined trust 845'),
#  ('american securities opportunities fund iii l p',
#   'aqr real asset fund ii l p'),
#  ('altegris paulson advantage plus fund l p',
#   'bp capital energy equity fund international i lp'),
#  ('aqr risk managed buywrite master account l p',
#   'axiom investors trust ii axiom u s small cap equity portfolio'),
#  ('basix capital fund l p',
#   'blue rock core fixed income portable alpha fund ii l p'),
#  ('aqr global asset allocation institutional fund ii l p', 'aqueous fund l p'),
#  ('advisors disciplined trust 1038', 'advisors disciplined trust 587'),
#  ('ameriprise financial inc', 'beard financial services inc'),
#  ('aci capital america fund lp', 'bogle investment fund lp'),
#  ('banc fund iv l p', 'brevan howard systematic trading fund l p'),
#  ('blackstone capital partners delaware nq v ac l p',
#   'brazil real estate opportunities fund ii l p'),
#  ('advisors disciplined trust series 76', 'advisors discplined trust 138'),
#  ('boyle capital management l l c', 'breeden partners ny i lp'),
#  ('blue bell country club l p', 'broadmark long short full exposure l p'),
#  ('ascend u s market neutral fund ltd', 'buyout core fund vi l p'),
#  ('ajo emerging markets enhanced hedge fund ltd',
#   'apollo emerging markets debt fund ltd'),
#  ('aberon capital fund l p', 'artis capital management l p'),
# ...
#  ('american express west equity fund l p',
#   'brookfield renewable energy partners l p'),
#  ('alliance fund inc', 'alliancebernstein global small cap fund inc'),
#  ('aqr global asset allocation institutional fund ii l p',
#   'bocage active commodity fund l p'),
#  ('american income fund i d', 'bocage active commodity fund l p'),
#  ('alger separate account a of voya insurance & annuity co',
#   'atlas energy for the nineties public no 5 ltd'),
#  ('aqr risk managed buywrite master account l p',
#   'belle haven investments l p'),
#  ('advisors disciplined trust series 58', 'advisors disciplined trust508'),
#  ('american income fund i b', 'braeside capital l p'),
#  ('alpha equity real estate securities market neutral fund lp',
#   'brigade opportunistic credit fund icl lp'),
#  ('blue rock capital fund ii l p', 'breeden partners new york i l p'),
#  ('acacia partners l p', 'artorius partners ii l p'),
#  ('american income fund i c ltd partnership', 'athena capital 2002 l p'),
#  ('athena capital 2002 l p', 'bain capital europe l p'),
#  ('altrinsic international equity portfolio l p',
#   'birch creek rmbs value fund l p'),
#  ('align impact fund l p', 'blackstone event driven fund l p'),
#  ('alliancebernstein global research growth fund inc',
#   'alliancebernstein international growth fund inc'),
#  ('advisory research global opportunities fund l p',
#   'aqr style premia emerging bond master account l p'),
#  ('american income fund i d ltd partnership',
#   'area european real estate fund iv l p'),
#  ('bear stearns arm trust 2005 5', 'capital one auto finance trust 2001 b'),
#  ('ag diversified income fund plus l p', 'anthem ventures fund l p'),
#  ('aqueous fund l p',
#   'axiom investors trust axiom u s small cap equity portfolio'),
#  ('anderson leneave & co', 'butler wick & co inc bd'),
#  ('camelot capital l p', 'capital preservation fund l p'),
#  ('alliancebernstein bond fund inc',
#   'alliancebernstein core opportunities fund inc'),
#  ('adapa new asia fund l p',
#   'america first real estate investment partners l p'),
#  ('ascend market neutral fund ltd', 'black diamond oc offshore fund ltd'),
#  ('adage capital partners l p', 'andor capital management l l c'),
#  ('adelphi emerging europe partners l p',
#   'blackstone fifth avenue offshore fund ltd class a d f k & l shares'),
#  ('aqr rick managed buywrite master account l p',
#   'breeden partners new york i l p'),
#  ('ag growth capital partners i annex fund l p',
#   'blue vista student housing v l p'),
#  ('aqr tax plus u s hedged equity fund l p',
#   'aqr trend following master account l p'),
#  ('ascend market neutral fund bpo ltd', 'augustus mjk offshore fund ltd'),
#  ('aberon capital fund ii l p',
#   'aqr tax plus u s relaxed constraint equity fund l p'),
#  ('adria partners l p', 'caiman partmers l p'),
#  ('alphasimplex quantitative global macro fund l p',
#   'birch run capital partners l p'),
#  ('alden global emerging markets fund i l p',
#   'alupka absolute return fund l p'),
#  ('advisory research opportunities fund l p', 'aqueous fund l p'),
#  ('american income fund i e', 'beta capital management l p'),
#  ('bear stearns asset backed securities i trust 2005 he10',
#   'bear stearns asset backed securities trust 2006 4'),
#  ('abs global long short asw fund a series of alternative strategies platform llc',
#   'berkeley graham tiverton series a series of the frontier fund'),
#  ('advantage advisers catalyst partners l p',
#   'altegris global macro fund l p'),
#  ('ai securities inc bd', 'arka securities inc bd'),
#  ('blackstone family investment partnership cayman v nq l p',
#   'blackstone park avenue fund l p'),
#  ('blackstone fifth avenue offshore fund ltd class a d f k & l shares',
#   'brookwood securities partners l p'),
#  ('advisor disciplined trust 902', 'advisors disciplined trust 1081'),
#  ('allen test co & rel 8 5 inc',
#   'allen test inc name changed for 860 cutover'),
#  ('acacia partners l p', 'brahman partners ii l p'),
#  ('aqr real return fund ii l p', 'aqueous fund l p'),
#  ('adviosrs disciplined trust 587', 'advisors disciplined trust 683'),
#  ('aramark cleanroom services inc', 'aramark food service llc'),
#  ('advisors disciplined trust 284', 'advisors disciplined trust 587'),
#  ('aqr volatility enhanced u s large cap equity fund l p',
#   'blackpier market neutral fund l p'),
#  ('allianzgi global equity & convertible income fund',
#   'berwyn income fund inc'),
#  ('american income fund i d',
#   'blackstone pacific opportunities master fund l p'),
#  ('aew capital management l p', 'arden strategic advisers l p'),
#  ('apm equity long short fund l p', 'blackstone advisory partners l p'),
#  ('alliance institutional fund a delaware business trust',
#   'ameritas variable life insurance co separate account v'),
#  ('avenue europe investments l p', 'bogle opportunity fund ii l p'),
#  ('aqueous fund l p series i',
#   'btg pactual global emerging markets & macro fund l p'),
#  ('american income fund i d ltd partnership', 'aqueous master fund l p'),
#  ('apm global macro ii fund l p', 'bowman capital management l l c'),
#  ('bear stearns asset backed securities 2006 4',
#   'capital one auto rec llc capital one prime auto rec tr 03 2'),
#  ('advisors disciplined trust 140', 'advisors disciplined trust 71'),
#  ('advisory research global all cap fund l p',
#   'aqr tax advantaged global equity market neutral fund l p'),
#  ('alloy global fund l p', 'black diamond capital management l l c'),
#  ('bernstein global opportunities l p',
#   'btg pactual global emerging markets & macro fund llc'),
#  ('ambulatory surgery associates l l c', 'boise cascade l l c'),
#  ('aqr tax plus global market neutral equity fund l p',
#   'blue water total return fund i l p'),
#  ('advisors disciplined trust 63', 'advisors discplined trust 138'),
#  ('barrow hanley high yield fixed income fund',
#   'barrow hanley mewhinney & strauss non us value fund'),
#  ('align impact fund l p', 'american income fund i e ltd partnership'),
#  ('broad run associates l p', 'cambria investment management l p'),
#  ('abs global long short asw fund a series of wachovia alternative strategies platform llc',
#   'alexander series trust clareant european credit opportunities fund ii'),
#  ('acn securities inc', 'alternet securities inc bd'),
#  ('apollo credit short opportunities master fund l p',
#   'bernstein global opportunities l p'),
#  ('alliance mid cap growth fund inc', 'basswood international fund inc'),
#  ('bernstein global opportunities hedge fund l p',
#   'blackstone event driven fund l p'),
#  ('2100 xenon managed futures fund lp',
#   'campbell managed futures onshore fund lp'),
#  ('advisors disciplined trust 75', 'advisors discplined trust 137'),
#  ('ascend market neutral fund ltd', 'blackgold opportunity offshore fund ltd'),
#  ('advisors disciplined trust series 46', 'advisors discplined trust 136'),
#  ('blue rock fixed income plus fund l p', 'caine investment fund i l p'),
#  ('blackrock muniyield insured fund inc',
#   'blackrock muniyield new jersey insured fund inc'),
#  ('american income fund i a ltd partnership',
#   'blackstone partners offshore fund ltd class e f g i j k q & r shares'),
#  ('altegris equity long short fund l p',
#   'american income fund i a ltd partnership'),
#  ('blackstone park avenue non taxable fund l p', 'blue bell country club l p'),
#  ('alden global distressed opportunities cayman fund l p',
#   'aqr rick managed buywrite master account l p'),
#  ('ameritas variable separate account va 2',
#   'campbell graham tiverton series a series of the frontier fund'),
#  ('beard financial services inc bd', 'callaway financial services inc'),
#  ('ba sometros market neutral fund lp',
#   'blackstone market opportunities fund lp'),
#  ('associated financial services inc', 'campbell financial services inc'),
#  ('7x7 partners l p', 'barrington partners l p'),
#  ('aqr tax plus u s relaxed constraint equity fund l p',
#   'basswood opportunity partners l p'),
#  ('abn amro asset management usa llc', 'berkshire asset management inc pa'),
#  ('bank of nova scotia trust co of new york ta',
#   'bishop manufacturing of new england inc'),
#  ('aew capital management l p ma', 'aqueous fund l p'),
#  ('blackstone customized commodities fund l p',
#   'blackstone family investment partnership delaware v nq l p'),
#  ('atlas america public #9 ltd', 'atlas america public 11 2002 ltd'),
#  ('aqr emerging bond master account l p',
#   'ares european real estate fund iv l p'),
#  ('aris multi strategy fund l p', 'berens capital partners l p'),
#  ('blue point oeg fund ii l p', 'bluecrest mercantile fund l p'),
#  ('blackstone partners investment fund l p', 'blue point oeg fund ii l p'),
#  ('allianzgi structured alpha multi beta series llc i international equity series',
#   'ameritas variable separate account va 2'),
#  ('arrowpoint fundamental opportunity fund l p',
#   'blackstone corporate opportunities master fund l p'),
#  ('aqr global asset allocation institutional fund ii l p',
#   'bluecrest emerging markets fund l p'),
#  ('blackstone capital partners cayman v nq l p',
#   'brahman institutional partners l p'),
#  ('alpine partners l p', 'canyon equities l p'),
#  ('alden global opportunities fund cayman l p',
#   'camden partners nexus fund l p'),
#  ('affinity ventures iii l p', 'alpine partners l p'),
#  ('american securities opportunities fund iii b l p',
#   'american securities partners l p'),
#  ('breeden partners california l p', 'buyout core fund vi l p'),
#  ('arizona tax free portfolio',
#   'california limited maturity tax free portfolio'),
#  ('breeden partners new york i l p', 'camelot capital l p'),
#  ('brown christopher m g', 'brown robert s'),
#  ('blackrock diamond property fund inc',
#   'blackrock muniyield michigan insured fund inc'),
#  ('alliancebernstein global technology fund inc',
#   'alliancebernstein small mid cap growth fund'),
#  ('ares european real estate fund iv l p', 'athene asset management l p'),
#  ('acm emerging markets multi strategy master fund i l p',
#   'breeden partners california l p'),
#  ('american income fund i b ltd partnership',
#   'apollo credit short opportunities fund l p'),
#  ('blackstone quarry fund l p', 'bogle opportunity fund i l p'),
#  ('adage capital partners gp l l c',
#   'brevan howard systematic trading fund l p'),
#  ('blackstone partners offshore fund ltd class e f g i j k q & r shares',
#   'caine investment fund i l p'),
#  ('boyle capital management l l c', 'campbell institutional trend fund l p'),
#  ('adria partners l p', 'brahman partners iv l p'),
#  ('augusta capital management l p', 'camden partners nexus fund l p'),
#  ('bb&t asset management llc', 'brar investment capital llc'),
#  ('advisors disciplined trust series 51',
#   'advisors disciplined trust series 69'),
#  ('blackstone capital partners delaware v nq l p',
#   'blue vista student housing select strategies fund l p'),
#  ('advisors disciplined trust 444', 'advisors disciplined trust 74'),
#  ('altegris paulson advantage plus fund l p', 'ares capital europe l p'),
#  ('alliance global growth trends fund inc',
#   'alliancebernstein international research growth fund inc'),
#  ('bacher & co inc bd', 'bradley woods & co'),
#  ('aberon capital fund l p', 'american securities opportunities fund ii b lp'),
#  ('advisors disciplined trust 57', 'advisors disciplined trust series 55'),
#  ('axa rosenberg us enhanced index institutional fund llc',
#   'banner apartments fund iii a operating limited partnership'),
#  ('advisors disciplined trust 551', 'advisors disciplined trust series 67'),
#  ('american income fund i b',
#   'blackstone participation partnership cayman v nq l p'),
#  ('aqueous master fund l p series i', 'blackstone madison avenue fund l p'),
#  ('blackstone park avenue non taxable fund l p',
#   'blackstone participation partnership delaware v nq l p'),
#  ('birch creek rmbs value fund l p', 'blue bell country club l p'),
#  ('blackstone event driven fund l p', 'blackstone hedged equity fund l p'),
#  ('banyan investment fund lp', 'brasada absolute return fund lp'),
#  ('ag super fund international partners l p', 'ark multi manager fund l p'),
#  ('advisors disciplined trust 52', 'advisors discliplined trust series 20'),
#  ('ark multi manager fund l p', 'camden partners nexus fund l p'),
#  ('alliance disiplined growth fund inc',
#   'blackrock global technology fund inc'),
#  ('7x7 institutional partners l p', 'bondurant partners l p'),
#  ('ag super fund international partners lp',
#   'american energy capital partners lp'),
#  ('adage capital partners l p', 'axiom small cap international fund l p'),
#  ('acm emerging markets fund i lp',
#   'american securities opportunities fund ii b lp'),
#  ('advantage advisers catalyst partners l p',
#   'blackstone family investment partnership delaware v nq l p'),
#  ('american express financial advisors', 'american express trust co'),
#  ('bp capital energy equity fund international i l p',
#   'broadmark long short equity fund l p'),
#  ('aqr rick managed buywrite master account l p',
#   'arden institutional holdings l p'),
#  ('alliancebernstein small mid cap growth fund',
#   'brookfield global listed infrastructure income fund inc'),
#  ('aqr tax plus global relaxed constraint equity fund l p',
#   'broad run associates l p'),
#  ('artigent capital partners lp', 'avighna capital partners lp'),
#  ('berens capital partners l p', 'bogle opportunity fund ii sri l p'),
#  ('amb u s logistics fund holdings l p',
#   'campbell financial futures fund l p'),
#  ('arden institutional holdings l p', 'blackstone advisory partners l p'),
#  ('alphadyne investment strategies partners lp',
#   'cabot industrial core fund blocker llc'),
#  ('birch creek credit value fund lp', 'blue rock capital fund ii lp'),
#  ('apollo real estate capital advisors iii l p',
#   'bluecrest emerging markets fund l p'),
#  ('aton securities inc bd', 'belfinance securities inc bd'),
#  ('a t a p financial services inc', 'c m capital advisors llc'),
#  ('advisors disciplined trust 845', 'advisors disciplined trust 942'),
#  ('altrinsic international equity portfolio l p',
#   'aqr real return fund ii l p'),
#  ('arden institutional advisers ii ms feeder l p', 'caldera equity fund l p'),
#  ('avalon advisors l p',
#   'blue vista student housing select strategies fund l p'),
#  ('advisors disciplined trust 47', 'advisors disciplined trust 802'),
#  ('artis capital management l p', 'candela capital l p'),
#  ('aqr tax advantaged global equity market neutral fund l p',
#   'bocage active commodity fund l p'),
#  ('athena capital 2002 l p', 'breeden partners new york i l p'),
#  ('adviosrs disciplined trust 802', 'advisors disciplined trust 508'),
#  ('advisors disciplined trust 49', 'advisors disciplined trust series 47'),
#  ('aberdeen global select opportunities fund inc',
#   'alliancebernstein international research growth fund inc'),
#  ('azure capital partners vc administrators ii l p',
#   'blackstone topaz fund l p'),
#  ('afsg securities corp bd', 'brighton securities corp bd'),
#  ('blackstone york ave offshore fund ltd',
#   'bogle offshore opportunity fund i ltd'),
#  ('alliancebernstein high income fund inc',
#   'bailard opportunity fund group inc'),
#  ('baldwin & clarke capital markets inc', 'beaty haynes & patterson inc'),
#  ('aberdeen asset management ltd aus',
#   'asset alliance investment services inc'),
#  ('berkeley graham tiverton series a series of the frontier fund',
#   'bluetrend asw fund a series of wachovia alternative strategies managed futures & commodities platform llc'),
#  ('basswood opportunity partners liquidating fund l p',
#   'blackstone pacific opportunities fund l p'),
#  ('acm emerging markets fund i lp',
#   'argonaut global equities partnership l p'),
#  ('blackstone event driven fund l p', 'canyon balanced fund l p'),
#  ('athena capital 2002 l p', 'candela capital l p'),
#  ('biotechnology value fund l p', 'blackstone quarry fund l p'),
#  ('axp dimensions series inc', 'axp income series inc'),
#  ('american income fund i d',
#   'aqr tax advantaged global equity market neutral fund l p'),
#  ('alfa capital markets usa inc', 'astoria capital markets inc'),
#  ('american healthways inc', 'american railcar industries inc de'),
#  ('aqr risk managed buywrite master account l p',
#   'birch run capital partners l p'),
#  ('advisors disciplined trust series 51',
#   'advisors disciplined trust series 71'),
#  ...}
