# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
# https://www.kaggle.com/dattapiy/sec-edgar-companies-list
subset_size = 100000 # change to 1000000 to see ann faster than brute force
names_df = pd.read_csv('data/sec__edgar_company_info.csv')[:subset_size]
names_df.head(3)
# Out:
#    Line Number                        Company Name  Company CIK Key
# 0            1                              !J INC          1438823
# 1            2       #1 A LIFESAFER HOLDINGS, INC.          1509607
# 2            3  #1 ARIZONA DISCOUNT PROPERTIES LLC          1457512

# %%
import re

irrelevant_regex = re.compile(r'[^a-z0-9\s\!\@\#\$\%\&]')
multispace_regex = re.compile(r'\s\s+')

def assign_no_symbols_name(df):
    return df.assign(
        name=df['Company Name']
             .str.lower()
             .str.replace(irrelevant_regex, ' ')
             .str.replace(multispace_regex, ' ')
             .str.strip())

names_df = assign_no_symbols_name(names_df)
names_df.head(9)
# Out:
#    Line Number                        Company Name  Company CIK Key  \
# 0            1                              !J INC          1438823
# 1            2       #1 A LIFESAFER HOLDINGS, INC.          1509607
# 2            3  #1 ARIZONA DISCOUNT PROPERTIES LLC          1457512
# 3            4                   #1 PAINTBALL CORP          1433777
# 4            5                               $ LLC          1427189
# 5            6                 & S MEDIA GROUP LLC          1447162
# 6            7             &TV COMMUNICATIONS INC.          1479357
# 7            8                        'MKTG, INC.'           886475
# 8            9                    'OHANA LABS INC.          1703629
#
#                                  name
# 0                              !j inc
# 1         #1 a lifesafer holdings inc
# 2  #1 arizona discount properties llc
# 3                   #1 paintball corp
# 4                               $ llc
# 5                 & s media group llc
# 6              &tv communications inc
# 7                            mktg inc
# 8                      ohana labs inc

# %%
index_to_name = names_df['name'].to_dict()
name_to_index = {v: k for k, v in index_to_name.items()}

# %%
import more_itertools

cik_clusters = (
    names_df[['name', 'Company CIK Key']]
    .groupby('Company CIK Key')
    .indices
)
more_itertools.take(10, cik_clusters.values())
# Out:
# [array([5878]),
#  array([6287]),
#  array([6375]),
#  array([6459, 6468]),
#  array([6521]),
#  array([6578]),
#  array([7053, 7055]),
#  array([7209]),
#  array([7175]),
#  array([7525])]

# %%
import itertools

cik_name_pairs = [
    (index_to_name[id_x], index_to_name[id_y])
    for cik_cluster in cik_clusters.values()
    for id_x, id_y in itertools.combinations(cik_cluster, 2)
    if index_to_name[id_x] != index_to_name[id_y]
]
cik_name_pairs[:10]
# Out:
# [('abel noser corp bd', 'abel noser corp'),
#  ('abraham & co inc bd', 'abraham & co inc'),
#  ('acme metals inc de', 'acme metals inc'),
#  ('adams diversified equity fund inc', 'adams diversified equity fund'),
#  ('adams diversified equity fund inc', 'adams express co'),
#  ('adams diversified equity fund', 'adams express co'),
#  ('alliance gaming corp', 'bally technologies inc'),
#  ('aei securities inc bd', 'aei securities inc'),
#  ('aeroflex inc', 'arx inc'),
#  ('aetna life & casualty co', 'aetna services inc ct')]

# %%
import more_itertools
from fuzzywuzzy import fuzz

true_pairs = {
    tuple(sorted(pair))
    for pair in cik_name_pairs
    if fuzz.token_sort_ratio(*pair) >= 60
    # if fuzz.partial_ratio(*pair) >= 60  
}
display(more_itertools.take(10, true_pairs))
display(len(true_pairs))
# Out:
# [('candela capital l p', 'candela capital lp'),
#  ('buffalo equity fund inc', 'buffalo large cap fund inc'),
#  ('better place llc', 'better plc llc'),
#  ('advest bank & trust co', 'advest trust co'),
#  ('brookwood securities partners llc', 'brookwood securities partners lp bd'),
#  ('americredit automobile receivables trust 2002 d',
#   'americredit financial services inc automobile rec tr 2002 d'),
#  ('azimuth diversified fund ii llc', 'azimuth diversified fund llc'),
#  ('ab cap fund inc', 'alliancebernstein cap fund inc'),
#  ('anangel american shipholdings ltd',
#   'anangel american shipholdings ltd adr'),
#  ('ag separate account a of agl', 'aga separate account a')]
# 3986

# %%
names_with_duplicates = list(set(itertools.chain.from_iterable(true_pairs)))
names_with_duplicates.sort()
len(names_with_duplicates)
# Out:
# 6735

# %%
string_list = names_with_duplicates
k = 50
threshold = 0.6

# %%
# %%time

from helpers.tfidf_blocker import block_with_tfidf_ann

ann_labels = block_with_tfidf_ann(string_list, threshold=threshold, k=k)
display(ann_labels)
# Out:
# array([2847, 2557, 2846, ...,  971, 1159, 1159])
# CPU times: user 17.7 s, sys: 543 ms, total: 18.2 s
# Wall time: 6.51 s

# %%
# %%time

from helpers.tfidf_blocker import block_with_tfidf_brute

brute_labels = block_with_tfidf_brute(string_list, threshold=threshold, k=k)
display(brute_labels)
# Out:
# array([2836, 2541, 2835, ...,  964, 2343, 2343])
# CPU times: user 2.07 s, sys: 440 ms, total: 2.51 s
# Wall time: 1.88 s

# %%
from collections import defaultdict

def blocks_from_labels(dataset, labels):
    blocks = defaultdict(list)
    for i, label in enumerate(labels):
        record = dataset[i]
        blocks[label].append(record)
    return blocks

def pairs_from_blocks(blocks):
    return set(
        tuple(sorted(pair))
        for block in blocks.values()
        for pair in itertools.combinations(block, 2))

# %%
def precision(found_pairs, true_pairs):
    return len(true_pairs & found_pairs) / len(found_pairs)

def recall(found_pairs, true_pairs):
    return len(true_pairs & found_pairs) / (len(true_pairs & found_pairs) + len(true_pairs - found_pairs))

# %%
ann_blocks = blocks_from_labels(string_list, ann_labels)
# ann_blocks

# %%
ann_pairs = pairs_from_blocks(ann_blocks)
display(precision(ann_pairs, true_pairs))
display(recall(ann_pairs, true_pairs))
# Out:
# 0.410547132498352
# 0.7812343201204215

# %%
brute_blocks = blocks_from_labels(string_list, brute_labels)
brute_pairs = pairs_from_blocks(brute_blocks)
display(precision(brute_pairs, true_pairs))
display(recall(brute_pairs, true_pairs))
# Out:
# 0.41153238546603477
# 0.7842448569994982

# %%
true_pairs - ann_pairs
# Out:
# {('012 smile communications ltd', 'b communications ltd'),
#  ('1 800 attorney inc', 'attorneys com inc'),
#  ('20th century industries', '21st century insurance group'),
#  ('2tor inc', '2u inc'),
#  ('4front software international inc co', '4front technologies inc'),
#  ('79 capital securities llc', 'capital innovations securities llc'),
#  ('@road inc', 'at road inc'),
#  ('a c r securities inc', 'acr securities inc bd'),
#  ('a l laboratories inc', 'a l pharma inc'),
#  ('a t a p financial services inc', 'atap financial services inc bd'),
#  ('a123 systems inc', 'b456 systems inc'),
#  ('ab bond fund inc', 'alliance bond fund inc'),
#  ('ab bond fund inc', 'alliancebernstein bond fund inc'),
#  ('ab cap fund inc', 'alliancebernstein cap fund inc'),
#  ('ab corporate shares', 'alliancebernstein corporate shares'),
#  ('ab corporate shares', 'alliancebernstein corporatee shares'),
#  ('ab discovery growth fund inc', 'alliance mid cap growth fund inc'),
#  ('ab discovery growth fund inc',
#   'alliancebernstein discovery growth fund inc'),
#  ('ab discovery growth fund inc', 'alliancebernstein mid cap growth fund inc'),
#  ('ab equity income fund inc', 'alliance utility income fund inc'),
#  ('ab equity income fund inc', 'alliancebernstein equity income fund inc'),
#  ('ab equity income fund inc', 'alliancebernstein utility income fund inc'),
#  ('ab fixed income shares inc', 'alliancebernstein fixed income shares inc'),
#  ('ab funds trust de', 'annuity board funds trust'),
#  ('ab global bond fund inc', 'alliancebernstein global bond fund inc'),
#  ('ab global thematic growth fund inc',
#   'alliancebernstein global thematic growth fund inc'),
#  ('ab growth & income fund inc', 'alliancebernstein growth & income fund inc'),
#  ('ab high income fund inc', 'alliancebernstein high income fund inc'),
#  ('ab large cap growth fund inc', 'alliance premier growth fund inc'),
#  ('ab large cap growth fund inc',
#   'alliancebernstein large cap growth fund inc'),
#  ('ab large cap growth fund inc', 'alliancebernstein premier growth fund inc'),
#  ('ab mortgage securities corp', 'alliance securities corp'),
#  ('ab sustainable global thematic fund inc',
#   'alliancebernstein global thematic growth fund inc'),
#  ('abacus impact fund 2013 l p', 'align impact fund l p'),
#  ('abada rami', 'abada yoram'),
#  ('abatix corp', 'abatix environmental corp'),
#  ('abattis bioceuticals corp', 'abattis biologix corp'),
#  ('abbey capital ltd', 'abbey capital multi manager fund'),
#  ('abc bancorp', 'ameris bancorp'),
#  ('abengoa bioenergy new technologies inc', 'abengoa bioenergy r&d inc'),
#  ('abengoa yield ltd', 'atlantica yield plc'),
#  ('abengoa yield plc', 'atlantica yield plc'),
#  ('abeona therapeutics inc', 'access pharmaceuticals inc'),
#  ('aberdeen commonwealth income fund inc', 'aberdeen global income fund inc'),
#  ('aberdeen global credit strategies fund inc',
#   'aberdeen global diversified fixed income fund inc'),
#  ('aberdeen global credit strategies fund inc',
#   'aberdeen global high yield fund inc'),
#  ('aberdeen global diversified fixed income fund inc',
#   'aberdeen global high yield fund inc'),
#  ('aberdeen global diversified fixed income fund inc',
#   'aberdeen global short duration income fund inc'),
#  ('aberdeen global high yield fund inc',
#   'aberdeen global short duration income fund inc'),
#  ('aberdeen investment funds', 'artio global investment funds'),
#  ('aberdeen investment funds', 'bjb investment funds'),
#  ('abilene behavioral health llc', 'acadia abilene llc'),
#  ('abn amro asset management holdings inc', 'alleghany asset management inc'),
#  ('abn amro funds', 'amg funds iv'),
#  ('abn amro funds', 'aston funds'),
#  ('abound solar inc', 'ava solar inc'),
#  ('abp investments us inc', 'apg asset management us inc'),
#  ('absolute potential inc', 'absolute waste services inc'),
#  ('absolute potnetial inc', 'absolute waste services inc'),
#  ('abt holdings inc', 'abt mining co inc'),
#  ('abundant power securities llc', 'bourne partners securities llc'),
#  ('abviva inc', 'biolabs inc'),
#  ('abx air inc', 'abx holdings inc'),
#  ('acadian global long short fund llc',
#   'acadian global market neutral fund llc'),
#  ('acap global fund', 'acap strategic fund'),
#  ('accel brands inc', 'accelpath inc'),
#  ('access 360 media inc', 'access sports media inc'),
#  ('access capital investment group inc', 'accesscapital inc'),
#  ('access integrated technologies inc',
#   'access integrated technologies inc d b a cinedigm digital cinema corp'),
#  ('accessfel inc', 'accesstel inc'),
#  ('accessfel inc', 'accesstel inc ut'),
#  ('accudial inc', 'accudial pharmaceutical inc'),
#  ('ackerley communications inc', 'ackerley group inc'),
#  ('acm income fund inc', 'alliancebernstein income fund inc'),
#  ('acordia securities inc', 'acordia securities of ohio inc'),
#  ('acorn energy inc', 'acorn factor inc'),
#  ('actavis funding scs', 'allergan funding scs'),
#  ('action minerals inc', 'aroway minerals inc'),
#  ('activa mutual fund trust', 'amway mutual fund inc'),
#  ('activcard corp', 'actividentity corp'),
#  ('activision blizzard inc', 'activision inc ny'),
#  ('actrade financial technologies ltd', 'actrade international ltd'),
#  ('acuitas emerging markets small cap fund lp',
#   'acuitas international small cap fund lp'),
#  ('acuitas long short fund lp', 'acuitas microcap fund lp'),
#  ('adams harkness inc', 'canaccord adams inc'),
#  ('adams laboratories inc', 'adams respiratory therapeutics inc'),
#  ('adance cps lp', 'advancepcs lp'),
#  ('adaptec inc', 'adpt corp'),
#  ('adaptimmune ltd', 'adaptimmune therapeutics plc'),
#  ('adaptive biotechnologies corp', 'adaptive tcr corp'),
#  ('adaptive insights inc', 'adaptive planning inc'),
#  ('adastra minerals inc', 'america mineral fields inc'),
#  ('adb systems international inc', 'bid com international inc'),
#  ('addicott virginia c', 'albanese virginia c'),
#  ('addvantage media group inc ok', 'addvantage technologies group inc'),
#  ('adient ltd', 'adient plc'),
#  ('ads in motion inc', 'ads on line inc'),
#  ('advanced investment partners llc', 'advanced investment technology inc fl'),
#  ('advanced magnetics inc', 'amag pharmaceuticals inc'),
#  ('advanced medical inc', 'alaris medical inc'),
#  ('advanced medical inc', 'alaris medical systems inc'),
#  ('advanced nutraceuticals inc tx', 'bactolac pharmaceutical inc'),
#  ('advanced thermal sciences corp', 'advanced thermal technologies inc'),
#  ('advanstar holdings inc', 'advanstar inc'),
#  ('advantage advisers global growth l l c',
#   'advantage advisers technology partners l l c'),
#  ('advantage advisers global growth l l c',
#   'advantage advisers technology partners llc'),
#  ('advantage advisers global growth ltd',
#   'advantage advisers technology international ltd'),
#  ('advantage advisers technology fund llc',
#   'advantage advisers xanthus ii llc'),
#  ('advent claymore enhanced growth & income fund',
#   'advent claymore global convertible opport income fd'),
#  ('advent claymore enhanced growth & income fund',
#   'advent claymore global total return fund'),
#  ('advent claymore global convertible opport income fd',
#   'advent claymore global total return fund'),
#  ('adventus funds trust', 'arrivato funds trust'),
#  ('advest bank & trust co', 'advest trust co'),
#  ('ae biofuels inc', 'aemetis inc'),
#  ('aeb corp bd', 'aeb corporation'),
#  ('aep energy services inc', 'aep pro serv inc'),
#  ('aep energy services inc', 'aep resources engineering & services co'),
#  ('aeris capital management co s a lu', 'calibrium management co s a'),
#  ('aero group inc', 'aero group incorporated'),
#  ('aeroflex high speed test solutions inc', 'aeroflex systems group inc'),
#  ('aeroflex inc', 'arx inc'),
#  ('aes corp', 'aes corporation'),
#  ('aeterna laboratories inc', 'aeterna zentaris inc'),
#  ('aetna life & casualty co', 'aetna services inc ct'),
#  ('afc building technologies inc', 'auto tool technologies inc'),
#  ('afem medical corp', 'athena medical corp'),
#  ('affiliated resources corp', 'basic natural resources inc'),
#  ('afton capital management llc', 'blue ridge capital management llc'),
#  ('ag diversified credit strategies fund lp',
#   'ag diversified income fund plus l p'),
#  ('ag diversified credit strategies fund ltd',
#   'ag diversified income fund plus ltd'),
#  ('ag growth capital partners i annex fund l p',
#   'ag private equity iv annex fund l p'),
#  ('agenus inc', 'antigenics inc de'),
#  ('agi inc', 'agl inc'),
#  ('agic convertible & income fund', 'allianzgi convertible & income fund'),
#  ('agic convertible & income fund ii',
#   'allianzgi convertible & income fund ii'),
#  ('agic equity & convertible income fund',
#   'allianzgi equity & convertible income fund'),
#  ('agic global equity & convertible income fund',
#   'allianzgi global equity & convertible income fund'),
#  ('agile group holdings limited adr', 'agile property holdings ltd'),
#  ('agl separate account vl r',
#   'american general life insurance co separate account vl r'),
#  ('agrieuro corp', 'artex corp'),
#  ('ai golf llc', 'aquimo llc'),
#  ('aig life insurance co', 'american general life insurance co of delaware'),
#  ('aim fund services inc ta', 'aim investment services inc'),
#  ('aim tax exempt funds', 'aim tax free funds inc'),
#  ('aim tax exempt funds inc new', 'aim tax free funds inc'),
#  ('aim tax exempt funds invesco tax exempt funds', 'aim tax free funds inc'),
#  ('aip alternative strategies funds', 'alternative investment funds'),
#  ('airgate pcs inc de', 'airgate wireless inc'),
#  ('aj greentech holdings', 'american jianye greentech holdings ltd'),
#  ('akeena solar inc', 'andalay solar inc'),
#  ('alabama municipals portfolio', 'alabama tax free portfolio'),
#  ('alamos gold inc', 'alamos minerals ltd'),
#  ('alanar inc bd', 'alanar incorporated'),
#  ('alaris medical inc', 'alaris medical systems inc'),
#  ('alberta star development corp', 'alberta star mining corp'),
#  ('alcatel', 'alcatel alsthom'),
#  ('alcatel alsthom', 'alcatel lucent'),
#  ('alcatel alsthom france', 'alcatel lucent'),
#  ('alcoa corp', 'alcoa upstream corp'),
#  ('alcoa inc', 'arconic inc'),
#  ('alcresta inc', 'alcresta therapeutics inc'),
#  ('alden global emerging markets fund i l p', 'alden global india fund lp'),
#  ('alden global emerging markets fund i ltd', 'alden global india fund ltd'),
#  ('alderon iron ore corp', 'alderon resource corp'),
#  ('alere health improvement co', 'alere health systems inc'),
#  ('alerus securities bd', 'alerus securities corporation'),
#  ('alexander series trust', 'bny series trust'),
#  ('alger institutional fund', 'alger retirement fund'),
#  ('alger institutional funds', 'alger retirement fund'),
#  ('alger separate account a of golden american life insur co',
#   'alger separate account a of ing usa annuity & life insurance co'),
#  ('alger separate account a of golden american life insur co',
#   'alger separate account a of voya insurance & annuity co'),
#  ('alivecor inc', 'aliveusa inc'),
#  ('all cap energy hedge fund llc', 'blackrock global energy dynamic fund llc'),
#  ('all cap energy hedge fund ltd', 'blackrock global energy dynamic fund ltd'),
#  ('all energy corp', 'all fuels & energy co'),
#  ('all state properties holdings inc', 'all state properties lp'),
#  ('alleghany funds', 'aston funds'),
#  ('allegheny energy inc', 'allegheny power system inc'),
#  ('allegheny energy service corp', 'allegheny power service corp'),
#  ('allegheny technologies inc', 'allegheny teledyne inc'),
#  ('allen & co inc bd', 'allen & company llc'),
#  ('allen arbitrage offshore', 'allen global partners offshore'),
#  ('allen test', 'allen test co inc 1'),
#  ('allen test & snow removal co inc', 'allen test co'),
#  ('allen test & snow removal co inc', 'allen test co & rel 8 5 inc'),
#  ('allen test & snow removal co inc', 'allen test co & rel 8 6 dr inc'),
#  ('allen test & snow removal co inc', 'allen test co & rel 8 6 inc'),
#  ('allen test & snow removal co inc', 'allen test co & release 8 2 inc'),
#  ('allen test & snow removal co inc', 'allen test co & release 8 3 inc'),
#  ('allen test & snow removal co inc', 'allen test co inc'),
#  ('allen test & snow removal co inc', 'allen test co inc & cut over test'),
#  ('allen test & snow removal co inc',
#   'allen test co inc & cut over test 8 18 01'),
#  ('allen test & snow removal co inc',
#   'allen test co inc & cut over test 8 4 01'),
#  ('allen test & snow removal co inc',
#   'allen test co inc & cut over test 9 23 01'),
#  ('allen test & snow removal co inc',
#   'allen test co inc & point release test 10 08 01'),
#  ('allen test & snow removal co inc', 'allen test co inc 1'),
#  ('allen test & snow removal co inc',
#   'allen test co inc cut over test 9 23 01'),
#  ('allen test & snow removal co inc', 'allen test co inc test time prod'),
#  ('allen test 440', 'allen test co rel test 550'),
#  ('allen test 440', 'allen test corp'),
#  ('allen test co', 'allen test co & rel 8 5 inc'),
#  ('allen test co', 'allen test co & rel 8 6 dr inc'),
#  ('allen test co', 'allen test co & rel 8 6 inc'),
#  ('allen test co', 'allen test co & release 8 2 inc'),
#  ('allen test co', 'allen test co & release 8 3 inc'),
#  ('allen test co', 'allen test co inc 1'),
#  ('allen test co & rel 8 5 inc', 'allen test co inc'),
#  ('allen test co & rel 8 5 inc', 'allen test co inc & cut over test'),
#  ('allen test co & rel 8 5 inc', 'allen test co inc & cut over test 8 18 01'),
#  ('allen test co & rel 8 5 inc', 'allen test co inc & cut over test 8 4 01'),
#  ('allen test co & rel 8 5 inc', 'allen test co inc & cut over test 9 23 01'),
#  ('allen test co & rel 8 5 inc',
#   'allen test co inc & point release test 10 08 01'),
#  ('allen test co & rel 8 5 inc', 'allen test co inc 1'),
#  ('allen test co & rel 8 5 inc', 'allen test co inc cut over test 9 23 01'),
#  ('allen test co & rel 8 5 inc', 'allen test co inc test time prod'),
#  ('allen test co & rel 8 5 inc', 'allen test ltd'),
#  ('allen test co & rel 8 6 dr inc', 'allen test co inc'),
#  ('allen test co & rel 8 6 dr inc', 'allen test co inc & cut over test'),
#  ('allen test co & rel 8 6 dr inc',
#   'allen test co inc & cut over test 8 18 01'),
#  ('allen test co & rel 8 6 dr inc',
#   'allen test co inc & cut over test 8 4 01'),
#  ('allen test co & rel 8 6 dr inc',
#   'allen test co inc & cut over test 9 23 01'),
#  ('allen test co & rel 8 6 dr inc',
#   'allen test co inc & point release test 10 08 01'),
#  ('allen test co & rel 8 6 dr inc', 'allen test co inc 1'),
#  ('allen test co & rel 8 6 dr inc', 'allen test co inc cut over test 9 23 01'),
#  ('allen test co & rel 8 6 dr inc', 'allen test co inc test time prod'),
#  ('allen test co & rel 8 6 inc', 'allen test co inc'),
#  ('allen test co & rel 8 6 inc', 'allen test co inc & cut over test'),
#  ('allen test co & rel 8 6 inc', 'allen test co inc & cut over test 8 18 01'),
#  ('allen test co & rel 8 6 inc', 'allen test co inc & cut over test 8 4 01'),
#  ('allen test co & rel 8 6 inc', 'allen test co inc & cut over test 9 23 01'),
#  ('allen test co & rel 8 6 inc',
#   'allen test co inc & point release test 10 08 01'),
#  ('allen test co & rel 8 6 inc', 'allen test co inc 1'),
#  ('allen test co & rel 8 6 inc', 'allen test co inc cut over test 9 23 01'),
#  ('allen test co & rel 8 6 inc', 'allen test co inc test time prod'),
#  ('allen test co & rel 8 6 inc', 'allen test ltd'),
#  ('allen test co & rel test 80 for version d',
#   'allen test co name change test'),
#  ('allen test co & rel test 80 for version d', 'allen test co rel test 550'),
#  ('allen test co & rel test 80 for version d', 'allen test co rel test 5660'),
#  ('allen test co & release 8 2 inc', 'allen test co inc'),
#  ('allen test co & release 8 2 inc', 'allen test co inc & cut over test'),
#  ('allen test co & release 8 2 inc',
#   'allen test co inc & cut over test 8 18 01'),
#  ('allen test co & release 8 2 inc',
#   'allen test co inc & cut over test 8 4 01'),
#  ('allen test co & release 8 2 inc',
#   'allen test co inc & cut over test 9 23 01'),
#  ('allen test co & release 8 2 inc',
#   'allen test co inc & point release test 10 08 01'),
#  ('allen test co & release 8 2 inc', 'allen test co inc 1'),
#  ('allen test co & release 8 2 inc',
#   'allen test co inc cut over test 9 23 01'),
#  ('allen test co & release 8 2 inc', 'allen test co inc test time prod'),
#  ('allen test co & release 8 3 inc', 'allen test co inc'),
#  ('allen test co & release 8 3 inc', 'allen test co inc & cut over test'),
#  ('allen test co & release 8 3 inc',
#   'allen test co inc & cut over test 8 18 01'),
#  ('allen test co & release 8 3 inc',
#   'allen test co inc & cut over test 8 4 01'),
#  ('allen test co & release 8 3 inc',
#   'allen test co inc & cut over test 9 23 01'),
#  ('allen test co & release 8 3 inc',
#   'allen test co inc & point release test 10 08 01'),
#  ('allen test co & release 8 3 inc', 'allen test co inc 1'),
#  ('allen test co & release 8 3 inc',
#   'allen test co inc cut over test 9 23 01'),
#  ('allen test co & release 8 3 inc', 'allen test co inc test time prod'),
#  ('allen test co inc', 'allen test co inc & cut over test'),
#  ('allen test co inc', 'allen test co inc & cut over test 8 18 01'),
#  ('allen test co inc', 'allen test co inc & cut over test 8 4 01'),
#  ('allen test co inc', 'allen test co inc & cut over test 9 23 01'),
#  ('allen test co inc', 'allen test co inc 1'),
#  ('allen test co inc', 'allen test co inc cut over test 9 23 01'),
#  ('allen test co inc', 'allen test co inc test time prod'),
#  ('allen test co inc', 'allen test inc & post 8 0 cutover co'),
#  ('allen test co inc', 'allen test inc new name 1'),
#  ('allen test co inc', 'allen test inc new name 2'),
#  ('allen test co inc', 'allen test inc new name 3'),
#  ('allen test co inc', 'allen testing co ind'),
#  ('allen test co inc', 'allen testing co ism'),
#  ('allen test co inc & cut over test',
#   'allen test co inc & cut over test 9 23 01'),
#  ('allen test co inc & cut over test',
#   'allen test co inc & point release test 10 08 01'),
#  ('allen test co inc & cut over test', 'allen test co inc 1'),
#  ('allen test co inc & cut over test',
#   'allen test co inc cut over test 9 23 01'),
#  ('allen test co inc & cut over test', 'allen test co inc test time prod'),
#  ('allen test co inc & cut over test 8 18 01',
#   'allen test co inc & cut over test 9 23 01'),
#  ('allen test co inc & cut over test 8 18 01',
#   'allen test co inc & point release test 10 08 01'),
#  ('allen test co inc & cut over test 8 18 01', 'allen test co inc 1'),
#  ('allen test co inc & cut over test 8 18 01',
#   'allen test co inc cut over test 9 23 01'),
#  ('allen test co inc & cut over test 8 18 01',
#   'allen test co inc test time prod'),
#  ('allen test co inc & cut over test 8 4 01',
#   'allen test co inc & cut over test 9 23 01'),
#  ('allen test co inc & cut over test 8 4 01',
#   'allen test co inc & point release test 10 08 01'),
#  ('allen test co inc & cut over test 8 4 01', 'allen test co inc 1'),
#  ('allen test co inc & cut over test 8 4 01',
#   'allen test co inc cut over test 9 23 01'),
#  ('allen test co inc & cut over test 8 4 01',
#   'allen test co inc test time prod'),
#  ('allen test co inc & cut over test 9 23 01',
#   'allen test co inc & point release test 10 08 01'),
#  ('allen test co inc & cut over test 9 23 01', 'allen test co inc 1'),
#  ('allen test co inc & cut over test 9 23 01',
#   'allen test co inc test time prod'),
#  ('allen test co inc & point release test 10 08 01',
#   'allen test co inc cut over test 9 23 01'),
#  ('allen test co inc & point release test 10 08 01',
#   'allen test co inc test time prod'),
#  ('allen test co inc 1', 'allen test co inc cut over test 9 23 01'),
#  ('allen test co inc 1', 'allen test co inc test time prod'),
#  ('allen test co inc 1', 'allen test ltd'),
#  ('allen test co inc cut over test 9 23 01',
#   'allen test co inc test time prod'),
#  ('allen test co name change test', 'allen test co rel test 550'),
#  ('allen test co name change test', 'allen test co rel test 5660'),
#  ('allen test co rel test 550', 'allen test corp'),
#  ('allen test co rel test 5660', 'allen test corp'),
#  ('allen test inc & post 8 0 cutover co',
#   'allen test inc name changed for 860 cutover'),
#  ('allen test inc and new name 2 limited',
#   'allen test inc name changed for 860 cutover'),
#  ('allen test inc new name 1', 'allen testing co ind'),
#  ('allen test inc new name 1', 'allen testing co ism'),
#  ('allen test inc new name 2', 'allen testing co ind'),
#  ('allen test inc new name 2', 'allen testing co ism'),
#  ('allen test inc new name 3', 'allen testing co ind'),
#  ('allen test inc new name 3', 'allen testing co ism'),
#  ('allen test new name inc md', 'allen test redfearn'),
#  ('alliance balanced shares inc', 'alliancebernstein balanced shares inc'),
#  ('alliance balanced shares inc nj', 'alliancebernstein balanced shares inc'),
#  ('alliance bond fund inc', 'alliancebernstein bond fund inc'),
#  ('alliance capital management holding lp', 'alliancebernstein holding l p'),
#  ('alliance disciplined growth fund inc',
#   'alliancebernstein disciplined growth fund inc'),
#  ('alliance disciplined value fund inc',
#   'alliancebernstein core opportunities fund inc'),
#  ('alliance disiplined growth fund inc',
#   'alliancebernstein disciplined growth fund inc'),
#  ('alliance emerging market debt fund inc',
#   'alliancebernstein high income fund inc'),
#  ('alliance fund inc', 'alliance mid cap growth fund inc'),
#  ('alliance global investor services inc ta',
#   'alliancebernstein investor services inc ta'),
#  ('alliance growth & income fund inc',
#   'alliancebernstein growth & income fund inc'),
#  ('alliance institutional fund',
#   'alliance institutional fund a delaware business trust'),
#  ('alliance institutional fund a delaware business trust',
#   'alliancebernstein institutional fund'),
#  ('alliance international premier growth fund inc',
#   'alliancebernstein international premier growth fund inc'),
#  ('alliance international premier growth fund inc',
#   'alliancebernstein international research growth fund inc'),
#  ('alliance mid cap growth fund inc',
#   'alliancebernstein discovery growth fund inc'),
#  ('alliance mid cap growth fund inc',
#   'alliancebernstein mid cap growth fund inc'),
#  ('alliance mid cap growth fund inc',
#   'alliancebernstein small mid cap growth fund'),
#  ('alliance premier growth fund inc',
#   'alliancebernstein large cap growth fund inc'),
#  ('alliance premier growth fund inc',
#   'alliancebernstein premier growth fund inc'),
#  ('alliance premier growth institutional fund',
#   'alliancebernstein large cap growth fund inc'),
#  ('alliance premier growth institutional fund',
#   'alliancebernstein premier growth fund inc'),
#  ('alliance quasar fund inc', 'alliancebernstein cap fund inc'),
#  ('alliance quasar fund inc', 'alliancebernstein small cap growth fund inc'),
#  ('alliance utility income fund inc',
#   'alliancebernstein equity income fund inc'),
#  ('alliancebernstein balanced shares inc',
#   'alliancebernstein global risk allocation fund inc'),
#  ('alliancebernstein cap fund inc', 'alliancebernstein quasar fund inc'),
#  ('alliancebernstein cap fund inc',
#   'alliancebernstein small cap growth fund inc'),
#  ('alliancebernstein core opportunities fund inc',
#   'alliancebernstein disciplined value fund inc'),
#  ('alliancebernstein core opportunities fund inc',
#   'alliancebernstein focused growth & income fund inc'),
#  ('alliancebernstein disciplined value fund inc',
#   'alliancebernstein focused growth & income fund inc'),
#  ('alliancebernstein diversified yield fund inc',
#   'alliancebernstein unconstrained bond fund inc'),
#  ('alliancebernstein emerging market debt fund inc',
#   'alliancebernstein high income fund inc'),
#  ('alliancebernstein equity income fund inc',
#   'alliancebernstein utility income fund inc'),
#  ('alliancebernstein fixed income shares inc',
#   'alliancebernstein institutional reserves inc'),
#  ('alliancebernstein global bond fund inc',
#   'alliancebernstein global government income trust inc'),
#  ('alliancebernstein global strategic income trust inc',
#   'alliancebernstein unconstrained bond fund inc'),
#  ('alliancebernstein global technology fund inc',
#   'alliancebernstein global thematic growth fund inc'),
#  ('alliancebernstein global thematic growth fund inc',
#   'alliancebernstein technology fund inc'),
#  ('alliancebernstein international growth fund inc',
#   'alliancebernstein worldwide privatization fund inc'),
#  ('alliancebernstein quasar fund inc',
#   'alliancebernstein small cap growth fund inc'),
#  ('allianz asset management of america l p',
#   'allianz global investors of america l p'),
#  ('allianz dresdner asset management of america l p',
#   'allianz global investors of america l p'),
#  ('allied gold ltd', 'allied gold mining ltd'),
#  ('allied gold ltd', 'allied gold mining plc'),
#  ('allied holdings inc', 'allied systems holdings inc'),
#  ('allmerica select sep acct ii of allmerica fin life ins co',
#   'allmerica select separate account ii of sma life assurance c'),
#  ('allmerica select sep acct of 1st allmerica fin life ins co',
#   'allmerica select seperate acct of state mutual life assur co'),
#  ('allmerica select separate account of allmer fn lf ins & an c',
#   'allmerica select separate account of sma life assurance co'),
#  ('allos i limited partnership', 'blue chip v limited partnership'),
#  ('allscripts healthcare solutions inc', 'allscripts holding inc'),
#  ('alpha equity asset allocation offshore fund ltd',
#   'alpha equity multi strategy offshore fund ltd'),
#  ('alpha equity global long short offshore fund ltd',
#   'alpha equity multi strategy offshore fund ltd'),
#  ('alpha equity real estate securities market neutral fund lp',
#   'alpha praedium market neutral fund lp'),
#  ('alphadyne investment strategies fund ltd',
#   'alphadyne investment strategies fund ltd class a & class b common stock segregated portfolio a'),
#  ('alphadyne investment strategies partners lp',
#   'alphadyne investment strategies partners lp series a lp interests segregated porfolio a'),
#  ('alphashares black dragon fund l p', 'baochuan black dragon fund l p'),
#  ('alphaterra fund l p', 'baranof fund l p'),
#  ('alpine associates a limited partnership', 'alpine associates l p'),
#  ('alpine enhanced lp', 'alpine heritage l p'),
#  ('altair international gold inc', 'altair nanotechnologies inc'),
#  ('altair international inc', 'altair nanotechnologies inc'),
#  ('altair international inc fi', 'altair nanotechnologies inc fi'),
#  ('altegris kkr commitments fund', 'altegris kkr private equity fund'),
#  ('altegris kkr commitments master fund',
#   'altegris kkr private equity master fund'),
#  ('altegris renaissance ie fund lp', 'altegris visium fund l p'),
#  ('altmfx trust', 'altx trust'),
#  ('altura interventional inc', 'altura medical inc'),
#  ('amalgamated bank', 'amalgamated bank of new york'),
#  ('amalgamated bank longview funds',
#   'amalgamated bank of new york longview collective investment'),
#  ('amanasu techno holdings corp', 'amanasu technologies corp'),
#  ('amarillo automotive c ltd', 'amarillo motors c ltd'),
#  ('amarillo automotive f ltd', 'amarillo motors f ltd'),
#  ('amarillo automotive j ltd', 'amarillo motors j ltd'),
#  ('ambac securities inc', 'cadre securities inc bd'),
#  ('ambra biohealth llc', 'ambra bioscience llc'),
#  ('america first multifamily investors l p',
#   'america first tax exempt investors lp'),
#  ('america northcoast securities inc', 'ancora securities inc'),
#  ('america northcoast securities inc', 'ancora securities inc bd'),
#  ('american aadvantage funds', 'american beacon funds'),
#  ('american aadvantage mileage funds', 'american beacon mileage funds'),
#  ('american aadvantage select funds', 'american beacon select funds'),
#  ('american aadvantage select funds', 'american select funds'),
#  ('american access technologies inc', 'american electric technologies inc'),
#  ('american artists entertainment corp', 'american artists film corp mo'),
#  ('american atm corp', 'american wireless web corp'),
#  ('american beacon municipal enhanced cash trust',
#   'amr investments municipal enhanced cash trust'),
#  ('american capital asset management llc', 'american capital llc'),
#  ('american capital ltd', 'american capital strategies ltd'),
#  ('american career centers inc', 'american water star inc'),
#  ('american century international bond funds', 'benham international funds'),
#  ('american century investment trust', 'benham investment trust'),
#  ('american century manager funds', 'benham manager funds'),
#  ('american century municipal trust', 'benham municipal trust'),
#  ('american claims evaluation inc', 'american learning corp'),
#  ('american core realty fund l p', 'american stable value fund llc'),
#  ('american core realty fund llc', 'american stable value fund llc'),
#  ('american energy partners inc de', 'american energy production inc'),
#  ('american enterprise variable annuity account',
#   'american express platinum variable annuity sm'),
#  ('american express certificate co', 'ameriprise certificate co'),
#  ('american express financial advisors', 'ameriprise financial inc'),
#  ('american express financial advisors inc',
#   'ameriprise financial services inc'),
#  ('american express financial corp', 'ameriprise financial inc'),
#  ('american express financial corp ta', 'ameriprise financial inc'),
#  ('american express trust co', 'ameriprise trust co'),
#  ('american fidelity separate account a',
#   'american fidelity variable annuity fund a'),
#  ('american finance trust inc', 'american realty capital trust v inc'),
#  ('american financial group inc et al', 'american premier group inc et al'),
#  ('american financial group inc oh', 'american premier group inc'),
#  ('american healthcorp inc', 'american healthways inc'),
#  ('american healthcorp inc de', 'american healthways inc'),
#  ('american independence funds trust', 'arrivato funds trust'),
#  ('american international ventures inc de', 'american precious metals inc'),
#  ('american international ventures inc de',
#   'american precious metals inc new'),
#  ('american life group inc', 'american life holdings inc'),
#  ('american patriot financial group inc', 'bg financial group inc'),
#  ('american pharmaceutical partners inc ca', 'app pharmaceuticals inc'),
#  ('american pharmaceutical partners inc de', 'app pharmaceuticals inc'),
#  ('american realty capital daily net asset value trust inc',
#   'american realty capital trust ii inc'),
#  ('american realty capital global daily net asset value trust inc',
#   'american realty capital global trust inc'),
#  ('american realty capital ii llc', 'ar capital llc'),
#  ('american renal associates holdings inc', 'c p atlas holdings inc'),
#  ('american river bankshares', 'american river holdings'),
#  ('american securities bd co lp', 'american securities partners l p'),
#  ('american securities corp', 'american securities partners l p'),
#  ('american tire corp', 'amerityre corp'),
#  ('american tower corp ma', 'american tower systems corp'),
#  ('americredit automobile receivables trust 2002 d',
#   'americredit financial services inc automobile rec tr 2002 d'),
#  ('americredit automobile receivables trust 2004 a f',
#   'americredit financial services inc auto rec trust 2004 af'),
#  ('ameriserv food co', 'ameriserve food distribution inc de'),
#  ('amerisource corp', 'amerisource health corp'),
#  ('amerisource distribution corp', 'amerisource health corp de'),
#  ('ameritrade holding corp', 'arrow stock holding corp'),
#  ('amg funds iv', 'aston funds'),
#  ('ammonia hold inc', 'cali holdings inc'),
#  ('amoco co', 'bp amoco co'),
#  ('amoco corp', 'bp amoco corp'),
#  ('amundi alternative investments llc', 'amundi investments usa llc'),
#  ('anaren inc', 'anaren microwave inc'),
#  ('anderson adam d', 'blue adam d'),
#  ('anderson group inc', 'anderson group incorporated'),
#  ('andesa services inc ta', 'andesa tpa inc ta'),
#  ('andor global offshore fund inc',
#   'andor technology aggressive offshore fund inc'),
#  ('angelciti entertainment inc', 'angelciti multimedia inc'),
#  ('anglo american corp of south africa ltd fi', 'anglo american plc fi'),
#  ('angstrom microsystems corp', 'angstrom technologies corp'),
#  ('anika research inc', 'anika therapeutics inc'),
#  ('annaly capital management inc', 'annaly mortgage management inc'),
#  ('annidis corp', 'annidis health systems corp'),
#  ('anooraq resources corp', 'atlatsa resources corp'),
#  ('anpac securities group', 'asg securities inc'),
#  ('aon asset management fund inc', 'aon money market fund inc'),
#  ('aon benfield securities inc', 'aon securities corporation'),
#  ('aon securities corporation', 'aon securities inc'),
#  ('apax partners & co ventures ltd et al', 'apax partners holdings ltd'),
#  ('apex therapeutics inc', 'apexian pharmaceuticals inc'),
#  ('apg asset management us inc', 'apg investments us inc'),
#  ('api nanotronics corp', 'api technologies corp'),
#  ('apoimmune inc', 'apovax inc'),
#  ('apollo capital group inc', 'apollo entertainment group inc'),
#  ('apollo gold corp', 'brigus gold corp'),
#  ('app47 inc', 'appmetrics inc'),
#  ('appalachian basin royalty trust', 'appalachian natural gas trust'),
#  ('appaloosa investment limited partnership i', 'appaloosa investment lp i'),
#  ('apple computer inc', 'apple inc'),
#  ('apple computer inc fa', 'apple inc'),
#  ('apple hospitality reit inc', 'apple reit nine inc'),
#  ('aqr global stock selection offshore fund aud ltd',
#   'aqr offshore multi strategy fund aud ltd'),
#  ('aqr style premia fund l p', 'aqr vme fund l p'),
#  ('aqr tax plus global market neutral equity fund l p',
#   'aqr tax plus u s hedged equity fund l p'),
#  ('aquantive inc', 'avenue a inc'),
#  ('ar asset management inc', 'ar asset managment inc'),
#  ('aramark corp', 'aramark services inc'),
#  ('arcbest corp de', 'arkansas best corp de'),
#  ('arch coal inc', 'arch mineral corp'),
#  ('arch communications inc', 'arch wireless communications inc'),
#  ('archstone absolute return strategies fund ltd',
#   'archstone market neutral strategies fund ltd'),
#  ('archstone communities trust', 'archstone smith operating trust'),
#  ('archview credit oportunities fund lp', 'archview fund l p'),
#  ('archview credit opportunities fund lp', 'archview fund l p'),
#  ('archview credit opportunities master fund ltd', 'archview master fund ltd'),
#  ('archview credit opportunities offshore fund ltd',
#   'archview offshore fund ltd'),
#  ('arctco inc', 'arctic cat inc'),
#  ('arden advisers lp', 'arden institutional advisers l p'),
#  ('arden institutional advisers lp', 'arden institutional holdings l p'),
#  ('arden realty limited partnership', 'arden realty ltd'),
#  ('arena online inc', 'attaq online inc'),
#  ('ares ix clo ltd', 'ares xi clo ltd'),
#  ('arguss communications inc', 'arguss holdings inc'),
#  ('ari financial services inc', 'cabin securities inc'),
#  ('arianne phosphate inc', 'arianne resources inc'),
#  ('aristar heat llc', 'brightline heat llc'),
#  ('aristar ventures ii b llc', 'brightline ventures ii b llc'),
#  ('arizona limited maturity municipals portfolio',
#   'arizona limited maturity tax free portfolio'),
#  ('arizona municipals portfolio', 'arizona tax free portfolio'),
#  ('arkansas municipals portfolio', 'arkansas tax free portfolio'),
#  ('arlen capital advisors llc', 'arlen capital llc'),
#  ('armor electric inc', 'armor enterprises inc'),
#  ('arris pharmaceutical corp de', 'axys pharmaceuticals inc'),
#  ('arris pharmaceutical corp de', 'axys pharmecueticals inc'),
#  ('arris resources inc', 'bassett ventures inc'),
#  ('arrowmark fundamental opportunity fund l p',
#   'arrowpoint fundamental opportunity fund l p'),
#  ('arrowmark fundamental opportunity fund ltd',
#   'arrowpoint fundamental opportunity fund ltd'),
#  ('arrowmark global opportunity fund ii lp',
#   'arrowpoint global opportunity fund ii lp'),
#  ('arrowmark global opportunity fund ii ltd',
#   'arrowpoint global opportunity fund ii ltd'),
#  ('arrowmark income opportunity fund lp',
#   'arrowpoint income opportunity fund lp'),
#  ('arrowmark income opportunity fund ltd',
#   'arrowpoint income opportunity fund ltd'),
#  ('arrowmark income opportunity fund qp l p',
#   'arrowpoint income opportunity fund qp l p'),
#  ('arrowmark income opportunity fund qp ltd',
#   'arrowpoint income opportunity fund qp ltd'),
#  ('arsenal medical inc', 'arsenal vascular inc'),
#  ('artigent capital partners lp', 'artigent china strategic lp'),
#  ('artio global investment funds', 'bjb investment funds'),
#  ('artisan partners holdings lp', 'artisan partners ltd partnership'),
#  ('artisan pharma inc', 'artisan therapeutics inc'),
#  ('arvest bank trust division', 'arvest trust co'),
#  ('ascend alpha strategies fund ltd', 'ascend multi strategy fund ltd'),
#  ('ascend market neutral fund l p', 'ascend sequoia fund lp'),
#  ('ascend market neutral fund ltd', 'ascend sequoia offshore fund ltd'),
#  ('ascend offshore fund ltd', 'ascend partners fund i ltd'),
#  ('ascend offshore leveraged fund ltd', 'ascend partners fund ii ltd'),
#  ('ascend sequoia fund lp', 'ascend u s market neutral fund l p'),
#  ('ascend sequoia offshore fund ltd', 'ascend u s market neutral fund ltd'),
#  ('asiainfo holdings inc', 'asiainfo linkage inc'),
#  ('aspenbio inc', 'bioptix inc'),
#  ('aspeon inc', 'aspi inc'),
#  ('asset management fund for financial institutions inc',
#   'asset management fund inc'),
#  ('associated bank green bay na ta', 'associated trust co na ta'),
#  ('astra ab', 'astrazeneca ab'),
#  ('astra ab adr', 'astrazeneca ab'),
#  ('astralis ltd', 'astralis pharmaceuticals ltd'),
#  ('astro med inc new', 'astronova inc'),
#  ('at&t capital corp de', 'capita corp'),
#  ('atc funds inc', 'avalon funds inc'),
#  ('athene securities llc', 'aviva securities llc'),
#  ('atlantic blue group inc', 'atlantic blue trust inc'),
#  ('atlantis group inc de', 'atlantis plastics inc'),
#  ('atlas enhanced fund ltd', 'atlas leveraged fund ltd'),
#  ('atmi holdings inc', 'atmi inc'),
#  ('atrium securities inc', 'atrium trading inc'),
#  ('attara ltd', 'atticus european ltd'),
#  ('attend com inc', 'attendware inc'),
#  ('ault glazer & co llc', 'ault glazer bodnar securities llc'),
#  ('aureal inc', 'aureal semiconductor'),
#  ('aurora global opportunities asw fund',
#   'aurora global opportunities asw fund a series of alternative strategies platform llc'),
#  ('aurora global opportunities ii asp fund a series of alternative strategies platform llc',
#   'aurora global opportunitites ii asw fund'),
#  ('aurora global opportunitites ii asw fund',
#   'aurora global opportunitites ii asw fund a series of alternative strategies platform llc'),
#  ('autech corp', 'avtech corp'),
#  ('autonation com inc', 'autonationdirect com inc'),
#  ('av homes inc', 'avatar holdings inc'),
#  ('avalon bay communities inc', 'bay apartment communities inc'),
#  ('avalon community services inc', 'avalon correctional services inc'),
#  ('avalon energy corp', 'avalon gold corp'),
#  ('avalonbay communities inc', 'bay apartment communities inc'),
#  ('avanyx therapeutics inc', 'boston therapeutics inc'),
#  ('aviation sales distribution services co', 'aviation sales operating co'),
#  ('avion gold corp', 'avion resources corp'),
#  ('aviragen therapeutics inc', 'biota pharmaceuticals inc'),
#  ('avtech corp', 'avtechtyee inc'),
#  ('axial market inc', 'axial networks inc'),
#  ('axiom pharmaceuticals inc', 'axm pharma inc'),
#  ('axp federal income fund inc mn', 'axp government income series inc'),
#  ('axp income series inc', 'axp selective fund inc mn'),
#  ('b b funds', 'bjurman barry funds'),
#  ('b b funds', 'bjurman funds'),
#  ('b corp holdings inc', 'bakercorp international holdings inc'),
#  ('b8ta inc', 'beta retail inc'),
#  ('ba nutrition llc', 'body armor nutrition llc'),
#  ('ba residential securities inc', 'banc of america mortgage securities inc'),
#  ('ba sports nutrition llc', 'body armor nutrition llc'),
#  ('babe inc', 'bebe stores inc'),
#  ('babson capital funds trust', 'barings funds trust'),
#  ('babson capital global floating rate & income fund',
#   'babson capital global short duration high yield fund'),
#  ('babson capital global investment funds 2 plc',
#   'barings global investment funds 2 plc'),
#  ('babson capital global investment funds plc',
#   'barings global investment funds plc'),
#  ('babson capital global umbrella fund plc', 'barings umbrella fund plc'),
#  ('babson capital securities inc', 'babson securities corporation'),
#  ('babson capital securities inc', 'barings securities llc'),
#  ('babson capital securities llc', 'babson securities corporation'),
#  ('babson capital securities llc', 'barings securities llc'),
#  ('babson securities corporation', 'barings securities llc'),
#  ('bailard biehl & kaiser inc', 'bailard inc'),
#  ('bailard biehl & kaiser international fund group inc',
#   'bailard biehl & kaiser opportunity fund group inc'),
#  ('bailard biehl & kaiser international fund group inc',
#   'bailard opportunity fund group inc'),
#  ('bailard biehl & kaiser tehachapi accredited investor fund lp',
#   'bailard long short accredited investor fund lp'),
#  ('bailard biehl & kaiser tehachapi offshore fund ltd',
#   'bailard long short offshore fund ltd'),
#  ('bailard biehl & kaiser tehachapi onshore fund lp',
#   'bailard long short onshore fund lp'),
#  ('bailard fund services inc', 'bb&k fund services inc'),
#  ('bailard fund services inc', 'bb&k fund services inc bd'),
#  ('bain capital public equity management llc',
#   'brookside capital management llc'),
#  ('baker biotech capital iii gp llc',
#   'baker brothers life sciences capital gp llc'),
#  ('baker tim c', 'baker timothy c'),
#  ('ballad gold & silver ltd fi', 'ballad ventures ltd fi'),
#  ('ballantyne of omaha inc', 'ballantyne strong inc'),
#  ('ballentine finn & company inc', 'ballentine partners llc'),
#  ('bally entertainment corp', 'bally manufacturing corp'),
#  ('bam investments corp', 'bnn investments ltd'),
#  ('bamco inc ny', 'banco inc'),
#  ('banc fund iv l p', 'banc funds co llc'),
#  ('banc of america alt mtg p t cert series 2004 3',
#   'banc of america mort sec inc mort pas thr cert series 2004 3'),
#  ('banc of america finance services inc', 'banc of america futures inc bd'),
#  ('banc of america finance services inc',
#   'banc of america futures incorporated'),
#  ('banc of america mort sec inc alternative loan trust 2003 1',
#   'banc of america mort sec inc mort pass thr certs ser 2003 1'),
#  ('bank of america mort sec inc mort pas thr certs ser 2001 h',
#   'bank of america mortgage securities inc 2001 h'),
#  ('bank of america mort sec inc mort pass thr cert er 2002 2',
#   'bank of america mortgage securities inc 2002 b'),
#  ('bank of america mort sec inc mort pass thr cert ser 2002 2',
#   'bank of america mortgage securities inc 2002 2'),
#  ('bank of america mortgage sec inc mor pas thr ce se 2001 12',
#   'bank of america mortgage securities inc 2001 12'),
#  ('bank of new york delaware', 'bny mellon trust of delaware'),
#  ('bank of new york delaware the', 'bny mellon trust of delaware'),
#  ('bankers trust corp', 'bankers trust new york corp'),
#  ('bankmont financial co', 'bmo financial corp'),
#  ('bankmont financial inc', 'bmo financial corp'),
#  ('bankwell financial group inc', 'bnc financial group inc'),
#  ('banque paribas', 'bnp paribas'),
#  ('banque paribas', 'bnp paribas ny'),
#  ('banque paribas', 'bnp paribas sa'),
#  ('bar var securities corp bd', 'breezy securities inc'),
#  ('barclays global fund advisors', 'blackrock fund advisors'),
#  ('barclays global investors fund distribution company',
#   'blackrock fund distribution company'),
#  ('barclays private bank & trust cayman ltd', 'barclays trust co cayman ltd'),
#  ('barclays private bank & trust ltd', 'barclays trust co jersey ltd'),
#  ('baring asset management llc', 'baring north america llc'),
#  ('barnabus energy inc', 'barnabus enterprises ltd'),
#  ('barnstar opportunities master fund ltd',
#   'barnstar opportunities master fund spc segregated portfolio one'),
#  ('barr laboratories inc', 'barr pharmaceuticals inc'),
#  ('barr rosenberg funds distributor inc', 'bisys distribution services inc'),
#  ('barrow hanley core income fund',
#   'barrow hanley mewhinney & strauss core fixed income fund'),
#  ('barrow hanley diversifield large cap value fund',
#   'barrow hanley mewhinney & strauss diversified large cap value fund'),
#  ('barrow hanley international value fund',
#   'barrow hanley mewhinney & strauss international value fund'),
#  ('barrow hanley international value fund',
#   'barrow hanley mewhinney & strauss non us value fund'),
#  ('barrow hanley large cap value fund',
#   'barrow hanley mewhinney & strauss large cap value fund'),
#  ('barrow hanley long duration fixed income fund',
#   'barrow hanley mewhinney & strauss long credit fixed income fund'),
#  ('barrow hanley mewhinney & strauss diversified small cap value fund',
#   'barrow hasnley diversified small cap fund'),
#  ('basin water inc', 'basin water technology group inc'),
#  ('basswood financial partners lp', 'basswood opportunity partners l p'),
#  ('basswood international fund inc', 'basswood opportunity fund inc'),
#  ('baxger bros inc', 'baxter bros inc'),
#  ('bay colony securities co inc', 'bc securities inc'),
#  ('baynet ltd', 'bayou international ltd'),
#  ('bcp affiliates fund llc', 'broadview capital partners affiliates fund ll'),
#  ('bdc securities inc', 'bdirect securities inc ok bd'),
#  ('bdc securities llc', 'bdirect securities inc ok bd'),
#  ('beanstalk tax inc', 'canopy tax inc'),
#  ('bear stearns asset back sec inc mort pas thr ce se 03 abf1',
#   'bear stearns asset backed securities trust 2003 abf1'),
#  ('bear stearns asset backed sec inc asset back cert se 03 sd1',
#   'bear stearns asset backed securities trust 2003 sd1'),
#  ('bear stearns equity focus fund lp',
#   'bear stearns focused opportunities fund lp'),
#  ('bear stearns equity focus fund master ltd',
#   'bear stearns focused opportunities fund master ltd'),
#  ('beautykind holdings inc', 'beautykind llc'),
#  ('beese fulmer & pincoe inc', 'beese fulmer investment management inc'),
#  ('behringer harvard real estate investment trust i inc',
#   'behringer harvard reit i i inc'),
#  ('behringer harvard real estate investment trust i inc',
#   'behringer harvard reit i inc'),
#  ('belden 1993 inc', 'belden inc'),
#  ('belden cdt inc', 'belden inc'),
#  ('bell bank', 'bell state bank & trust'),
#  ('bell global trust', 'bell international trust'),
#  ('bengal investments ltd',
#   'bengal investments ltd spc segregated portfolio i'),
#  ('benham california tax free & municipal funds',
#   'benham california tax free trust'),
#  ('beranek cheri podzimek', 'beranek cheryl'),
#  ('beranek cheri podzimek', 'beranek cheryl p'),
#  ('berean capital inc', 'berean capital incorporated'),
#  ('berens credit opportunities fund l p',
#   'berens distressed opporntunities lp'),
#  ('berens credit opportunities fund l p',
#   'berens distressed opportunities fund l p'),
#  ('berens credit opportunities fund l p',
#   'berens distressed opportunities lp'),
#  ('berens credit opportunities fund ltd',
#   'berens distressed opportunities fund ltd'),
#  ('berenson & company llc', 'berenson minella & co llc bd'),
#  ('berger growth & income fund inc', 'berger large cap growth fund'),
#  ('berger growth & income fund inc', 'berger one hundred & one fund inc'),
#  ('berkeley capital management funds', 'berkeley funds trust'),
#  ('berkshire capital corporation', 'berkshire capital securities llc'),
#  ('berman capital llc', 'berman cohn llc bd'),
#  ('berry global group inc', 'berry plastics group inc'),
#  ('berry iowa llc', 'berry plastics ik llc'),
#  ('berry plastics acquisition corp vii', 'berry plastics opco inc'),
#  ('berry plastics holding corp', 'bpc holding corp'),
#  ('berwyn funds', 'berwyn income fund inc'),
#  ('beta capital management l p', 'beta capital securities llc'),
#  ('beta capital management lp', 'beta capital securities llc'),
#  ('beverly enterprises california inc', 'beverly healthcare california inc'),
#  ('bft financial group llc', 'butler freeman tally financial group llc'),
#  ('bg retail llc', 'brown group retail inc'),
#  ('bhp billiton ltd', 'bhp ltd'),
#  ('bhp billiton plc fi', 'billiton plc fi'),
#  ('bhp steel ltd', 'bluescope steel ltd'),
#  ('bi02 medical inc', 'bio2 medical inc'),
#  ('big 5 holdings corp', 'big 5 sporting goods corp'),
#  ('big equipment services inc', 'bigequip net inc'),
#  ('bimini capital management inc', 'bimini mortgage management inc'),
#  ('binks estates limited partnership', 'binks estates lp'),
#  ('biolase inc', 'biolase technology inc'),
#  ('biolex inc', 'biolex therapeutics inc'),
#  ('biomimetic pharmaceuticals inc', 'biomimetic therapeutics inc'),
#  ('bion pharmaceuticals inc', 'bionpharma inc'),
#  ('bionano genomics inc', 'bionanomatrix inc'),
#  ('biosepra inc', 'biosphere medical inc'),
#  ('biosite diagnostics inc', 'biosite inc'),
#  ('biovail corp', 'biovail corp international'),
#  ('bird estate limited partnership', 'bird estate lp'),
#  ('bkd corporate finance llc', 'bkd financial l l c'),
#  ('black diamond mortgage opportunity ii l p',
#   'black diamond structured opportunities partners ii l p'),
#  ('black diamond mortgage opportunity ii lp',
#   'black diamond structured opportunities partners ii l p'),
#  ('black diamond oc offshore fund ltd',
#   'black diamond structured opportunities ltd'),
#  ('black rock dividend achievers trust', 'blackrock equity dividend trust'),
#  ('black strategic fund lp', 'calamos arista strategic fund lp'),
#  ('black strategic master fund ltd',
#   'calamos arista strategic master fund ltd'),
#  ('blackpier atlas fund lp', 'blackpier market neutral fund l p'),
#  ('blackrock build america bond trust',
#   'blackrock taxable municipal bond trust'),
#  ('blackrock capital & income strategies fund inc',
#   'blackrock enhanced capital & income fund inc'),
#  ('blackrock capital investment corp', 'blackrock kelso capital corp'),
#  ('blackrock credit allocation income trust',
#   'blackrock preferred & equity advantage trust'),
#  ('blackrock credit opportunities trust',
#   'blackrock fixed income value opportunities'),
#  ('blackrock defined opportunity credit trust',
#   'blackrock strategic income opportunities trust'),
#  ('blackrock developing capital markets fund inc',
#   'blackrock emerging markets fund inc'),
#  ('blackrock developing capital markets fund inc',
#   'blackrock global emerging markets fund inc'),
#  ('blackrock diamond property fund inc',
#   'blackrock income & growth property fund inc'),
#  ('blackrock diamond property inc',
#   'blackrock income & growth property fund inc'),
#  ('blackrock dividend achievers trust', 'blackrock equity dividend trust'),
#  ('blackrock dividend income trust', 'blackrock s&p quality rankings trust'),
#  ('blackrock enhanced capital & income fund inc',
#   'capital & income strategies fund inc'),
#  ('blackrock enhanced dividend achievers trust',
#   'blackrock enhanced equity dividend trust'),
#  ('blackrock fixed income strategic opportunities',
#   'blackrock multi sector income trust'),
#  ('blackrock fixed income trust', 'blackrock funds ii'),
#  ('blackrock floating rate income trust',
#   'blackrock global inflation protected securities trust'),
#  ('blackrock floating rate income trust',
#   'blackrock variable rate & inflation protected securities'),
#  ('blackrock focus growth fund inc', 'blackrock focus twenty fund inc'),
#  ('blackrock global dynamic equity fund',
#   'blackrock long horizon equity fund'),
#  ('blackrock global floating rate income trust',
#   'blackrock global inflation protected securities trust'),
#  ('blackrock holdco 2 inc', 'blackrock inc ny'),
#  ('blackrock income opportunity trust inc',
#   'blackrock north american government income trust inc'),
#  ('blackrock liquidity funds', 'blackrock provident institutional funds'),
#  ('blackrock mid cap dividend series inc',
#   'blackrock mid cap value opportunities series inc'),
#  ('blackrock prime rate trust', 'blackrock senior income trust'),
#  ('blackrock strategic dividend achievers trust',
#   'blackrock strategic equity dividend trust'),
#  ('blackstone fifth ave offshore fund ltd',
#   'blackstone fifth avenue offshore fund ltd class a d f k & l shares'),
#  ('blackstone gso dynamic credit income fund',
#   'blackstone gso long short credit income fund'),
#  ('blackstone madison ave offshore fund ltd',
#   'blackstone madison avenue offshore fund ltd class a b c & g shares'),
#  ('bli holding inc', 'bli holdings corp'),
#  ('blue arch coal co', 'blue arch resources inc'),
#  ('blue point capital partners ii executive fund l p',
#   'blue point oeg fund ii l p'),
#  ('blue rock capital fund l p', 'blue rock capital fund limited partnership'),
#  ('blue rock core equity portable alpha fund i l p',
#   'blue rock equity plus fund l p'),
#  ('blue rock core equity prtable alpha fund i l p',
#   'blue rock equity plus fund l p'),
#  ('blue rock market neutral fund llc', 'blue rock registered fund llc'),
#  ('blue water strategic currency fund i llc',
#   'blue water total return fund i l p'),
#  ('bluerock enhanced multifamily reit inc',
#   'bluerock enhanced residential reit inc'),
#  ('bluerock enhanced multifamily trust inc',
#   'bluerock enhanced residential reit inc'),
#  ('bluerock multifamily growth reit inc',
#   'bluerock residential growth reit inc'),
#  ('bmo harris investment management inc',
#   'bmo private investment counsel inc'),
#  ('bnp paribas exchange traded trust', 'bnp paribas l s commodities trust'),
#  ('bny brokerage inc', 'bny esi & co inc'),
#  ('bogle investment fund lp', 'bogle opportunity fund ii l p'),
#  ('bogle offshore investment fund ltd',
#   'bogle offshore opportunity fund ii sri ltd'),
#  ('boise building solutions manufacturing holdings corp',
#   'boise cascade wood products holdings corp'),
#  ('bonanza resources corp', 'brs resources ltd'),
#  ('bonde hank', 'bonde john h'),
#  ('bonny paul a', 'bonny pual v'),
#  ('bonny paul v', 'bonny pual v'),
#  ('borden chemical inc', 'borden inc'),
#  ('boren kim', 'boren kimberly'),
#  ('bosco flooring inc', 'bosco holdings inc'),
#  ('boss gold corp fi', 'boss power corp fi'),
#  ('boss gold international corp fi', 'boss power corp fi'),
#  ('boston capital securities inc', 'boston capital services inc'),
#  ('boston heart diagnostics corp', 'boston heart lab corp'),
#  ('boston private wealth llc', 'bp wealth management llc'),
#  ('bow capital fund i lp', 'bow ventures fund i lp'),
#  ('bp amoco plc', 'bp plc'),
#  ('bpv capital management llc', 'bpv wealth management llc'),
#  ('bpy canada subholdings 2 ulc', 'canholdco 2 ulc'),
#  ('bpy canada subholdings 3 ulc', 'canholdco 3 ulc'),
#  ('bpy canada subholdings 4 ulc', 'canholdco 4 ulc'),
#  ('bradley linda jacobsen', 'bradley mckee linda j'),
#  ('brahman capital corp bd', 'brahman securities inc bd'),
#  ('brar investment capital llc', 'brar investment fund lp'),
#  ('brasada absolute return fund lp', 'brasada value opportunites fund lp'),
#  ('brasada absolute return fund lp', 'brasada value opportunities fund lp'),
#  ('brasada long short equity fund lp', 'brasada strategic growth fund lp'),
#  ('brascan technology fund', 'brookfield technology fund'),
#  ('brean capital llc', 'brean murray carret & co llc'),
#  ('bridgeline digital inc', 'bridgeline software inc'),
#  ('bright mountain acquisition corp', 'bright mountain media inc'),
#  ('brightstream institutional llc', 'brightwater institutional llc'),
#  ('brightstream international ltd', 'brightwater international ltd'),
#  ('brio software inc', 'brio technology inc'),
#  ('britesmile inc', 'bsml inc'),
#  ('broadmark dynamic enhanced equity alpha fund ltd',
#   'broadmark long short equity fund ltd'),
#  ('broadmark futures fund ltd', 'broadmark long short equity fund ltd'),
#  ('broadmark opportunity offshore ltd',
#   'broadmark value hedged offshore fund ltd'),
#  ('broadwview holding llp', 'bv holdings llp'),
#  ('brock financial services llc', 'brock securities llc'),
#  ('brokertec americas llc', 'brokertec usa llc bd'),
#  ('bronczek david j', 'bronezck david j'),
#  ('brooklyn craft works llc', 'brooklyn distilling co llc'),
#  ('brown burke securities inc bd', 'burke securities llc'),
#  ('brown group inc', 'brown shoe co inc'),
#  ('brummett alison', 'burcar alison d'),
#  ('brummett burcar alison', 'burcar alison d'),
#  ('bryne niall j', 'byrne niall j'),
#  ('bt advisor funds', 'bt global advisors'),
#  ('btm financial services inc', 'btmu securities inc'),
#  ('btmu financial services inc', 'btmu securities inc'),
#  ('bueter & co inc bd', 'bueter and company inc'),
#  ('buffalo high yield fund inc', 'buffalo premium income fund inc'),
#  ('builders fixed income fund inc', 'builders proloan fund inc'),
#  ('bulldog fund inc', 'bullfinch fund inc'),
#  ('burke trading limited partnership', 'burke trading lp bd'),
#  ('burlington holdings inc', 'burlington stores inc'),
#  ('buscar co', 'buscar oil inc'),
#  ('bush odonnell & co inc', 'bush odonnell investment advisors inc'),
#  ('bwip holding inc', 'bwip inc'),
#  ('c & c tours inc', 'c&c tours inc'),
#  ('c & l securities corporation', 'c&l securities corp bd'),
#  ('c cor electronics inc', 'c cor inc'),
#  ('c cube microsystems inc de', 'c cube semiconductor inc'),
#  ('cadogan alternative strategies ii llc',
#   'cadogan opportunistic alternatives fund llc'),
#  ('cadogan alternative strategies ii llc',
#   'cantor opportunistic alternatives fund llc'),
#  ('calamos advisors trust il', 'calamos insurance trust'),
#  ('calamos global diversified income & opportunities fund',
#   'calamos global dynamic income fund'),
#  ('caldera corp', 'caplan corp'),
#  ('caldera international inc ut', 'caldera systems inc'),
#  ('calient networks inc', 'calient technologies inc'),
#  ('california limited maturity municipals portfolio',
#   'california limited maturity tax free portfolio'),
#  ('california limited maturity tax free portfolio',
#   'california ltd maturity municipals portfolio'),
#  ('california municipals portfolio', 'california tax free portfolio'),
#  ('caliper life sciences inc', 'caliper technologies corp'),
#  ('calix inc', 'calix networks inc'),
#  ('calliance realty fund llc',
#   'calliance realty fund llc advisors mortgage division'),
#  ('callinan mines limited', 'callinan royalties corp'),
#  ('calvert 2000 series inc', 'calvert responsible index series inc'),
#  ('calvert 2000 series inc', 'calvert social index series inc'),
#  ('calvert management series', 'calvert tax free reserves'),
#  ('cambria global tactical fund 2x lp', 'cambria special situations fund lp'),
#  ('camden partners lp', 'camden partners ltd partnership'),
#  ('campbell institutional multi strategy investment fund ltd',
#   'campbell long short equity investment fund ltd'),
#  ('campbell newman asset management inc',
#   'campbell newman pottinger & associates inc'),
#  ('campussims inc', 'campustvs inc'),
#  ('can capital inc', 'capital access network inc'),
#  ('canaccord adams inc', 'canaccord genuity inc'),
#  ('canamex resources corp', 'canamex silver corp'),
#  ('candente copper corp', 'candente resource corp'),
#  ('canney ricardo rodriguez', 'canney richard r'),
#  ('canterbury consulting group inc', 'canterbury corporate services inc'),
#  ('canterbury corporate services inc',
#   'canterbury information technology inc'),
#  ('cap gemini sa adr', 'capgemini se adr'),
#  ('capfinancial partners llc', 'capfinancial securities llc'),
#  ('capital conservation corp', 'capital preservation fund l p'),
#  ('capital group absolute income grower common trust us',
#   'capital guardian absolute income grower fd for tax exe tru'),
#  ('capital group all country world equity common trust us',
#   'capital guardian all country world equity fd tax exem tr'),
#  ('capital group companies inc', 'capital group inc'),
#  ('capital group companies inc et al', 'capital group inc'),
#  ('capital group emerging markets debt common trust us',
#   'capital guardian emerging markets debt fund for tax exempt trusts'),
#  ('capital group emerging markets equity common trust us',
#   'capital guardian emerging markets equity fund for tax exempt trusts'),
#  ('capital group emerging markets restricted equity common trust us',
#   'capital guardian emerging markets restricted equity fund for tax exempt trusts'),
#  ('capital group emerging markets total opportunities common trust us',
#   'capital guardian emerging markets total opportunities fund for tax exempt trusts'),
#  ('capital group emerging markets total opportunities common trust us',
#   'capital guardian energing markets total opportunities fund for tax exempt trusts'),
#  ('capital group emerging markets us dollar debt common trust us',
#   'capital guardian emerging markets debt usd fund for tax exempt trusts'),
#  ('capital group global equity common trust us',
#   'capital guardian global equity fund for tax exempt trusts'),
#  ('capital group international all countries equity common trust us',
#   'capital guardian all country world ex us equity fund for tax exempt trusts'),
#  ('capital group international all countries equity common trust us',
#   'capital guardian international all countries equity fund for tax exempt trusts'),
#  ('capital group international equity common trust us',
#   'capital guardian international equity fund for tax exempt trusts'),
#  ('capital group international equity common trust us',
#   'capital guardian international non us equity fund for tax exe tr'),
#  ('capital group international equity common trust us',
#   'capital guardian international non us equity fund for tax tr'),
#  ('capital group us core fixed income common trust us',
#   'capital guardian u s core fixed income fund for tax exempt trusts'),
#  ('capital one auto finance trust 2001 b',
#   'capital one auto receivables trust 2001 b'),
#  ('capital one auto finance trust 2002 b',
#   'capital one auto receivables trust 2002 b'),
#  ('capital one auto rec llc capital one prime auto rec tr 03 2',
#   'capital one prime auto receivables trust 2003 2'),
#  ('capital one securities inc', 'capital one southcoast inc'),
#  ('capital square investment trust', 'capitol square funds')}

# %%
ann_pairs - true_pairs
# Out:
# {('american express financial advisors', 'american express financial corp ta'),
#  ('a t a p financial services inc', 'bolton financial services llc bd'),
#  ('1 lane technologies corp', 'calient technologies inc'),
#  ('barclays bank plc', 'barclays private bank & trust cayman ltd'),
#  ('american realty capital trust ii inc', 'american realty trust inc'),
#  ('bencmark capital management co llc', 'berkeley capital management funds'),
#  ('advisors disciplined trust 50', 'advisors discliplined trust series 20'),
#  ('amalgamated bank', 'amalgamated bank longview funds'),
#  ('advisors disciplined trust 52', 'advisors disciplined trust series 57'),
#  ('ammon robert j', 'beckman robert j'),
#  ('alpine associates l p', 'amici associates l p'),
#  ('capital guardian international all countries equity fund for tax exempt trusts',
#   'capital guardian international non us equity fund for tax tr'),
#  ('ascent acquisition corp', 'ascent acquisition psc llc'),
#  ('aegis investments inc bd', 'altegris investments llc'),
#  ('barneys america ca lease corp', 'barneys america ny lease corp'),
#  ('canholdco 2 ulc', 'canholdco 4 ulc'),
#  ('blackstone fifth avenue fund lp',
#   'blackstone park avenue non taxable fund l p'),
#  ('advisoros disciplined trust 716', 'advisors disciplined trust series 72'),
#  ('banc of america mort sec inc mort pass thr certs ser 2003 1',
#   'banc one mortgage sec inc mort pass thr certs ser 2003 9'),
#  ('alphametrix managed futures iv llc',
#   'alphametrix managed futures llc aspect series'),
#  ('alliance securities corp', 'asset allocation securities corp bd'),
#  ('aqr tax plus global relaxed constraint equity fund l p',
#   'aqr tax plus u s hedged equity fund l p'),
#  ('aimco properties l p', 'all state properties lp'),
#  ('brahman capital corp bd', 'cahn capital corp'),
#  ('argos funds sicav argos funds the bamboo fund',
#   'argos funds sicav in respect of argos funds argonaut fund'),
#  ('advisors disciplined trust 57', 'advisors disciplined trust series 52'),
#  ('cancer prevention pharmaceuticals inc', 'canyon pharmaceuticals inc'),
#  ('alternative investments institutional lp',
#   'amundi alternative investments llc'),
#  ('advisors disciplined trust 71', 'advisors disciplined trust 716'),
#  ('baker timothy c', 'barton timothy a'),
#  ('blackrock new york insured municipal income trust',
#   'blackrock new york municipal 2020 term trust'),
#  ('american securities opportunities fund ii b lp',
#   'american securities opportunities fund iii l p'),
#  ('anchor bay securities llc bd', 'bayou securities llc bd'),
#  ('american securities corp', 'american securities team inc'),
#  ('advisors disciplined trust series 71',
#   'advisors disciplined trust series 72'),
#  ('brock securities llc', 'bulltick securities llc'),
#  ('aberdeen global income fund inc',
#   'aberdeen global short duration income fund inc'),
#  ('achelios therapeutics', 'bolt therapeutics inc'),
#  ('a c r securities inc', 'bates securities inc bd'),
#  ('americal securities inc bd', 'american heritage securities inc'),
#  ('access securities inc bd', 'acci securities inc bd'),
#  ('blackstone capital partners delaware nq v ac l p',
#   'blackstone capital partners delaware v nq l p'),
#  ('advisors disciplined trust 74', 'advisors disciplined trust series 71'),
#  ('abbey capital multi manager fund', 'ark multi manager fund lp'),
#  ('barrow hanley diversifield large cap value fund',
#   'barrow hanley international value fund'),
#  ('bt insurance funds trust ma', 'calamos insurance trust'),
#  ('blackrock municipal income investment trust',
#   'blackrock municipal income trust iii'),
#  ('broadway brokerage services inc bd',
#   'bull & bear brokerage services inc bd'),
#  ('blackrock municipal bond investment trust',
#   'blackrock municipal income trust iii'),
#  ('adventrx pharmaceuticals inc', 'app pharmaceuticals inc'),
#  ('adar investment management lp', 'cambria investment management l p'),
#  ('american capital llc', 'american realty capital ii llc'),
#  ('bright horizons childrens centers inc',
#   'bright horizons family solutions inc'),
#  ('abraham & co inc', 'abraham & london securities inc bd'),
#  ('aer energy resources inc ga', 'aurora energy respurces inc'),
#  ('advisors disciplined trust 437', 'advisors disciplined trust 47'),
#  ('advisors disciplined trust 641', 'advisors disciplined trust series 64'),
#  ('blackstone market opportunities fund l p',
#   'blackstone pacific opportunities master fund lp'),
#  ('bcmcredit opportunities fund lp', 'berens credit opportunities fund l p'),
#  ('acr securities inc bd', 'ancora securities inc'),
#  ('access capital investment group inc', 'acer investment group llc bd'),
#  ('c p atlas holdings inc', 'c t holdings inc'),
#  ('argos funds sicav argos funds argonaut fund',
#   'argos funds sicav argos funds yield opportunities'),
#  ('accipiter capital management', 'altimeter capital management lp'),
#  ('anika therapeutics inc', 'ascent therapeutics inc'),
#  ('absolute value fund llp', 'bsp absolute fund of funds lp'),
#  ('c p atlas holdings inc', 'cali holdings inc'),
#  ('blackrock equity dividend trust',
#   'blackrock global enhanced equity income trust'),
#  ('adventrx pharmaceuticals inc', 'bion pharmaceuticals inc'),
#  ('bailard biehl & kaiser international fund group inc',
#   'bailard biehl & kaiser tehachapi offshore fund ltd'),
#  ('asci holdings germany de inc', 'asci holdings mexico de inc'),
#  ('aon asset management fund inc', 'ar asset management inc'),
#  ('barclays private bank & trust cayman ltd',
#   'barclays private bank & trust ltd'),
#  ('ares leveraged investment fund corp ii', 'cap iii co investment lp'),
#  ('blackrock florida municipal bond trust',
#   'blackrock insured municipal income investment trust'),
#  ('advisors disciplined trust 64', 'advisors disciplined trust 641'),
#  ('biomimetic therapeutics inc', 'bolt therapeutics inc'),
#  ('blackrock muniyield florida fund',
#   'blackrock muniyield michigan insured fund ii inc'),
#  ('ascend partners fund ii ltd', 'ascend partners lp'),
#  ('alternative investments institutional ltd', 'alternative investments lp'),
#  ('baker timothy c', 'brog timothy'),
#  ('artemis investment management llc', 'cambria investment management inc'),
#  ('black rock dividend achievers trust',
#   'blackrock mid cap dividend series inc'),
#  ('actimis pharmaceuticals inc', 'canyon pharmaceuticals inc'),
#  ('blackrock municipal series trust',
#   'blackrock taxable municipal bond trust'),
#  ('barrow hanley high yield fixed income fund',
#   'barrow hanley long duration fixed income fund'),
#  ('altegris multi strategy fund lp', 'beacon rock multi strategy fund llc'),
#  ('anchor capital advisors llc', 'capital asset advisors inc bd'),
#  ('all energy corp', 'bt energy corp'),
#  ('abraham & co inc', 'abraham & london securities inc'),
#  ('brahman c p f partners lp', 'brahman institutional partners l p'),
#  ('american municipal securities inc', 'american securities team inc bd'),
#  ('bhp ltd', 'bhp steel ltd'),
#  ('bourne lent asset management inc',
#   'bourne stenstrom capital management inc'),
#  ('answer think consulting group inc', 'answerthink inc'),
#  ('american caresouce holdings inc', 'american renal associates holdings inc'),
#  ('aqr us long short equity equity fund lp',
#   'brasada long short equity fund lp'),
#  ('bridgeline software inc', 'brio software inc'),
#  ('agricapital securities inc bd', 'brinker capital securities inc'),
#  ('atlantic securities inc bd', 'atlas securities inc bd'),
#  ('amsouth investment services inc', 'bancorpsouth investment services inc'),
#  ('apex therapeutics inc', 'bolt therapeutics inc'),
#  ('alternative investment institutional ltd',
#   'alternative investments institutional lp'),
#  ('blackstone vanderbilt avenue offshore fund ltd',
#   'blackstone york avenue offshore fund ltd'),
#  ('bear stearns asset back sec inc mort pas thr ce se 03 abf1',
#   'bear stearns asset backed sec inc asset back cert se 03 sd1'),
#  ('alles investments inc bd', 'arrow investments inc'),
#  ('canandaigua b v', 'canandaigua west inc'),
#  ('abdiel capital advisors llc', 'anchor capital advisors inc'),
#  ('ab portfolios', 'alliancebernstein pooling portfolios'),
#  ('adage capital partners gp llc', 'adage capital partners l p'),
#  ('access financial group inc', 'bossio financial group inc'),
#  ('advisors disciplined trust 57', 'advisors disciplined trust series 59'),
#  ('allianz global investors of america l p',
#   'allianz global investors total return trust'),
#  ('americal securities inc bd', 'american securities bd co lp'),
#  ('alliancebernstein investment research and management inc',
#   'alliancebernstein investor services inc ta'),
#  ('american securities bd co lp', 'american securities team inc bd'),
#  ('akiba technologies inc', 'asyst technologies inc ca'),
#  ('ag diversified credit strategies fund ltd',
#   'atlantic trust diversified strategies fund fund llc'),
#  ('advisors disciplined trust 54', 'advisors disciplined trust 590'),
#  ('berkshire capital securities llc', 'beta capital securities llc'),
#  ('berry plastics acquisition corp', 'berry plastics acquisition llc x'),
#  ('altegris equity long short fund l p', 'brasada long short equity fund lp'),
#  ('brahman institutional partners l p', 'brahman partners iii l p'),
#  ('amstar financial services inc', 'calamos financial services llc'),
#  ('aurora global opportunitites ii asw fund a series of alternative strategies platform llc',
#   'blue trend asw fund a series of alternative strategies managed futures & commodities platform llc'),
#  ('brandes investment partners l p', 'broadbill investment partners lp'),
#  ('alliance municipal income fund ii', 'alliance municipal income fund inc'),
#  ('ani pharmaceuticals inc', 'barr pharmaceuticals inc'),
#  ('blackrock california municipal income trust iii',
#   'blackrock municipal income investment trust'),
#  ('bright horizons family solutions llc', 'bright horizons inc'),
#  ('advent central & eastern europe iii b ltd partnership',
#   'advent healthcare & life sciences iii limited partnership'),
#  ('acunto john p jr', 'calonico john e jr'),
#  ('ba sometros market neutral fund l p', 'blue rock market neutral fund llc'),
#  ('access financial group inc', 'bg financial group inc'),
#  ('american financial group holdings inc',
#   'american patriot financial group inc'),
#  ('brar investment fund lp', 'bristol investment fund inc'),
#  ('aetos distressed investment strategies fund llc',
#   'aetos long short strategies fund llc'),
#  ('bear stearns trust mortgage pass through certs ser 2004',
#   'bear sterns alt a trust mort pass thr certs sers 2003 6'),
#  ('advisors disciplined trust 75', 'advisors disciplined trust series 76'),
#  ('barrow hanley mewhinney & strauss diversified large cap value fund',
#   'barrow hanley mewhinney & strauss inc'),
#  ('blackrock california insured municipal income trust',
#   'blackrock florida investment quality municipal trust'),
#  ('alliance growth & income fund inc',
#   'capital world growth & income fund inc'),
#  ('aurora global opportunities ii asp fund a series of alternative strategies platform llc',
#   'blue trend asw fund a series of alternative strategies managed futures & commodities platform llc'),
#  ('accipiter capital management', 'altimeter capital management llc'),
#  ('capital careresources inc', 'capital careresources of south carolina inc'),
#  ('andor capital management llc', 'basso capital management l p'),
#  ('advisors disciplined trust 74', 'advisors disciplined trust series 72'),
#  ('banc one mortgage sec inc mort pass thr certs ser 2003 9',
#   'bank of america mortgage sec mor pa th cert ser 2002 f'),
#  ('a & m securities llc bd', 'aca securities llc bd'),
#  ('alden global opportunities fund cayman l p',
#   'alden global opportunities fund lp'),
#  ('advisor disciplined trust 645', 'advisors disciplined trust 64'),
#  ('abn amro asset management holdings inc',
#   'abn amro asset management usa inc'),
#  ('amsouth investment services inc', 'borst investment planning services inc'),
#  ('ariel capital management inc et al', 'capital management partners inc bd'),
#  ('arrowstreet eafe alpha extension fund ii a sub fund of arrowstreet multi strategy umbrella plc',
#   'arrowstreet emerging market fund iii a sub fund of arrowstreet multi strategy umbrella plc'),
#  ('blackrock florida investment quality municipal trust',
#   'blackrock insured municipal income trust'),
#  ('bg holdings ii inc', 'bli holding inc'),
#  ('alphametrix managed futures ii llc',
#   'alphametrix managed futures llc aspect series'),
#  ('advisors disciplined trust 49', 'advisors discliplined trust series 19'),
#  ('bogle offshore opportunity fund ii ltd',
#   'broadmark opportunity offshore ltd'),
#  ('american realty capital global trust inc', 'american realty trust inc'),
#  ('bechtel financing services llc bd', 'birchtree financial services inc'),
#  ('access investments inc', 'alles investments inc'),
#  ('banc of america mort sec inc mort pass thr certs ser 2003 1',
#   'bank of america mortgage sec inc mor pas thr ce se 2001 12'),
#  ('accumulus emerging managers fund lp', 'blue rock emerging manager fund lp'),
#  ('allianz global investors capital total return trust',
#   'allianz global investors of america l p'),
#  ('blackrock muniyield florida insured fund',
#   'blackrock muniyield michigan insured fund inc'),
#  ('capital investment brokerage inc', 'capital investments inc'),
#  ('blue rock emerging manager fund l p', 'burnham emerging managers fund lp'),
#  ('blackrock muniholdings new york insured fund inc',
#   'blackrock muniholdings quality fund inc'),
#  ('brokerageamerica llc', 'brokertec americas llc'),
#  ('blackrock credit allocation income trust ii inc',
#   'blackrock multi sector income trust'),
#  ('blackrock muniyield insured investment fund',
#   'blackrock muniyield quality fund iii inc'),
#  ('barrow hanley mewhinney & strauss core fixed income fund',
#   'barrow hanley mewhinney & strauss inc'),
#  ('borden chemical foundry llc', 'borden chemical inc'),
#  ('access financial group inc bd', 'bossio financial group inc bd'),
#  ('alcoa corp', 'alcoa inc'),
#  ('aei serious materials investments i llc', 'aei sermat investments ii llc'),
#  ('american securities opportunities fund iii l p',
#   'ascribe opportunities fund ii b lp'),
#  ('ayre investments inc', 'barclay investments inc bd'),
#  ('brahman partners ii l p', 'brahman partners iv lp'),
#  ('a p securities inc', 'bates securities inc bd'),
#  ('aim advisor funds', 'bt advisor funds'),
#  ('aston asset management lp', 'boston partners asset management llc'),
#  ('camelot capital lp', 'candela capital lp'),
#  ('ascend market neutral fund l p', 'ascend u s market neutral fund ltd'),
#  ('aramark food service corp of texas llc', 'aramark food service llc'),
#  ('blackrock dividend achievers trust',
#   'blackrock mid cap dividend series inc'),
#  ('austin securities inc', 'cabin securities inc'),
#  ('arrowmark fundamental opportunity fund ltd',
#   'arrowmark global opportunity fund ii ltd'),
#  ('ab institutional funds inc', 'alger institutional fund'),
#  ('archview fund l p', 'archview offshore fund ltd'),
#  ('aramark corp', 'aramark worldwide corp'),
#  ('blackstone capital partners cayman nq v ac l p',
#   'blackstone capital partners delaware v nq l p'),
#  ('bain capital partners lp', 'berens capital partners lp'),
#  ('blackrock emerging markets fund inc',
#   'blackstone emerging markets fund i lp'),
#  ('california ltd maturity municipals portfolio',
#   'california municipals portfolio'),
#  ('ac trading inc', 'c & c trading inc'),
#  ('asset securitization corp com mor pass thr cer ser 1997 md',
#   'asset securitization corp comm mort pass thr cert 1996 d3'),
#  ('campbell global trend fund l p', 'campbell world trend fund l p'),
#  ('amstar financial services inc', 'callahan financial services inc'),
#  ('barrow hanley mewhinney & strauss large cap value fund',
#   'barrow hanley mewhinney & strauss non us value fund'),
#  ('asset alliance investment services inc',
#   'bancorpsouth investment services inc bd'),
#  ('american century capital preservation fund inc',
#   'capital preservation fund l p'),
#  ('american fidelity financial services inc',
#   'calamos financial services inc'),
#  ('advantage advisers technology fund llc',
#   'advantage advisers technology partners llc'),
#  ('arconic inc', 'arctic cat inc'),
#  ('campbell & co inc md', 'campbell & co inc ta'),
#  ('aig international securities inc',
#   'banorte securities international ltd bd'),
#  ('american dental technologies inc', 'american electric technologies inc'),
#  ('blackrock muniyield california quality fund inc',
#   'blackrock muniyield michigan insured fund inc'),
#  ('a ch securities inc bd', 'a p securities inc bd'),
#  ('blackrock california municipal 2020 term trust',
#   'blackrock municipal 2020 term trust'),
#  ('aca securities llc bd', 'ama securities llc'),
#  ('allied holdings inc', 'c t holdings inc'),
#  ('brahman c p f partners lp', 'brahman partners ii l p'),
#  ('berry plastics acquisition corp', 'berry plastics acquisition corp x'),
#  ('apg asset management us inc', 'athene asset management l p'),
#  ('blackrock florida municipal 2020 term trust',
#   'blackrock municipal target term trust'),
#  ('bailard biehl & kaiser fund group inc', 'bailard biehl & kaiser inc'),
#  ('armetis investment management llc', 'bt investment management ltd'),
#  ('a i m distributors inc bd', 'ariel distributors llc'),
#  ('allen & co inc bd', 'allen c ewing & co bd'),
#  ('alliancebernstein large cap growth fund inc',
#   'alliancebernstein small mid cap growth fund'),
#  ('blackrock florida municipal income trust iii',
#   'blackrock municipal bond investment trust'),
#  ('advisors disciplined trust 75', 'advisors disciplined trust 76'),
#  ('aetna inc ct', 'aetna services inc ct'),
#  ('basf aktiengesellschaft fa', 'brokat aktiengesellschaft'),
#  ('aim treasurers series funds inc',
#   'aim treasurers series trust invesco treasurer s series trust'),
#  ('alcan securities corp', 'asset allocation securities corp'),
#  ('avanir pharmaceuticals inc', 'biosante pharmaceuticals inc'),
#  ('capital guardian emerging markets restricted equity fund for tax exempt trusts',
#   'capital guardian emerging markets total opportunities fund for tax exempt trusts'),
#  ('anchortherapeutics inc', 'artisan therapeutics inc'),
#  ('capital guardian emerging markets equity fund for tax exempt trusts',
#   'capital guardian emerging markets total opportunities fund for tax exempt trusts'),
#  ('blackrock new york insured municipal 2008 term trust inc',
#   'blackrock new york municipal 2022 term trust'),
#  ('allostem therapeutics llc', 'bellerophon therapeutics inc'),
#  ('averil capital markets group inc', 'capital group inc'),
#  ('bank of america mortgage securities inc 2001 12',
#   'bank of america mortgage securities inc 2002 b'),
#  ('a i m distributors inc', 'aquila distributors inc'),
#  ('biokeys pharmaceuticals inc', 'biosante pharmaceuticals inc'),
#  ('advisors disciplined trust 53', 'advisors disciplined trust 54'),
#  ('brahman c p f partners l p', 'brahman institutional partners lp'),
#  ('artal international sa', 'capital international sarl'),
#  ('adage capital partners gp l l c', 'adage capital partners lp'),
#  ('blackrock new york municipal 2020 term trust',
#   'blackrock new york municipal income quality trust'),
#  ('asci holdings mexico de inc', 'asci holdings uk de inc'),
#  ('canyon balanced equity fund l p', 'canyon balanced fund cayman ltd'),
#  ('allmerica select sep acct ii of allmerica fin life ins co',
#   'allmerica select separate account of allmer fn lf ins & an c'),
#  ('alliance bond fund inc', 'alliance fund inc'),
#  ('ama internatinal equity fund lp',
#   'bp capital energy equity fund international i lp'),
#  ('capital guardian global equity fund for tax exempt trusts',
#   'capital guardian international non us equity fund for tax tr'),
#  ('barrow hanley mewhinney & strauss large cap value fund',
#   'barrow hanley mewhinney & strauss long credit fixed income fund'),
#  ('allete inc', 'allette inc ta'),
#  ('brahman partners ii lp', 'brahman partners iv lp'),
#  ('blackrock credit allocation income trust', 'blackrock senior income trust'),
#  ('blackrock capital investment corp', 'blackrock investments inc bd'),
#  ('blackrock muniyield insured investment fund',
#   'blackrock muniyield michigan insured fund inc'),
#  ('altimeter capital management lp', 'andor capital management l l c'),
#  ('blackstone fifth avenue fund l p', 'blackstone madison avenue fund l p'),
#  ('alternative investments institutional ltd',
#   'american alternative investments corp'),
#  ('blackrock muniyield insured fund inc',
#   'blackrock muniyield michigan insured fund inc'),
#  ('ani pharmaceuticals inc', 'avanir pharmaceuticals'),
#  ('arrowpoint fundamental opportunity fund ltd',
#   'arrowpoint income opportunity fund qp ltd'),
#  ('aurora global opportunities asp fund a series of alternative strategies platform llc',
#   'blue trend asp fund a series of alternative strategies managed futures & commodities platform llc'),
#  ('advisors disciplined trust series 61',
#   'advisors disciplined trust series 65'),
#  ('alex brown investment management llc',
#   'alexandra investment management llc'),
#  ('capital group inc', 'capital hill group inc bd'),
#  ('am capital llc bd', 'aurum capital llc bd'),
#  ('avenue investments lp', 'belle haven investments l p'),
#  ('blackrock muniyield insured investment fund',
#   'blackrock muniyield michigan quality fund inc'),
#  ('arrowmark global opportunity fund ii ltd',
#   'arrowmark income opportunity fund ltd'),
#  ('bechtel financing services llc', 'birchtree financial services llc'),
#  ('blackrock california municipal income trust iii',
#   'blackrock florida municipal income trust iii'),
#  ('alden global distressed opportunities cayman fund l p',
#   'alden global opportunities fund lp'),
#  ('alabama tax free portfolio',
#   'california limited maturity tax free portfolio'),
#  ('canyon balanced fund cayman ltd', 'canyon balanced fund l p'),
#  ('blackrock california municipal income trust iii',
#   'blackrock municipal income trust iii'),
#  ('americal securities inc', 'american municipal securities inc'),
#  ('black river fixed income relative value opportunity fund ltd',
#   'blackstone relative value fund fixed income lp'),
#  ('blackrock emerging markets fund inc',
#   'blackstone emerging markets fund l p'),
#  ('brahman partners iii lp', 'brahman partners iv l p'),
#  ('bion pharmaceuticals inc', 'biosante pharmaceuticals inc'),
#  ('advisors disciplined trust series 57',
#   'advisors disciplined trust series 59'),
#  ('alliancebernstein discovery growth fund inc',
#   'alliancebernstein premier growth fund inc'),
#  ('blackrock new york insured muncipal 2008 term trust inc',
#   'blackrock new york insured municipal income trust'),
#  ('bank of america mortgage securities inc 2001 h',
#   'bank of america mortgage securities inc 2002 2'),
#  ('blackrock muniholdings insured fund ii inc',
#   'blackrock muniholdings new york quality fund inc'),
#  ('apollo investment fund pb vii lp', 'apollo value investment fund lp'),
#  ('adar investment management lp', 'alex brown investment management llc'),
#  ('advisors discplined trust 136', 'advisors discplined trust 137'),
#  ('bechtel financing services llc', 'birchtree financial services inc'),
#  ('aim international funds inc md',
#   'aim international mutual funds invesco international mutual funds'),
#  ('amaranth global securities llc', 'amaranth securities l l c'),
#  ('advisors disciplined trust series 53',
#   'advisors disciplined trust series 59'),
#  ('abbey capital multi manager fund', 'ark multi manager fund l p'),
#  ('asci holdings czech de inc', 'asci holdings uk inc de'),
#  ('andor capital management llc', 'basso capital management lp'),
#  ('aris multi strategy fund lp', 'bacap alternative multi strategy fund llc'),
#  ('banc of america mtg sec inc mort pass thr certs ser 2003 9',
#   'bank of america mort sec inc mort pass thr cert ser 2002 2'),
#  ('ashe capital management lp', 'ashton capital management inc'),
#  ('bg financial group inc', 'bnc financial group inc'),
#  ('amerimutual funds distributor inc bd', 'ark funds distributors llc'),
#  ('addvantage media group inc ok', 'advantage trading group inc bd'),
#  ('adamas opportunities lp', 'brasada value opportunites fund lp'),
#  ('blackstone capital partners delaware nq v ac l p',
#   'blackstone family investment partnership cayman v nq l p'),
#  ('beta capital management l p', 'cadian capital management llc'),
#  ('blackrock insured municipal income investment trust',
#   'blackrock insured municipal income trust'),
#  ('a i m distributors inc', 'aquila distributors inc bd'),
#  ('advisors disciplined trust 70', 'advisors disciplined trust series 71'),
#  ('advisors disciplined trust 53', 'advisors disciplined trust series 52'),
#  ('bh dg systematic trading fund ltd',
#   'brevan howard systematic trading fund l p'),
#  ('beanpot financial services inc bd', 'benchmark financial services inc'),
#  ('advisors disciplined trus 437', 'advisors disciplined trust 47'),
#  ('belfinance securities inc', 'benefit finance securities llc bd'),
#  ('bailard real estate investment trust i inc',
#   'behringer harvard real estate investment trust i inc'),
#  ('cap gemini sa', 'cap gemini sa adr'),
#  ('altimeter capital management lp', 'andor capital management llc'),
#  ('bear stearns alt a trust mort pass thr certs sers 2003 6',
#   'bear stearns trust mortgage pass through certs ser 2004'),
#  ('atlas america public #16 2007 a l p',
#   'atlas america public #16 2007 program'),
#  ('alden global emerging markets fund offshore lp',
#   'alden global emerging markets fund ofshore ltd'),
#  ('advisors disciplined trust 72', 'advisors disciplined trust 76'),
#  ('atlas america public series 25 2004 a l p',
#   'atlas america series 25 2004 b l p'),
#  ('blackrock muniholdings california insured fund inc',
#   'blackrock muniholdings new jersey quality fund inc'),
#  ('blackstone madison avenue offshore fund ltd class a b c & g shares',
#   'blackstone sixth avenue offshore fund ltd class a b c & k shares'),
#  ('blackrock muniholdings florida insured fund inc',
#   'blackrock muniholdings quality fund ii inc'),
#  ('altimeter capital management llc', 'basso capital management l p'),
#  ('blackstone capital partners vi lp',
#   'blackstone partners investment fund l p'),
#  ('american eastern securities inc bd', 'american securities corp'),
#  ('allis chalmers management lp', 'allis chalmers rental services llc'),
#  ('blackrock muniyield california quality fund inc',
#   'blackrock muniyield florida insured fund'),
#  ('bakercorp international holdings inc', 'caibs holding international inc'),
#  ('advest trust co', 'arvest trust co'),
#  ('brevan howard systematic trading fund l p',
#   'brevan howard systematic trading fund ltd'),
#  ('ascend market neutral fund l p', 'ascend market neutral fund ltd'),
#  ('american eastern securities inc', 'american securities team inc'),
#  ('banc of america investment services inc',
#   'canada life of america financial services inc bd'),
#  ('blackrock muniyield california quality fund inc',
#   'blackrock muniyield insured fund inc'),
#  ('blackrock global emerging markets fund inc',
#   'blackstone emerging markets fund lp'),
#  ('adar investment management lp', 'alex brown investment management l p'),
#  ('blackrock muniholdings insured investment fund',
#   'blackrock muniholdings new jersey quality fund inc'),
#  ('american securities opportunities fund iii b l p',
#   'ascribe opportunities fund ii b lp'),
#  ('blackrock florida municipal bond trust',
#   'blackrock municipal income quality trust'),
#  ('capital group all country world equity common trust us',
#   'capital group us core fixed income common trust us'),
#  ('american fidelity financial services inc', 'ari financial services inc'),
#  ('advisors disciplined trust 75', 'advisors disciplined trust series 73'),
#  ('blackrock muniholdings new jersey insured fund inc',
#   'blackrock muniholdings quality fund ii inc'),
#  ('alphadyne investment strategies fund ltd',
#   'alphadyne investment strategies partners lp'),
#  ('alliancebernstein international growth fund inc',
#   'alliancebernstein international research growth fund inc'),
#  ('asyst technologies inc ca', 'auto tool technologies inc'),
#  ('brown robert s', 'brown robertg'),
#  ('bailard biehl & kaiser international fund group inc',
#   'bailard biehl & kaiser tehachapi onshore fund lp'),
#  ('bank of new york mellon', 'bank of new york trust company n a'),
#  ('allied asset management inc', 'baring asset management inc ma'),
#  ('aquila distributors inc bd', 'ariel distributors inc'),
#  ('cadence resources corp lp', 'canadente resource corp'),
#  ('amarillo motors f ltd', 'amarillo motors j ltd'),
#  ('blackrock muniyield insured investment fund',
#   'blackrock muniyield michigan insured fund ii inc'),
#  ('americal securities inc', 'american securities team inc bd'),
#  ('capital guardian all country world equity fd tax exem tr',
#   'capital guardian all country world ex us equity fund for tax exempt trusts'),
#  ('advisors disciplined trust series 73',
#   'advisors disciplined trust series 75'),
#  ('asci holdings asia inc de', 'asci holdings germany de inc'),
#  ('blue capital group llc bd', 'capital planning group llc bd'),
#  ('boston capital securities inc', 'capital one securities inc'),
#  ('blackstone gso dynamic credit income fund',
#   'blackstone gso global dynamic credit feeder fund ireland'),
#  ('advanced investment partners llc', 'broadbill investment partners lp'),
#  ('allianzgi convertible & income fund',
#   'allianzgi convertible & income fund ii'),
#  ('allied gold ltd', 'aurion gold ltd'),
#  ('campbell classic trend fund l p', 'campbell institutional trend fund l p'),
#  ('advisors disciplined trust series 53',
#   'advisors disciplined trust series 57'),
#  ('a p securities inc', 'aton securities inc bd'),
#  ('american fidelity variable annuity fund a',
#   'athene variable annuity account a'),
#  ('alpha strategic management ltd bd', 'ascend alpha strategies fund ltd'),
#  ('bnc financial group inc', 'bossio financial group inc'),
#  ('anika therapeutics inc', 'artisan therapeutics inc'),
#  ('blackrock california insured municipal income trust',
#   'blackrock florida municipal income trust iii'),
#  ('american energy capital partners lp', 'american energy partners inc de'),
#  ('astoria capital markets inc', 'cabrera capital markets inc'),
#  ('black river fixed income relative value opportunity fund ltd',
#   'blackstone relative value offshore fund fixed income ltd'),
#  ('arc international corporation', 'biltmore international corporation'),
#  ('basso capital management l p', 'cadian capital management lp'),
#  ('american income fund i a ltd partnership', 'american income fund i d'),
#  ('avenue europe investments lp', 'belle haven investments l p'),
#  ('americas senior financial services inc', 'ari financial services inc'),
#  ('atlas america series 25 2004 a l p', 'atlas america series 25 2004 b lp'),
#  ('advisors disciplined trust 645', 'advisors disciplined trust series 61'),
#  ('american diversified financial group llc',
#   'asia pacific financial management group inc'),
#  ('athene asset management llc', 'baring asset management inc ma'),
#  ('asci holdings asia inc de', 'asci holdings czech de inc'),
#  ('aim combination stock & bond funds inc', 'aim stock funds'),
#  ('brahman c p f partners lp', 'brahman institutional partners lp'),
#  ('americredit automobile receivables trust 2002 d',
#   'americredit automobile receivables trust 2010 1'),
#  ('ahalife holdings llc', 'american life holdings inc'),
#  ('american mutual fund', 'amway mutual fund inc'),
#  ('advisors disciplined trust series 63',
#   'advisors disciplined trust series 64'),
#  ('blackrock muniyield insured fund inc',
#   'blackrock muniyield insured investment fund'),
#  ('alliance north american government income tru inc',
#   'american century government income trust'),
#  ('brown robert g', 'brown roger alan'),
#  ('biolex therapeutics inc', 'boston therapeutics inc'),
#  ('blackrock defined opportunity credit trust',
#   'blackrock income opportunity trust inc'),
#  ('avenue capital management ii llc', 'bimini capital management inc'),
#  ('blackrock municipal advantage income trust',
#   'blackrock taxable municipal bond trust'),
#  ('aurora global opportunities ii asp fund a series of alternative strategies platform llc',
#   'blue trend asp fund a series of alternative strategies managed futures & commodities platform llc'),
#  ('apm global macro fund l p', 'apm global macro ii fund l p'),
#  ('behringer harvard reit i i inc', 'behringer harvard reit ii inc'),
#  ('aig international securities inc', 'banorte securities international ltd'),
#  ('beazer homes holdings llc', 'beazer homes investments llc'),
#  ('blackstone madison avenue offshore fund ltd class a b c & g shares',
#   'blackstone partners offshore fund ltd class e f g i j k q & r shares'),
#  ('access pharmaceuticals inc', 'barr pharmaceuticals inc'),
#  ('blackrock muniyield california insured fund inc',
#   'blackrock muniyield michigan quality fund inc'),
#  ('arrowpoint fundamental opportunity fund l p',
#   'arrowpoint income opportunity fund lp'),
#  ('binks estates limited partnership', 'burke trading limited partnership'),
#  ('aim investment funds', 'aim investment securities funds'),
#  ('americal securities inc', 'american securities bd co lp'),
#  ('arguss communications inc', 'atx communications inc'),
#  ('arden institutional advisers l p', 'arden institutional advisers lp'),
#  ('blackrock california insured municipal income trust',
#   'blackrock insured municipal income trust'),
#  ('blackstone partners offshore fund ltd class e f i j k q & r shares',
#   'blackstone sixth avenue offshore fund ltd class a b c k & l shares'),
#  ('associated technologies', 'breed technologies incorporated'),
#  ('advisors disciplined trust series 20',
#   'advisors disciplined trust series 60'),
#  ('blackrock muniholdings california quality fund inc',
#   'blackrock muniholdings insured fund ii inc'),
#  ('advanced investment partners llc', 'brandes investment partners lp'),
#  ('aspen technology inc de', 'brio technology inc'),
#  ('blackrock insured municipal income investment trust',
#   'blackrock investment quality municipal income trust'),
#  ('alternative investments institutional lp',
#   'american alternative investments llc'),
#  ('bayside street ii inc', 'bayside street inc'),
#  ('american financial group inc et al', 'american financial group inc oh'),
#  ('alphametrix managed futures iii llc',
#   'alphametrix managed futures llc aspect series'),
#  ('alliance all asia investment fund inc', 'aspen investment alliance inc'),
#  ('blackrock credit allocation income trust ii',
#   'blackrock senior income trust'),
#  ('ammon robert j', 'beckham robert j'),
#  ('active link communications inc co',
#   'alliance atlantis communications inc inactive'),
#  ('advisors disciplined trust 641', 'advisors disciplined trust series 65'),
#  ('agricapital securities inc', 'capital market securities inc'),
#  ('aetos capital distressed investment strategies fund llc',
#   'aetos long short strategies fund llc'),
#  ('barrow hanley mewhinney & strauss inc',
#   'barrow hanley mewhinney & strauss long credit fixed income fund'),
#  ('anagnostakis michael', 'bisignano michael c'),
#  ('brown robert s', 'brown roger a'),
#  ('allied asset management inc', 'ar asset management inc'),
#  ('blackstone credit opportunities fund l p',
#   'blackstone pacific opportunities master fund lp'),
#  ('andor capital management l l c', 'basso capital management l p'),
#  ('avalon gold corp', 'avion gold corp'),
#  ('ares leveraged investment fund corp ii', 'cap iii co investment l p'),
#  ('callahan financial services inc bd', 'callaway financial services inc'),
#  ('burger joseph c', 'burstein joseph'),
#  ('afton capital management llc', 'ashton capital management inc'),
#  ('abi capital management llc', 'avenue capital management ii llc'),
#  ('antares european fund lp', 'ares european real estate fund iv l p'),
#  ('american beacon enhanced cash trust',
#   'american beacon municipal enhanced cash trust'),
#  ('boyd louisiana racing llc', 'boyd racing llc'),
#  ('arianne resources inc', 'blue arch resources inc'),
#  ('antares european fund l p', 'area european real estate fund iv l p'),
#  ('advisors disciplined trust 70', 'advisors disciplined trust series 74'),
#  ('ab growth & income fund inc', 'capital world growth & income fund'),
#  ('ab cap fund inc', 'ab global bond fund inc'),
#  ('aim investment services inc', 'asset alliance investment services inc'),
#  ('arrowpoint income opportunity fund lp',
#   'arrowpoint income opportunity fund ltd'),
#  ('acuitas emerging markets small cap fund lp',
#   'artha emerging markets fund l p'),
#  ('banc of america mort sec inc mort pas thr cert series 2004 3',
#   'bank of america mort sec inc mort pass thr cert er 2002 2'),
#  ('bcm credit opportunities fund lp', 'berens credit opportunities fund ltd'),
#  ('alfa capital markets usa inc', 'cabrera capital markets llc'),
#  ('atalanta sosnoff capital llc', 'atalanta sosnoff management corporation'),
#  ('capital one auto receivables trust 2001 b',
#   'capital one prime auto receivables trust 2003 1'),
#  ('blackrock florida insured municipal income trust',
#   'blackrock municipal income investment trust'),
#  ('atlas america public #16 2007 b l p',
#   'atlas resources public #16 2007 program'),
#  ('baystate capital services inc bd', 'boston capital services inc'),
#  ('apollo gold corp', 'apolo gold & energy inc'),
#  ('capital investment brokerage inc bd', 'capital investments inc bd'),
#  ('alliance international fund inc',
#   'alliancebernstein national municipal income fund'),
#  ('blackstone family investment partnership delaware v nq l p',
#   'blackstone participation partnership delaware v nq l p'),
#  ('blackstone real estate international ii q gp l l c',
#   'brep international ii q gp l p'),
#  ('american income fund i b', 'american income fund i e'),
#  ('argos funds sicav in respect of argos funds argonaut fund',
#   'argos funds sicav in respect of argos funds the bamboo fund'),
#  ('af brokerage inc bd', 'affinity brokerage llc'),
#  ('alden global distressed opportunities cayman fund l p',
#   'alden global distressed opportunities fund lp'),
#  ('accipiter capital management llc', 'beta capital management l p'),
#  ('alleghany asset management inc', 'asset management fund'),
#  ('allianz global investors capital total return trust',
#   'allianz global investors u s llc'),
#  ('advisors disciplined trust 72', 'advisors disciplined trust series 70'),
#  ('atlas america public #15 2005 a program',
#   'atlas america public #15 2006 b l p'),
#  ('alaris medical systems inc', 'aria systems llc'),
#  ('blackrock florida municipal 2022 term trust',
#   'blackrock municipal 2030 target term trust'),
#  ('alderon resource corp', 'canadente resource corp'),
#  ('arizona municipals portfolio', 'california municipals portfolio'),
#  ('abs global long short asw fund a series of wachovia alternative strategies platform llc',
#   'aurora global opportunities asp fund a series of alternative strategies platform llc'),
#  ('alliancebernstein small cap growth fund inc',
#   'alliancebernstein small mid cap growth fund'),
#  ('advisors disciplined trust 641', 'advisors disciplined trust 65'),
#  ('acuitas international small cap fund lp',
#   'axa im international small cap fund llc'),
#  ('americal securities inc', 'american classic securities inc'),
#  ('apollo european strategic investments holdings lp',
#   'ball pan european holdings llc'),
#  ('barrow hanley mewhinney & strauss core fixed income fund',
#   'barrow hanley mewhinney & strauss llc'),
#  ('blackrock muniyield michigan insured fund inc',
#   'blackrock muniyield michigan quality fund ii inc'),
#  ('blackrock dividend achievers trust',
#   'blackrock strategic dividend achievers trust'),
#  ('blackstone park avenue fund lp',
#   'blackstone park avenue non taxable fund lp'),
#  ('apollo partners lp bd', 'arapaho partners llc'),
#  ('advisors disciplined trust 70', 'advisors disciplined trust series 73'),
#  ('allianz global investors of america l p',
#   'allianz global investors u s llc'),
#  ('capital group global equity common trust us',
#   'capital group international all countries equity common trust us'),
#  ('blackrock municipal 2022 term trust',
#   'blackrock municipal 2027 term trust'),
#  ('asci holdings czech inc de', 'asci holdings mexico inc de'),
#  ('bhp billiton plc adr', 'bhp billiton plc fi'),
#  ('argonaut aggressive global partnership l p',
#   'argonaut global equities partnership l p'),
#  ('boston celtics limited partnership',
#   'boston millenia partners iv limited partnership'),
#  ('alderon resource corp', 'candente resource corp'),
#  ('axp federal income fund inc mn', 'axp selective fund inc mn'),
#  ('abs global long short asw fund a series of alternative strategies platform llc',
#   'blue trend asp fund a series of alternative strategies managed futures & commodities platform llc'),
#  ('abs global long short asw fund a series of wachovia alternative strategies platform llc',
#   'aurora global opportunities asw fund a series of alternative strategies platform llc'),
#  ('ares clo x ltd', 'ares xi clo ltd'),
#  ('arrowpoint income opportunity fund lp',
#   'arrowpoint income opportunity fund qp l p'),
#  ('bear stearns & co inc bd', 'bear stearns securities corp'),
#  ('artisan therapeutics inc', 'ascent therapeutics inc'),
#  ('atlanta aktiengesellschaft', 'brokat technologies aktiengesellschaft'),
#  ('barrow hanley diversifield large cap value fund',
#   'barrow hanley large cap value fund'),
#  ('alliancebernstein discovery growth fund inc',
#   'alliancebernstein small cap growth fund inc'),
#  ('americas senior financial services inc', 'callaway financial services inc'),
#  ('boston celtics limited partnership de',
#   'boston millenia partners iv limited partnership'),
#  ('artal international s c a', 'capital international s a'),
#  ('arcion thereapeutics inc', 'bolt biotherapeutics inc'),
#  ('blackstone customized commodities fund l p',
#   'blackstone sers customized fund lp'),
#  ('7 rod real estate north ltd liability co',
#   '7 rod real estate south ltd liability co'),
#  ('a c r securities inc', 'a p securities inc'),
#  ('barrow hanley mewhinney & strauss diversified large cap value fund',
#   'barrow hanley mewhinney & strauss llc'),
#  ('accipiter capital management llc', 'american capital asset management llc'),
#  ('abilene behavioral health llc', 'behavioral healthcare llc'),
#  ('arkansas municipals portfolio',
#   'california ltd maturity municipals portfolio'),
#  ('akiban technologies inc', 'auto tool technologies inc'),
#  ('berry plastics corp', 'berry plastics group inc'),
#  ('american capital asset management llc', 'basso capital management lp'),
#  ('buell securities corp', 'bullaro securities corp bd'),
#  ('blackrock florida investment quality municipal trust',
#   'blackrock florida municipal income trust iii'),
#  ('blackstone partners offshore fund ltd class e f i j k q & r shares',
#   'blackstone partners offshore fund ltd class h & l shares'),
#  ('advisors disciplined trust series 61',
#   'advisors disciplined trust series 63'),
#  ('abs global long short asw fund a series of wachovia alternative strategies platform llc',
#   'blue trend asw fund a series of alternative strategies managed futures & commodities platform llc'),
#  ('allianz global investors capital llc',
#   'allianz global investors total return trust'),
#  ('alliance international fund inc',
#   'alliance national municipal income fund'),
#  ('apax partners holdings ltd', 'artisan partners holdings lp'),
#  ('bancorpsouth investment services inc',
#   'borst investment planning services inc'),
#  ('amanasu technologies corp', 'calient technologies inc'),
#  ('alliancebernstein bond fund inc', 'alliancebernstein high income fund inc'),
#  ('adp broker dealer inc', 'broker dealer financial services corp'),
#  ('avenue europe investments l p', 'avenue investments lp'),
#  ('bain capital partners lp', 'blr capital partners l p'),
#  ('agricapital securities inc bd', 'capital market securities inc bd'),
#  ('ae partners llc bd', 'aew partners l p et al'),
#  ('american heritage securities inc bd', 'american securities team inc'),
#  ('ari financial services inc', 'callahan financial services inc'),
#  ('blackrock muniyield new jersey quality fund inc',
#   'blackrock muniyield new york insured fund inc'),
#  ('ares capital europe l p', 'bain capital europe llc'),
#  ('blackstone capital partners delaware v nq l p',
#   'blackstone family investment partnership cayman v nq l p'),
#  ('altimeter capital management llc', 'beta capital management l p'),
#  ('ag series trust', 'bny series trust'),
#  ('brent capital corp bd', 'capita corp'),
#  ('brookfield canada office properties', 'brookfield properties corp'),
#  ('benchmark capital management co llc', 'berkeley capital management llc'),
#  ('barrow hanley mewhinney & strauss diversified small cap value fund',
#   'barrow hanley mewhinney & strauss inc'),
#  ('blackrock muniholdings new jersey quality fund inc',
#   'blackrock muniholdings new york insured fund inc'),
#  ('barnstar opportunities master fund ltd',
#   'bear stearns focused opportunities fund lp'),
#  ('bt investment management ltd', 'cambria investment management l p'),
#  ('altrinsic global advisors llc', 'bt global advisors'),
#  ('berkeley capital management llc', 'capital markets management llc'),
#  ('aim investment services inc', 'amsouth investment services inc bd'),
#  ('bid com international inc', 'biopulse international inc'),
#  ('blackstone fifth ave offshore fund ltd',
#   'blackstone vanderbilt avenue offshore fund ltd'),
#  ('blackstone partners offshore fund ltd class e f g i j k q & r shares',
#   'blackstone partners offshore fund ltd class h & l shares'),
#  ('aria partner ii lp', 'artorius partners ii lp'),
#  ('blackrock investment quality municipal income trust',
#   'blackrock municipal income quality trust'),
#  ('alleghany asset management inc', 'allied asset management inc bd'),
#  ('admc absolute return strategies l p',
#   'archstone absolute return strategies fund ltd'),
#  ('advisors disciplined trust series 51', 'advisors disciplined turst 551'),
#  ('bg holdings i', 'bg holdings ii'),
#  ('allen test co inc test time prod', 'allen test co name change test'),
#  ('capital group international all countries equity common trust us',
#   'capital group international equity common trust us'),
#  ('alternative investments institutional l p',
#   'alternative investments institutional ltd'),
#  ('alliancebernstein diversified yield fund inc',
#   'bernstein global diversified hedge fund ltd'),
#  ('barry iii john j', 'cagle john m iii'),
#  ('blackstone capital partners delaware v nq l p',
#   'blackstone participation partnership delaware v nq l p'),
#  ('bank of new york ta', 'bankers trust new york corp'),
#  ('advisors disciplined trust 802', 'advisors disciplined trust 902'),
#  ('capital one auto receivables trust 2003 1',
#   'capital one prime auto receivables trust 2003 2'),
#  ('blackstone capital partners cayman v nq l p',
#   'blackstone capital partners delaware nq v ac l p'),
#  ('a i m distributors inc bd', 'aquila distributors llc'),
#  ('blackrock global emerging markets fund inc',
#   'blackstone emerging markets fund i l p'),
#  ('advisoros disciplined trust 716', 'advisors disciplined trust series 73'),
#  ('american income fund i c ltd partnership',
#   'american income fund i e ltd partnership'),
#  ('blackrock fixed income value opportunities',
#   'blackrock mid cap value opportunities series inc'),
#  ('alaris medical systems inc', 'aria systems inc'),
#  ('alliance americas government income trust inc',
#   'american century government income trust'),
#  ('american heritage securities inc', 'american securities team inc bd'),
#  ('banc of america investment services inc',
#   'canada life of america financial services inc'),
#  ('acadian asset management llc', 'activa asset management llc'),
#  ('argos funds sicav argos funds argonaut fund',
#   'argos funds sicav in respect of argos funds yield opportunities'),
#  ('advisors disciplined trust series 70',
#   'advisors disciplined trust series 75'),
#  ('advisors disciplind trust 641', 'advisors disciplined trust series 61'),
#  ('bailard biehl & kaiser tehachapi accredited investor fund lp',
#   'bailard biehl & kaiser tehachapi offshore fund ltd'),
#  ('apex securities inc', 'cape securities inc bd'),
#  ('advisors disciplined trust 66', 'advisors disciplined trust series 56'),
#  ('berens distressed opporntunities lp',
#   'berens distressed opportunities fund ltd'),
#  ('aip alternative strategies funds', 'cadogan alternative strategies ii llc'),
#  ('american atm corp', 'american tire corp'),
# ...
#  ('beverly enterprises kansas llc', 'beverly enterprises minnesota llc'),
#  ('atalanta sosnoff capital llc', 'atalanta sosnoff management llc'),
#  ('bear stearns alt a trust mtg pass through certs ser 2004 4',
#   'bear sterns alt a trust mort pass thr certs sers 2003 6'),
#  ('augusta capital management lp bd', 'augustus capital l l c'),
#  ('artio global investment funds', 'barings global investment funds plc'),
#  ('blackstone fifth avenue fund l p',
#   'blackstone park avenue non taxable fund l p'),
#  ('achelios therapeutics', 'biolex therapeutics inc'),
#  ('bowman capital management lp', 'brown capital management llc'),
#  ('avanir pharmaceuticals', 'bion pharmaceuticals inc'),
#  ('capital guardian emerging markets equity fund for tax exempt trusts',
#   'capital guardian emerging markets restricted equity fund for tax exempt trusts'),
#  ('buell securities corp bd', 'bullaro securities corp'),
#  ('brahman partners ii lp', 'brahman partners iii lp'),
#  ('alpha equity asset allocation offshore fund ltd',
#   'bbh longshort equity offshore fund ltd'),
#  ('abax brokerage services inc bd', 'bull & bear brokerage services inc bd'),
#  ('abs global long short asp fund a series of alternative strategies platform llc',
#   'aurora global opportunitites ii asw fund a series of alternative strategies platform llc'),
#  ('alexandra investment management ltd', 'artemis investment management llc'),
#  ('astoria capital markets inc bd', 'cabrera capital markets llc'),
#  ('advisors disciplined trust 64', 'advisors disciplined trust series 65'),
#  ('alternative investments institutional lp',
#   'alternative investments institutional ltd'),
#  ('blackstone capital partners cayman v nq l p',
#   'blackstone family investment partnership cayman v nq l p'),
#  ('advanced investment partners llc', 'broadbill investment partners llc'),
#  ('advantage advisers global growth l l c',
#   'advantage advisers global growth ltd'),
#  ('advisors disciplined 206', 'advisors disciplined trust 1066'),
#  ('alliance financial group inc', 'bossio financial group inc bd'),
#  ('acer investment group llc bd', 'all tech investment group inc et al'),
#  ('capital emerging markets total opportunities fund',
#   'capital group emerging markets total opportunities common trust us'),
#  ('accipiter capital management llc', 'basso capital management lp'),
#  ('aldeyra therapeutics inc', 'anika therapeutics inc'),
#  ('atalanta sosnoff capital corp delaware',
#   'atalanta sosnoff management corp'),
#  ('cabo drilling corp fi', 'cabo mining enterprises corp fi'),
#  ('boardwalk casino llc', 'boardwalk pipelines llc'),
#  ('blackrock florida insured municipal income trust',
#   'blackrock investment quality municipal income trust'),
#  ('aetos capital market neutral strategies fund llc',
#   'archstone market neutral strategies fund ltd'),
#  ('acorn partners l p', 'arbor partners lp'),
#  ('bestvest investments ltd', 'bnn investments ltd'),
#  ('aspen technology inc de', 'capital technology inc bd'),
#  ('bcm credit opportunities fund lp', 'berens credit opportunities fund l p'),
#  ('avista capital partners ii lp', 'avista capital partners offshore ii l p'),
#  ('advisors disciplined trust 46', 'advisors disciplined trust series 56'),
#  ('associated technologies inc', 'breed technologies inc'),
#  ('basf aktiengesellschaft fa', 'brokat technologies aktiengesellschaft'),
#  ('apollo capital group inc', 'apollo education group inc'),
#  ('biolase technology inc', 'brascan technology fund'),
#  ('adp broker dealer inc bd', 'broker dealer inc bd'),
#  ('ascend multi strategy fund ltd',
#   'bacap alternative mult strategy fund llc'),
#  ('barneys america ny lease corp', 'barneys ca lease corp'),
#  ('american mutual fund inc', 'amway mutual fund inc'),
#  ('achelios therapeutics', 'bolt biotherapeutics inc'),
#  ('alaris medical systems inc', 'alterrus sysytems inc'),
#  ('capital analysts inc bd', 'capital analysts llc'),
#  ('blackrock muniyield florida insured fund',
#   'blackrock muniyield insured fund inc'),
#  ('biomimetic pharmaceuticals inc', 'cancer prevention pharmaceuticals inc'),
#  ('alden global opportunities fund cayman l p',
#   'artio global credit opportunities fund'),
#  ('adventrx pharmaceuticals inc', 'barr pharmaceuticals inc'),
#  ('bank of new york mellon', 'bank of new york ta'),
#  ('agic convertible & income fund ii',
#   'agic global equity & convertible income fund'),
#  ('boston celtics limited partnership ii de',
#   'boston millenia partners iv limited partnership'),
#  ('broker dealer financial services corp bd', 'broker dealer inc'),
#  ('ares leveraged investment corp ii', 'cap iii co investment lp'),
#  ('allos therapeutics inc', 'bellerophon therapeutics inc'),
#  ('blackrock california insured municipal income trust',
#   'blackrock insured municipal income investment trust'),
#  ('blackstone family investment partnership delaware v nq l p',
#   'blackstone participation partnership cayman v nq l p'),
#  ('allied asset management inc bd', 'athene asset management llc'),
#  ('adams laboratories inc', 'aeterna laboratories inc'),
#  ('active link communications inc co', 'alliance atlantis communications inc'),
#  ('atap financial services inc bd', 'btmu financial services inc'),
#  ('basswood financial enhanced fund l p', 'basswood international fund inc'),
#  ('abdiel capital advisors llc', 'anchor capital advisors llc'),
#  ('blue ridge capital management llc', 'brigade capital management lp'),
#  ('american realty capital daily net asset value trust inc',
#   'american realty capital global daily net asset value trust inc'),
#  ('beverly enterprises california inc', 'beverly enterprises minnesota inc'),
#  ('alliance financial group inc', 'bossio financial group inc'),
#  ('campbell & co inc md', 'campbell & co lp ta'),
#  ('banc of america mort sec inc mort pas thr cert series 2004 3',
#   'bank of america mortgage sec mor pa th cert ser 2002 f'),
#  ('biltmore international corporation', 'biovail corp international'),
#  ('blackrock florida municipal bond trust',
#   'blackrock florida municipal income trust'),
#  ('arden advisers lp', 'arden strategic advisers l p'),
#  ('aurora global opportunities ii asp fund a series of alternative strategies platform llc',
#   'bluetrend asw fund a series of wachovia alternative strategies managed futures & commodities platform llc'),
#  ('ascend multi strategy fund ltd', 'bandon multi strategy fund llc'),
#  ('ari financial services inc', 'calamos financial services inc'),
#  ('blackrock muniholdings california quality fund inc',
#   'blackrock muniholdings investment quality fund'),
#  ('apg asset management us inc', 'asset management fund inc'),
#  ('babson capital global investment funds 2 plc',
#   'babson capital global umbrella fund plc'),
#  ('acr securities inc bd', 'ancora securities inc bd'),
#  ('asset alliance investment services inc bd',
#   'bancorpsouth investment services inc'),
#  ('capital guardian international all countries equity fund for tax exempt trusts',
#   'capital guardian international equity fund for tax exempt trusts'),
#  ('altegris multi strategy fund lp', 'aris multi strategy fund l p'),
#  ('advance power technology inc', 'advanced gaming technolgy inc'),
#  ('blue rock all asset plus fund l p', 'blue rock equity plus fund l p'),
#  ('banc of america finance services inc',
#   'canada life of america financial services inc bd'),
#  ('asci holdings czech inc de', 'asci holdings germany de inc'),
#  ('advisors disciplined trust series 71',
#   'advisors disciplined trust series 74'),
#  ('afba 5star funds', 'afba five star funds inc'),
#  ('capital careresources llc', 'capital careresources of south carolina llc'),
#  ('alliance north american government income tru inc',
#   'benham government income trust'),
#  ('american alternative investments llc',
#   'amundi alternative investments llc'),
#  ('amman robert j', 'beckham robert j'),
#  ('brahman partners ii lp', 'brahman partners iv l p'),
#  ('arrowpoint fundamental opportunity fund l p',
#   'arrowpoint global opportunity fund ii lp'),
#  ('blackrock advisors inc', 'blackrock funds ii'),
#  ('capital one auto finance trust 2001 b',
#   'capital one auto finance trust 2002 c'),
#  ('beverly enterprises international ltd', 'beverly enterprises kansas llc'),
#  ('advisors disciplined trust series 46',
#   'advisors disciplined trust series 56'),
#  ('american eastern securities inc', 'american municipal securities inc bd'),
#  ('berkeley capital management funds', 'capital markets mangement llc'),
#  ('banc of america mort sec inc mort pass thr certs ser 2003 1',
#   'bank of america mortgage sec mor pa th cert ser 2002 f'),
#  ('blue capital group llc', 'capital planning group llc bd'),
#  ('american income fund i c', 'american income fund i e'),
#  ('blackrock muniholdings insured fund inc',
#   'blackrock muniholdings investment quality fund'),
#  ('american classic securities inc', 'american heritage securities inc bd'),
#  ('advisors disciplined trust 75', 'advisors disciplined trust series 72'),
#  ('arrowpoint fundamental opportunity fund l p',
#   'arrowpoint global opportunity fund ii ltd'),
#  ('amc entertainment inc et al', 'angelciti entertainment inc'),
#  ('bernstein global opportunities hedge fund lp',
#   'bernstein global opportunities hedge fund ltd'),
#  ('brown & brown securities inc bd', 'brown burke securities inc bd'),
#  ('agic convertible & income fund', 'agic equity & convertible income fund'),
#  ('alcresta therapeutics inc', 'aldeyra therapeutics inc'),
#  ('apollo european strategic investments holdings lp',
#   'ball pan european holdings inc'),
#  ('apm multi strategy fund lp', 'bacap alternative mult strategy fund llc'),
#  ('averil capital markets group inc', 'capital hill group inc'),
#  ('aldeyra therapeutics inc', 'artisan therapeutics inc'),
#  ('advanced investment technology inc fl', 'advanced power technology inc'),
#  ('blackrock equity dividend trust', 'blackrock global equity income trust'),
#  ('a t a p financial services inc', 'aurora financial services l l c'),
#  ('afg investment partners iii lp', 'afg investment partners iv l p'),
#  ('ani pharmaceuticals inc', 'avanir pharmaceuticals inc'),
#  ('atlas capital services llc', 'baystate capital services inc bd'),
#  ('access capital investment group inc', 'all tech investment group inc de'),
#  ('blackrock california municipal 2022 term trust',
#   'blackrock florida municipal 2020 term trust'),
#  ('alaris medical systems inc', 'alterrus systems inc'),
#  ('bogle offshore opportunity fund ii ltd',
#   'bogle offshore opportunity fund ii sri ltd'),
#  ('advisors disciplined trust 716', 'advisors disciplined trust series 71'),
#  ('bnp paribas sa', 'bnp paribas securities corp'),
#  ('american core realty fund llc', 'calliance realty fund llc'),
#  ('blackrock muniholdings california insured fund inc',
#   'blackrock muniholdings new york insured fund inc'),
#  ('alliancebernstein diversified yield fund inc',
#   'alliancebernstein global diversified strategies usd managed ltd hedge fund b'),
#  ('callahan financial services inc bd', 'callaway financial services inc bd'),
#  ('brent capital corp', 'capita corp'),
#  ('american century services llc ta', 'american funds service co ta'),
#  ('asci holdings asia inc de', 'asci holdings mexico de inc'),
#  ('blackrock municipal bond investment trust',
#   'blackrock municipal income investment quality trust'),
#  ('avista capital opportunities fund ii offshore lp',
#   'avista capital opportunities fund ii onshore l p'),
#  ('bank of america mort sec inc mort pas thr certs ser 2001 h',
#   'bank of america mortgage sec inc mor pa th cert ser 2002 f'),
#  ('binks estates lp', 'bird estate lp'),
#  ('a c r securities inc', 'aton securities inc bd'),
#  ('berry plastics acquisition corp vii', 'berry plastics acquisition llc x'),
#  ('arrowmark global opportunity fund ii ltd',
#   'arrowmark income opportunity fund lp'),
#  ('advisors disciplined trust 767', 'advisors disciplined trust series 67'),
#  ('bhp billiton ltd', 'bhp billiton plc fi'),
#  ('brep international ii q gp l l c', 'brep international ii q gp l p'),
#  ('arrowpoint income opportunity fund ltd',
#   'arrowpoint income opportunity fund qp l p'),
#  ('bolton financial services llc bd', 'brock financial services llc'),
#  ('acadian diversified alpha institutional equity fund llc',
#   'adams diversified equity fund inc'),
#  ('adar investment management llc', 'bt investment management re ltd'),
#  ('blackstone credit opportunities fund l p',
#   'blackstone pacific opportunities fund lp'),
#  ('arizona municipals portfolio',
#   'california ltd maturity municipals portfolio'),
#  ('active semiconductor inc', 'c cube semiconductor inc'),
#  ('alger separate account a of golden american life insur co',
#   'american general life insurance co of delaware'),
#  ('blackrock new york insured muncipal 2008 term trust inc',
#   'blackrock new york municipal 2022 term trust'),
#  ('americal securities inc bd', 'american securities team inc'),
#  ('asci holdings czech inc de', 'asci holdings mexico de inc'),
#  ('american enterprise variable annuity account',
#   'american fidelity variable annuity fund a'),
#  ('advisors disciplined trust 136', 'advisors discplined trust 134'),
#  ('augusta capital management l p', 'augustus capital llc bd'),
#  ('aqr global asset allocation instituitonal fund ii l p',
#   'aqr global asset allocation offshore fund usd ii ltd'),
#  ('alliance growth & income fund inc', 'berger growth & income fund inc'),
#  ('blackstone fifth avenue offshore fund ltd class a d f k & l shares',
#   'blackstone sixth avenue offshore fund ltd class a b c & k shares'),
#  ('arcion therapeutics inc', 'boston therapeutics inc'),
#  ('advantage advisers technology fund llc',
#   'advantage advisers technology international ltd'),
#  ('boston investment securities corp', 'capital securities investment corp'),
#  ('bulldog fund inc', 'bulldog trading llc'),
#  ('blackrock muniyield california insured fund inc',
#   'blackrock muniyield michigan insured fund inc'),
#  ('access investments inc', 'arrow investments inc bd'),
#  ('ayre investments inc bd', 'barclay investments inc bd'),
#  ('adams natural resources fund', 'alpha natural resources inc'),
#  ('arden realty limited partnership',
#   'boston millenia partners iv limited partnership'),
#  ('blackstone capital partners vi executive fund l p',
#   'blackstone partners investment fund lp'),
#  ('alex brown investment management llc', 'armetis investment management llc'),
#  ('atmi holdings inc', 'bosco holdings inc'),
#  ('access securities inc', 'acci securities inc bd'),
#  ('advisors disciplined trust 716', 'advisors disciplined trust 72'),
#  ('allen test inc and new name 2 limited', 'allen test new name inc md'),
#  ('alternative investments l p', 'american alternative investments llc'),
#  ('capital careresources inc', 'capital careresources of south carolina llc'),
#  ('blackrock florida municipal income trust',
#   'blackrock florida municipal income trust iii'),
#  ('beese fulmer investment management inc',
#   'bmo harris investment management inc'),
#  ('advisors disciplined trust 61', 'advisors disciplined trust series 63'),
#  ('abeona therapeutics inc', 'aldeyra therapeutics inc'),
#  ('alliance international fund',
#   'alliancebernstein national municipal income fund'),
#  ('arris pharmaceutical corp de', 'bactolac pharmaceutical inc'),
#  ('alpharma inc', 'artisan pharma inc'),
#  ('alterrus systems inc', 'aria systems inc'),
#  ('bright horizons family solutions llc', 'bright horizons solutions corp'),
#  ('ark investments bd', 'benchmark investments inc'),
#  ('bailard biehl & kaiser tehachapi offshore fund ltd',
#   'bailard biehl & kaiser tehachapi onshore fund lp'),
#  ('advanced equities foveon investments i llc',
#   'advanced equities foveon investments ii llc'),
#  ('advisors disciplined trust adt 1279',
#   'advisors discliplined trust series 19'),
#  ('banc of america mtg sec inc mort pass thr certs ser 2003 9',
#   'bank of america mortgage sec mor pa th cert ser 2002 f'),
#  ('banc of america mtg sec inc mort pass thr certs ser 2003 9',
#   'bank of america mortgage sec inc mor pa th cert ser 2002 f'),
#  ('capital one auto finance trust 2001 b',
#   'capital one auto finance trust 2002 b'),
#  ('alphametrix managed futures ii llc', 'alphametrix managed futures llc'),
#  ...}

# %%
# debugging
from helpers.tfidf_blocker import vectorize, index_on_approx_knn, compute_knn_similarity_matrix

tfidf_matrix = vectorize(string_list, ngram_range=(2, 2), analyzer='char_wb')
tfidf_dense_matrix = tfidf_matrix.toarray()
approx_knn_index = index_on_approx_knn(tfidf_dense_matrix)
pairwise_similarity_csr_matrix = compute_knn_similarity_matrix(approx_knn_index, tfidf_dense_matrix, k=k, threshold=threshold)
i_to_string = dict(enumerate(string_list))
string_to_i = {v: k for k, v in i_to_string.items()}

# %%
def string_pair_to_i_pair(string_pair):
    name_x, name_y = string_pair
    return string_to_i[name_x], string_to_i[name_y]

pairwise_similarity_csr_matrix[string_pair_to_i_pair(('blackey jeffrey', 'blakey jeff'))]
# Out:
# 0.7754569

# %%
pairwise_similarity_csr_matrix.nonzero()
# Out:
# (array([   0,    1,    2, ..., 6733, 6734, 6734], dtype=int32),
#  array([   0,    1,    2, ..., 6734, 6733, 6734], dtype=int32))

# %%
non_zero_pairs = {
    (i_to_string[i], i_to_string[j])
    for i, j in zip(*(list(arr) for arr in pairwise_similarity_csr_matrix.nonzero()))
    if i < j
}
non_zero_pairs
# Out:
# {('apollo capital group inc', 'blue capital group llc bd'),
#  ('advisors disciplined trust 551', 'advisors disciplined trust 63'),
#  ('apollo distressed investment fund lp', 'brar investment fund lp'),
#  ('apollo real estate opportunity fund vi lp',
#   'capital structures opportunity fund lp'),
#  ('alliancebernstein global bond fund inc',
#   'allliancebernstein greater china 97 fund inc'),
#  ('acadian asset management llc', 'boston partners asset management llc'),
#  ('capital growth financial llc', 'capital growth securities llc'),
#  ('achelios therapeutics inc', 'agilis biotherapeutics inc'),
#  ('atlantic coast airlines holdings inc', 'c t holdings inc'),
#  ('abi capital management llc', 'berkeley capital management llc'),
#  ('banc of america mort sec inc mort pass thr certs ser 2003 1',
#   'banc one mortgage sec inc mort pass thr certs ser 2003 9'),
#  ('accipiter capital management llc', 'capital markets mangement llc'),
#  ('brar investment capital llc', 'brar investment fund lp'),
#  ('altair nanotechnologies inc', 'apeel technologies inc'),
#  ('accredited morgage loan trust 2006 1',
#   'accredited mortgage loan trust 2006 1'),
#  ('boston capital securities inc', 'cape securities inc bd'),
#  ('aim investment funds', 'caine investment fund i l p'),
#  ('aew capital management l p', 'brown capital management inc'),
#  ('apollo management lp', 'basso capital management lp'),
#  ('aviation technologies inc', 'brio technology inc'),
#  ('13a commercial mortgage securities fund inc',
#   'aew commercial mortgage securities fund inc'),
#  ('ab global real estate investment fund inc',
#   'alliancebernstein real estate investment fund inc'),
#  ('altegris eckhardt futures fund l p', 'altegris winton futures fund l p'),
#  ('american realty trust inc ga', 'biomed realty trust inc'),
#  ('ba nutrition llc', 'body armor nutrition llc'),
#  ('alliancebernstein global government income trust inc',
#   'alliancebernstein global growth trends fund inc'),
#  ('bhp billiton ltd', 'bhp ltd'),
#  ('alden global opportunities fund lp',
#   'apollo credit short opportunities fund l p'),
#  ('acunto john p', 'acunto john p jr'),
#  ('agic convertible & income fund ii',
#   'allianzgi equity & convertible income fund'),
#  ('avista capital partners ii lp', 'blackstone capital partners vi l p'),
#  ('blackstone emerging markets fund l p',
#   'blackstone market opportunities fund l p'),
#  ('advisoros disciplined trust 716', 'advisors disciplined trust 61'),
#  ('aew capital management l p ma', 'capital management partners inc bd'),
#  ('ariel capital management inc et al',
#   'brookhaven capital management co ltd et al'),
#  ('acm institutional reserves inc', 'cai institutional services llc'),
#  ('blackrock equity dividend trust',
#   'blackrock global enhanced equity income trust'),
#  ('blackrock muniyield michigan insured fund ii inc',
#   'blackrock muniyield michigan quality fund ii inc'),
#  ('campbell institutional trend fund l p', 'campbell world trend fund l p'),
#  ('artha emerging markets fund l p', 'bluecrest emerging markets fund ltd'),
#  ('ab growth & income fund inc', 'alliance mid cap growth fund inc'),
#  ('barclays private bank & trust cayman ltd',
#   'barclays private bank & trust ltd'),
#  ('a l laboratories inc', 'audyssey laboratories inc'),
#  ('actimis pharmaceuticals inc', 'canyon pharmaceuticals inc'),
#  ('active link communications inc', 'b communications ltd'),
#  ('ark investments', 'barclay investments inc'),
#  ('bates securities inc bd', 'bc securities inc'),
#  ('anchor capital advisors llc', 'capital asset advisors inc bd'),
#  ('abraham & co inc', 'abraham & london securities inc'),
#  ('advisors disciplined trsut 590', 'advisors disciplined trust 56'),
#  ('americal securities inc bd', 'brill securities inc'),
#  ('blackstone madison avenue offshore fund ltd class a b c & g shares',
#   'blackstone vanderbilt avenue offshore fund ltd'),
#  ('acci securities inc bd', 'berlind securities inc bd'),
#  ('bruke robert d', 'burke robert d'),
#  ('alphametrix managed futures iii llc',
#   'alphametrix managed futures iii llc alphametrix wc diversified series'),
#  ('asa bermuda ltd', 'asa ltd'),
#  ('aim investment securities funds invesco investment securities funds',
#   'capital securities investment corporation'),
#  ('banner apartments fund iii a operating limited partnership',
#   'boston millennia partners iv limited partnership'),
#  ('buffalo gold ltd', 'buffalo large cap fund inc'),
#  ('bloombergsen investment partners', 'brandes investment partners l p'),
#  ('berens capital partners lp', 'capital partnerships'),
#  ('american securities corp', 'american securities opportunities fund ii lp'),
#  ('bolton financial services llc', 'bolton financial services llc bd'),
#  ('andor capital management llc', 'basso capital management l p'),
#  ('advisors disciplined trust 74', 'advisors disciplined trust series 72'),
#  ('bmo lgm frontier markets equity fund',
#   'bmo lloyd george frontier markets equity fund'),
#  ('apac customer services inc', 'bessemer investor services inc bd'),
#  ('blackrock managed duration trust', 'blackrock senior income trust'),
#  ('asg securities inc', 'aton securities inc'),
#  ('berens capital partners l p', 'birch run capital partners lp'),
#  ('blue ridge capital management llc', 'blue river capital llc'),
#  ('banc of america mortgage securities inc',
#   'bank of america mortgage securities inc 2002 2'),
#  ('acadian asset management inc ma', 'athene asset management l p'),
#  ('american financial group inc', 'anderson group inc'),
#  ('ayre investments inc', 'barclay investments inc bd'),
#  ('aston asset management llc', 'bb&t asset management llc'),
#  ('a p securities inc bd', 'bdc securities inc'),
#  ('advanced investment technology inc fl',
#   'advanced orthopedic technologies inc'),
#  ('asset management fund', 'bourne lent asset management inc'),
#  ('american access technologies inc', 'calient technologies inc'),
#  ('blackstone capital partners vi lp', 'blr capital partners lp'),
#  ('archon securities llc', 'athene securities llc'),
#  ('advisors disciplined trust 437', 'advisors disciplined trust 70'),
#  ('ama securities inc', 'americal securities inc'),
#  ('berens credit opportunities fund ltd',
#   'canyon opportunistic credit grf fund cayman ltd'),
#  ('ad systems communications inc', 'arch communications inc'),
#  ('adamas partners lp', 'camden partners lp'),
#  ('blackstone partners offshore fund ltd class e f i j & k shares',
#   'blackstone partners offshore fund ltd class e f i j k q & r shares'),
#  ('body central corp', 'brady corp'),
#  ('allen & co inc bd', 'allen c ewing & co bd'),
#  ('advisors disciplined trust series 60',
#   'advisors disciplined trust series 71'),
#  ('allen test co inc test time prod', 'allen testing co ind'),
#  ('allostem therapeutics llc', 'bellerophon therapeutics inc'),
#  ('averil capital markets group inc', 'capital group inc'),
#  ('american commerce solutions', 'american commerce solutions inc'),
#  ('asci holdings mexico de inc', 'asci holdings uk de inc'),
#  ('alden global emerging markets fund i l p',
#   'alden global emerging markets fund offshore lp'),
#  ('advisors disciplined trust 136', 'advisors disciplined trust 57'),
#  ('american heritage securities inc bd', 'camden securities inc bd'),
#  ('advisors disciplined trust 1066', 'advisors disciplined trust series 19'),
#  ('american financial group inc', 'bnc financial group inc'),
#  ('access securities inc bd', 'bc securities inc'),
#  ('ani pharmaceuticals inc', 'avanir pharmaceuticals'),
#  ('arrowmark income opportunity fund ltd',
#   'arrowpoint income opportunity fund lp'),
#  ('alles investments inc', 'belle haven investments l p'),
#  ('advisors disciplined trust 683', 'advisors disciplined trust series 20'),
#  ('advisors disciplined trust series 54',
#   'advisors disciplined trust series 55'),
#  ('american landmark securities inc bd', 'atlantic securities inc bd'),
#  ('am capital llc', 'ar capital llc'),
#  ('blackrock emerging markets fund inc',
#   'blackstone emerging markets fund l p'),
#  ('advisors disciplined trust series 48',
#   'advisors disciplined trust series 59'),
#  ('blackrock muniholdings insured fund ii inc',
#   'blackrock muniholdings new york quality fund inc'),
#  ('axa financial services llc', 'callahan financial services inc bd'),
#  ('b riley & co llc', 'b riley and co inc'),
#  ('atlas america public #15 2005 a program',
#   'atlas america public #16 2007 a l p'),
#  ('acorn partners l p', 'arklow partners l p'),
#  ('advisors disciplined trust 136', 'advisors disciplined trust 52'),
#  ('american equity investment corporation', 'ameritas investment corp'),
#  ('berens credit opportunities fund l p',
#   'blackrock credit opportunities trust'),
#  ('blackrock municipal 2020 term trust',
#   'blackrock taxable municipal bond trust'),
#  ('advisors disciplined trus 437', 'advisors disciplined trust 47'),
#  ('avista capital opportunities fund ii offshore lp',
#   'bernstein global opportunities offshore ltd'),
#  ('aha financial solutions inc bd', 'broadridge financial solutions inc'),
#  ('altair nanotechnologies inc', 'american access technologies inc'),
#  ('alliancebernstein institutional funds inc',
#   'alliancebernstein institutional reserves inc'),
#  ('atlas america public #16 2007 a l p',
#   'atlas america public #16 2007 program'),
#  ('blackrock muniholdings florida insured fund inc',
#   'blackrock muniholdings quality fund ii inc'),
#  ('american eastern securities inc bd', 'american securities corp'),
#  ('ag diversified credit strategies fund lp',
#   'ag diversified income fund plus ltd'),
#  ('advisors disciplined trsut 683', 'advisors disciplined trust 63'),
#  ('adar investment management lp', 'alex brown investment management l p'),
#  ('brookfield investment funds', 'brookfield properties corp'),
#  ('advisors disciplined trust 46', 'advisors disciplined trust 63'),
#  ('brokers from campbell inc', 'brokers from campbell llc'),
#  ('blue capital group llc bd', 'capital planning group llc bd'),
#  ('bioma medical corp fi', 'bioms medical corp fi'),
#  ('apex clean energy holdings llc', 'apex wind energy holdings llc'),
#  ('campbell classic trend fund l p', 'campbell institutional trend fund l p'),
#  ('aig international securities inc', 'axp international series inc'),
#  ('armetis investment management llc', 'avi management llc'),
#  ('ab municipal income fund inc', 'american income fund i b'),
#  ('achelios therapeutics', 'achelios therapeutics inc'),
#  ('aramark uniform services baltimore llc',
#   'aramark uniform services pittsburgh llc'),
#  ('afg investment partners iii l p', 'afg investment partners iii lp'),
#  ('avenue europe investments lp', 'belle haven investments l p'),
#  ('basso capital management l p', 'black diamond capital management l l c'),
#  ('asante partners llc bd', 'avondale partners llc bd'),
#  ('alliancebernstein global real estate investment fund inc',
#   'alliancebernstein investor services inc ta'),
#  ('alliancebernstein exchange reserves',
#   'alliancebernstein investor services inc ta'),
#  ('all vest securities inc', 'ancora securities inc'),
#  ('apollo fund', 'apolo gold inc'),
#  ('capitol securities management inc', 'capitol securities management inc bd'),
#  ('al yousuf eqbal', 'al yousuf iqbal'),
#  ('advisors disciplined trust series 47',
#   'advisors disciplined trust series 58'),
#  ('aim investment funds', 'aim investment securities funds'),
#  ('acn securities inc bd', 'agricapital securities inc bd'),
#  ('alcan securities corp bd', 'aurum securities corp bd'),
#  ('advanced investment partners llc', 'brandes investment partners lp'),
#  ('bba icatu securities inc bd', 'brill securities inc bd'),
#  ('agricapital securities inc bd', 'brill securities inc'),
#  ('advisors disciplined trust series 53',
#   'advisors disciplined trust series 61'),
#  ('alliance all asia investment fund inc', 'aspen investment alliance inc'),
#  ('alliance securities corp', 'brill securities inc'),
#  ('acn securities inc bd', 'all vest securities inc bd'),
#  ('actuate software corp', 'ants software com inc'),
#  ('benchmark plus institutional parnters llc',
#   'brahman institutional partners lp'),
#  ('aon corp', 'aon securities corporation'),
#  ('candela capital lp', 'capita corp'),
#  ('american capital asset management llc', 'ashton capital management inc'),
#  ('alfa capital markets usa inc', 'cabrera capital markets llc'),
#  ('aes corporation', 'babson securities corporation'),
#  ('bank of america mortgage securities inc',
#   'bank of america mortgage securities inc 2001 h'),
#  ('accriva diagnostics holdings inc', 'aria diagnostics inc'),
#  ('advisors disciplined trust 72', 'advisors disciplined trust series 70'),
#  ('american eastern securities inc', 'american landmark securities inc bd'),
#  ('asset alliance investment services inc bd',
#   'bessemer investor services inc'),
#  ('blackrock muniholdings quality fund ii inc',
#   'blackrock muniyield pennsylvania quality fund'),
#  ('advisors disciplined trust 68', 'advisors disciplined trust 69'),
#  ('alderon resource corp', 'canadente resource corp'),
#  ('a ch securities inc bd', 'camden securities inc bd'),
#  ('american medical technologies inc de', 'breed technologies inc'),
#  ('advisors disciplined trust 138', 'advisors disciplined trust 206'),
#  ('americal securities inc', 'american classic securities inc'),
#  ('account management llc', 'bt investment management ltd'),
#  ('cambridge international partners inc',
#   'cambridge international partners llc'),
#  ('advisors disciplined trust 46', 'advisors disciplined trust 73'),
#  ('bailard long short offshore fund ltd',
#   'bbh longshort equity offshore fund ltd'),
#  ('adar investment management lp', 'bridgewater investment management llc'),
#  ('2713 commerce wf llc', '2716 commerce wf llc'),
#  ('artemis investment management llc',
#   'brandywine global investment management llc'),
#  ('brinker capital securities inc bd', 'brown burke securities inc bd'),
#  ('ault glazer asset management llc',
#   'ault glazer bodnar investment management llc'),
#  ('advisors disciplined trust 284', 'advisors disciplined trust 75'),
#  ('ashe capital management lp', 'basso capital management l p'),
#  ('alliance financial group inc', 'american financial group holdings inc'),
#  ('aegis investments inc bd', 'capital investments inc bd'),
#  ('allied urological services llc', 'allied urological services llc md'),
#  ('bear stearns focused opportunities fund lp',
#   'berens distressed opportunities fund ltd'),
#  ('all vest securities inc', 'capital one securities inc'),
#  ('brahman c p f partners l p', 'caiman partners l p'),
#  ('bracken george r', 'braden george r'),
#  ('burrill life sciences capital fund iii l p',
#   'burrill life scienes capital fund iii l p'),
#  ('brand scaffold builders inc', 'brand scaffold services inc'),
#  ('advisors disciplined trust 942', 'advisors disciplined trust series 52'),
#  ('advisors disciplined trust series 66',
#   'advisors disciplined trust series 74'),
#  ('barrington associates bd', 'barrington partners'),
#  ('brown bridge industries inc tx', 'brown ridge industries inc'),
#  ('aria partner ii lp', 'artorius partners ii lp'),
#  ('bc securities inc', 'cape securities inc bd'),
#  ('alliancebernstein americas government income trust inc',
#   'alliancebernstein utility income fund inc'),
#  ('alliance all asia investment fund inc',
#   'asset alliance investment services inc'),
#  ('artis capital management l p', 'bimini capital management inc'),
#  ('aq holdings inc', 'c p atlas holdings inc'),
#  ('brenner dainel l', 'brenner daniel l'),
#  ('blackstone capital partners delaware v nq l p',
#   'blackstone participation partnership delaware v nq l p'),
#  ('a4s technologies inc', 'aviation technologies inc'),
#  ('adage capital partners gp llc', 'adirondack capital partners inc'),
#  ('aviation technologies inc', 'calient technologies inc'),
#  ('allied asset management inc', 'ault glazer asset management llc'),
#  ('activa asset management llc bd', 'alleghany asset management inc'),
#  ('breitman leo', 'breitman leo r'),
#  ('advanced medical inc', 'advanced medical optics inc'),
#  ('arrowmark global opportunity fund ii lp',
#   'arrowmark global opportunity fund ii ltd'),
#  ('babson capital global advisors ltd',
#   'babson capital global investment funds plc'),
#  ('aim investment services inc', 'banc of america investment services inc bd'),
#  ('american energy capital partners lp', 'berens capital partners lp'),
#  ('babson capital securities llc', 'capital real estate securities llc'),
#  ('american income fund i a', 'american income fund i b ltd partnership'),
#  ('alphadyne asset management llc', 'asset management fund'),
#  ('cadence resources corp', 'camcap resources lp'),
#  ('bird estate limited partnership', 'burke trading limited partnership'),
#  ('advisors disciplined trust series 47',
#   'advisors discliplined trust series 20'),
#  ('blackrock muniyield insured investment fund',
#   'blackrock muniyield investment fund'),
#  ('american colonial corporation', 'cannamed corporation'),
#  ('advisors disciplined trus 437', 'advisors disciplined trust 61'),
#  ('alphadyne asset management llc', 'aston asset management llc'),
#  ('ad systems communications inc', 'caldera systems inc'),
#  ('actimis pharmaceuticals inc', 'ani pharmaceuticals inc'),
#  ('americal securities inc bd', 'austin securities inc bd'),
#  ('advanced equities altra investment ii llc',
#   'advanced equities foveon investments i llc'),
#  ('asset management fund inc', 'bluebay asset management plc'),
#  ('act capital america fund lp', 'akana capital fund lp'),
#  ('blackrock credit allocation income trust i',
#   'blackrock florida municipal income trust'),
#  ('a p securities inc', 'ancora securities inc bd'),
#  ('blackstone capital partners cayman v nq l p',
#   'blackstone participation partnership delaware v nq l p'),
#  ('advisors disciplined trust 551', 'advisors disciplined trust 57'),
#  ('babson capital securities inc', 'cape securities inc'),
#  ('american securities opportunities fund iii b l p',
#   'avista capital opportunities fund ii onshore l p'),
#  ('blackrock intermediate municipal fund of blackrock municipal series trust',
#   'blackrock municipal target term trust'),
#  ('calamos financial services llc', 'campbell financial services inc'),
#  ('aca securities llc bd', 'burrill securities llc'),
#  ('basswood capital management l l c', 'boyle capital management l l c'),
#  ('beazer homes investments llc', 'beazer homes sales arizona inc'),
#  ('atap financial services inc bd',
#   'automated trading desk financial services llc bd'),
#  ('access securities inc bd', 'bioscience securities inc bd'),
#  ('brown group inc', 'brownstone investment group llc bd'),
#  ('black diamond oc offshore fund ltd',
#   'blackstone vanderbilt avenue offshore fund ltd'),
#  ('brill securities inc bd', 'brinker capital securities inc bd'),
#  ('alderon resource corp', 'cadence resources corp'),
#  ('arris international ltd', 'beverly enterprises international ltd'),
#  ('ari financial services inc', 'btm financial services inc'),
#  ('capital group emerging markets restricted equity common trust us',
#   'capital group international all countries equity common trust us'),
#  ('a c t holdings inc', 'american caresouce holdings inc'),
#  ('beloyan investment securities inc bd',
#   'boston investment securities corp bd'),
#  ('argent capital advisors llc', 'capri capital advisors llc adv'),
#  ('cahn capital corp bd', 'canaccord capital corp usa inc bd'),
#  ('ab multi manager alternative fund', 'ark multi manager fund lp'),
#  ('ara services inc', 'brand services'),
#  ('american securities group inc bd', 'american securities team inc'),
#  ('brio technology inc', 'brooktrout technology inc'),
#  ('american capital asset management llc', 'ashe capital management llc'),
#  ('artis capital management llc', 'capital management partners inc bd'),
#  ('atlantic trust group inc', 'atlantic trust group llc'),
#  ('california capital services inc bd', 'california treatment services llc'),
#  ('anchor bay securities llc', 'bates securities inc bd'),
#  ('berens distressed opportunities lp',
#   'black diamond structured opportunities ltd'),
#  ('adar investment management llc', 'athene asset management llc'),
#  ('advisors disciplined trust 53', 'advisors disciplined trust 72'),
#  ('ab core opportunities fund inc',
#   'american securities opportunities fund iii l p'),
#  ('atx communications inc', 'b communications ltd'),
#  ('advisors disciplined trust series 56',
#   'advisors disciplined trust series 66'),
#  ('allied capital corp', 'america capital corp'),
#  ('american securities corp', 'ancora securities inc'),
#  ('arrowpoint fundamental opportunity fund l p',
#   'arrowpoint fundamental opportunity fund ltd'),
#  ('acorn partners l p', 'camden partners ltd partnership'),
#  ('big cat energy corp', 'bt energy corp'),
#  ('aim investment funds invesco investment funds',
#   'aim investment securities funds inc'),
#  ('bluecrest emerging markets fund l p', 'bluecrest emerging markets ltd'),
#  ('apollo fund', 'apollo fund ct'),
#  ('bernstein global diversified hedge fund ltd',
#   'bernstein global opportunities hedge fund lp'),
#  ('blue chip investor fund', 'blue chip special investment fund llc'),
#  ('aquinox pharmaceuticals inc', 'avanir pharmaceuticals inc'),
#  ('agic equity & convertible income fund',
#   'allianzgi global equity & convertible income fund'),
#  ('bocage active commodity long fund l p',
#   'bocage active commodity offshore fund'),
#  ('american colonial corporation', 'canyon bancorportion'),
#  ('access investments inc bd', 'accesstel inc'),
#  ('american securities opportunities fund ii b lp',
#   'ascribe opportunities fund ii b lp'),
#  ('atlas america public #16 2007 program',
#   'atlas resources public #16 2007 program'),
#  ('advisory research international value fund l p',
#   'advisory research opportunities fund l p'),
#  ('bion pharmaceuticals inc', 'canyon pharmaceutical inc'),
#  ('alliance securities corp', 'banca imi securities corp bd'),
#  ('canyon balanced equity fund cayman ltd', 'canyon balanced fund cayman ltd'),
#  ('athene asset management llc', 'bluebay asset management ltd'),
#  ('advisors disciplined trust 1197', 'advisors disciplined trust 55'),
#  ('blackstone fifth avenue fund lp',
#   'blackstone fifth avenue offshore fund ltd class a d f k & l shares'),
#  ('ambac securities inc', 'bates securities inc bd'),
#  ('alpha equity asset allocation offshore fund ltd',
#   'aqr global asset allocation offshore fund usd ii ltd'),
#  ('7advisors disciplined trust 1197', 'advisors disciplined trust 73'),
#  ('aetos capital market neutral strategies fund llc',
#   'archstone market neutral strategies fund ltd'),
#  ('avista capital partners ii lp', 'avista capital partners offshore ii l p'),
#  ('afm investments inc bd', 'alles investments inc bd'),
#  ('altimeter capital management lp', 'bimini capital management inc'),
#  ('a p securities inc', 'bdc securities inc'),
#  ('brown and brown securities inc', 'brown bob'),
#  ('advantage advisers global growth ltd', 'alger global growth fund'),
#  ('barings securities llc', 'brill securities inc'),
#  ('cabot industrial core fund blocker llc',
#   'cabot industrial core fund blocker reit llc'),
#  ('aim counselor series funds inc', 'aim investment securities funds inc'),
#  ('advanced thermal technologies inc', 'breed technologies inc'),
#  ('alexander international inc', 'altair international inc fi'),
#  ('blackrock california insured municipal income trust',
#   'blackrock insured municipal income investment trust'),
#  ('altegris qim futures fund l p', 'altegris winton futures fund l p'),
#  ('bonde john h', 'calonico john'),
#  ('alliance international fund', 'bid com international inc'),
#  ('allied gold mining ltd', 'allied gold mining plc'),
#  ('blackrock muniholdings california quality fund inc',
#   'blackrock muniholdings investment quality fund'),
#  ('calvert investment management inc', 'cambria investment management l p'),
#  ('acm emerging markets multi strategy fund i lp',
#   'aris multi strategy fund lp'),
#  ('agf securities inc', 'aton securities inc'),
#  ('abi capital management llc bd', 'burch capital management inc'),
#  ('advisors disciplined trust series 55',
#   'advisors disciplined trust series 66'),
#  ('advisor disciplined trust 902', 'advisors disciplined trust 942'),
#  ('access financial group inc', 'belmont financial group inc'),
#  ('advisors disciplined trust 61', 'advisors disciplined trust series 68'),
#  ('american capital asset management llc', 'american capital llc'),
#  ('american dental technologies inc', 'auto tool technologies inc'),
#  ('bengal partners llc', 'berens capital partners lp'),
#  ('capital one auto finance trust 2001 b',
#   'capital one auto finance trust 2002 c'),
#  ('advisors disciplined trsut 683', 'advisors disciplined trust 69'),
#  ('advisors disciplined trust 437', 'advisors disciplined trust series 46'),
#  ('aglialord john', 'cagle john m iii'),
#  ('alpha equity asset allocation offshore fund ltd',
#   'alpha equity global long short offshore fund ltd'),
#  ('associated financial services inc', 'calypso financial services inc'),
#  ('ariel capital management inc', 'brown capital management llc'),
#  ('alliance fund inc', 'alliance international fund inc'),
#  ('alliancebernstein focused growth & income fund inc',
#   'alliancebernstein international premier growth fund inc'),
#  ('atlas capital services llc', 'baystate capital services inc bd'),
#  ('cabot wealth management inc',
#   'canaccord genuity wealth management usa inc'),
#  ('capital guardian emerging markets debt usd fund for tax exempt trusts',
#   'capital guardian u s core fixed income fund for tax exempt trusts'),
#  ('antero resources corp', 'atlatsa resources corp'),
#  ('advisors disciplined trust 716', 'advisors disciplined trust series 71'),
#  ('bloombergsen investment partners', 'brandes investment partners lp'),
#  ('advisors disciplined trust 1279', 'advisors disciplined trust 64'),
#  ('advisors discplined trust 136', 'advisors discplined trust 138'),
#  ('atlas securities inc', 'aton securities inc bd'),
#  ('bhp billiton plc', 'bhp ltd'),
#  ('blackrock municipal income quality trust',
#   'blackrock muniyield michigan quality fund ii inc'),
#  ('atmi holdings inc', 'atmi inc'),
#  ('bolton financial services llc bd', 'brock financial services llc'),
#  ('aig multi strategy fund of funds llc',
#   'air multi strategy fund of funds spc class h aig volatility arbitrage portfolio'),
#  ('american pharmaceutical partners inc ca', 'canyon pharmaceutical inc'),
#  ('akros securities inc', 'brill securities inc'),
#  ('a c t holdings inc', 'adf holdings llc'),
#  ('advisory research global all cap fund l p',
#   'advisory research global value fund lp'),
#  ('brinker capital securities inc', 'capital innovations securities llc'),
#  ('ashton young financial services inc bd',
#   'bolton financial services llc bd'),
#  ('avenue capital management ii l p', 'capital management partners inc bd'),
#  ('blackrock municipal income investment trust',
#   'blackrock new york municipal income quality trust'),
#  ('alpine partners l p', 'artorius partners ii l p'),
#  ('barclays private bank & trust ltd', 'barclays trust co cayman ltd'),
#  ('allos therapeutics', 'artielle immuno therapeutics inc'),
#  ('blackrock build america bond trust', 'blackrock municipal series trust'),
#  ('bridgeway capital management inc', 'brown capital management llc'),
#  ('alternative investments l p', 'american alternative investments llc'),
#  ('asset holder pcc 2 ltd re ashmore emerging economy port',
#   'asset holder pcc 2 ltd re ashmore emerging economy portfolio'),
#  ('acn securities inc bd', 'atlas securities inc bd'),
#  ('advisors disciplined trust 52', 'advisors disciplined trust 942'),
#  ('alliancebernstein global small cap fund inc',
#   'alliancebernstein small cap growth fund inc'),
#  ('babson capital securities inc', 'capital securities investment corp'),
#  ('ameritas investment corp bd', 'ameritas investment partners inc'),
#  ('bengston jon', 'bengtson jon n'),
#  ('afton capital management llc', 'avenue capital management ii llc'),
#  ('avanti securities corp bd', 'aviva securities llc'),
#  ('brown and brown securities inc', 'brown group inc'),
#  ('alcan securities corp bd', 'boston investment securities corp bd'),
#  ('allied asset management inc', 'athene asset management l p'),
#  ('baring asset management inc ma', 'bluebay asset management llp'),
#  ('bates securities inc bd', 'brill securities inc bd'),
#  ('blackstone relative value offshore fund fixed income ltd',
#   'blackstone sixth avenue offshore fund ltd class a b c k & l shares'),
#  ('broadwood partners lp', 'brookwood securities partners lp bd'),
#  ('astoria capital markets inc', 'averil capital markets group inc ca bd'),
#  ('btmu financial services inc', 'callahan financial services inc bd'),
#  ('aim investment securities funds invesco investment securities funds',
#   'alternative investment funds'),
#  ('apm equity long short fund l p', 'broadmark long short equity fund l p'),
#  ('a i m distributors inc', 'artisan distributors llc bd'),
#  ('alliancebernstein dynamic growth fund inc',
#   'alliancebernstein income fund inc'),
#  ('acn securities inc bd', 'actinver securities inc bd'),
#  ('activa asset management llc bd', 'bolton asset mamagement llc'),
#  ('blackstone corporate opportunities master fund l p',
#   'blackstone pacific opportunities fund lp'),
#  ('atlas america public #15 2005 program',
#   'atlas america public #15 2006 b l p'),
#  ('aer energy resources inc', 'aer energy resources inc ga'),
#  ('blackstone capital partners cayman nq v ac l p',
#   'blackstone participation partnership cayman v nq l p'),
#  ('abernathy capital preservation fund lp',
#   'american century capital preservation fund ii inc'),
#  ('aspiriant global equity trust', 'aspiriant trust'),
#  ('aria partner ii lp', 'artorius partners ii l p'),
#  ('activa asset management llc', 'aim private asset management inc'),
#  ('advisors disciplined trust 76', 'advisors disciplined trust series 74'),
#  ('advisors disciplined trust series 20',
#   'advisors disciplined trust series 57'),
#  ('bioscience securities inc bd', 'cadre securities inc bd'),
#  ('bowman capital management l l c', 'brown capital management inc'),
#  ('advisors disciplined trust 284', 'advisors disciplined trust series 51'),
#  ('airband communications inc', 'alliance atlantis communications inc'),
#  ('abernathy capital preservation fund lp', 'aberon capital fund l p'),
#  ('a ch securities inc', 'a ch securities inc bd'),
#  ('bear stearns asset backed securities i trust 2005 he10',
#   'bear stearns asset backed securities trust 2003 sd1'),
#  ('afg investment partners iv lp', 'ameritas investment partners inc'),
#  ('artisan partners ltd partnership',
#   'boston millennia partners iv limited partnership'),
#  ('biotechnology value fund l p', 'biotechnology value fund l p et al'),
#  ('advisors disciplined trust series 20',
#   'advisors disciplined trust series 76'),
#  ('alliancebernstein institutional reserves inc',
#   'boston institutional services incorporated'),
#  ('atap financial services inc bd', 'beanpot financial services inc'),
#  ('blackrock insured municipal income investment trust',
#   'blackrock municipal advantage income trust'),
#  ('brar investment fund lp', 'caine investment fund i l p'),
#  ('burch capital management inc bd', 'capital health management group inc'),
#  ('avighna capital partners lp', 'berens capital partners l p'),
#  ('amman robert j', 'ammon robert j'),
#  ('berry joseph c', 'burstein joseph'),
#  ('brooke securities inc', 'brookwood securities partners lp bd'),
#  ('abeona therapeutics inc', 'aldexa therapeutics inc'),
#  ('advisors disciplined trust series 47',
#   'advisors disciplined trust series 53'),
#  ('american express certificate co',
#   'american express financial advisors inc'),
#  ('balckmon zack w sr', 'blackmon zack w sr'),
#  ('ai securities inc bd', 'akros securities inc bd'),
#  ('blackstone corporate opportunities master fund l p',
#   'blackstone market opportunities fund lp'),
#  ('act ii partners l p', 'adamas partners l p'),
#  ('arka securities inc', 'aton securities inc'),
#  ('advisors disciplined trust 134', 'advisors disciplined trust 71'),
#  ('advisors disciplind trust 641', 'advisors disciplined trust series 20'),
#  ('artio global credit opportunities fund',
#   'bernstein global opportunities offshore ltd'),
#  ('act ii partners l p', 'armata partners l p'),
#  ('american income fund i c ltd partnership', 'american income fund i d'),
#  ('american express west equity fund l p',
#   'american express west equity fund limited partnership'),
#  ('blackrock municipal income quality trust',
#   'blackrock real asset equity trust'),
#  ('advisors disciplined trust 802', 'advisors disciplined trust series 71'),
#  ('asset management fund inc', 'baring asset management inc ma'),
#  ('advisors disciplined trust 67', 'advisors disciplined trust series 67'),
#  ('airtouch communications', 'airtouch communications inc'),
#  ('associated financial services inc bd', 'axa financial services llc'),
#  ('2100 capital managed futures fund lp', 'candence managed futures fund llc'),
#  ('aew capital management l p', 'bowman capital management l l c'),
#  ('boston institutional services inc bd', 'cai institutional services llc'),
#  ('capital beverage corp', 'capital beverage corp fa'),
#  ('american balanced fund inc', 'american income fund i e'),
#  ('aew capital management l p', 'american capital asset management llc'),
#  ('american commerce solutions inc', 'biometric solutions llc'),
#  ('blackstone firestone transaction participation cayman l p',
#   'blackstone participation partnership cayman v nq l p'),
#  ('actimis pharmaceutical inc', 'canyon pharmaceuticals inc'),
#  ('actinver securities inc bd', 'all vest securities inc'),
#  ('ascribe opportunities fund ii lp', 'ascribe opportunities fund iii b l p'),
#  ('airband communications inc', 'atx communications inc'),
#  ('advisors disciplined trust 60', 'advisors disciplined trust 61'),
#  ('american fidelity financial services inc',
#   'ameriprise financial services inc'),
#  ('american core realty fund l p', 'american realty trust inc'),
#  ('acacia partners l p', 'axel partners l p'),
#  ('a & m securities llc', 'burrill securities llc'),
#  ('alexander barbara t', 'alexander stiles barbara'),
#  ('american securities bd co lp',
#   'american securities opportunities fund ii b lp'),
#  ('afting ernst guenter', 'afting ernst gunter'),
#  ('a ch securities inc bd', 'atlas securities inc bd'),
#  ('advisors disciplined trust 63', 'advisors disciplined trust series 65'),
#  ('advanced orthopedic technologies inc', 'breed technologies inc'),
#  ('alliancebernstein bond fund inc',
#   'alliancebernstein municipal income fund inc'),
#  ('capistrano cogeneration co', 'capistrano congeneration co'),
#  ('allen test co & release 8 2 inc', 'allen test co & release 8 3 inc'),
#  ('babson enterprise fund ii inc', 'babson enterprise fund ii inc mo'),
#  ('blackrock florida municipal bond trust',
#   'blackrock municipal target term trust'),
#  ('capital market securities inc bd', 'capitol securities management inc bd'),
#  ('advisors disciplined trust 63', 'advisors disciplined trust 76'),
#  ('bowman capital management l l c', 'brown capital management llc'),
#  ('amag pharmaceuticals inc', 'barr pharmaceuticals inc'),
#  ('allianz asset management of america l p', 'asset management fund'),
#  ('blackrock florida municipal income trust iii',
#   'blackrock muniyield florida fund'),
#  ('bolton financial services llc bd', 'callahan financial services inc'),
#  ('akros securities inc bd', 'berlind securities inc bd'),
#  ('capital guardian emerging markets total opportunities fund for tax exempt trusts',
#   'capital guardian energing markets total opportunities fund for tax exempt trusts'),
#  ('berkeley capital management', 'beta capital management l p'),
#  ('bluebay asset management ltd', 'bluebay asset management plc'),
#  ('calamos financial services inc', 'callaway financial services inc bd'),
#  ('blackrock insured municipal income investment trust',
#   'blackrock muniholdings insured investment fund'),
#  ('blackrock municipal 2022 term trust',
#   'blackrock new york insured municipal 2008 term trust inc'),
#  ('acadian global low volatility equity fund llc',
#   'amundi volatility world equities llc'),
#  ('blackrock multi sector income trust',
#   'blackrock municipal income quality trust'),
#  ('breitburn management co llc', 'breitburn management company llc'),
#  ('capital guardian emerging markets total opportunities fund for tax exempt trusts',
#   'capital guardian international non us equity fund for tax exe tr'),
#  ('allen test co inc & cut over test', 'allen test co name change test'),
#  ('american enterprise variable annuity account',
#   'ameritas variable separate account v'),
#  ('brokerwest', 'brokerwest bd bd'),
#  ('alternative investments lp', 'ark investments'),
#  ('allen test co & rel 8 5 inc', 'allen test co & release 8 2 inc'),
#  ('american real estate income fund',
#   'american realty capital real estate income fund'),
#  ('american pharmaceutical partners inc de', 'biosante pharmaceuticals inc'),
#  ('alliancebernstein international growth fund inc',
#   'alliancebernstein investments inc'),
#  ('american access technologies inc', 'aviation technologies inc'),
#  ('capital management of the carolinas llc bd',
#   'capitol securities management inc bd'),
#  ('balanced financial securities corp bd',
#   'callahan financial services inc bd'),
#  ('abraham & london securities inc', 'abraham & london securities inc bd'),
#  ('capital auto receivables inc',
#   'capital one prime auto receivables trust 2003 2'),
#  ('bengal investments ltd',
#   'bengal investments ltd spc segregated portfolio i'),
#  ('brahman institutional partners lp', 'brahman partners ii l p'),
#  ('alfa international corp', 'cal bay international inc'),
#  ('alliancebernstein global bond fund inc',
#   'alliancebernstein investments inc'),
#  ('advisors disciplined trust 73', 'advisors disciplined trust series 70'),
#  ('alliancebernstein growth & income fund inc',
#   'alliancebernstein municipal income fund ii'),
#  ('ba mortgage securities inc', 'bates securities inc'),
#  ('advisors disciplined trust 49', 'advisors disciplined trust series 19'),
#  ('avenue capital management ii llc', 'beta capital management lp'),
#  ('adp broker dealer inc bd', 'broker dealer inc'),
#  ('alliancebernstein americas government income trust inc',
#   'alliancebernstein municipal trust'),
#  ('allied signal inc', 'alliedsignal inc'),
#  ('agilis biotherapeutics inc', 'allos therapeutics inc'),
#  ('anchor bay securities llc', 'bates securities inc'),
#  ('access financial group inc bd', 'apb financial group inc'),
#  ('a c t holdings inc', 'amh holdings inc'),
#  ('advisors disciplined trust 64', 'advisors disciplined trust 69'),
#  ('boston equity advisors llc', 'boston equity advisors llc bd'),
#  ('agora securities corp', 'avanti securities corporation'),
#  ('american income fund i a', 'american income fund i a ltd partnership'),
#  ('ark investments', 'capital investments inc'),
#  ('asset allocation securities corp',
#   'capital securities investment corporation'),
#  ('alliance capital management lp', 'brown capital management llc'),
#  ('brandon i inc', 'brandon investments inc bd'),
#  ('ascent acquisition corp', 'berry plastics acquisition corp x'),
#  ('barclays global fund advisors',
#   'barclays global investors fund distribution company'),
#  ('bonny paul v', 'bonny pual v'),
#  ('am capital llc bd', 'arlen capital llc'),
#  ('advisors disciplined trust 76', 'advisors disciplined trust series 66'),
#  ('amarantus bioscience inc', 'anaptys biosciences inc'),
#  ('blue capital group llc', 'capital planning group llc'),
#  ('canyon balanced equity fund cayman ltd',
#   'canyon opportunistic credit grf fund cayman ltd'),
#  ('adar investment management llc', 'artis capital management llc'),
#  ('alliance international premier growth fund inc',
#   'alliancebernstein premier growth fund inc'),
#  ('belfinance securities inc bd', 'benefit finance securities llc'),
#  ('agora securities corp', 'ancora securities inc bd'),
#  ('amc entertainment inc et al', 'american artists entertainment corp'),
#  ('acap global fund', 'alloy global fund l p'),
#  ('bank of new york mellon ta', 'bank of new york mellon trust company n a'),
#  ('adage capital partners gp llc', 'artigent capital partners lp'),
#  ('actinver securities inc bd', 'bates securities inc'),
#  ('american heritage securities inc bd', 'brill securities inc'),
#  ('apollo capital group inc', 'capital hill group inc'),
#  ('allstate global funding trust 2005 3',
#   'allstate life global funding trust 2005 3'),
#  ('anderson richard allen', 'berenson richard a'),
#  ('acadian asset management llc', 'ar asset managment inc'),
#  ('alcan securities corp', 'ancora securities inc'),
#  ('canada life of america financial services inc',
#   'canada life of america financial services inc bd'),
#  ('aer energy resources inc', 'aurora energy resources inc'),
#  ('alliance global investor services inc ta',
#   'bessemer investor services inc'),
#  ('apm equity long short fund l p', 'aqr us long short equity fund lp'),
#  ('advisors disciplined trust 59', 'advisors disciplined trust 76'),
#  ('across america real estate corp', 'american real estate income fund'),
#  ('allen test inc and new name 2 limited', 'allen test inc new name 2'),
#  ('advisors disciplined trust series 64',
#   'advisors disciplined trust series 76'),
#  ('alliance international fund', 'american century international bond funds'),
#  ('advanced communications technologies inc', 'advanced power technology inc'),
#  ('cancer prevention pharmaceuticals llc', 'cantata pharmaceuticals inc'),
#  ('alliancebernstein health care fund inc',
#   'alliancebernstein high income fund inc'),
#  ('aegis investments inc', 'alles investments inc'),
#  ('blackstone partners investment fund l p',
#   'brandes investment partners llc'),
#  ('arguss communications inc', 'atx communications nc'),
#  ('altimeter capital management lp', 'burch capital management inc'),
#  ('american heritage securities inc', 'american securities corp'),
#  ('cambridge international partners inc bd',
#   'cambridge international securities llc'),
#  ('atlantic securities inc', 'atlas securities llc'),
#  ('ameritas investment corp', 'capital securities investment corp'),
#  ('alliancebernstein municipal income fund ii',
#   'alliancebernstein real estate investment fund inc'),
#  ('adamas partners l p', 'asante partners llc'),
#  ('advisors disciplined trust 134', 'advisors disciplined trust 50'),
#  ('andesa services inc ta', 'andesa tpa inc ta'),
#  ('alden global emerging markets fund i ltd', 'alden global india fund ltd'),
#  ('abdiel capital advisors lp', 'capital growth advisors llc bd'),
#  ('alliancebernstein institutional fund',
#   'alliancebernstein mid cap growth fund inc'),
#  ('artisan partners ltd partnership', 'capital partnerships'),
#  ('advisors disciplined trust 134', 'advisors discliplined trust series 19'),
#  ('brimberg & co l p', 'brimberg & co lp bd'),
#  ('astoria capital markets inc bd', 'capital market securities inc bd'),
#  ('accipiter capital management', 'andor capital management l l c'),
#  ('allen robert emmet', 'allen robert emmett'),
#  ('anchor drilling fluids usa inc', 'anchor drilling fluids usa llc'),
#  ('analyte media inc', 'analytic investors inc ca'),
#  ('advisors disciplined trust 134', 'advisors discplined trust 136'),
#  ('cal bay internatinoal inc', 'cal bay international inc'),
#  ('blackrock income & growth property fund inc',
#   'blackrock income opportunity trust inc'),
#  ('bolton financial services llc', 'boston capital services inc'),
#  ('alternet securities inc bd', 'ancora securities inc bd'),
#  ('american commerce solutions inc', 'cam commerce solutions inc'),
#  ('asci holdings mexico de inc', 'asci holdings mexico inc de'),
#  ('abax brokerage services inc bd', 'bull & bear brokerage services inc'),
#  ('asian coast development canada ltd', 'asian coast drvelopment canada ltd'),
#  ('artha emerging markets fund l p', 'blackstone emerging markets fund i l p'),
#  ('aramark clinical technology services llc', 'aramark services inc'),
#  ('blackrock muniholdings investment quality fund',
#   'blackrock muniholdings new jersey quality fund inc'),
#  ('assetmark capital corporation', 'capital conservation corp'),
#  ('blackrock muniholdings california insured fund inc',
#   'blackrock muniholdings investment quality fund'),
#  ('advisors disciplined trust series 49',
#   'advisors disciplined trust series 69'),
#  ('blackrock muniyield california quality fund inc',
#   'blackrock muniyield new york insured fund inc'),
#  ('american financial group holdings inc', 'bg financial group inc'),
#  ('blackrock muniyield california insured fund inc',
#   'blackrock muniyield investment quality fund'),
#  ('american income fund i a ltd partnership',
#   'american income fund i e ltd partnership'),
#  ('blackstone emerging markets fund lp',
#   'bluecrest emerging markets fund l p'),
#  ('alliance institutional reserves inc',
#   'alternative investments institutional l p'),
#  ('access pharmaceuticals inc', 'biosante pharmaceuticals inc'),
#  ('alleghany asset management inc', 'bolton asset management llc'),
#  ('aim private asset management inc', 'baring asset management llc'),
#  ('barclays global investors funds inc', 'barclays global investors na ca'),
#  ('axes america llc', 'axes america llc bd'),
#  ('abraxis biosciences inc', 'bioscience securities inc'),
#  ('afton capital management llc', 'alara capital avi management llc'),
#  ('bnp paribas ny', 'bnp paribas securities corp ny bd'),
#  ('brightfield partners ii l p', 'brightfield partners lp'),
#  ('ascribe opportunities fund iii b l p',
#   'brazil real estate opportunities fund ii l p'),
#  ('alger separate account a of ing usa annuity & life insurance co',
#   'ameritas variable life insurance co separate account v'),
#  ('aca securities l l c', 'acci securities inc'),
#  ('alloy global fund l p', 'campbell global trend fund l p'),
#  ('bolton financial services llc', 'btm financial services inc'),
#  ('banc of america mort sec inc alternative loan trust 2003 1',
#   'banc of america mort sec inc mort pass thr certs ser 2003 1'),
#  ('advisors disciplined trust series 20',
#   'advisors disciplined trust series 58'),
#  ('brand yourself com llc', 'brandyourself com inc'),
#  ('blackrock inc ny', 'blackrock investments llc'),
#  ('apollo distressed investment fund lp', 'apollo investment fund pb vii lp'),
#  ('blackrock advisors llc', 'blackrock inc ny'),
#  ('alliancebernstein investment research and management inc',
#   'alliancebernstein real estate investment fund inc'),
#  ('camden partners ltd partnership', 'camden partners nexus fund l p'),
#  ('advisors disciplined trust series 73',
#   'advisors discliplined trust series 19'),
#  ('black rock dividend achievers trust', 'blackrock dividend income trust'),
#  ('archview credit oportunities fund lp', 'bcmcredit opportunities fund lp'),
#  ('bernstein global opportunities l p',
#   'bernstein global opportunities offshore ltd'),
#  ('alliancebernstein global growth trends fund inc',
#   'alliancebernstein premier growth fund inc'),
#  ('avanyx therapeutics inc', 'bolt therapeutics inc'),
#  ('access integrated technologies inc', 'asempra technologies inc'),
#  ('aqr absolute return offshore fund usd iii ltd',
#   'aqr global asset allocation offshore fund usd ii ltd'),
#  ('america northcoast securities inc', 'americal securities inc'),
#  ('american national municipal corp bd',
#   'american national municipal corporation'),
#  ('aon asset management fund inc', 'boston partners asset management llc'),
#  ('ariel way inc', 'arielway'),
#  ('archetype alpha i fund lp', 'archetype low vol equity fund lp'),
#  ('asset management fund', 'bnp paribas asset management'),
#  ('blackrock muniyield investment quality fund',
#   'blackrock muniyield new york insured fund inc'),
#  ('bailard emerging opportunities fund i l p',
#   'bailard opportunity fund group inc'),
#  ('busada advisory services inc', 'busada advisory services inc bd'),
#  ('blackstone event driven fund l p',
#   'blackstone partners investment fund lp'),
#  ('arrowmark fundamental opportunity fund l p',
#   'arrowmark income opportunity fund qp l p'),
#  ('anchor capital advisors llc', 'argent capital advisors llc'),
#  ('blackrock municipal income trust iii',
#   'blackrock municipal target term trust'),
#  ('ark securities co inc bd', 'atlantic securities inc bd'),
#  ('canandaigua brands inc', 'canandaigua west inc'),
#  ('aetos capital market neutral strategies fund llc',
#   'ba sometros market neutral fund l p'),
#  ('allomek therapeutics llc', 'apex therapeutics inc'),
#  ('cabel net inc', 'cable net inc'),
#  ('advanced magnetics inc', 'advanced medical optics inc'),
# ...
#  ('bioscience securities inc bd', 'cabin securities inc'),
#  ('advisors disciplined trust 206', 'advisors disciplined trust 284'),
#  ('apollo credit short opportunities fund l p',
#   'berens distressed opportunities fund l p'),
#  ('black diamond capital management llc', 'cadian capital management llc'),
#  ('apollo partners l p', 'arapaho partners llc bd'),
#  ('avionic instruments inc', 'avionic instruments llc'),
#  ('abn amro mort corp multi class mort pas thr certs ser 2003 5',
#   'bank of america mort sec inc mort pas thr certs ser 2001 h'),
#  ('aim private asset management co inc', 'calvert asset management co inc md'),
#  ('advisors disciplined trust 206', 'advisors disciplined trust series 76'),
#  ('advisors disciplined trust series 61',
#   'advisors disciplined trust series 72'),
#  ('blackrock municipal income investment trust',
#   'blackrock municipal income quality trust'),
#  ('anchor bay securities llc bd', 'brill securities inc bd'),
#  ('alternet securities inc', 'ark securities co inc'),
#  ('brandywine securities inc', 'brandywine securities inc bd'),
#  ('archon securities llc', 'burke securities llc'),
#  ('ark securities co inc bd', 'austin securities inc bd'),
#  ('a b financial l l c', 'bkd financial l l c'),
#  ('bronk eric chess', 'bronk erick chess'),
#  ('brandon investments inc bd', 'capital investments inc bd'),
#  ('bailard biehl & kaiser opportunity fund group inc',
#   'bailard opportunity fund group inc'),
#  ('acacia ii partners l p', 'adria partners l p'),
#  ('alliance technology fund inc', 'aviation technology group inc'),
#  ('allianz global investors europe gmbh', 'allianz global investors gmbh'),
#  ('american aadvantage funds', 'american aadvantage select funds'),
#  ('blackrock prime rate trust', 'blackrock real asset trust'),
#  ('aim investment securities funds', 'boston investment securities corp bd'),
#  ('advisors disciplined trust 61', 'advisors disciplined trust 71'),
#  ('advisors disciplined trust series 19',
#   'advisors disciplined trust series 56'),
#  ('bonanza resources corp', 'canamex resources corp'),
#  ('altair international inc', 'altura interventional inc'),
#  ('acm emerging markets multi strategy master fund i l p',
#   'blackstone emerging markets fund i lp'),
#  ('agri general securities corp bd', 'alcan securities corp'),
#  ('alliancebernstein international research growth fund inc',
#   'alliancebernstein mid cap growth fund inc'),
#  ('alternative construction company inc',
#   'alternative construction technologies inc'),
#  ('bluecrest capital management llp', 'cadian capital management lp'),
#  ('aspen trading l l c', 'aspen trading llc bd'),
#  ('apollo entertainment group inc', 'avenue entertainment group inc'),
#  ('alcan securities corp bd', 'asset allocation securities corp'),
#  ('ariel capital management inc il', 'ashe capital management lp'),
#  ('access capital investment group inc',
#   'avalon investment & securities group inc'),
#  ('allmerica select separate account of sma life assurance co',
#   'ameritas variable life insurance co separate acct va 2'),
#  ('ai securities inc bd', 'ancora securities inc'),
#  ('acm emerging markets master fund i l p',
#   'acm emerging markets multi strategy fund i lp'),
#  ('amalgamated bank of new york', 'bank of new york delaware the'),
#  ('bcs brokerage inc', 'bny brokerage inc'),
#  ('ariel capital management inc et al', 'brown capital management inc'),
#  ('agf securities inc bd', 'austin securities inc bd'),
#  ('advanced magnetics inc', 'advanced medical inc'),
#  ('abacus international capital corp bd', 'arc international corporation'),
#  ('abn amro rothschild llc', 'abn amro rothschild llc bd'),
#  ('bba icatu securities inc', 'bbva securities inc'),
#  ('american electric technologies inc', 'calient technologies inc'),
#  ('behringer harvard mid term value enhancement fund i lp',
#   'behringer harvard mid term value enhancement liquidating trust'),
#  ('balanced financial securities corp bd', 'buell securities corp bd'),
#  ('access securities inc bd', 'brill securities inc bd'),
#  ('atomico iii l p', 'atomico ventures iii l p'),
#  ('ameritas investment advisors inc',
#   'amundi investment solutions advisers llc'),
#  ('blackrock muniholdings quality fund ii inc',
#   'blackrock muniyield new jersey quality fund inc'),
#  ('alliancebernstein institutional funds inc',
#   'alliancebernstein technology fund inc'),
#  ('advisors disciplined trust 645', 'advisors disciplined trust 68'),
#  ('american classic financial company', 'american ostrich company llc'),
#  ('ai securities inc', 'atlas securities inc'),
#  ('ab growth & income fund inc', 'ab large cap growth fund inc'),
#  ('aim investment securities funds',
#   'aim investment securities funds invesco investment securities funds'),
#  ('alliancebernstein blended style series inc',
#   'alliancebernstein select investor series inc'),
#  ('allis chalmers rental services llc', 'allis chalmers tubular services llc'),
#  ('advisors disciplined trust 206', 'advisors disciplined trust 52'),
#  ('burke securities llc', 'capital market securities inc'),
#  ('aetos distressed investment strategies fund llc',
#   'aetos market neutral strategies fund llc'),
#  ('a p securities inc bd', 'banca imi securities corp bd'),
#  ('altrinsic global advisors llc', 'attrinsic global advisors llc'),
#  ('blackstone credit opportunities fund lp',
#   'blackstone pacific opportunities master fund lp'),
#  ('bank of new york mellon trust co na', 'bank of new york ny'),
#  ('bg holdings ii inc', 'bli holdings corp'),
#  ('advanced gaming technology inc', 'apeel technology inc'),
#  ('brio technology inc', 'capital technology inc bd'),
#  ('afton capital management llc', 'capital management of the carolinas llc'),
#  ('calamos financial services inc', 'callahan financial services inc'),
#  ('anchor capital advisors inc', 'blue rose capital advisors inc'),
#  ('bourne lent asset management inc', 'cabot money management inc'),
#  ('api technologies corp', 'breed technologies incorporated'),
#  ('advisors disciplined trust 134', 'advisors disciplined trust 57'),
#  ('allied asset management inc bd', 'bb&t asset management llc'),
#  ('bailard biehl & kaiser fund group',
#   'bailard biehl & kaiser opportunity fund group inc'),
#  ('ama securities llc', 'arka securities inc'),
#  ('ag energy partners ii l p', 'brookfield renewable energy partners l p'),
#  ('advisors disciplined trust series 61',
#   'advisors disciplined trust series 71'),
#  ('alliancebernstein municipal income fund inc',
#   'alliancebernstein national municipal income fund'),
#  ('avista capital opportunities fund ii offshore lp',
#   'avista capital partners offshore ii lp'),
#  ('accriva diagnostics inc', 'ariosa diagnostics inc'),
#  ('blue chip v limited partnership', 'capital partnership lp'),
#  ('aim international funds inc md', 'altair international inc'),
#  ('blackstone partners offshore fund ltd class e f i j & k shares',
#   'blackstone sixth avenue offshore fund ltd class a b c & k shares'),
#  ('bright horizons family solutions inc', 'bright horizons solutions corp'),
#  ('american express financial advisors inc', 'american express trust co'),
#  ('ab government exchange reserves', 'alliance government reserves'),
#  ('a & m securities llc bd', 'brill securities inc bd'),
#  ('all vest securities inc', 'avian securities inc'),
#  ('advisors disciplined trust 845', 'advisors discliplined trust series 20'),
#  ('advisors disciplined trust series 20',
#   'advisors disciplined trust series 50'),
#  ('arbor partners l p', 'bondurant partners l p'),
#  ('alliance global growth trends fund inc',
#   'alliance mid cap growth fund inc'),
#  ('bz group holding ag', 'bz group holding ltd'),
#  ('agrilab technologies inc', 'akiban technologies inc'),
#  ('advisors disciplined trust 1081', 'advisors disciplined trust 72'),
#  ('advisors disciplined trust 845', 'advisors disciplined trust series 60'),
#  ('alphametrix llc', 'alphametrix llc ta'),
#  ('access investments inc bd', 'atlantis investment co inc bd'),
#  ('alliancebernstein dynamic growth fund inc',
#   'alliancebernstein global thematic growth fund inc'),
#  ('ariel capital management inc', 'bencmark capital management co llc'),
#  ('blackrock florida insured municipal income trust',
#   'blackrock insured municipal income trust'),
#  ('activa asset management llc bd', 'ar asset management inc'),
#  ('artis capital management llc', 'boyle capital management llc'),
#  ('amanasu technologies corp', 'american access technologies inc'),
#  ('black diamond oc offshore fund ltd',
#   'blackrock asia pacific partners offshore ltd'),
#  ('ai securities inc bd', 'ark securities co inc bd'),
#  ('blackrock insured municipal income trust',
#   'blackrock taxable municipal bond trust'),
#  ('a ch securities inc bd', 'c p baker securities inc bd'),
#  ('access securities llc', 'ama securities inc'),
#  ('a p securities inc bd', 'aton securities inc'),
#  ('access investments inc bd', 'arrow investments inc'),
#  ('arka securities inc bd', 'bates securities inc'),
#  ('advisors disciplined trust 1066', 'advisors discplined trust 136'),
#  ('astralis pharmaceuticals ltd', 'cancer prevention pharmaceuticals llc'),
#  ('american income fund i c ltd partnership',
#   'camden partners ltd partnership'),
#  ('abacus international capital corp bd', 'arc international corp'),
#  ('becker christopher', 'berthoux christopher'),
#  ('altegris multi strategy fund lp', 'blackrock multi strategy fund ltd'),
#  ('advisor disciplined trust 902', 'advisors disciplined trust series 19'),
#  ('asset management fund', 'brandywine asset management inc'),
#  ('berry joseph c', 'burger joseph c'),
#  ('alliancebernstein income fund inc',
#   'alliancebernstein institutional funds inc'),
#  ('altegris holdings ii llc', 'c t holdings inc'),
#  ('alliance capital management holding lp', 'altimeter capital management lp'),
#  ('akros securities inc', 'bioscience securities inc'),
#  ('alcan securities corp bd', 'bullaro securities corp'),
#  ('activein inc', 'activein ltd'),
#  ('alaris medical inc', 'auris medical ag'),
#  ('alphametrix managed futures ii llc',
#   'alphametrix managed futures iii llc alphametrix wc diversified series'),
#  ('brahman securities inc bd', 'brauvin securities inc bd'),
#  ('aha financial solutions inc', 'almax financial solutions llc'),
#  ('advisors disciplined trust 645', 'advisors disciplined trust 76'),
#  ('all vest securities inc bd', 'ama securities inc'),
#  ('abner herrman & brock inc', 'abner herrman & brock llc'),
#  ('biomet manufacturing llc', 'bishop manufacturing of new england inc'),
#  ('american eastern securities inc bd', 'american securities china lp'),
#  ('a p securities inc bd', 'cadre securities inc bd'),
#  ('axys pharmaceuticals inc', 'cantata pharmaceuticals inc'),
#  ('babcock & brown financial co llc', 'babcock & brown financial co llc bd'),
#  ('apollo credit short opportunities fund l p',
#   'ascribe opportunities fund iii l p'),
#  ('avalon securities ltd', 'avalon securities ltd bd'),
#  ('americredit financial services inc americredit automobile receivables trust 2005 1',
#   'americredit financial services inc automobile rec tr 2002 d'),
#  ('advisors disciplined trust 46', 'advisors disciplined trust 48'),
#  ('american bancorporation oh', 'american bancorporation wv'),
#  ('advisors disciplined trust series 20',
#   'advisors disciplined trust series 52'),
#  ('asb securities inc', 'bates securities inc'),
#  ('blackstone credit opportunities fund lp',
#   'blackstone pacific opportunities fund lp'),
#  ('anooraq resources corp', 'avion resources corp'),
#  ('acorn partners l p', 'barrington partners l p'),
#  ('alliancebernstein cap fund inc',
#   'alliancebernstein national municipal income fund'),
#  ('arrowmark global opportunity fund ii ltd',
#   'arrowpoint income opportunity fund ltd'),
#  ('advisors disciplined trust series 19',
#   'advisors disciplined trust series 48'),
#  ('arrowmark fundamental opportunity fund ltd',
#   'arrowmark income opportunity fund ltd'),
#  ('alliancebernstein global government income trust inc',
#   'alliancebernstein real estate investment fund inc'),
#  ('arrowpoint fundamental opportunity fund l p',
#   'bogle opportunity fund i l p'),
#  ('ancora catalyst institutional lp', 'capital analysts inc'),
#  ('adamski william v', 'adamski william w'),
#  ('american financial group inc', 'bossio financial group inc'),
#  ('benedente holdings llc', 'c t holdings inc'),
#  ('bosco holdings inc', 'cali holdings inc'),
#  ('advisors disciplined trust series 59',
#   'advisors disciplined trust series 67'),
#  ('amg pantheon fund llc', 'amg pantheon private equity master fund llc'),
#  ('advisors disciplined trust 51', 'advisors disciplined trust series 58'),
#  ('artist capital llc', 'c m capital advisors llc'),
#  ('adria partners l p', 'american securities partners l p'),
#  ('a g separate account a', 'american fidelity separate account a'),
#  ('aegis asset backed securities llc', 'aegis mortgage backed securities llc'),
#  ('advisors disciplined trust series 54',
#   'advisors disciplined trust series 68'),
#  ('calibert explorations inc', 'calibert explorations ltd'),
#  ('activa asset management llc bd', 'allianz asset management ag'),
#  ('allos i limited partnership', 'boston celtics limited partnership de'),
#  ('aeroflex inc', 'aeroflex systems group inc'),
#  ('american fidelity financial services inc', 'bolton financial services llc'),
#  ('blackrock muniholdings insured fund inc',
#   'blackrock muniyield california insured fund inc'),
#  ('arc international corporation', 'artal international s c a'),
#  ('aspac communications inc', 'atc communications group inc'),
#  ('active link communications inc', 'airband communications inc'),
#  ('angstrom technologies corp', 'atc technology corp'),
#  ('ama international equity fund lp', 'aquila international fund ltd'),
#  ('a ch securities inc', 'ai securities inc'),
#  ('advisors disciplined trust series 57',
#   'advisors disciplined trust series 74'),
#  ('berger biam worldwide portfolios trust', 'berger worldwide funds trust'),
#  ('aetos market neutral strategies fund llc',
#   'blue rock market neutral fund llc'),
#  ('alliance municipal income fund ii',
#   'alliancebernstein national municipal income fund'),
#  ('advisors disciplined trust 437', 'advisors disciplined trust 57'),
#  ('basswood partners llc', 'berchwood partners llc bd'),
#  ('bdc securities inc', 'brill securities inc bd'),
#  ('bates securities inc bd', 'berlind securities inc bd'),
#  ('basso capital management lp', 'bimini capital management inc'),
#  ('alternet securities inc', 'berlind securities inc'),
#  ('american realty capital trust v inc', 'american realty trust inc et al'),
#  ('ascend offshore fund ltd', 'augustus offshore fund ltd'),
#  ('blackstone fifth ave offshore fund ltd',
#   'blackstone york avenue offshore fund ltd'),
#  ('brahman c p f partners l p', 'brahman partners iii lp'),
#  ('alliant holdings i llc', 'ares management holdings llc'),
#  ('anchor capital advisors inc', 'arlen capital advisors llc'),
#  ('adar investment management llc', 'aston asset management llc'),
#  ('abax brokerage services inc', 'broadway brokerage services inc bd'),
#  ('basswood financial partners lp', 'basswood opportunity partners lp'),
#  ('alcan securities corp bd', 'barwell securities corp bd'),
#  ('alliancebernstein income fund inc',
#   'alliancebernstein utility income fund inc'),
#  ('allos i limited partnership', 'boston celtics limited partnership ii de'),
#  ('archon securities llc bd', 'cape securities inc bd'),
#  ('alliance financial group inc bd', 'california fina group inc bd'),
#  ('a p securities inc', 'arka securities inc'),
#  ('andover energy holdings inc', 'apex clean energy holdings llc'),
#  ('allos therapeutics', 'allos therapeutics inc'),
#  ('ariel capital management inc et al', 'artis capital management llc'),
#  ('callahan financial services inc', 'calypso financial services inc'),
#  ('area real estate opportunity fund vi lp',
#   'avista capital opportunities fund ii onshore l p'),
#  ('backaus marjorie', 'backaus marjorte'),
#  ('advisors disciplined trust series 47',
#   'advisors discliplined trust series 19'),
#  ('a l laboratories inc', 'barr laboratories inc'),
#  ('advisors disciplined trust 64', 'advisors disciplined trust series 54'),
#  ...}

# %%
display(precision(non_zero_pairs, true_pairs))
display(recall(non_zero_pairs, true_pairs))
# Out:
# 0.12789753432747675
# 0.8692925238334169

# %%
true_pairs - non_zero_pairs
# Out:
# {('012 smile communications ltd', 'b communications ltd'),
#  ('1 800 attorney inc', 'attorneys com inc'),
#  ('20th century industries', '21st century insurance group'),
#  ('2tor inc', '2u inc'),
#  ('4front software international inc co', '4front technologies inc'),
#  ('6922767 holding s a r l', '6922767 holding s r l'),
#  ('79 capital securities llc', 'capital innovations securities llc'),
#  ('@road inc', 'at road inc'),
#  ('a l laboratories inc', 'a l pharma inc'),
#  ('a123 systems inc', 'b456 systems inc'),
#  ('ab bond fund inc', 'alliancebernstein bond fund inc'),
#  ('ab cap fund inc', 'alliancebernstein cap fund inc'),
#  ('ab discovery growth fund inc', 'alliance mid cap growth fund inc'),
#  ('ab discovery growth fund inc', 'alliancebernstein mid cap growth fund inc'),
#  ('ab equity income fund inc', 'alliance utility income fund inc'),
#  ('ab equity income fund inc', 'alliancebernstein utility income fund inc'),
#  ('ab funds trust de', 'annuity board funds trust'),
#  ('ab large cap growth fund inc', 'alliance premier growth fund inc'),
#  ('ab large cap growth fund inc', 'alliancebernstein premier growth fund inc'),
#  ('ab mortgage securities corp', 'alliance securities corp'),
#  ('ab sustainable global thematic fund inc',
#   'alliancebernstein global thematic growth fund inc'),
#  ('abacus impact fund 2013 l p', 'align impact fund l p'),
#  ('abada rami', 'abada yoram'),
#  ('abattis bioceuticals corp', 'abattis biologix corp'),
#  ('abc bancorp', 'ameris bancorp'),
#  ('abengoa bioenergy new technologies inc', 'abengoa bioenergy r&d inc'),
#  ('abengoa yield ltd', 'atlantica yield plc'),
#  ('abeona therapeutics inc', 'access pharmaceuticals inc'),
#  ('aberdeen emerging markets smaller co opportunities fund inc',
#   'aberdeen emerging markets telecommunications & infrastructure fund inc'),
#  ('aberdeen global credit strategies fund inc',
#   'aberdeen global diversified fixed income fund inc'),
#  ('aberdeen global credit strategies fund inc',
#   'aberdeen global high yield fund inc'),
#  ('aberdeen global diversified fixed income fund inc',
#   'aberdeen global high yield fund inc'),
#  ('aberdeen global high yield fund inc',
#   'aberdeen global short duration income fund inc'),
#  ('aberdeen investment funds', 'artio global investment funds'),
#  ('aberdeen investment funds', 'bjb investment funds'),
#  ('abilene behavioral health llc', 'acadia abilene llc'),
#  ('abn amro asset management holdings inc', 'alleghany asset management inc'),
#  ('abn amro funds', 'amg funds iv'),
#  ('abn amro funds', 'aston funds'),
#  ('abound solar inc', 'ava solar inc'),
#  ('abp investments us inc', 'apg asset management us inc'),
#  ('absolute potential inc', 'absolute waste services inc'),
#  ('absolute potnetial inc', 'absolute waste services inc'),
#  ('abt holdings inc', 'abt mining co inc'),
#  ('abundant power securities llc', 'bourne partners securities llc'),
#  ('abviva inc', 'biolabs inc'),
#  ('acap global fund', 'acap strategic fund'),
#  ('accel brands inc', 'accelpath inc'),
#  ('access 360 media inc', 'access sports media inc'),
#  ('accessfel inc', 'accesstel inc ut'),
#  ('ackerley communications inc', 'ackerley group inc'),
#  ('acm income fund inc', 'alliancebernstein income fund inc'),
#  ('acorn energy inc', 'acorn factor inc'),
#  ('actavis funding scs', 'allergan funding scs'),
#  ('action minerals inc', 'aroway minerals inc'),
#  ('activa mutual fund trust', 'amway mutual fund inc'),
#  ('activcard corp', 'actividentity corp'),
#  ('activision blizzard inc', 'activision inc ny'),
#  ('actrade financial technologies ltd', 'actrade international ltd'),
#  ('acuitas long short fund lp', 'acuitas microcap fund lp'),
#  ('adams harkness inc', 'canaccord adams inc'),
#  ('adams laboratories inc', 'adams respiratory therapeutics inc'),
#  ('adance cps lp', 'advancepcs lp'),
#  ('adaptec inc', 'adpt corp'),
#  ('adaptive biotechnologies corp', 'adaptive tcr corp'),
#  ('adaptive insights inc', 'adaptive planning inc'),
#  ('adastra minerals inc', 'america mineral fields inc'),
#  ('adb systems international inc', 'bid com international inc'),
#  ('addicott virginia c', 'albanese virginia c'),
#  ('adient ltd', 'adient plc'),
#  ('ads in motion inc', 'ads on line inc'),
#  ('advanced investment partners llc', 'advanced investment technology inc fl'),
#  ('advanced magnetics inc', 'amag pharmaceuticals inc'),
#  ('advanced medical inc', 'alaris medical systems inc'),
#  ('advanced nutraceuticals inc tx', 'bactolac pharmaceutical inc'),
#  ('advanstar holdings inc', 'advanstar inc'),
#  ('advantage advisers global growth l l c',
#   'advantage advisers technology partners l l c'),
#  ('advantage advisers global growth l l c',
#   'advantage advisers technology partners llc'),
#  ('advantage advisers global growth ltd',
#   'advantage advisers technology international ltd'),
#  ('advantage advisers technology fund llc',
#   'advantage advisers xanthus ii llc'),
#  ('advent claymore enhanced growth & income fund',
#   'advent claymore global convertible opport income fd'),
#  ('advent claymore enhanced growth & income fund',
#   'advent claymore global total return fund'),
#  ('advent claymore global convertible opport income fd',
#   'advent claymore global total return fund'),
#  ('adventus funds trust', 'arrivato funds trust'),
#  ('ae biofuels inc', 'aemetis inc'),
#  ('aep energy services inc', 'aep pro serv inc'),
#  ('aep energy services inc', 'aep resources engineering & services co'),
#  ('aeris capital management co s a lu', 'calibrium management co s a'),
#  ('aeroflex high speed test solutions inc', 'aeroflex systems group inc'),
#  ('aeroflex inc', 'arx inc'),
#  ('aeterna laboratories inc', 'aeterna zentaris inc'),
#  ('aetna life & casualty co', 'aetna services inc ct'),
#  ('afc building technologies inc', 'auto tool technologies inc'),
#  ('afem medical corp', 'athena medical corp'),
#  ('affiliated resources corp', 'basic natural resources inc'),
#  ('ag growth capital partners i annex fund l p',
#   'ag private equity iv annex fund l p'),
#  ('agenus inc', 'antigenics inc de'),
#  ('agi inc', 'agl inc'),
#  ('agile group holdings limited adr', 'agile property holdings ltd'),
#  ('agrieuro corp', 'artex corp'),
#  ('ai golf llc', 'aquimo llc'),
#  ('aig life insurance co', 'american general life insurance co of delaware'),
#  ('aim tax exempt funds inc new', 'aim tax free funds inc'),
#  ('aim tax exempt funds invesco tax exempt funds', 'aim tax free funds inc'),
#  ('airgate pcs inc de', 'airgate wireless inc'),
#  ('aj greentech holdings', 'american jianye greentech holdings ltd'),
#  ('akeena solar inc', 'andalay solar inc'),
#  ('alamos gold inc', 'alamos minerals ltd'),
#  ('alanar inc bd', 'alanar incorporated'),
#  ('alberta star development corp', 'alberta star mining corp'),
#  ('alcatel alsthom', 'alcatel lucent'),
#  ('alcatel alsthom france', 'alcatel lucent'),
#  ('alcoa inc', 'arconic inc'),
#  ('alcresta inc', 'alcresta therapeutics inc'),
#  ('alere health improvement co', 'alere health systems inc'),
#  ('alexander series trust', 'bny series trust'),
#  ('alger institutional fund', 'alger retirement fund'),
#  ('alger institutional funds', 'alger retirement fund'),
#  ('alivecor inc', 'aliveusa inc'),
#  ('all cap energy hedge fund llc', 'blackrock global energy dynamic fund llc'),
#  ('all cap energy hedge fund ltd', 'blackrock global energy dynamic fund ltd'),
#  ('all state properties holdings inc', 'all state properties lp'),
#  ('alleghany funds', 'aston funds'),
#  ('allegheny energy inc', 'allegheny power system inc'),
#  ('allegheny technologies inc', 'allegheny teledyne inc'),
#  ('allen & co inc bd', 'allen & company llc'),
#  ('allen test & snow removal co inc', 'allen test co'),
#  ('allen test & snow removal co inc', 'allen test co & rel 8 5 inc'),
#  ('allen test & snow removal co inc', 'allen test co & rel 8 6 dr inc'),
#  ('allen test & snow removal co inc', 'allen test co & rel 8 6 inc'),
#  ('allen test & snow removal co inc', 'allen test co & release 8 2 inc'),
#  ('allen test & snow removal co inc', 'allen test co & release 8 3 inc'),
#  ('allen test & snow removal co inc', 'allen test co inc'),
#  ('allen test & snow removal co inc', 'allen test co inc & cut over test'),
#  ('allen test & snow removal co inc',
#   'allen test co inc & cut over test 8 18 01'),
#  ('allen test & snow removal co inc',
#   'allen test co inc & cut over test 8 4 01'),
#  ('allen test & snow removal co inc',
#   'allen test co inc & cut over test 9 23 01'),
#  ('allen test & snow removal co inc',
#   'allen test co inc & point release test 10 08 01'),
#  ('allen test & snow removal co inc', 'allen test co inc 1'),
#  ('allen test & snow removal co inc',
#   'allen test co inc cut over test 9 23 01'),
#  ('allen test & snow removal co inc', 'allen test co inc test time prod'),
#  ('allen test 440', 'allen test co rel test 550'),
#  ('allen test 440', 'allen test corp'),
#  ('allen test co', 'allen test co & rel 8 5 inc'),
#  ('allen test co', 'allen test co & rel 8 6 dr inc'),
#  ('allen test co', 'allen test co & rel 8 6 inc'),
#  ('allen test co', 'allen test co & release 8 2 inc'),
#  ('allen test co', 'allen test co & release 8 3 inc'),
#  ('allen test co & rel 8 5 inc', 'allen test co inc'),
#  ('allen test co & rel 8 5 inc', 'allen test co inc & cut over test'),
#  ('allen test co & rel 8 5 inc', 'allen test co inc & cut over test 8 18 01'),
#  ('allen test co & rel 8 5 inc', 'allen test co inc & cut over test 8 4 01'),
#  ('allen test co & rel 8 5 inc', 'allen test co inc & cut over test 9 23 01'),
#  ('allen test co & rel 8 5 inc',
#   'allen test co inc & point release test 10 08 01'),
#  ('allen test co & rel 8 5 inc', 'allen test co inc 1'),
#  ('allen test co & rel 8 5 inc', 'allen test co inc cut over test 9 23 01'),
#  ('allen test co & rel 8 5 inc', 'allen test co inc test time prod'),
#  ('allen test co & rel 8 5 inc', 'allen test ltd'),
#  ('allen test co & rel 8 6 dr inc', 'allen test co inc'),
#  ('allen test co & rel 8 6 dr inc', 'allen test co inc & cut over test'),
#  ('allen test co & rel 8 6 dr inc',
#   'allen test co inc & cut over test 8 18 01'),
#  ('allen test co & rel 8 6 dr inc',
#   'allen test co inc & cut over test 8 4 01'),
#  ('allen test co & rel 8 6 dr inc',
#   'allen test co inc & cut over test 9 23 01'),
#  ('allen test co & rel 8 6 dr inc',
#   'allen test co inc & point release test 10 08 01'),
#  ('allen test co & rel 8 6 dr inc', 'allen test co inc 1'),
#  ('allen test co & rel 8 6 dr inc', 'allen test co inc cut over test 9 23 01'),
#  ('allen test co & rel 8 6 dr inc', 'allen test co inc test time prod'),
#  ('allen test co & rel 8 6 inc', 'allen test co inc'),
#  ('allen test co & rel 8 6 inc', 'allen test co inc & cut over test'),
#  ('allen test co & rel 8 6 inc', 'allen test co inc & cut over test 8 18 01'),
#  ('allen test co & rel 8 6 inc', 'allen test co inc & cut over test 8 4 01'),
#  ('allen test co & rel 8 6 inc', 'allen test co inc & cut over test 9 23 01'),
#  ('allen test co & rel 8 6 inc',
#   'allen test co inc & point release test 10 08 01'),
#  ('allen test co & rel 8 6 inc', 'allen test co inc 1'),
#  ('allen test co & rel 8 6 inc', 'allen test co inc cut over test 9 23 01'),
#  ('allen test co & rel 8 6 inc', 'allen test co inc test time prod'),
#  ('allen test co & rel 8 6 inc', 'allen test ltd'),
#  ('allen test co & rel test 80 for version d',
#   'allen test co name change test'),
#  ('allen test co & rel test 80 for version d', 'allen test co rel test 550'),
#  ('allen test co & rel test 80 for version d', 'allen test co rel test 5660'),
#  ('allen test co & release 8 2 inc', 'allen test co inc'),
#  ('allen test co & release 8 2 inc', 'allen test co inc & cut over test'),
#  ('allen test co & release 8 2 inc',
#   'allen test co inc & cut over test 8 18 01'),
#  ('allen test co & release 8 2 inc',
#   'allen test co inc & cut over test 8 4 01'),
#  ('allen test co & release 8 2 inc',
#   'allen test co inc & cut over test 9 23 01'),
#  ('allen test co & release 8 2 inc',
#   'allen test co inc & point release test 10 08 01'),
#  ('allen test co & release 8 2 inc', 'allen test co inc 1'),
#  ('allen test co & release 8 2 inc',
#   'allen test co inc cut over test 9 23 01'),
#  ('allen test co & release 8 2 inc', 'allen test co inc test time prod'),
#  ('allen test co & release 8 3 inc', 'allen test co inc'),
#  ('allen test co & release 8 3 inc', 'allen test co inc & cut over test'),
#  ('allen test co & release 8 3 inc',
#   'allen test co inc & cut over test 8 18 01'),
#  ('allen test co & release 8 3 inc',
#   'allen test co inc & cut over test 8 4 01'),
#  ('allen test co & release 8 3 inc',
#   'allen test co inc & cut over test 9 23 01'),
#  ('allen test co & release 8 3 inc',
#   'allen test co inc & point release test 10 08 01'),
#  ('allen test co & release 8 3 inc', 'allen test co inc 1'),
#  ('allen test co & release 8 3 inc',
#   'allen test co inc cut over test 9 23 01'),
#  ('allen test co & release 8 3 inc', 'allen test co inc test time prod'),
#  ('allen test co inc', 'allen test co inc & cut over test 8 18 01'),
#  ('allen test co inc', 'allen test co inc & cut over test 8 4 01'),
#  ('allen test co inc', 'allen test co inc & cut over test 9 23 01'),
#  ('allen test co inc', 'allen test co inc cut over test 9 23 01'),
#  ('allen test co inc', 'allen test inc & post 8 0 cutover co'),
#  ('allen test co inc', 'allen test inc new name 1'),
#  ('allen test co inc', 'allen test inc new name 2'),
#  ('allen test co inc', 'allen test inc new name 3'),
#  ('allen test co inc & cut over test',
#   'allen test co inc & point release test 10 08 01'),
#  ('allen test co inc & cut over test 8 18 01', 'allen test co inc 1'),
#  ('allen test co inc & cut over test 8 18 01',
#   'allen test co inc test time prod'),
#  ('allen test co inc & cut over test 8 4 01', 'allen test co inc 1'),
#  ('allen test co inc & cut over test 8 4 01',
#   'allen test co inc test time prod'),
#  ('allen test co inc & cut over test 9 23 01',
#   'allen test co inc & point release test 10 08 01'),
#  ('allen test co inc & cut over test 9 23 01', 'allen test co inc 1'),
#  ('allen test co inc & cut over test 9 23 01',
#   'allen test co inc test time prod'),
#  ('allen test co inc & point release test 10 08 01',
#   'allen test co inc cut over test 9 23 01'),
#  ('allen test co inc & point release test 10 08 01',
#   'allen test co inc test time prod'),
#  ('allen test co inc 1', 'allen test co inc cut over test 9 23 01'),
#  ('allen test co inc 1', 'allen test ltd'),
#  ('allen test co inc cut over test 9 23 01',
#   'allen test co inc test time prod'),
#  ('allen test co name change test', 'allen test co rel test 550'),
#  ('allen test co name change test', 'allen test co rel test 5660'),
#  ('allen test co rel test 550', 'allen test corp'),
#  ('allen test co rel test 5660', 'allen test corp'),
#  ('allen test inc & post 8 0 cutover co',
#   'allen test inc name changed for 860 cutover'),
#  ('allen test inc and new name 2 limited',
#   'allen test inc name changed for 860 cutover'),
#  ('allen test inc new name 1', 'allen testing co ind'),
#  ('allen test inc new name 1', 'allen testing co ism'),
#  ('allen test inc new name 2', 'allen testing co ind'),
#  ('allen test inc new name 2', 'allen testing co ism'),
#  ('allen test inc new name 3', 'allen testing co ind'),
#  ('allen test inc new name 3', 'allen testing co ism'),
#  ('allen test new name inc md', 'allen test redfearn'),
#  ('alliance capital management holding lp', 'alliancebernstein holding l p'),
#  ('alliance disciplined value fund inc',
#   'alliancebernstein core opportunities fund inc'),
#  ('alliance emerging market debt fund inc',
#   'alliancebernstein high income fund inc'),
#  ('alliance institutional fund a delaware business trust',
#   'alliancebernstein institutional fund'),
#  ('alliance mid cap growth fund inc',
#   'alliancebernstein discovery growth fund inc'),
#  ('alliance premier growth institutional fund',
#   'alliancebernstein large cap growth fund inc'),
#  ('alliance quasar fund inc', 'alliancebernstein cap fund inc'),
#  ('alliance quasar fund inc', 'alliancebernstein small cap growth fund inc'),
#  ('alliancebernstein balanced shares inc',
#   'alliancebernstein global risk allocation fund inc'),
#  ('alliancebernstein core opportunities fund inc',
#   'alliancebernstein disciplined value fund inc'),
#  ('alliancebernstein core opportunities fund inc',
#   'alliancebernstein focused growth & income fund inc'),
#  ('alliancebernstein disciplined value fund inc',
#   'alliancebernstein focused growth & income fund inc'),
#  ('alliancebernstein emerging market debt fund inc',
#   'alliancebernstein high income fund inc'),
#  ('alliancebernstein global strategic income trust inc',
#   'alliancebernstein unconstrained bond fund inc'),
#  ('alliancebernstein global thematic growth fund inc',
#   'alliancebernstein technology fund inc'),
#  ('alliancebernstein international growth fund inc',
#   'alliancebernstein worldwide privatization fund inc'),
#  ('alliancebernstein quasar fund inc',
#   'alliancebernstein small cap growth fund inc'),
#  ('allianz dresdner asset management of america l p',
#   'allianz global investors of america l p'),
#  ('allscripts healthcare solutions inc', 'allscripts holding inc'),
#  ('alpha equity real estate securities market neutral fund lp',
#   'alpha praedium market neutral fund lp'),
#  ('alphashares black dragon fund l p', 'baochuan black dragon fund l p'),
#  ('alphaterra fund l p', 'baranof fund l p'),
#  ('alpine enhanced lp', 'alpine heritage l p'),
#  ('altair international gold inc', 'altair nanotechnologies inc'),
#  ('altair international inc', 'altair nanotechnologies inc'),
#  ('altair international inc fi', 'altair nanotechnologies inc fi'),
#  ('altegris renaissance ie fund lp', 'altegris visium fund l p'),
#  ('altmfx trust', 'altx trust'),
#  ('altura interventional inc', 'altura medical inc'),
#  ('ambac securities inc', 'cadre securities inc bd'),
#  ('ambra biohealth llc', 'ambra bioscience llc'),
#  ('america first multifamily investors l p',
#   'america first tax exempt investors lp'),
#  ('america northcoast securities inc', 'ancora securities inc'),
#  ('america northcoast securities inc', 'ancora securities inc bd'),
#  ('american aadvantage funds', 'american beacon funds'),
#  ('american artists entertainment corp', 'american artists film corp mo'),
#  ('american atm corp', 'american wireless web corp'),
#  ('american career centers inc', 'american water star inc'),
#  ('american century manager funds', 'benham manager funds'),
#  ('american claims evaluation inc', 'american learning corp'),
#  ('american consolidated management group inc',
#   'american consolidated mining co'),
#  ('american core realty fund l p', 'american stable value fund llc'),
#  ('american core realty fund llc', 'american stable value fund llc'),
#  ('american energy partners inc de', 'american energy production inc'),
#  ('american express financial advisors', 'ameriprise financial inc'),
#  ('american express financial corp', 'ameriprise financial inc'),
#  ('american express financial corp ta', 'ameriprise financial inc'),
#  ('american fidelity separate account a',
#   'american fidelity variable annuity fund a'),
#  ('american finance trust inc', 'american realty capital trust v inc'),
#  ('american financial group inc oh', 'american premier group inc'),
#  ('american healthcorp inc', 'american healthways inc'),
#  ('american healthcorp inc de', 'american healthways inc'),
#  ('american independence financial services llc',
#   'american independence funds trust'),
#  ('american independence funds trust', 'arrivato funds trust'),
#  ('american international ventures inc de', 'american precious metals inc'),
#  ('american international ventures inc de',
#   'american precious metals inc new'),
#  ('american realty capital ii llc', 'ar capital llc'),
#  ('american renal associates holdings inc', 'c p atlas holdings inc'),
#  ('american river bankshares', 'american river holdings'),
#  ('american tire corp', 'amerityre corp'),
#  ('ameriserv food co', 'ameriserve food distribution inc de'),
#  ('amerisource distribution corp', 'amerisource health corp de'),
#  ('ameritrade holding corp', 'arrow stock holding corp'),
#  ('amg funds iv', 'aston funds'),
#  ('ammonia hold inc', 'cali holdings inc'),
#  ('anaren inc', 'anaren microwave inc'),
#  ('anderson adam d', 'blue adam d'),
#  ('angelciti entertainment inc', 'angelciti multimedia inc'),
#  ('anglo american corp of south africa ltd fi', 'anglo american plc fi'),
#  ('angstrom microsystems corp', 'angstrom technologies corp'),
#  ('anika research inc', 'anika therapeutics inc'),
#  ('anooraq resources corp', 'atlatsa resources corp'),
#  ('anpac securities group', 'asg securities inc'),
#  ('aon asset management fund inc', 'aon money market fund inc'),
#  ('aon benfield securities inc', 'aon securities corporation'),
#  ('apex therapeutics inc', 'apexian pharmaceuticals inc'),
#  ('apg asset management us inc', 'apg investments us inc'),
#  ('api nanotronics corp', 'api technologies corp'),
#  ('apoimmune inc', 'apovax inc'),
#  ('apollo gold corp', 'brigus gold corp'),
#  ('app47 inc', 'appmetrics inc'),
#  ('appalachian basin royalty trust', 'appalachian natural gas trust'),
#  ('apple computer inc fa', 'apple inc'),
#  ('aqr style premia fund l p', 'aqr vme fund l p'),
#  ('aquantive inc', 'avenue a inc'),
#  ('aramark corp', 'aramark services inc'),
#  ('arcbest corp de', 'arkansas best corp de'),
#  ('arch coal inc', 'arch mineral corp'),
#  ('archstone communities trust', 'archstone smith operating trust'),
#  ('arctco inc', 'arctic cat inc'),
#  ('arena online inc', 'attaq online inc'),
#  ('arguss communications inc', 'arguss holdings inc'),
#  ('ari financial services inc', 'cabin securities inc'),
#  ('arianne phosphate inc', 'arianne resources inc'),
#  ('aristar heat llc', 'brightline heat llc'),
#  ('armor electric inc', 'armor enterprises inc'),
#  ('arris pharmaceutical corp de', 'axys pharmaceuticals inc'),
#  ('arris pharmaceutical corp de', 'axys pharmecueticals inc'),
#  ('arris resources inc', 'bassett ventures inc'),
#  ('arsenal medical inc', 'arsenal vascular inc'),
#  ('artigent capital partners lp', 'artigent china strategic lp'),
#  ('artio global investment funds', 'bjb investment funds'),
#  ('artisan pharma inc', 'artisan therapeutics inc'),
#  ('ascend market neutral fund l p', 'ascend sequoia fund lp'),
#  ('ascend market neutral fund ltd', 'ascend sequoia offshore fund ltd'),
#  ('ascend offshore fund ltd', 'ascend partners fund i ltd'),
#  ('ascend offshore leveraged fund ltd', 'ascend partners fund ii ltd'),
#  ('ascend sequoia fund lp', 'ascend u s market neutral fund l p'),
#  ('ascend sequoia offshore fund ltd', 'ascend u s market neutral fund ltd'),
#  ('aspenbio inc', 'bioptix inc'),
#  ('aspeon inc', 'aspi inc'),
#  ('associated bank green bay na ta', 'associated trust co na ta'),
#  ('astra ab adr', 'astrazeneca ab'),
#  ('astro med inc new', 'astronova inc'),
#  ('at&t capital corp de', 'capita corp'),
#  ('atc funds inc', 'avalon funds inc'),
#  ('atlantis group inc de', 'atlantis plastics inc'),
#  ('atrium securities inc', 'atrium trading inc'),
#  ('attara ltd', 'atticus european ltd'),
#  ('attend com inc', 'attendware inc'),
#  ('ault glazer & co llc', 'ault glazer bodnar securities llc'),
#  ('aureal inc', 'aureal semiconductor'),
#  ('autech corp', 'avtech corp'),
#  ('av homes inc', 'avatar holdings inc'),
#  ('avalon energy corp', 'avalon gold corp'),
#  ('avion gold corp', 'avion resources corp'),
#  ('aviragen therapeutics inc', 'biota pharmaceuticals inc'),
#  ('avtech corp', 'avtechtyee inc'),
#  ('axial market inc', 'axial networks inc'),
#  ('axiom pharmaceuticals inc', 'axm pharma inc'),
#  ('axp federal income fund inc mn', 'axp government income series inc'),
#  ('axp income series inc', 'axp selective fund inc mn'),
#  ('b b funds', 'bjurman barry funds'),
#  ('b b funds', 'bjurman funds'),
#  ('b8ta inc', 'beta retail inc'),
#  ('ba residential securities inc', 'banc of america mortgage securities inc'),
#  ('ba sports nutrition llc', 'body armor nutrition llc'),
#  ('babe inc', 'bebe stores inc'),
#  ('babson capital funds trust', 'barings funds trust'),
#  ('babson capital global floating rate & income fund',
#   'babson capital global short duration high yield fund'),
#  ('babson capital securities inc', 'barings securities llc'),
#  ('babson securities corporation', 'barings securities llc'),
#  ('bailard biehl & kaiser international fund group inc',
#   'bailard opportunity fund group inc'),
#  ('bailard biehl & kaiser tehachapi offshore fund ltd',
#   'bailard long short offshore fund ltd'),
#  ('bailard biehl & kaiser tehachapi onshore fund lp',
#   'bailard long short onshore fund lp'),
#  ('bailard fund services inc', 'bb&k fund services inc'),
#  ('bailard fund services inc', 'bb&k fund services inc bd'),
#  ('bain capital public equity management llc',
#   'brookside capital management llc'),
#  ('baker biotech capital iii gp llc',
#   'baker brothers life sciences capital gp llc'),
#  ('ballad gold & silver ltd fi', 'ballad ventures ltd fi'),
#  ('ballantyne of omaha inc', 'ballantyne strong inc'),
#  ('ballentine finn & company inc', 'ballentine partners llc'),
#  ('bally entertainment corp', 'bally manufacturing corp'),
#  ('bam investments corp', 'bnn investments ltd'),
#  ('bamco inc ny', 'banco inc'),
#  ('banc fund iv l p', 'banc funds co llc'),
#  ('banc of america finance services inc',
#   'banc of america futures incorporated'),
#  ('bank of new york delaware', 'bny mellon trust of delaware'),
#  ('bank of new york delaware the', 'bny mellon trust of delaware'),
#  ('bankmont financial co', 'bmo financial corp'),
#  ('bankmont financial inc', 'bmo financial corp'),
#  ('banque paribas', 'bnp paribas'),
#  ('banque paribas', 'bnp paribas ny'),
#  ('banque paribas', 'bnp paribas sa'),
#  ('bar var securities corp bd', 'breezy securities inc'),
#  ('barclays global fund advisors', 'blackrock fund advisors'),
#  ('barclays global investors fund distribution company',
#   'blackrock fund distribution company'),
#  ('barclays private bank & trust ltd', 'barclays trust co jersey ltd'),
#  ('baring asset management llc', 'baring north america llc'),
#  ('barnabus energy inc', 'barnabus enterprises ltd'),
#  ('barr laboratories inc', 'barr pharmaceuticals inc'),
#  ('barr rosenberg funds distributor inc', 'bisys distribution services inc'),
#  ('baxger bros inc', 'baxter bros inc'),
#  ('bay colony securities co inc', 'bc securities inc'),
#  ('baynet ltd', 'bayou international ltd'),
#  ('bcp affiliates fund llc', 'broadview capital partners affiliates fund ll'),
#  ('bdc securities inc', 'bdirect securities inc ok bd'),
#  ('bdc securities llc', 'bdirect securities inc ok bd'),
#  ('beanstalk tax inc', 'canopy tax inc'),
#  ('beese fulmer & pincoe inc', 'beese fulmer investment management inc'),
#  ('belden 1993 inc', 'belden inc'),
#  ('belden cdt inc', 'belden inc'),
#  ('bell global trust', 'bell international trust'),
#  ('beranek cheri podzimek', 'beranek cheryl'),
#  ('beranek cheri podzimek', 'beranek cheryl p'),
#  ('berger growth & income fund inc', 'berger one hundred & one fund inc'),
#  ('berman capital llc', 'berman cohn llc bd'),
#  ('berry iowa llc', 'berry plastics ik llc'),
#  ('berry plastics acquisition corp vii', 'berry plastics opco inc'),
#  ('berry plastics holding corp', 'bpc holding corp'),
#  ('beta capital management l p', 'beta capital securities llc'),
#  ('beta capital management lp', 'beta capital securities llc'),
#  ('bft financial group llc', 'butler freeman tally financial group llc'),
#  ('bg retail llc', 'brown group retail inc'),
#  ('bhp steel ltd', 'bluescope steel ltd'),
#  ('bi02 medical inc', 'bio2 medical inc'),
#  ('big equipment services inc', 'bigequip net inc'),
#  ('binks estates limited partnership', 'binks estates lp'),
#  ('bion pharmaceuticals inc', 'bionpharma inc'),
#  ('bionano genomics inc', 'bionanomatrix inc'),
#  ('biosepra inc', 'biosphere medical inc'),
#  ('bkd corporate finance llc', 'bkd financial l l c'),
#  ('black diamond oc offshore fund ltd',
#   'black diamond structured opportunities ltd'),
#  ('blackrock credit allocation income trust',
#   'blackrock preferred & equity advantage trust'),
#  ('blackrock dividend income trust', 'blackrock s&p quality rankings trust'),
#  ('blackrock enhanced capital & income fund inc',
#   'capital & income strategies fund inc'),
#  ('blackrock fixed income strategic opportunities',
#   'blackrock multi sector income trust'),
#  ('blackrock fixed income trust', 'blackrock funds ii'),
#  ('blackrock floating rate income trust',
#   'blackrock global inflation protected securities trust'),
#  ('blackrock floating rate income trust',
#   'blackrock variable rate & inflation protected securities'),
#  ('blackrock income opportunity trust inc',
#   'blackrock north american government income trust inc'),
#  ('blackrock liquidity funds', 'blackrock provident institutional funds'),
#  ('blue arch coal co', 'blue arch resources inc'),
#  ('blue point capital partners ii executive fund l p',
#   'blue point oeg fund ii l p'),
#  ('blue rock market neutral fund llc', 'blue rock registered fund llc'),
#  ('blue water strategic currency fund i llc',
#   'blue water total return fund i l p'),
#  ('bluerock enhanced multifamily trust inc',
#   'bluerock enhanced residential reit inc'),
#  ('bmo harris investment management inc',
#   'bmo private investment counsel inc'),
#  ('bnp paribas exchange traded trust', 'bnp paribas l s commodities trust'),
#  ('bny brokerage inc', 'bny esi & co inc'),
#  ('bogle investment fund lp', 'bogle opportunity fund ii l p'),
#  ('boise building solutions manufacturing holdings corp',
#   'boise cascade wood products holdings corp'),
#  ('bonanza resources corp', 'brs resources ltd'),
#  ('bonde hank', 'bonde john h'),
#  ('bonny paul a', 'bonny pual v'),
#  ('bosco flooring inc', 'bosco holdings inc'),
#  ('boss gold international corp fi', 'boss power corp fi'),
#  ('boston private wealth llc', 'bp wealth management llc'),
#  ('bounty minerals holdings llc', 'bounty minerals ii llc'),
#  ('bow capital fund i lp', 'bow ventures fund i lp'),
#  ('bpy canada subholdings 2 ulc', 'canholdco 2 ulc'),
#  ('bpy canada subholdings 3 ulc', 'canholdco 3 ulc'),
#  ('bpy canada subholdings 4 ulc', 'canholdco 4 ulc'),
#  ('bradley linda jacobsen', 'bradley mckee linda j'),
#  ('brasada absolute return fund lp', 'brasada value opportunites fund lp'),
#  ('brasada absolute return fund lp', 'brasada value opportunities fund lp'),
#  ('brasada long short equity fund lp', 'brasada strategic growth fund lp'),
#  ('brean capital llc', 'brean murray carret & co llc'),
#  ('bridgeline digital inc', 'bridgeline software inc'),
#  ('brio software inc', 'brio technology inc'),
#  ('britesmile inc', 'bsml inc'),
#  ('broadwview holding llp', 'bv holdings llp'),
#  ('brock financial services llc', 'brock securities llc'),
#  ('bronczek david j', 'bronezck david j'),
#  ('brooklyn craft works llc', 'brooklyn distilling co llc'),
#  ('brown group inc', 'brown shoe co inc'),
#  ('brummett alison', 'burcar alison d'),
#  ('bryne niall j', 'byrne niall j'),
#  ('btm financial services inc', 'btmu securities inc'),
#  ('btmu financial services inc', 'btmu securities inc'),
#  ('bueter & co inc bd', 'bueter and company inc'),
#  ('buffalo high yield fund inc', 'buffalo premium income fund inc'),
#  ('builders fixed income fund inc', 'builders proloan fund inc'),
#  ('bulldog fund inc', 'bullfinch fund inc'),
#  ('burlington holdings inc', 'burlington stores inc'),
#  ('buscar co', 'buscar oil inc'),
#  ('bush odonnell & co inc', 'bush odonnell investment advisors inc'),
#  ('c & c tours inc', 'c&c tours inc'),
#  ('c & l securities corporation', 'c&l securities corp bd'),
#  ('c cor electronics inc', 'c cor inc'),
#  ('c cube microsystems inc de', 'c cube semiconductor inc'),
#  ('cadogan alternative strategies ii llc',
#   'cantor opportunistic alternatives fund llc'),
#  ('calamos advisors trust il', 'calamos insurance trust'),
#  ('calamos global diversified income & opportunities fund',
#   'calamos global dynamic income fund'),
#  ('caldera corp', 'caplan corp'),
#  ('caldera international inc ut', 'caldera systems inc'),
#  ('calient networks inc', 'calient technologies inc'),
#  ('caliper life sciences inc', 'caliper technologies corp'),
#  ('calix inc', 'calix networks inc'),
#  ('callinan mines limited', 'callinan royalties corp'),
#  ('calvert 2000 series inc', 'calvert responsible index series inc'),
#  ('calvert 2000 series inc', 'calvert social index series inc'),
#  ('calvert management series', 'calvert tax free reserves'),
#  ('cambria global tactical fund 2x lp', 'cambria special situations fund lp'),
#  ('campbell institutional multi strategy investment fund ltd',
#   'campbell long short equity investment fund ltd'),
#  ('campbell newman asset management inc',
#   'campbell newman pottinger & associates inc'),
#  ('campussims inc', 'campustvs inc'),
#  ('can capital inc', 'capital access network inc'),
#  ('canaccord adams inc', 'canaccord genuity inc'),
#  ('canamex resources corp', 'canamex silver corp'),
#  ('candente copper corp', 'candente resource corp'),
#  ('canney ricardo rodriguez', 'canney richard r'),
#  ('canterbury consulting group inc', 'canterbury corporate services inc'),
#  ('canterbury corporate services inc',
#   'canterbury information technology inc'),
#  ('capfinancial partners llc', 'capfinancial securities llc'),
#  ('capital group global equity common trust us',
#   'capital guardian global equity fund for tax exempt trusts'),
#  ('capital group international all countries equity common trust us',
#   'capital guardian all country world ex us equity fund for tax exempt trusts'),
#  ('capital one securities inc', 'capital one southcoast inc'),
#  ('capital square investment trust', 'capitol square funds')}

# %%
non_zero_pairs - true_pairs
# Out:
# {('apollo capital group inc', 'blue capital group llc bd'),
#  ('american energy capital partners lp', 'breitburn energy partners l p'),
#  ('advisors disciplined trust 551', 'advisors disciplined trust 63'),
#  ('apollo distressed investment fund lp', 'brar investment fund lp'),
#  ('apollo real estate opportunity fund vi lp',
#   'capital structures opportunity fund lp'),
#  ('alliancebernstein global bond fund inc',
#   'allliancebernstein greater china 97 fund inc'),
#  ('basso capital management lp', 'bencmark capital management co llc'),
#  ('acadian asset management llc', 'boston partners asset management llc'),
#  ('achelios therapeutics inc', 'agilis biotherapeutics inc'),
#  ('atlantic coast airlines holdings inc', 'c t holdings inc'),
#  ('adamas opportunities l p',
#   'american securities opportunities fund iii b l p'),
#  ('abi capital management llc', 'berkeley capital management llc'),
#  ('banc of america mort sec inc mort pass thr certs ser 2003 1',
#   'banc one mortgage sec inc mort pass thr certs ser 2003 9'),
#  ('alliance securities corp', 'asset allocation securities corp bd'),
#  ('avista capital partners ii l p',
#   'beacon capital strategic partners vi l p'),
#  ('accipiter capital management llc', 'capital markets mangement llc'),
#  ('blackrock muniholdings insured fund inc',
#   'blackrock muniyield florida insured fund'),
#  ('adar investment management llc', 'bridgewater investment management llc'),
#  ('aes corporation', 'arc international corporation'),
#  ('altair nanotechnologies inc', 'apeel technologies inc'),
#  ('boston capital securities inc', 'cape securities inc bd'),
#  ('altimeter capital management lp', 'brigade capital management lp'),
#  ('aim investment funds', 'caine investment fund i l p'),
#  ('aim international mutual funds invesco international mutual funds',
#   'benham international funds'),
#  ('aew capital management l p', 'brown capital management inc'),
#  ('apollo management lp', 'basso capital management lp'),
#  ('ascend multi strategy fund ltd', 'blackrock multi strategy fund ltd'),
#  ('a k capital llc bd', 'bay city capital bd llc bd'),
#  ('aviation technologies inc', 'brio technology inc'),
#  ('alliance disiplined growth fund inc',
#   'alliance global growth trends fund inc'),
#  ('acacia partners l p', 'armata partners l p bd'),
#  ('access securities inc bd', 'acci securities inc bd'),
#  ('advisors disciplined trust 74', 'advisors disciplined trust series 71'),
#  ('blackrock florida insured municipal income trust',
#   'blackrock new york insured municipal 2008 term trust inc'),
#  ('altegris eckhardt futures fund l p', 'altegris winton futures fund l p'),
#  ('allied capital corp', 'capita corp'),
#  ('adventrx pharmaceuticals inc', 'app pharmaceuticals inc'),
#  ('ascend fund lp', 'ascend partners lp'),
#  ('american realty trust inc ga', 'biomed realty trust inc'),
#  ('all vest securities inc bd', 'americal securities inc bd'),
#  ('alliancebernstein global government income trust inc',
#   'alliancebernstein global growth trends fund inc'),
#  ('alden global opportunities fund lp',
#   'apollo credit short opportunities fund l p'),
#  ('agic convertible & income fund ii',
#   'allianzgi equity & convertible income fund'),
#  ('avista capital partners ii lp', 'blackstone capital partners vi l p'),
#  ('american capital corp', 'american enterprise corp'),
#  ('blue ridge capital management llc', 'boyle capital management llc'),
#  ('blackstone emerging markets fund l p',
#   'blackstone market opportunities fund l p'),
#  ('api technologies corp', 'auto tool technologies inc'),
#  ('advisoros disciplined trust 716', 'advisors disciplined trust 61'),
#  ('aew capital management l p ma', 'capital management partners inc bd'),
#  ('ariel capital management inc et al',
#   'brookhaven capital management co ltd et al'),
#  ('artisan distributors llc bd', 'bny hamilton distributors llc'),
#  ('blackstone park avenue fund lp',
#   'blackstone york avenue offshore fund ltd'),
#  ('acm institutional reserves inc', 'cai institutional services llc'),
#  ('blackrock equity dividend trust',
#   'blackrock global enhanced equity income trust'),
#  ('actinver securities inc', 'brill securities inc'),
#  ('anchor capital advisors llc', 'atlantic american capital advisors llc bd'),
#  ('acci securities inc', 'ai securities inc'),
#  ('artio select opportunities fund inc',
#   'berens credit opportunities fund ltd'),
#  ('artha emerging markets fund l p', 'bluecrest emerging markets fund ltd'),
#  ('ab growth & income fund inc', 'alliance mid cap growth fund inc'),
#  ('barclays private bank & trust cayman ltd',
#   'barclays private bank & trust ltd'),
#  ('blackrock california municipal income trust iii',
#   'blackrock municipal target term trust'),
#  ('american equity investment corporation',
#   'bear and bull investment corporation'),
#  ('ancora securities inc', 'bradesco securities inc'),
#  ('a l laboratories inc', 'audyssey laboratories inc'),
#  ('american securities group inc', 'cabin securities inc'),
#  ('actimis pharmaceuticals inc', 'canyon pharmaceuticals inc'),
#  ('active link communications inc', 'b communications ltd'),
#  ('alphadyne asset management lp', 'ar asset management inc'),
#  ('ark investments', 'barclay investments inc'),
#  ('bates securities inc bd', 'bc securities inc'),
#  ('anchor capital advisors llc', 'capital asset advisors inc bd'),
#  ('abraham & co inc', 'abraham & london securities inc'),
#  ('advisors disciplined trsut 590', 'advisors disciplined trust 56'),
#  ('bourne lent asset management inc',
#   'bourne stenstrom capital management inc'),
#  ('americal securities inc bd', 'brill securities inc'),
#  ('brown john e', 'calonico john'),
#  ('ari financial services inc', 'beanpot financial services inc'),
#  ('blackstone madison avenue offshore fund ltd class a b c & g shares',
#   'blackstone vanderbilt avenue offshore fund ltd'),
#  ('acci securities inc bd', 'berlind securities inc bd'),
#  ('acacia pledge capital lp', 'aci capital america fund lp'),
#  ('advanced investment partners llc', 'barings clo investment partners lp'),
#  ('aim investment securities funds invesco investment securities funds',
#   'capital securities investment corporation'),
#  ('banner apartments fund iii a operating limited partnership',
#   'boston millennia partners iv limited partnership'),
#  ('buffalo gold ltd', 'buffalo large cap fund inc'),
#  ('american securities bd co lp', 'american securities team inc bd'),
#  ('advisors disciplined trust series 56',
#   'advisors disciplined trust series 60'),
#  ('bloombergsen investment partners', 'brandes investment partners l p'),
#  ('berens capital partners lp', 'capital partnerships'),
#  ('afg investment partners iii lp', 'cap iii co investment lp'),
#  ('alliance municipal income fund ii', 'alliance municipal income fund inc'),
#  ('american securities corp', 'american securities opportunities fund ii lp'),
#  ('axa financial services llc',
#   'canada life of america financial services inc'),
#  ('banc of america capital management llc', 'bowman capital management l l c'),
#  ('artal international sca', 'bid com international inc'),
#  ('apollo partners lp bd', 'ascend partners lp'),
#  ('advisors disciplined trust 50', 'advisors disciplined trust 68'),
#  ('bowman capital management l l c', 'brigade capital management llc'),
#  ('barrow hanley mewhinney & strauss diversified large cap value fund',
#   'barrow hanley mewhinney & strauss inc'),
#  ('alliancebernstein global real estate investment fund inc',
#   'bailard real estate investment trust inc'),
#  ('abi capital management llc', 'american capital asset management llc'),
#  ('andor capital management llc', 'basso capital management l p'),
#  ('advisors disciplined trust 74', 'advisors disciplined trust series 72'),
#  ('blackrock muniyield michigan quality fund ii inc',
#   'blackrock muniyield new york quality fund inc'),
#  ('apac customer services inc', 'bessemer investor services inc bd'),
#  ('ba residential securities inc', 'bates securities inc bd'),
#  ('blackrock managed duration trust', 'blackrock senior income trust'),
#  ('asg securities inc', 'aton securities inc'),
#  ('berens capital partners l p', 'birch run capital partners lp'),
#  ('baring asset management inc ma', 'brandywine asset management inc'),
#  ('ashton capital management inc', 'bencmark capital management co llc'),
#  ('blue ridge capital management llc', 'blue river capital llc'),
#  ('bechtel financing services llc bd', 'birchtree financial services inc'),
#  ('banc of america mortgage securities inc',
#   'bank of america mortgage securities inc 2002 2'),
#  ('accumulus emerging managers fund lp', 'blue rock emerging manager fund lp'),
#  ('acadian asset management inc ma', 'athene asset management l p'),
#  ('american financial group inc', 'anderson group inc'),
#  ('ayre investments inc', 'barclay investments inc bd'),
#  ('aston asset management llc', 'bb&t asset management llc'),
#  ('advisors disciplined trsut 590', 'advisors disciplined trust 140'),
#  ('a p securities inc bd', 'bdc securities inc'),
#  ('advanced investment technology inc fl',
#   'advanced orthopedic technologies inc'),
#  ('burch capital management inc', 'capital management partners inc bd'),
#  ('black strategic fund lp', 'blackrock debt strategies fund'),
#  ('advisors disciplined trust series 47',
#   'advisors disciplined trust series 70'),
#  ('asset management fund', 'bourne lent asset management inc'),
#  ('barrow hanley mewhinney & strauss large cap value fund',
#   'barrow hanley mewhinney & strauss non us value fund'),
#  ('american access technologies inc', 'calient technologies inc'),
#  ('blackstone capital partners vi lp', 'blr capital partners lp'),
#  ('abs offshore spc', 'aqueous offshore fund spc'),
#  ('archon securities llc', 'athene securities llc'),
#  ('baring asset management llc', 'bourne stenstrom lent asset management inc'),
#  ('atap financial services inc bd', 'baystate capital services inc bd'),
#  ('advisors disciplined trust 437', 'advisors disciplined trust 70'),
#  ('ama securities inc', 'americal securities inc'),
#  ('berens credit opportunities fund ltd',
#   'canyon opportunistic credit grf fund cayman ltd'),
#  ('ad systems communications inc', 'arch communications inc'),
#  ('axxia pharmaceuticals inc', 'canyon pharmaceuticals inc'),
#  ('blackrock allocation target shares',
#   'blackrock credit allocation income trust ii'),
#  ('7advisors disciplined trust 1197', 'advisors disciplined trust 70'),
#  ('adamas partners lp', 'camden partners lp'),
#  ('alpine partners lp bd', 'bain capital partners lp'),
#  ('body central corp', 'brady corp'),
#  ('alliancebernstein all asia investment fund inc',
#   'alliancebernstein global small cap fund inc'),
#  ('arbor realty trust inc', 'biomed realty trust inc'),
#  ('allen & co inc bd', 'allen c ewing & co bd'),
#  ('alliancebernstein government reserves',
#   'alliancebernstein institutional reserves inc'),
#  ('advisors disciplined trust series 60',
#   'advisors disciplined trust series 71'),
#  ('american realty capital real estate income fund',
#   'american realty trust inc'),
#  ('allen test co inc test time prod', 'allen testing co ind'),
#  ('bolton asset mamagement llc', 'bourne stenstrom lent asset management inc'),
#  ('adirondack electronic markets llc bd',
#   'adirondack emerging markets fund lp'),
#  ('boston millennia partners iv limited partnership',
#   'burke trading limited partnership'),
#  ('allostem therapeutics llc', 'bellerophon therapeutics inc'),
#  ('averil capital markets group inc', 'capital group inc'),
#  ('aga separate account a', 'american fidelity separate account a'),
#  ('bank of america mortgage securities inc 2001 12',
#   'bank of america mortgage securities inc 2002 b'),
#  ('blue ridge capital management llc', 'bluebridge digital llc'),
#  ('alerus securities bd', 'americal securities inc bd'),
#  ('asci holdings mexico de inc', 'asci holdings uk de inc'),
#  ('advisors disciplined trust 136', 'advisors disciplined trust 57'),
#  ('american heritage securities inc bd', 'camden securities inc bd'),
#  ('balanced financial securities corporation',
#   'bentley securities corporation'),
#  ('atap financial services inc bd', 'bolton financial services llc bd'),
#  ('advisors disciplined trust 1066', 'advisors disciplined trust series 19'),
#  ('acadia management company llc', 'acadian asset management inc ma'),
#  ('american financial group inc', 'bnc financial group inc'),
#  ('access securities inc bd', 'bc securities inc'),
#  ('alternative investments institutional ltd',
#   'american alternative investments corp'),
#  ('ani pharmaceuticals inc', 'avanir pharmaceuticals'),
#  ('arrowmark income opportunity fund ltd',
#   'arrowpoint income opportunity fund lp'),
#  ('alles investments inc', 'belle haven investments l p'),
#  ('artisan partners ltd partnership',
#   'blackstone participation partnership cayman v nq l p'),
#  ('alliancebernstein equity income fund inc',
#   'alliancebernstein technology fund inc'),
#  ('advisors disciplined trust 683', 'advisors disciplined trust series 20'),
#  ('advisors disciplined trust series 54',
#   'advisors disciplined trust series 55'),
#  ('american landmark securities inc bd', 'atlantic securities inc bd'),
#  ('antares european fund l p', 'ares capital europe lp'),
#  ('am capital llc', 'ar capital llc'),
#  ('blackrock emerging markets fund inc',
#   'blackstone emerging markets fund l p'),
#  ('advisors disciplined trust series 48',
#   'advisors disciplined trust series 59'),
#  ('blackrock muniholdings insured fund ii inc',
#   'blackrock muniholdings new york quality fund inc'),
#  ('blackrock florida municipal income trust',
#   'blackrock muniyield florida insured fund'),
#  ('alternet securities inc', 'aton securities inc'),
#  ('altimeter capital management llc', 'ariel capital management inc et al'),
#  ('arcadia securities llc', 'athene securities llc'),
#  ('blackrock build america bond trust', 'blackrock dividend income trust'),
#  ('axa financial services llc', 'callahan financial services inc bd'),
#  ('asci holdings czech de inc', 'asci holdings uk inc de'),
#  ('atlas america public #15 2005 a program',
#   'atlas america public #16 2007 a l p'),
#  ('bg financial group inc', 'bnc financial group inc'),
#  ('aig multi strategy fund of funds llc', 'aris multi strategy fund l p'),
#  ('alliancebernstein global government income trust inc',
#   'alliancebernstein global real estate investment fund inc'),
#  ('acorn partners l p', 'arklow partners l p'),
#  ('achelios therapeutics', 'allomek therapeutics llc'),
#  ('advisors disciplined trust 136', 'advisors disciplined trust 52'),
#  ('american equity investment corporation', 'ameritas investment corp'),
#  ('berens credit opportunities fund l p',
#   'blackrock credit opportunities trust'),
#  ('bates securities inc bd', 'brill securities inc'),
#  ('alliancebernstein national municipal income fund',
#   'alliancebernstein utility income fund inc'),
#  ('blackrock municipal 2020 term trust',
#   'blackrock taxable municipal bond trust'),
#  ('advisors disciplined trust series 46',
#   'advisors disciplined trust series 57'),
#  ('advisors disciplined trus 437', 'advisors disciplined trust 47'),
#  ('belfinance securities inc', 'benefit finance securities llc bd'),
#  ('avista capital opportunities fund ii offshore lp',
#   'bernstein global opportunities offshore ltd'),
#  ('aha financial solutions inc bd', 'broadridge financial solutions inc'),
#  ('altair nanotechnologies inc', 'american access technologies inc'),
#  ('alliancebernstein institutional funds inc',
#   'alliancebernstein institutional reserves inc'),
#  ('atlas america public #16 2007 a l p',
#   'atlas america public #16 2007 program'),
#  ('blackrock multi sector income trust',
#   'blackrock municipal income investment trust'),
#  ('blackrock muniholdings florida insured fund inc',
#   'blackrock muniholdings quality fund ii inc'),
#  ('american eastern securities inc bd', 'american securities corp'),
#  ('ag diversified credit strategies fund lp',
#   'ag diversified income fund plus ltd'),
#  ('advisors disciplined trsut 683', 'advisors disciplined trust 63'),
#  ('boise building solutions distribution l l c',
#   'boise building solutions manufacturing holdings corp'),
#  ('adar investment management lp', 'alex brown investment management l p'),
#  ('brookfield investment funds', 'brookfield properties corp'),
#  ('abi capital management llc bd', 'artis capital management l p'),
#  ('achelios therapeutics', 'algos therapeuitics inc'),
#  ('american fidelity financial services inc', 'ari financial services inc'),
#  ('alphadyne investment strategies fund ltd',
#   'alphadyne investment strategies partners lp'),
#  ('apollo credit short opportunities master fund l p',
#   'boston co long short opportunistic equity fund lp'),
#  ('blackrock global energy & resources trust',
#   'blackrock global energy dynamic fund ltd'),
#  ('allos therapeutics', 'anika therapeutics inc'),
#  ('advisors disciplined trust 46', 'advisors disciplined trust 63'),
#  ('americal securities inc', 'american securities team inc bd'),
#  ('agora securities corp', 'bullaro securities corp'),
#  ('blue capital group llc bd', 'capital planning group llc bd'),
#  ('campbell classic trend fund l p', 'campbell institutional trend fund l p'),
#  ('black diamond mortgage opportunity ii l p',
#   'black diamond structured opportunities ltd'),
#  ('aig international securities inc', 'axp international series inc'),
#  ('armetis investment management llc', 'avi management llc'),
#  ('altimeter capital management llc', 'berkeley capital management llc'),
#  ('ab municipal income fund inc', 'american income fund i b'),
#  ('c m capital advisors llc', 'capri capital advisors llc adv'),
#  ('artigent capital partners lp', 'blackstone capital partners vi lp'),
#  ('blackrock florida investment quality municipal trust',
#   'blackrock municipal series trust'),
#  ('avenue europe investments lp', 'belle haven investments l p'),
#  ('basso capital management l p', 'black diamond capital management l l c'),
#  ('beacon investment co bd', 'boston investment securities corp bd'),
#  ('asante partners llc bd', 'avondale partners llc bd'),
#  ('alliance real estate investment fund inc',
#   'bailard real estate investment trust i inc'),
#  ('advisors disciplined trust 59', 'advisors disciplined trust 66'),
#  ('brahman c p f partners lp', 'brahman institutional partners lp'),
#  ('advisory research global opportunities fund l p',
#   'alden global opportunities fund cayman l p'),
#  ('advisors disciplined trust series 46',
#   'advisors disciplined trust series 51'),
#  ('alliancebernstein global real estate investment fund inc',
#   'alliancebernstein investor services inc ta'),
#  ('alliancebernstein exchange reserves',
#   'alliancebernstein investor services inc ta'),
#  ('arcadia securities llc bd', 'barings securities llc'),
#  ('all vest securities inc', 'ancora securities inc'),
#  ('apollo fund', 'apolo gold inc'),
#  ('aew capital management l p', 'bluecrest capital management llp'),
#  ('asche transportation services inc', 'ascher decision services inc'),
#  ('advisors disciplined trust series 47',
#   'advisors disciplined trust series 58'),
#  ('binks estates limited partnership', 'burke trading limited partnership'),
#  ('blackrock master trust', 'blackrock prime rate trust'),
#  ('aim investment funds', 'aim investment securities funds'),
#  ('arguss communications inc', 'atx communications inc'),
#  ('acn securities inc bd', 'agricapital securities inc bd'),
#  ('alcan securities corp bd', 'aurum securities corp bd'),
#  ('blackrock muniholdings california quality fund inc',
#   'blackrock muniholdings insured fund ii inc'),
#  ('access financial group inc bd', 'american financial group inc et al'),
#  ('access pharmaceuticals inc', 'cancer prevention pharmaceuticals llc'),
#  ('advanced investment partners llc', 'brandes investment partners lp'),
#  ('alanar incorporated', 'capital analysts incorporated'),
#  ('bba icatu securities inc bd', 'brill securities inc bd'),
#  ('agricapital securities inc bd', 'brill securities inc'),
#  ('alles investments inc bd', 'benchmark investments inc'),
#  ('agri general securities corporation',
#   'capital securities investment corporation'),
#  ('advisors disciplined trust series 53',
#   'advisors disciplined trust series 61'),
#  ('alliance all asia investment fund inc', 'aspen investment alliance inc'),
#  ('alliance securities corp', 'brill securities inc'),
#  ('acadian asset management inc ma', 'ar asset managment inc'),
#  ('agricapital securities inc', 'capital market securities inc'),
#  ('axiom pharmaceuticals inc', 'cancer prevention pharmaceuticals inc'),
#  ('acn securities inc bd', 'all vest securities inc bd'),
#  ('api technologies corp', 'aviation technologies inc'),
#  ('actuate software corp', 'ants software com inc'),
#  ('benchmark plus institutional parnters llc',
#   'brahman institutional partners lp'),
#  ('aon corp', 'aon securities corporation'),
#  ('american diversified financial group llc',
#   'american patriot financial group inc'),
#  ('advisors disciplined trus 437', 'advisors disciplined trust 68'),
#  ('asempra technologies inc', 'auto tool technologies inc'),
#  ('candela capital lp', 'capita corp'),
#  ('apb financial group llc', 'bg financial group inc'),
#  ('advisors disciplined trust 206', 'advisors disciplined trust 61'),
#  ('blue capital group llc', 'capital hill group inc bd'),
#  ('adventus funds trust', 'advest trust co'),
#  ('alles investments inc bd', 'altegris investments inc'),
#  ('apollo credit short opportunities fund l p',
#   'blackrock credit opportunities trust'),
#  ('american capital asset management llc', 'ashton capital management inc'),
#  ('advisors disciplined trust series 74',
#   'advisors discliplined trust series 20'),
#  ('alfa capital markets usa inc', 'cabrera capital markets llc'),
#  ('american fidelity financial services inc',
#   'campbell financial services inc'),
#  ('acl semiconductor inc', 'bridge semiconductor corp'),
#  ('bertelli james r', 'bolin james'),
#  ('aes corporation', 'babson securities corporation'),
#  ('american eastern securities inc bd', 'cape securities inc bd'),
#  ('ajo emerging markets levered hedge fund ltd',
#   'brevan howard emerging markets strategies fund ltd'),
#  ('baystate capital services inc bd', 'boston capital services inc'),
#  ('astor capital inc bd', 'can capital inc'),
#  ('advisors disciplined trust 57', 'advisors disciplined trust 69'),
#  ('bank of america mortgage securities inc',
#   'bank of america mortgage securities inc 2001 h'),
#  ('ascribe opportunities fund iii l p',
#   'avista capital opportunities fund ii onshore lp'),
#  ('bank of new york delaware', 'bank of new york ny'),
#  ('advisors disciplined trust 508', 'advisors disciplined trust series 58'),
#  ('accriva diagnostics holdings inc', 'aria diagnostics inc'),
#  ('a p securities inc', 'actinver securities inc'),
#  ('advisors disciplined trust 72', 'advisors disciplined trust series 70'),
#  ('american eastern securities inc', 'american landmark securities inc bd'),
#  ('asset alliance investment services inc bd',
#   'bessemer investor services inc'),
#  ('blackrock muniholdings quality fund ii inc',
#   'blackrock muniyield pennsylvania quality fund'),
#  ('advisors disciplined trust 68', 'advisors disciplined trust 69'),
#  ('alderon resource corp', 'canadente resource corp'),
#  ('a ch securities inc bd', 'camden securities inc bd'),
#  ('blackstone capital partners cayman v nq l p',
#   'blackstone capital partners vi l p'),
#  ('american medical technologies inc de', 'breed technologies inc'),
#  ('advisors disciplined trust 138', 'advisors disciplined trust 206'),
#  ('americal securities inc', 'american classic securities inc'),
#  ('ab large cap growth fund inc', 'alliance growth & income fund inc'),
#  ('basswood capital management l l c', 'cadian capital management lp'),
#  ('a c t holdings inc', 'bli holdings corp'),
#  ('blackrock muniyield michigan insured fund inc',
#   'blackrock muniyield michigan quality fund ii inc'),
#  ('advisors disciplined trust 48', 'advisors disciplined trust 65'),
#  ('account management llc', 'bt investment management ltd'),
#  ('alden global distressed opportunities fund lp',
#   'alden global india fund lp'),
#  ('ameritas variable separate account v', 'athene variable life account a'),
#  ('ama internatinal equity fund lp', 'caldera equity fund lp'),
#  ('advisory research global all cap fund l p',
#   'advisoty research small cap value fund ii lp'),
#  ('advisors disciplined trust 46', 'advisors disciplined trust 73'),
#  ('bailard long short offshore fund ltd',
#   'bbh longshort equity offshore fund ltd'),
#  ('asco healthcare inc', 'bsd healthcare industries inc'),
#  ('adar investment management lp', 'bridgewater investment management llc'),
#  ('advisors disciplined trus 437', 'advisors disciplined trust 71'),
#  ('ares clo x ltd', 'ares xi clo ltd'),
#  ('artemis investment management llc',
#   'brandywine global investment management llc'),
#  ('brinker capital securities inc bd', 'brown burke securities inc bd'),
#  ('alliance real estate investment fund inc',
#   'behringer harvard real estate investment trust i inc'),
#  ('advisors disciplined trust 284', 'advisors disciplined trust 75'),
#  ('aew partners l p', 'artisan partners ltd partnership'),
#  ('altus capital llc', 'apis capital lp'),
#  ('ashe capital management lp', 'basso capital management l p'),
#  ('alliance financial group inc', 'american financial group holdings inc'),
#  ('bar var securities corp bd', 'c p baker securities inc bd'),
#  ('aegis investments inc bd', 'capital investments inc bd'),
#  ('belfinance securities inc bd', 'berlind securities inc'),
#  ('advisors disciplined trust 1197', 'advisors disciplined trust 72'),
#  ('aim investment funds invesco investment funds',
#   'ares leveraged investment fund corp ii'),
#  ('beese fulmer investment management inc', 'bt investment management re ltd'),
#  ('bear stearns focused opportunities fund lp',
#   'berens distressed opportunities fund ltd'),
#  ('advisoros disciplined trust 716', 'advisors disciplined trust 52'),
#  ('all vest securities inc', 'capital one securities inc'),
#  ('brahman c p f partners l p', 'caiman partners l p'),
#  ('axar acquisition corp', 'brimfield acquisition corp'),
#  ('alden global distressed opportunities cayman fund l p',
#   'berens distressed opportunities fund ltd'),
#  ('avi management llc', 'capital markets management llc'),
#  ('brand scaffold builders inc', 'brand scaffold services inc'),
#  ('bid com international inc', 'biopulse international inc'),
#  ('advisors disciplined trust 942', 'advisors disciplined trust series 52'),
#  ('advisors disciplined trust series 66',
#   'advisors disciplined trust series 74'),
#  ('barrington associates bd', 'barrington partners'),
#  ('advisors disciplined trust 49', 'advisors disciplined trust series 46'),
#  ('aria partner ii lp', 'artorius partners ii lp'),
#  ('blackrock investment quality municipal income trust',
#   'blackrock municipal income quality trust'),
#  ('bc securities inc', 'cape securities inc bd'),
#  ('avian securities inc', 'cape securities inc'),
#  ('alliancebernstein americas government income trust inc',
#   'alliancebernstein utility income fund inc'),
#  ('alliance all asia investment fund inc',
#   'asset alliance investment services inc'),
#  ('artis capital management l p', 'bimini capital management inc'),
#  ('advisors disciplined trust series 51', 'advisors disciplined turst 551'),
#  ('aq holdings inc', 'c p atlas holdings inc'),
#  ('bdc securities inc', 'cadre securities inc bd'),
#  ('advisory research global opportunities fund l p',
#   'alden global distressed opportunities fund lp'),
#  ('blackstone capital partners delaware v nq l p',
#   'blackstone participation partnership delaware v nq l p'),
#  ('a4s technologies inc', 'aviation technologies inc'),
#  ('adage capital partners gp llc', 'adirondack capital partners inc'),
#  ('advisors disciplined trust 1038', 'advisors disciplined trust 60'),
#  ('blackrock global emerging markets fund inc',
#   'blackstone emerging markets fund i l p'),
#  ('blackrock municipal 2020 term trust',
#   'blackrock municipal income trust iii'),
#  ('aviation technologies inc', 'calient technologies inc'),
#  ('atap financial services inc bd',
#   'broker dealer financial services corp bd'),
#  ('allied asset management inc', 'ault glazer asset management llc'),
#  ('asset management fund inc', 'berkshire asset management inc pa'),
#  ('activa asset management llc bd', 'alleghany asset management inc'),
#  ('aramark corp', 'aramark corp de'),
#  ('advanced medical inc', 'advanced medical optics inc'),
#  ('arrowmark global opportunity fund ii lp',
#   'arrowmark global opportunity fund ii ltd'),
#  ('bnp paribas ny', 'bnp paribas s a london branch'),
#  ('argyrople christopher', 'becker christopher'),
#  ('a t a p financial services inc', 'andesa services inc ta'),
#  ('benchmark capital management co llc', 'burch capital management inc'),
#  ('ai securities inc', 'avian securities inc'),
#  ('asci holdings mexico de inc', 'asci holdings uk inc de'),
#  ('babson capital global advisors ltd',
#   'babson capital global investment funds plc'),
#  ('bernstein global diversified hedge fund l p',
#   'bernstein global opportunities hedge fund ltd'),
#  ('biota pharmaceuticals inc', 'canyon pharmaceuticals inc'),
#  ('aim investment services inc', 'banc of america investment services inc bd'),
#  ('advisors disciplined trust series 73',
#   'advisors disciplined trust series 74'),
#  ('american energy capital partners lp', 'berens capital partners lp'),
#  ('babson capital securities llc', 'capital real estate securities llc'),
#  ('capital auto finance trust 2002 c',
#   'capital one auto finance trust 2002 b'),
#  ('arrowmark fundamental opportunity fund l p',
#   'arrowmark income opportunity fund lp'),
#  ('american heritage securities inc', 'cabin securities inc'),
#  ('can capital inc', 'capital consultants inc'),
#  ('alpha praedium market neutral fund lp',
#   'ba sometros market neutral fund lp'),
#  ('american income fund i a', 'american income fund i b ltd partnership'),
#  ('artisan therapeutics inc', 'aviragen therapeutics inc'),
#  ('alphadyne asset management llc', 'asset management fund'),
#  ('attkisson carter & company inc', 'attkisson ronald l'),
#  ('bridgecreek investment management llc', 'bt investment management re ltd'),
#  ('cadence resources corp', 'camcap resources lp'),
#  ('abbey national securities inc bd',
#   'banorte securities international ltd bd'),
#  ('bird estate limited partnership', 'burke trading limited partnership'),
#  ('benchmark financial services inc', 'birchtree financial services inc bd'),
#  ('advisors disciplined trust series 47',
#   'advisors discliplined trust series 20'),
#  ('bradesco securities inc bd', 'brinker capital securities inc bd'),
#  ('blackrock muniyield insured investment fund',
#   'blackrock muniyield investment fund'),
#  ('american colonial corporation', 'cannamed corporation'),
#  ('advisors disciplined trus 437', 'advisors disciplined trust 61'),
#  ('alphadyne asset management llc', 'aston asset management llc'),
#  ('ad systems communications inc', 'caldera systems inc'),
#  ('actimis pharmaceuticals inc', 'ani pharmaceuticals inc'),
#  ('bianco james a', 'bolin james'),
#  ('americal securities inc bd', 'austin securities inc bd'),
#  ('advanced equities altra investment ii llc',
#   'advanced equities foveon investments i llc'),
#  ('advisors disciplined trust 56', 'advisors disciplined trust series 66'),
#  ('advisors disciplined trust 902', 'advisors disciplined trust series 60'),
#  ('asset management fund inc', 'bluebay asset management plc'),
#  ('act capital america fund lp', 'akana capital fund lp'),
#  ('blackrock credit allocation income trust i',
#   'blackrock florida municipal income trust'),
#  ('a p securities inc', 'ancora securities inc bd'),
#  ('blackstone capital partners cayman v nq l p',
#   'blackstone participation partnership delaware v nq l p'),
#  ('advisors disciplined trust 551', 'advisors disciplined trust 57'),
#  ('beneficial capital inc bd', 'bergen capital inc bd'),
#  ('babson capital securities inc', 'cape securities inc'),
#  ('american securities opportunities fund iii b l p',
#   'avista capital opportunities fund ii onshore l p'),
#  ('blackrock intermediate municipal fund of blackrock municipal series trust',
#   'blackrock municipal target term trust'),
#  ('capital securities investment corporation',
#   'capital select investments corp'),
#  ('calamos financial services llc', 'campbell financial services inc'),
#  ('biosite diagnostics inc', 'boston heart diagnostics corp'),
#  ('aca securities llc bd', 'burrill securities llc'),
#  ('basswood capital management l l c', 'boyle capital management l l c'),
#  ('beazer homes investments llc', 'beazer homes sales arizona inc'),
#  ('atap financial services inc bd',
#   'automated trading desk financial services llc bd'),
#  ('access securities inc bd', 'bioscience securities inc bd'),
#  ('brown group inc', 'brownstone investment group llc bd'),
#  ('capital market securities inc', 'capital securities investment corp'),
#  ('black diamond oc offshore fund ltd',
#   'blackstone vanderbilt avenue offshore fund ltd'),
#  ('artielle immunotherapeutics inc', 'bolt therapeutics inc'),
#  ('brill securities inc bd', 'brinker capital securities inc bd'),
#  ('alderon resource corp', 'cadence resources corp'),
#  ('arris international ltd', 'beverly enterprises international ltd'),
#  ('ari financial services inc', 'btm financial services inc'),
#  ('capital group emerging markets restricted equity common trust us',
#   'capital group international all countries equity common trust us'),
#  ('abbey national securities inc', 'aig international securities inc bd'),
#  ('advisory research inc', 'advisory research value equity fund lp'),
#  ('ab discovery growth fund inc', 'ab global thematic growth fund inc'),
#  ('bactolac pharmaceutical inc', 'cantata pharmaceuticals inc'),
#  ('a c t holdings inc', 'american caresouce holdings inc'),
#  ('beloyan investment securities inc bd',
#   'boston investment securities corp bd'),
#  ('allos therapeutics', 'bolt biotherapeutics inc'),
#  ('argent capital advisors llc', 'capri capital advisors llc adv'),
#  ('cahn capital corp bd', 'canaccord capital corp usa inc bd'),
#  ('ab multi manager alternative fund', 'ark multi manager fund lp'),
#  ('ara services inc', 'brand services'),
#  ('adage capital partners lp', 'advantage advisers catalyst partners l p'),
#  ('aurora global opportunities asw fund a series of alternative strategies platform llc',
#   'aurora global opportunitites ii asw fund'),
#  ('american core realty fund l p', 'american realty capital ii llc'),
#  ('american securities group inc bd', 'american securities team inc'),
#  ('brio technology inc', 'brooktrout technology inc'),
#  ('american capital asset management llc', 'ashe capital management llc'),
#  ('artis capital management llc', 'capital management partners inc bd'),
#  ('allstate distributors l l c', 'aquila distributors llc'),
#  ('blackrock credit allocation income trust i inc',
#   'blackrock credit allocation income trust ii'),
#  ('california capital services inc bd', 'california treatment services llc'),
#  ('advest bank & trust co', 'arvest bank trust division'),
#  ('alpine partners lp bd', 'ascend partners fund i lp'),
#  ('anchor bay securities llc', 'bates securities inc bd'),
#  ('berens distressed opportunities lp',
#   'black diamond structured opportunities ltd'),
#  ('alpinvest partners n v', 'bain capital partners iv lp'),
#  ('adar investment management llc', 'athene asset management llc'),
#  ('advisors disciplined trust 53', 'advisors disciplined trust 72'),
#  ('ab core opportunities fund inc',
#   'american securities opportunities fund iii l p'),
#  ('blackstone fifth avenue offshore fund ltd class a d f k & l shares',
#   'blackstone partners offshore fund ltd class e f i j k q & r shares'),
#  ('american family securities llc', 'american securities team inc'),
#  ('advisors disciplined trust 136', 'advisors disciplined trust series 56'),
#  ('advisors disciplined trust 71', 'advisors disciplined trust 72'),
#  ('alcan securities corp bd', 'capital securities investment corp'),
#  ('atx communications inc', 'b communications ltd'),
#  ('advisors disciplined trust series 56',
#   'advisors disciplined trust series 66'),
#  ('allied capital corp', 'america capital corp'),
#  ('blackrock insured municipal income investment trust',
#   'blackrock new york municipal income quality trust'),
#  ('abi capital management llc bd', 'blue ridge capital management llc'),
#  ('american securities corp', 'ancora securities inc'),
#  ('arrowpoint fundamental opportunity fund l p',
#   'arrowpoint fundamental opportunity fund ltd'),
#  ('blackrock credit allocation income trust ii',
#   'blackrock insured municipal income trust'),
#  ('acorn partners l p', 'camden partners ltd partnership'),
#  ('actrade financial technologies ltd', 'american electric technologies inc'),
#  ('bear stearns securities corp bd', 'bullaro securities corp bd'),
#  ('big cat energy corp', 'bt energy corp'),
#  ('aim investment funds invesco investment funds',
#   'aim investment securities funds inc'),
#  ('bluecrest emerging markets fund l p', 'bluecrest emerging markets ltd'),
#  ('alles investments inc', 'avenue investments lp'),
#  ('bernstein global diversified hedge fund ltd',
#   'bernstein global opportunities hedge fund lp'),
#  ('blue chip investor fund', 'blue chip special investment fund llc'),
#  ('aquinox pharmaceuticals inc', 'avanir pharmaceuticals inc'),
#  ('agic equity & convertible income fund',
#   'allianzgi global equity & convertible income fund'),
#  ('bocage active commodity long fund l p',
#   'bocage active commodity offshore fund'),
#  ('alliancebernstein americas government income trust inc',
#   'american century government income trust'),
#  ('advisors disciplined trust 437', 'advisors disciplined trust 65'),
#  ('ariel capital management inc et al', 'ariel capital management llc'),
#  ('american colonial corporation', 'canyon bancorportion'),
#  ('blue rose capital advisors llc', 'c m capital advisors llc'),
#  ('access investments inc bd', 'accesstel inc'),
#  ('advisory research international value fund l p',
#   'advisory research opportunities fund l p'),
#  ('advisors disciplined trust series 69',
#   'advisors discliplined trust series 20'),
#  ('bion pharmaceuticals inc', 'canyon pharmaceutical inc'),
#  ('alliance securities corp', 'banca imi securities corp bd'),
#  ('athene asset management llc', 'bluebay asset management ltd'),
#  ('advisors disciplined trust 1197', 'advisors disciplined trust 55'),
#  ('american capital corp', 'banc one capital corp'),
#  ('blackstone fifth avenue fund lp',
#   'blackstone fifth avenue offshore fund ltd class a d f k & l shares'),
#  ('ambac securities inc', 'bates securities inc bd'),
#  ('alpha equity asset allocation offshore fund ltd',
#   'aqr global asset allocation offshore fund usd ii ltd'),
#  ('benchmark financial services inc', 'calamos financial services inc'),
#  ('7advisors disciplined trust 1197', 'advisors disciplined trust 73'),
#  ('babson capital securities inc', 'capital market securities inc'),
#  ('cabo drilling corp fi', 'cabo mining enterprises corp fi'),
#  ('advisors disciplined trust 55', 'advisors disciplined trust 76'),
#  ('aetos capital market neutral strategies fund llc',
#   'archstone market neutral strategies fund ltd'),
#  ('barclay investments inc bd', 'benchmark investments inc bd'),
#  ('all vest securities inc bd', 'aton securities inc'),
#  ('avista capital partners ii lp', 'avista capital partners offshore ii l p'),
#  ('blackrock credit allocation income trust i inc',
#   'blackrock global enhanced equity income trust'),
#  ('beese fulmer investment management inc',
#   'bridgewater investment management llc'),
#  ('acn securities inc bd', 'aei securities inc bd'),
#  ('access securities llc', 'ambac securities inc'),
#  ('afm investments inc bd', 'alles investments inc bd'),
#  ('blackrock global enhanced equity income trust',
#   'blackrock s&p quality rankings global equity managed trust'),
#  ('acer investment group llc', 'blackthorn investment group llc'),
#  ('altimeter capital management lp', 'bimini capital management inc'),
#  ('blackstone fifth avenue fund l p',
#   'blackstone fifth avenue offshore fund ltd class a d f k & l shares'),
#  ('a p securities inc', 'bdc securities inc'),
#  ('brown and brown securities inc', 'brown bob'),
#  ('advantage advisers global growth ltd', 'alger global growth fund'),
#  ('allen global securities llc bd', 'bdc securities llc'),
#  ('barings securities llc', 'brill securities inc'),
#  ('allen & co inc bd', 'bacher & co inc bd'),
#  ('agricapital securities inc bd', 'cadre securities inc bd'),
#  ('aston asset management lp', 'calvert asset management co inc md'),
#  ('aim counselor series funds inc', 'aim investment securities funds inc'),
#  ('advanced thermal technologies inc', 'breed technologies inc'),
#  ('alexander international inc', 'altair international inc fi'),
#  ('allos therapeutics inc', 'bellerophon therapeutics inc'),
#  ('blackrock california insured municipal income trust',
#   'blackrock insured municipal income investment trust'),
#  ('aton securities inc', 'avian securities inc'),
#  ('altegris qim futures fund l p', 'altegris winton futures fund l p'),
#  ('aew capital management l p', 'alara capital avi management llc'),
#  ('abdiel capital advisors llc', 'anchor capital advisors llc'),
#  ('alex brown investment management l p', 'bpu investment management inc'),
#  ('bonde john h', 'calonico john'),
#  ('alliance international fund', 'bid com international inc'),
#  ('a p securities inc', 'aletheia securities inc'),
#  ('acacia ii partners l p', 'arsenal venture partners ii l p'),
#  ('blackrock muniholdings california quality fund inc',
#   'blackrock muniholdings investment quality fund'),
#  ('calvert investment management inc', 'cambria investment management l p'),
#  ('acm emerging markets multi strategy fund i lp',
#   'aris multi strategy fund lp'),
#  ('agf securities inc', 'aton securities inc'),
#  ('blackrock muniyield florida insured fund',
#   'blackrock muniyield new york insured fund inc'),
#  ('abi capital management llc bd', 'burch capital management inc'),
#  ('advisors disciplined trust series 55',
#   'advisors disciplined trust series 66'),
#  ('advisor disciplined trust 902', 'advisors disciplined trust 942'),
#  ('access financial group inc', 'belmont financial group inc'),
#  ('altegris equity long short fund l p',
#   'campbell long short equity investment fund ltd'),
#  ('advisors disciplined trust 61', 'advisors disciplined trust series 68'),
#  ('american dental technologies inc', 'auto tool technologies inc'),
#  ('blackrock california municipal income trust iii',
#   'blackrock muniyield california quality fund inc'),
#  ('bengal partners llc', 'berens capital partners lp'),
#  ('adamas partners l p', 'aew partners l p'),
#  ('ascend fund lp', 'ascend offshore fund ltd'),
#  ('capital one auto finance trust 2001 b',
#   'capital one auto finance trust 2002 c'),
#  ('advisors disciplined trsut 683', 'advisors disciplined trust 69'),
#  ('advisors disciplined trust 437', 'advisors disciplined trust series 46'),
#  ('aglialord john', 'cagle john m iii'),
#  ('a c t holdings inc', 'abx holdings inc'),
#  ('archview credit opportunities offshore fund ltd',
#   'bogle offshore opportunity fund ii sri ltd'),
#  ('brokerageamerica llc bd', 'capital research brokerage services llc bd'),
#  ('associated financial services inc', 'calypso financial services inc'),
#  ('ariel capital management inc', 'brown capital management llc'),
#  ('alliance fund inc', 'alliance international fund inc'),
#  ('capital world bond fund inc', 'capital world growth & income fund'),
#  ('alliancebernstein focused growth & income fund inc',
#   'alliancebernstein international premier growth fund inc'),
#  ('ani pharmaceuticals inc', 'avanir pharmaceuticals inc'),
#  ('atlas capital services llc', 'baystate capital services inc bd'),
#  ('cabot wealth management inc',
#   'canaccord genuity wealth management usa inc'),
#  ('capital guardian emerging markets debt usd fund for tax exempt trusts',
#   'capital guardian u s core fixed income fund for tax exempt trusts'),
#  ('antero resources corp', 'atlatsa resources corp'),
#  ('a p securities inc', 'aca securities l l c'),
#  ('alliance municipal income fund inc',
#   'alliancebernstein national municipal income fund'),
#  ('advisors disciplined trust 716', 'advisors disciplined trust series 71'),
#  ('access securities inc', 'all vest securities inc bd'),
#  ('bloombergsen investment partners', 'brandes investment partners lp'),
#  ('advisors disciplined trust 1279', 'advisors disciplined trust 64'),
#  ('advisors discplined trust 136', 'advisors discplined trust 138'),
#  ('atlas securities inc', 'aton securities inc bd'),
#  ('bhp billiton plc', 'bhp ltd'),
#  ('blackrock municipal income quality trust',
#   'blackrock muniyield michigan quality fund ii inc'),
#  ('advanced communications technologies inc', 'breed technologies inc'),
#  ('anvil international lp', 'biovail corporation international'),
#  ('berlind securities inc bd', 'c p baker securities inc bd'),
#  ('bolton financial services llc bd', 'brock financial services llc'),
#  ('aig multi strategy fund of funds llc',
#   'air multi strategy fund of funds spc class h aig volatility arbitrage portfolio'),
#  ('american pharmaceutical partners inc ca', 'canyon pharmaceutical inc'),
#  ('adar investment management llc', 'bt investment management re ltd'),
#  ('akros securities inc', 'brill securities inc'),
#  ('a c t holdings inc', 'adf holdings llc'),
#  ('brinker capital securities inc', 'capital innovations securities llc'),
#  ('access financial group inc', 'american patriot financial group inc'),
#  ('basswood capital management llc', 'brookside capital management llc'),
#  ('american century municipal trust', 'american municipal securities inc bd'),
#  ('ashton young financial services inc bd',
#   'bolton financial services llc bd'),
#  ('avenue capital management ii l p', 'capital management partners inc bd'),
#  ('blackrock municipal income investment trust',
#   'blackrock new york municipal income quality trust'),
#  ('aberon capital fund ii l p', 'aci capital america fund lp'),
#  ('ameridrives international llc', 'arris international plc'),
#  ('alpine partners l p', 'artorius partners ii l p'),
#  ('barclays private bank & trust ltd', 'barclays trust co cayman ltd'),
#  ('allos therapeutics', 'artielle immuno therapeutics inc'),
#  ('all energy corp', 'allegheny energy service corp'),
#  ('advisors disciplined trust 437', 'advisors disciplined trust 53'),
#  ('blackstone fifth avenue offshore fund ltd class a d f k & l shares',
#   'blackstone sixth avenue offshore fund ltd class a b c & k shares'),
#  ('american national municipal corporation', 'cannamed corporation'),
#  ('blackrock build america bond trust', 'blackrock municipal series trust'),
#  ('bridgeway capital management inc', 'brown capital management llc'),
#  ('alternative investments l p', 'american alternative investments llc'),
#  ('acn securities inc bd', 'atlas securities inc bd'),
#  ('aletheia securities inc bd', 'alternet securities inc bd'),
#  ('advantage advisers catalyst partners l p',
#   'advantage advisers technology partners l l c'),
#  ('advisors disciplined trust 52', 'advisors disciplined trust 942'),
#  ('alliancebernstein global small cap fund inc',
#   'alliancebernstein small cap growth fund inc'),
#  ('ark investments bd', 'benchmark investments inc'),
#  ('babson capital securities inc', 'capital securities investment corp'),
#  ('ameritas investment corp bd', 'ameritas investment partners inc'),
#  ('borden chemicals & plastics limited partnership',
#   'boston millenia partners iv limited partnership'),
#  ('afton capital management llc', 'avenue capital management ii llc'),
#  ('campbell managed futures onshore fund lp',
#   'candence managed futures fund llc'),
#  ('blackrock fixed income value opportunities',
#   'blackstone relative value fund fixed income lp'),
#  ('avanti securities corp bd', 'aviva securities llc'),
#  ('artal international sca', 'axp international series inc'),
#  ('aqr us long short equity fund lp', 'broadmark long short equity fund l p'),
#  ('bluecrest capital management llp', 'brown capital management llc'),
#  ('brown and brown securities inc', 'brown group inc'),
#  ('alcan securities corp bd', 'boston investment securities corp bd'),
#  ('allied asset management inc', 'athene asset management l p'),
#  ('baring asset management inc ma', 'bluebay asset management llp'),
#  ('bates securities inc bd', 'brill securities inc bd'),
#  ('axys pharmaceuticals inc', 'biosante pharmaceuticals inc'),
#  ('american eastern securities inc bd',
#   'american municipal securities inc bd'),
# ...
#  ('american commerce solutions inc', 'biometric solutions llc'),
#  ('blackstone firestone transaction participation cayman l p',
#   'blackstone participation partnership cayman v nq l p'),
#  ('actimis pharmaceutical inc', 'canyon pharmaceuticals inc'),
#  ('actinver securities inc bd', 'all vest securities inc'),
#  ('ascribe opportunities fund ii lp', 'ascribe opportunities fund iii b l p'),
#  ('advisors disciplined trust 551', 'advisors disciplined trust series 56'),
#  ('airband communications inc', 'atx communications inc'),
#  ('advisors disciplined trust 60', 'advisors disciplined trust 61'),
#  ('babson capital corporate investors',
#   'babson capital participation investors'),
#  ('aton securities inc', 'cape securities inc bd'),
#  ('alliant holdings i llc', 'bli holdings corp'),
#  ('american fidelity financial services inc',
#   'ameriprise financial services inc'),
#  ('allen & co inc bd', 'burch & co inc bd'),
#  ('american core realty fund l p', 'american realty trust inc'),
#  ('acacia partners l p', 'axel partners l p'),
#  ('a & m securities llc', 'burrill securities llc'),
#  ('american securities bd co lp',
#   'american securities opportunities fund ii b lp'),
#  ('access securities inc bd', 'belfinance securities inc bd'),
#  ('astralis pharmaceuticals ltd', 'biosante pharmaceuticals inc'),
#  ('ariel distributors llc', 'calvert distributors inc'),
#  ('aca securities llc bd', 'acci securities inc bd'),
#  ('blackrock mid cap value opportunities series inc',
#   'blackrock strategic income opportunities trust'),
#  ('ameritas investment corp bd', 'capital securities investment corp'),
#  ('a ch securities inc bd', 'atlas securities inc bd'),
#  ('advisors disciplined trust 63', 'advisors disciplined trust series 65'),
#  ('american pharmaceutical partners inc de', 'bactolac pharmaceutical inc'),
#  ('advisors disciplined trust 48', 'advisors disciplined trust series 68'),
#  ('advanced orthopedic technologies inc', 'breed technologies inc'),
#  ('alliancebernstein bond fund inc',
#   'alliancebernstein municipal income fund inc'),
#  ('blackrock florida municipal bond trust',
#   'blackrock municipal target term trust'),
#  ('capital market securities inc bd', 'capitol securities management inc bd'),
#  ('advisors disciplined trust 63', 'advisors disciplined trust 76'),
#  ('bowman capital management l l c', 'brown capital management llc'),
#  ('amag pharmaceuticals inc', 'barr pharmaceuticals inc'),
#  ('aew partners ii lp', 'alpine partners l p'),
#  ('ascend offshore fund ltd', 'bogle offshore opportunity fund ltd'),
#  ('allianz asset management of america l p', 'asset management fund'),
#  ('blackrock florida municipal income trust iii',
#   'blackrock muniyield florida fund'),
#  ('bolton financial services llc bd', 'callahan financial services inc'),
#  ('advisors disciplined trust 1197', 'advisors disciplined trust 57'),
#  ('akros securities inc bd', 'berlind securities inc bd'),
#  ('bender john f', 'broderick john p'),
#  ('allis chalmers production services inc',
#   'allis chalmers tubular services llc'),
#  ('berkeley capital management', 'beta capital management l p'),
#  ('calamos financial services inc', 'callaway financial services inc bd'),
#  ('blackrock insured municipal income investment trust',
#   'blackrock muniholdings insured investment fund'),
#  ('albany securities llc bd', 'anchor bay securities llc bd'),
#  ('blackrock municipal 2022 term trust',
#   'blackrock new york insured municipal 2008 term trust inc'),
#  ('acadian global low volatility equity fund llc',
#   'amundi volatility world equities llc'),
#  ('blackrock multi sector income trust',
#   'blackrock municipal income quality trust'),
#  ('capital guardian emerging markets total opportunities fund for tax exempt trusts',
#   'capital guardian international non us equity fund for tax exe tr'),
#  ('allen test co inc & cut over test', 'allen test co name change test'),
#  ('capital health management group llc',
#   'capital management of the carolinas llc'),
#  ('american enterprise variable annuity account',
#   'ameritas variable separate account v'),
#  ('ariel distributors inc', 'calvert investment distributors inc'),
#  ('advisors disciplined trust 63', 'advisors disciplined trust series 61'),
#  ('alerus securities bd', 'avanti securities corp bd'),
#  ('area real estate opportunity fund vi lp', 'bogle opportunity fund i l p'),
#  ('advisors disciplined trust 140', 'advisors disciplined trust 61'),
#  ('abn amro asset management usa inc', 'baring asset management inc ma'),
#  ('alles investments inc bd', 'arrow investments inc bd'),
#  ('asset management fund inc', 'bnp paribas asset management'),
#  ('alternative investments lp', 'ark investments'),
#  ('arrowmark global opportunity fund ii lp', 'bogle opportunity fund ii l p'),
#  ('blackrock credit allocation income trust ii inc',
#   'blackrock senior income trust'),
#  ('american pharmaceutical partners inc de', 'biosante pharmaceuticals inc'),
#  ('alliancebernstein international growth fund inc',
#   'alliancebernstein investments inc'),
#  ('american access technologies inc', 'aviation technologies inc'),
#  ('capital management of the carolinas llc bd',
#   'capitol securities management inc bd'),
#  ('balanced financial securities corp bd',
#   'callahan financial services inc bd'),
#  ('capital auto receivables inc',
#   'capital one prime auto receivables trust 2003 2'),
#  ('brahman institutional partners lp', 'brahman partners ii l p'),
#  ('alfa international corp', 'cal bay international inc'),
#  ('alliancebernstein global bond fund inc',
#   'alliancebernstein investments inc'),
#  ('aladdin capital llc bd', 'am capital llc bd'),
#  ('advisors disciplind trust 641', 'advisors disciplined trust series 68'),
#  ('advisors disciplined trust series 53',
#   'advisors disciplined trust series 56'),
#  ('blackburn & company inc', 'burch & company inc'),
#  ('advisors disciplined trust 73', 'advisors disciplined trust series 70'),
#  ('american income fund i d ltd partnership', 'ascend partners fund i ltd'),
#  ('alliancebernstein growth & income fund inc',
#   'alliancebernstein municipal income fund ii'),
#  ('ba mortgage securities inc', 'bates securities inc'),
#  ('advisors disciplined trust 49', 'advisors disciplined trust series 19'),
#  ('avenue capital management ii llc', 'beta capital management lp'),
#  ('blackrock florida investment quality municipal trust',
#   'blackrock municipal income quality trust'),
#  ('acci securities inc bd', 'aei securities inc bd'),
#  ('caldwell securities incorporated',
#   'capital securities investment corporation'),
#  ('advisors disciplined trust 72', 'advisors disciplined trust series 75'),
#  ('arka securities inc bd', 'austin securities inc bd'),
#  ('adp broker dealer inc bd', 'broker dealer inc'),
#  ('alliancebernstein americas government income trust inc',
#   'alliancebernstein municipal trust'),
#  ('artio global investment funds', 'barings global investment funds 2 plc'),
#  ('boll andrew r', 'burton andrew c'),
#  ('agilis biotherapeutics inc', 'allos therapeutics inc'),
#  ('adama technologies corp', 'angstrom technologies corp'),
#  ('aegis investments inc', 'altegris investments inc'),
#  ('beard financial services inc bd', 'callaway financial services inc bd'),
#  ('advisory research international value fund l p',
#   'advisory research value equity fund lp'),
#  ('anchor bay securities llc', 'bates securities inc'),
#  ('alliance municipal income fund inc ny',
#   'alliancebernstein national municipal income fund'),
#  ('ab core opportunities fund inc',
#   'berens distressed opportunities fund ltd'),
#  ('blackrock credit allocation income trust iv', 'blackrock master trust'),
#  ('abn amro asset management usa inc', 'asset management fund'),
#  ('aston asset management llc', 'ault glazer asset management llc'),
#  ('apollo management lp', 'avi management llc'),
#  ('brown capital management inc', 'burch capital management inc'),
#  ('artisan therapeutics inc', 'bellerophon therapeutics llc'),
#  ('access financial group inc bd', 'apb financial group inc'),
#  ('a c t holdings inc', 'amh holdings inc'),
#  ('advisors disciplined trust 64', 'advisors disciplined trust 69'),
#  ('agora securities corp', 'avanti securities corporation'),
#  ('access securities inc bd', 'ambac securities inc'),
#  ('ark investments', 'capital investments inc'),
#  ('alliance capital management lp', 'augusta capital management lp bd'),
#  ('asset allocation securities corp',
#   'capital securities investment corporation'),
#  ('alliance capital management lp', 'brown capital management llc'),
#  ('brandon i inc', 'brandon investments inc bd'),
#  ('alliance bond fund inc', 'alliancebernstein income fund inc'),
#  ('amici associates l p', 'associated financial services inc'),
#  ('bancorp hawaii inc', 'cadinha & co inc hawaii'),
#  ('ascent acquisition corp', 'berry plastics acquisition corp x'),
#  ('babson capital securities inc', 'boston capital securities inc'),
#  ('brasbares jeffrey r', 'butler jeffrey e sr'),
#  ('asset alliance investment services inc',
#   'banc of america investment services inc'),
#  ('barclays global fund advisors',
#   'barclays global investors fund distribution company'),
#  ('basso capital management l p', 'basswood capital management llc'),
#  ('actimis pharmaceutical inc', 'biomimetic pharmaceuticals inc'),
#  ('adams respiratory therapeutics inc', 'aviragen therapeutics inc'),
#  ('am capital llc bd', 'arlen capital llc'),
#  ('amundi investment solutions advisers llc',
#   'amundi investment solutions americas inc'),
#  ('alliancebernstein disciplined growth fund inc',
#   'alliancebernstein small cap growth fund inc'),
#  ('advisors disciplined trust 76', 'advisors disciplined trust series 66'),
#  ('amarantus bioscience inc', 'anaptys biosciences inc'),
#  ('blue capital group llc', 'capital planning group llc'),
#  ('augusta capital management lp bd', 'burch capital management inc bd'),
#  ('actinver securities inc bd', 'ambac securities inc'),
#  ('canyon balanced equity fund cayman ltd',
#   'canyon opportunistic credit grf fund cayman ltd'),
#  ('adar investment management llc', 'artis capital management llc'),
#  ('alliancebernstein real estate investment fund inc',
#   'alliancebernstein unconstrained bond fund inc'),
#  ('alliance international premier growth fund inc',
#   'alliancebernstein premier growth fund inc'),
#  ('advisors disciplined trsut 683', 'advisors disciplined trust 53'),
#  ('access securities inc bd', 'cape securities inc bd'),
#  ('belfinance securities inc bd', 'benefit finance securities llc'),
#  ('alexander international inc', 'alliance international fund inc'),
#  ('bluebay asset management ltd', 'bluecrest capital management ltd'),
#  ('agora securities corp', 'ancora securities inc bd'),
#  ('alger global growth fund',
#   'alliancebernstein global growth trends fund inc'),
#  ('adventrx pharmaceuticals inc', 'avanir pharmaceuticals'),
#  ('amc entertainment inc et al', 'american artists entertainment corp'),
#  ('acap global fund', 'alloy global fund l p'),
#  ('alcan securities corp', 'american securities china lp'),
#  ('alliance capital management holding lp', 'cadian capital management llc'),
#  ('bank of new york mellon ta', 'bank of new york mellon trust company n a'),
#  ('adage capital partners gp llc', 'artigent capital partners lp'),
#  ('actinver securities inc bd', 'bates securities inc'),
#  ('american heritage securities inc bd', 'brill securities inc'),
#  ('apollo capital group inc', 'capital hill group inc'),
#  ('arden realty limited partnership', 'artisan partners ltd partnership'),
#  ('blackrock capital investment corp',
#   'blackrock capital structure investments fund ltd'),
#  ('campbell & co lp de', 'campbell carlos'),
#  ('america first real estate investment co inc',
#   'behringer harvard real estate investment trust i inc'),
#  ('alternet securities inc bd', 'american eastern securities inc bd'),
#  ('anderson richard allen', 'berenson richard a'),
#  ('acadian asset management llc', 'ar asset managment inc'),
#  ('aig international securities inc bd',
#   'bbva bancomer securities international inc bd'),
#  ('bluebay asset management llp', 'bolton asset management llc'),
#  ('biomimetic pharmaceuticals inc', 'canyon pharmaceutical inc'),
#  ('alcan securities corp', 'ancora securities inc'),
#  ('aer energy resources inc', 'aurora energy resources inc'),
#  ('alliance global investor services inc ta',
#   'bessemer investor services inc'),
#  ('act capital america fund lp', 'america capital corp'),
#  ('blackrock technology fund inc', 'brascan technology fund'),
#  ('ab municipal income fund ii', 'bull & bear municipal income fund inc'),
#  ('alerus securities bd', 'apex securities inc bd'),
#  ('apm equity long short fund l p', 'aqr us long short equity fund lp'),
#  ('advisors disciplined trust 59', 'advisors disciplined trust 76'),
#  ('american dental technologies inc', 'aspen technology inc de'),
#  ('alliance fund inc', 'alliance municipal income fund ii'),
#  ('ascend offshore fund ltd', 'blackgold opportunities offshore fund ltd'),
#  ('across america real estate corp', 'american real estate income fund'),
#  ('advisors disciplind trust 641', 'advisors disciplined trust 683'),
#  ('advisors disciplined trust 1038', 'advisors disciplined trust 51'),
#  ('advisors disciplined trust series 64',
#   'advisors disciplined trust series 76'),
#  ('ab international growth fund inc', 'axp international fund inc'),
#  ('alliance international fund', 'american century international bond funds'),
#  ('amarantus biosciences inc', 'ambra bioscience llc'),
#  ('advanced communications technologies inc', 'advanced power technology inc'),
#  ('cancer prevention pharmaceuticals llc', 'cantata pharmaceuticals inc'),
#  ('alliancebernstein health care fund inc',
#   'alliancebernstein high income fund inc'),
#  ('acacia ii partners l p', 'acacia partners l p ny'),
#  ('berlind securities inc bd', 'camden securities inc bd'),
#  ('aegis investments inc', 'alles investments inc'),
#  ('benchmark capital management co llc', 'brown capital management llc'),
#  ('blackstone partners investment fund l p',
#   'brandes investment partners llc'),
#  ('agic convertible & income fund', 'agic convertible & income fund ii'),
#  ('amag pharmaceuticals inc', 'app pharmaceuticals inc'),
#  ('arguss communications inc', 'atx communications nc'),
#  ('acacia partners l p', 'aria partners ii lp'),
#  ('advisors disciplined trust series 57',
#   'advisors disciplined trust series 70'),
#  ('alliancebernstein institutional funds inc',
#   'alliancebernstein new europe fund inc'),
#  ('altimeter capital management lp', 'burch capital management inc'),
#  ('american heritage securities inc', 'american securities corp'),
#  ('bio florescent technologies inc', 'calient technologies inc'),
#  ('banc of america capital management llc',
#   'capital management of the carolinas llc bd'),
#  ('a & m securities llc bd', 'barings securities llc'),
#  ('cambridge international partners inc bd',
#   'cambridge international securities llc'),
#  ('achelios therapeutics', 'allos therapeutics'),
#  ('a ch securities inc bd', 'alcan securities corp bd'),
#  ('berkeley capital management', 'capital management partners inc'),
#  ('alcan securities corp bd', 'bates securities inc bd'),
#  ('atlantic securities inc', 'atlas securities llc'),
#  ('acr securities inc bd', 'berlind securities inc bd'),
#  ('ameritas investment corp', 'capital securities investment corp'),
#  ('allianz asset management of america l p',
#   'american capital asset management llc'),
#  ('alliancebernstein municipal income fund ii',
#   'alliancebernstein real estate investment fund inc'),
#  ('adamas partners l p', 'asante partners llc'),
#  ('advisors disciplined trust 134', 'advisors disciplined trust 50'),
#  ('access pharmaceuticals inc', 'american pharmaceutical partners inc ca'),
#  ('ares clo xi ltd', 'ares x clo ltd'),
#  ('acn securities inc bd', 'ancora securities inc bd'),
#  ('abdiel capital advisors lp', 'capital growth advisors llc bd'),
#  ('alliancebernstein institutional fund',
#   'alliancebernstein mid cap growth fund inc'),
#  ('artisan partners ltd partnership', 'capital partnerships'),
#  ('advisors disciplined trust 134', 'advisors discliplined trust series 19'),
#  ('astoria capital markets inc bd', 'capital market securities inc bd'),
#  ...}

# %%
pairwise_similarity_csr_matrix[string_pair_to_i_pair(('aikins mark r', 'atkins mark r'))]
# Out:
# 0.64621115
